# %%
# %load_ext autoreload
# %autoreload 2

import os
from pathlib import Path
import time
from typing import Tuple, Type

import haiku as hk
import jax
import jax.numpy as jnp
import jraph
import networkx as nx
import matplotlib.pyplot as plt
import numpy as np
import optax

# Numpyro
import numpyro
import numpyro.distributions as dist
from numpyro.infer import MCMC, NUTS, init_to_median, Predictive
from numpyro.diagnostics import hpdi

# Local imports
import loss
import dataset_1dgp
import plotting
import model

print(f"JAX version: {jax.__version__}")
print(f"Numpyro version: {numpyro.__version__}")
# Out:
# /Users/salmanfaris/miniforge3/envs/prior-vgae/lib/python3.9/site-packages/jax/_src/lib/__init__.py:34: UserWarning: JAX on Mac ARM machines is experimental and minimally tested. Please see https://github.com/google/jax/issues/5501 in the event of problems.
#   warnings.warn("JAX on Mac ARM machines is experimental and minimally tested. "
# JAX version: 0.3.13
# Numpyro version: 0.9.2

# %%
FIG_PATH = Path('./figures/1DGP_figures')
FIG_PATH.mkdir(exist_ok=True)

DATASET_PATH = Path('./dataset.nosync')
DATASET_PATH.mkdir(exist_ok=True)

# %%
RNG_SEED = 44
RNG_KEY = jax.random.PRNGKey(RNG_SEED)

# %% [markdown]
# # WANT TO TRY DROPOUT LAYER

# %%
from dataclasses import dataclass
from typing import Dict, Optional, Callable

LossFun = Callable[[jax.numpy.ndarray, jax.numpy.ndarray], jnp.float32]

@dataclass
class GP1DArgs:
  kernel: Callable = dataset_1dgp.exp_sq_kernel
  num_locations: int = 400
  
@dataclass
class Args:  
  # Training params
  loss_fn: LossFun = loss.compute_mse_loss
  epochs: int = 100_000
  eval_frequency: int = 1000
  learning_rate: float = 1e-3
  beta: float = 1e-2  # beta-VAE
  dropout_rate: float = 0.5
  training: bool = True
  
  # Model params
  hidden_gnn_dim: int = 2
  hidden_fc_dim: int = 60
  latent_dim: int = 30
  output_dim: int = 1
  act_fn: Callable = jax.nn.elu

GP1D_ARGS = GP1DArgs()
ARGS = Args()

# %%
model_name = (
    f'PriorVGAE_Dropout_1DGP_lr{ARGS.learning_rate}_epochs{ARGS.epochs}_'
    f'beta{ARGS.beta}_gnn{ARGS.hidden_gnn_dim}_fc{ARGS.hidden_fc_dim}_z{ARGS.latent_dim}_'
    f'numLocations{GP1D_ARGS.num_locations}'
)

model_params_title = (
    '('
    f'epochs = {plotting.convert_to_string_int(ARGS.epochs)}, '
    f'lr = {ARGS.learning_rate}, '
    f'act_fn = {jax.nn.elu.__name__}, '
    rf'$\beta = {ARGS.beta}$, '
    f'\ngnn_dim = {ARGS.hidden_gnn_dim},  fc_dim = {ARGS.hidden_fc_dim},  z_dim = {ARGS.latent_dim}'
    f'\n num_loc = {GP1D_ARGS.num_locations}'
    ')'
)

print(model_name)
# Out:
# PriorVGAE_1DGP_lr0.001_epochs2000000_beta0.01_gnn2_fc60_z30_numLocations400

# %% [markdown]
# # Dataset: GP priors to be encoded

# %%
# GP priors to encode
X = jnp.arange(0, 1, 1/GP1D_ARGS.num_locations)

num_to_plot = 10
gp_draws = dataset_1dgp.generate_gp_batch(RNG_KEY, 
                                          X, 
                                          batch_size=num_to_plot,
                                          kernel=GP1D_ARGS.kernel)

plotting.plot_gp_draws(
    X, gp_draws,
    num_draws_to_plot=num_to_plot,
    title='Example of GP priors to encode', 
    x_label='$x$', 
    y_label='$y=f_{GP}(x)$',
)

# %% [markdown]
# # Building the model

# %%
data_filepath = DATASET_PATH / f'1DGP_numLoc{GP1D_ARGS.num_locations}_1M_train_data.npy'

OVERRIDE_SAVE = False

# Initial RNG_KEY seed is 44.
RNG_KEY, data_rng = jax.random.split(RNG_KEY)
if data_filepath.exists() and not OVERRIDE_SAVE:
    print(f"Loading dataset from {data_filepath}")
    data = np.load(data_filepath)
else:
    num_samples = 1_000_000
    data = dataset_1dgp.generate_gp_batch(data_rng, X, 
                                          batch_size=num_samples, 
                                          kernel=GP1D_ARGS.kernel)
    print(f"Saving dataset to {data_filepath}")
    np.save(data_filepath, np.asarray(data))
# Out:
# Loading dataset from dataset.nosync/1DGP_numLoc400_1M_train_data.npy

# %%
# Remove NaNs from dataset
data = data[~np.isnan(data).any(axis=1), :]

train_size_limit = 700_000
val_size = 11_000  # + 1000 for the final epoch evaluation and batching

# train_data = data[:train_size_limit]
train_data = data[:]
val_data = data[train_size_limit:train_size_limit+val_size]

# %%
BASE_GRAPH = dataset_1dgp.create_1dgp_graph(GP1D_ARGS.num_locations)

graph_train_data = [BASE_GRAPH._replace(nodes=nodes.reshape(-1, 1)) for nodes in train_data]
graph_val_data = [BASE_GRAPH._replace(nodes=nodes.reshape(-1, 1)) for nodes in val_data]

# %% [markdown]
# Comment: Removing linear (hidden_fc) before latent hidden layer makes samples even NOISIER

# %%
from functools import partial
from model import VGAEOutput
import layer

class VGAE(hk.Module):
    """VGAE network definition."""

    def __init__(
        self,
        hidden_gnn_dim: int,
        hidden_fc_dim: int,
        latent_dim: int,
        output_dim: int,
        num_nodes: int,
        dropout_rate: float,
    ):
        super().__init__()
        self._hidden_gnn_dim = hidden_gnn_dim
        self._hidden_fc_dim = hidden_fc_dim
        self._latent_dim = latent_dim
        self._output_dim = output_dim
        self._num_nodes = num_nodes
        self._dropout_rate = dropout_rate
        self.act = ARGS.act_fn

    def __call__(self, graph: jraph.GraphsTuple) -> VGAEOutput:
        mean, log_std = encoder(
            graph,
            self._hidden_gnn_dim,
            self._hidden_fc_dim,
            self._latent_dim,
            self._num_nodes,
            self._dropout_rate,
            self.act,
        )

        std = jnp.exp(log_std)
        z = mean + std * jax.random.normal(hk.next_rng_key(), mean.shape)

        output = decoder(
            z,
            self._hidden_fc_dim,
            self._hidden_gnn_dim,
            self._output_dim,
            self._num_nodes,
            self._dropout_rate,
            self.act
        )

        return VGAEOutput(mean, log_std, output)


def encoder(
        graph: jraph.GraphsTuple,
        hidden_gnn_dim: int,
        hidden_fc_dim: int,
        latent_dim: int,
        num_nodes: int,
        dropout_rate: float,
        act_fn: Callable = jax.nn.elu) -> Tuple[jnp.ndarray, jnp.ndarray]:
    
    # Graph layer
    gn = jraph.GraphConvolution(
        update_node_fn=hk.Sequential([
            hk.Linear(hidden_gnn_dim), act_fn,
        ]),
        add_self_edges=True,
    )
    graph = gn(graph)

    graph = layer.GraphwiseLayerNorm()(graph)
    
    x = graph.nodes.reshape(1, num_nodes, hidden_gnn_dim)
    x = hk.Flatten()(x)  # dim: (1, num_nodes*hidden_gnn_dim)

    # I've added another hidden layer
    x = hk.Linear(hidden_fc_dim)(x)
    x = act_fn(x)
    
    if ARGS.training: x = hk.dropout(hk.next_rng_key(), dropout_rate)(x)
    
    x = hk.Linear(hidden_fc_dim)(x)
    x = act_fn(x)
    
    if ARGS.training: x = hk.dropout(hk.next_rng_key(), dropout_rate)(x)
    
    # No activation
    mean = hk.Linear(latent_dim, name='mean')(x)
    log_std = hk.Linear(latent_dim, name='log_std')(x)
    return mean, log_std


def decoder(
        z: jnp.ndarray,
        hidden_fc_dim: int,
        hidden_gnn_dim: int,
        output_dim: int,
        num_nodes: int,
        dropout_rate: float,
        act_fn: Callable = jax.nn.elu) -> jraph.GraphsTuple:
    
    z = hk.Linear(hidden_fc_dim, name='decoder_hidden_fc')(z)
    z = act_fn(z)
    
    if ARGS.training: x = hk.dropout(hk.next_rng_key(), dropout_rate)(x)
    
    z = hk.Linear(hidden_fc_dim, name='decoder_hidden_fc2')(z)
    z = act_fn(z)
    
    if ARGS.training: x = hk.dropout(hk.next_rng_key(), dropout_rate)(x)
    
    z = hk.Linear(num_nodes*hidden_gnn_dim,
                  name='decoder_hidden2_fc')(z)  # (1, num_nodes*hidden_gnn_dim)
    z = act_fn(z)
    
    # Reshape to jraph.batch format: (num_nodes, hidden_gnn_dim)
    z = z.reshape((num_nodes, hidden_gnn_dim))
    graph = BASE_GRAPH._replace(nodes=z)

    gn = layer.GraphConvolutionSharpening(
        update_node_fn=hk.Sequential([
            hk.Linear(hidden_gnn_dim, name='decoder_hidden_gnn'), act_fn,
        ]),
        add_self_edges=True,
    )
    graph = gn(graph)
    
    # # Layer normalization
    # NOTE :- Layer normalization on the decoder yields a shrinked GP.
    # graph = layer.GraphwiseLayerNorm()(graph)
    
    # No activation
    gn = layer.GraphConvolutionSharpening(
        update_node_fn=hk.Linear(output_dim, name='decoder_output'),
        add_self_edges=False,
    )
    graph = gn(graph)


    return graph

# %%
extend_model_params_title = True
    
extension_string = 'using_GAT = False, add_self_edges = True, dropout = True'

if extend_model_params_title:
    model_params_title = model_params_title[:-1] + ', ' + extension_string

# %% [markdown]
# # Training time

# %%
# Initialize network and optimizer.
net = hk.transform(
  lambda x: VGAE(hidden_gnn_dim=ARGS.hidden_gnn_dim,
                 hidden_fc_dim=ARGS.hidden_fc_dim,
                 latent_dim=ARGS.latent_dim, 
                 output_dim=ARGS.output_dim,
                 dropout_rate=ARGS.dropout_rate,
                 num_nodes=GP1D_ARGS.num_locations)(x))

# %% [markdown]
# ## Training optimizer

# %%
# optimizer = optax.adam(ARGS.learning_rate)

scheduler = optax.exponential_decay(
    init_value=ARGS.learning_rate,
    transition_steps=2000,
    decay_rate=0.99,
)

# Combining gradient transforms using `optax.chain`
optimizer = optax.chain(
    optax.clip_by_global_norm(1.0),  # Clip by the gradient by the global norm.
    optax.scale_by_adam(),  # Use the updates from adam.
    optax.scale_by_schedule(scheduler),  # Use the learning rate from the scheduler.
    # Scale updates by -1 since optax.apply_updates is additive and we want to descend on the loss.
    optax.scale(-1.0)
)

# %% [markdown]
# ### Loss function and update

# %%
@jax.jit
def loss_fn(
    params: hk.Params, 
    rng_key: jnp.ndarray,
    graph: jraph.GraphsTuple,
) -> jnp.ndarray:
  """Computes VGAE loss."""
  log_likelihood_loss_fn = ARGS.loss_fn
  
  outputs: VGAEOutput = net.apply(params, rng_key, graph)
  log_likelihood = -log_likelihood_loss_fn(outputs.output.nodes, graph.nodes)
  kld = jnp.mean(loss.compute_kl_gaussian(outputs.mean, outputs.log_std), axis=-1)
  elbo = (1.0/ARGS.beta)*log_likelihood - kld
  
  return -elbo, kld
  
@jax.jit
def update(
    params: hk.Params,
    rng_key: jnp.ndarray,
    opt_state: optax.OptState,
    graph: jraph.GraphsTuple,
):
  """Updates the parameters of the network."""
  grads, _ = jax.grad(loss_fn, has_aux=True)(params, rng_key, graph)
  updates, new_opt_state = optimizer.update(grads, opt_state)
  new_params = optax.apply_updates(params, updates)
  return new_params, new_opt_state

# %% [markdown]
# ### Initialize net and optimizer

# %%
# Initialize net with an arbitrary graph
RNG_KEY, params_rng = jax.random.split(RNG_KEY)

init_graph = graph_train_data[0]
params = net.init(params_rng, init_graph)
opt_state = optimizer.init(params)

# %%
RNG_KEY, train_rng = jax.random.split(RNG_KEY)

train_losses = []
val_losses = []
train_klds = []
val_klds = []

train_size = len(graph_train_data)
val_size = len(graph_val_data)

eval_counter: int = 0

training_start_time = time.time()
print('using: ', ARGS.loss_fn)
for epoch in range(ARGS.epochs):
  update_rng = jax.random.fold_in(train_rng, epoch)

  train_graph_batch = graph_train_data[epoch % train_size]
  params, opt_state = update(params, update_rng, opt_state, train_graph_batch)
    
  if epoch % ARGS.eval_frequency == 0 or epoch == (ARGS.epochs - 1):
    evaluate_rng = jax.random.fold_in(update_rng, epoch)
    train_loss_rng, eval_loss_rng = jax.random.split(evaluate_rng)
    
    train_loss, train_kld = loss_fn(params, train_loss_rng, train_graph_batch)
    
    val_graph_batch = graph_val_data[eval_counter]
    val_loss, val_kld = loss_fn(params, eval_loss_rng, val_graph_batch)
    
    print(f'{time.strftime("%H:%M:%S", time.localtime())} STEP: {epoch}; '
          f'Train loss: {train_loss:.3f}; Validation loss: {val_loss:.3f}; '
          # f'Train kld: {train_kld:.3f}; Validation kld: {val_kld:.3f}'
    )
      
    train_losses.append(train_loss.item())
    val_losses.append(val_loss.item())
    train_klds.append(train_kld.item())
    val_klds.append(val_kld.item())
    
    eval_counter += 1

training_end_time = time.time() - training_start_time
print(f'Training took: ({training_end_time:.3f} secs; equivalently {training_end_time/60:.3f} mins)')
# Out:
# using:  <function compute_mse_loss at 0x152f710d0>
# 21:38:38 STEP: 0; Train loss: 93.888; Validation loss: 170.666;
# 21:38:39 STEP: 1000; Train loss: 48.347; Validation loss: 17.130;
# 21:38:39 STEP: 2000; Train loss: 21.711; Validation loss: 69.372;
# 21:38:40 STEP: 3000; Train loss: 21.397; Validation loss: 18.541;
# 21:38:40 STEP: 4000; Train loss: 36.868; Validation loss: 30.913;
# 21:38:41 STEP: 5000; Train loss: 27.201; Validation loss: 100.169;
# 21:38:41 STEP: 6000; Train loss: 15.015; Validation loss: 83.704;
# 21:38:42 STEP: 7000; Train loss: 12.687; Validation loss: 77.305;
# 21:38:42 STEP: 8000; Train loss: 54.072; Validation loss: 76.795;
# 21:38:43 STEP: 9000; Train loss: 10.597; Validation loss: 13.509;
# 21:38:43 STEP: 10000; Train loss: 33.042; Validation loss: 26.142;
# 21:38:44 STEP: 11000; Train loss: 14.301; Validation loss: 15.601;
# 21:38:45 STEP: 12000; Train loss: 11.757; Validation loss: 28.899;
# 21:38:45 STEP: 13000; Train loss: 9.229; Validation loss: 16.899;
# 21:38:46 STEP: 14000; Train loss: 91.245; Validation loss: 28.851;
# 21:38:46 STEP: 15000; Train loss: 12.549; Validation loss: 12.768;
# 21:38:47 STEP: 16000; Train loss: 26.288; Validation loss: 18.646;
# 21:38:47 STEP: 17000; Train loss: 15.645; Validation loss: 23.178;
# 21:38:48 STEP: 18000; Train loss: 27.010; Validation loss: 27.861;
# 21:38:48 STEP: 19000; Train loss: 23.184; Validation loss: 11.809;
# 21:38:49 STEP: 20000; Train loss: 28.508; Validation loss: 35.881;
# 21:38:49 STEP: 21000; Train loss: 10.497; Validation loss: 18.103;
# 21:38:50 STEP: 22000; Train loss: 13.562; Validation loss: 15.044;
# 21:38:50 STEP: 23000; Train loss: 86.740; Validation loss: 13.352;
# 21:38:51 STEP: 24000; Train loss: 34.362; Validation loss: 33.308;
# 21:38:51 STEP: 25000; Train loss: 147.673; Validation loss: 33.546;
# 21:38:52 STEP: 26000; Train loss: 12.660; Validation loss: 14.430;
# 21:38:52 STEP: 27000; Train loss: 14.648; Validation loss: 34.555;
# 21:38:53 STEP: 28000; Train loss: 81.138; Validation loss: 18.303;
# 21:38:53 STEP: 29000; Train loss: 12.498; Validation loss: 21.759;
# 21:38:54 STEP: 30000; Train loss: 28.640; Validation loss: 8.321;
# 21:38:54 STEP: 31000; Train loss: 13.623; Validation loss: 29.882;
# 21:38:55 STEP: 32000; Train loss: 24.347; Validation loss: 21.386;
# 21:38:56 STEP: 33000; Train loss: 7.562; Validation loss: 45.217;
# 21:38:56 STEP: 34000; Train loss: 26.131; Validation loss: 16.462;
# 21:38:57 STEP: 35000; Train loss: 15.709; Validation loss: 79.689;
# 21:38:57 STEP: 36000; Train loss: 11.706; Validation loss: 14.189;
# 21:38:58 STEP: 37000; Train loss: 59.951; Validation loss: 34.761;
# 21:38:58 STEP: 38000; Train loss: 26.573; Validation loss: 7.502;
# 21:38:59 STEP: 39000; Train loss: 29.117; Validation loss: 18.917;
# 21:38:59 STEP: 40000; Train loss: 20.229; Validation loss: 22.605;
# 21:39:00 STEP: 41000; Train loss: 12.909; Validation loss: 47.892;
# 21:39:00 STEP: 42000; Train loss: 22.653; Validation loss: 8.922;
# 21:39:01 STEP: 43000; Train loss: 8.102; Validation loss: 21.037;
# 21:39:01 STEP: 44000; Train loss: 7.525; Validation loss: 27.599;
# 21:39:02 STEP: 45000; Train loss: 16.699; Validation loss: 115.012;
# 21:39:03 STEP: 46000; Train loss: 10.776; Validation loss: 21.743;
# 21:39:03 STEP: 47000; Train loss: 14.978; Validation loss: 14.060;
# 21:39:04 STEP: 48000; Train loss: 13.812; Validation loss: 6.811;
# 21:39:04 STEP: 49000; Train loss: 67.388; Validation loss: 17.223;
# 21:39:05 STEP: 50000; Train loss: 8.842; Validation loss: 15.988;
# 21:39:05 STEP: 51000; Train loss: 9.139; Validation loss: 11.947;
# 21:39:06 STEP: 52000; Train loss: 4.769; Validation loss: 5.738;
# 21:39:06 STEP: 53000; Train loss: 12.321; Validation loss: 60.283;
# 21:39:07 STEP: 54000; Train loss: 8.494; Validation loss: 9.670;
# 21:39:07 STEP: 55000; Train loss: 11.601; Validation loss: 15.991;
# 21:39:08 STEP: 56000; Train loss: 8.868; Validation loss: 17.539;
# 21:39:08 STEP: 57000; Train loss: 37.504; Validation loss: 18.558;
# 21:39:09 STEP: 58000; Train loss: 7.070; Validation loss: 14.786;
# 21:39:09 STEP: 59000; Train loss: 8.272; Validation loss: 12.870;
# 21:39:10 STEP: 60000; Train loss: 26.310; Validation loss: 10.962;
# 21:39:10 STEP: 61000; Train loss: 8.186; Validation loss: 21.334;
# 21:39:11 STEP: 62000; Train loss: 13.950; Validation loss: 27.962;
# 21:39:11 STEP: 63000; Train loss: 8.753; Validation loss: 21.278;
# 21:39:12 STEP: 64000; Train loss: 9.583; Validation loss: 11.609;
# 21:39:13 STEP: 65000; Train loss: 27.598; Validation loss: 9.058;
# 21:39:13 STEP: 66000; Train loss: 7.493; Validation loss: 10.802;
# 21:39:14 STEP: 67000; Train loss: 19.028; Validation loss: 7.161;
# 21:39:14 STEP: 68000; Train loss: 18.210; Validation loss: 8.602;
# 21:39:15 STEP: 69000; Train loss: 9.178; Validation loss: 11.618;
# 21:39:15 STEP: 70000; Train loss: 15.604; Validation loss: 14.194;
# 21:39:16 STEP: 71000; Train loss: 11.985; Validation loss: 32.098;
# 21:39:16 STEP: 72000; Train loss: 15.593; Validation loss: 28.146;
# 21:39:17 STEP: 73000; Train loss: 9.797; Validation loss: 12.271;
# 21:39:17 STEP: 74000; Train loss: 33.493; Validation loss: 10.861;
# 21:39:18 STEP: 75000; Train loss: 22.555; Validation loss: 24.847;
# 21:39:19 STEP: 76000; Train loss: 7.442; Validation loss: 20.448;
# 21:39:19 STEP: 77000; Train loss: 12.538; Validation loss: 7.741;
# 21:39:20 STEP: 78000; Train loss: 20.507; Validation loss: 6.829;
# 21:39:20 STEP: 79000; Train loss: 11.967; Validation loss: 13.180;
# 21:39:21 STEP: 80000; Train loss: 9.856; Validation loss: 7.365;
# 21:39:21 STEP: 81000; Train loss: 35.166; Validation loss: 12.829;
# 21:39:22 STEP: 82000; Train loss: 31.215; Validation loss: 22.234;
# 21:39:22 STEP: 83000; Train loss: 7.400; Validation loss: 24.493;
# 21:39:23 STEP: 84000; Train loss: 8.756; Validation loss: 8.775;
# 21:39:23 STEP: 85000; Train loss: 21.747; Validation loss: 18.335;
# 21:39:24 STEP: 86000; Train loss: 10.438; Validation loss: 8.744;
# 21:39:24 STEP: 87000; Train loss: 27.307; Validation loss: 21.438;
# 21:39:25 STEP: 88000; Train loss: 21.248; Validation loss: 14.742;
# 21:39:25 STEP: 89000; Train loss: 26.902; Validation loss: 15.945;
# 21:39:26 STEP: 90000; Train loss: 57.554; Validation loss: 21.206;
# 21:39:26 STEP: 91000; Train loss: 9.864; Validation loss: 13.367;
# 21:39:27 STEP: 92000; Train loss: 18.602; Validation loss: 19.016;
# 21:39:27 STEP: 93000; Train loss: 13.616; Validation loss: 10.144;
# 21:39:28 STEP: 94000; Train loss: 10.984; Validation loss: 6.148;
# 21:39:28 STEP: 95000; Train loss: 12.505; Validation loss: 13.227;
# 21:39:29 STEP: 96000; Train loss: 20.459; Validation loss: 33.803;
# 21:39:30 STEP: 97000; Train loss: 8.354; Validation loss: 7.901;
# 21:39:30 STEP: 98000; Train loss: 14.836; Validation loss: 10.497;
# 21:39:31 STEP: 99000; Train loss: 15.879; Validation loss: 7.997;
# 21:39:31 STEP: 100000; Train loss: 25.366; Validation loss: 6.919;
# 21:39:32 STEP: 101000; Train loss: 8.292; Validation loss: 12.093;
# 21:39:32 STEP: 102000; Train loss: 19.942; Validation loss: 12.429;
# 21:39:33 STEP: 103000; Train loss: 6.057; Validation loss: 12.032;
# 21:39:33 STEP: 104000; Train loss: 21.338; Validation loss: 10.052;
# 21:39:34 STEP: 105000; Train loss: 21.620; Validation loss: 11.313;
# 21:39:34 STEP: 106000; Train loss: 5.670; Validation loss: 21.456;
# 21:39:35 STEP: 107000; Train loss: 123.325; Validation loss: 26.867;
# 21:39:35 STEP: 108000; Train loss: 10.415; Validation loss: 9.000;
# 21:39:36 STEP: 109000; Train loss: 7.581; Validation loss: 9.082;
# 21:39:37 STEP: 110000; Train loss: 14.046; Validation loss: 22.026;
# 21:39:37 STEP: 111000; Train loss: 41.017; Validation loss: 21.011;
# 21:39:38 STEP: 112000; Train loss: 34.815; Validation loss: 9.720;
# 21:39:38 STEP: 113000; Train loss: 17.410; Validation loss: 33.323;
# 21:39:39 STEP: 114000; Train loss: 25.103; Validation loss: 13.252;
# 21:39:39 STEP: 115000; Train loss: 5.164; Validation loss: 17.222;
# 21:39:40 STEP: 116000; Train loss: 23.740; Validation loss: 13.449;
# 21:39:40 STEP: 117000; Train loss: 9.925; Validation loss: 18.229;
# 21:39:41 STEP: 118000; Train loss: 31.024; Validation loss: 13.044;
# 21:39:41 STEP: 119000; Train loss: 25.268; Validation loss: 9.181;
# 21:39:42 STEP: 120000; Train loss: 10.358; Validation loss: 11.460;
# 21:39:42 STEP: 121000; Train loss: 19.166; Validation loss: 27.309;
# 21:39:43 STEP: 122000; Train loss: 10.440; Validation loss: 8.015;
# 21:39:44 STEP: 123000; Train loss: 5.721; Validation loss: 13.559;
# 21:39:44 STEP: 124000; Train loss: 23.143; Validation loss: 9.513;
# 21:39:45 STEP: 125000; Train loss: 6.496; Validation loss: 9.648;
# 21:39:45 STEP: 126000; Train loss: 11.022; Validation loss: 10.838;
# 21:39:46 STEP: 127000; Train loss: 10.553; Validation loss: 11.037;
# 21:39:46 STEP: 128000; Train loss: 22.850; Validation loss: 14.726;
# 21:39:47 STEP: 129000; Train loss: 7.611; Validation loss: 11.860;
# 21:39:47 STEP: 130000; Train loss: 15.853; Validation loss: 14.616;
# 21:39:48 STEP: 131000; Train loss: 7.960; Validation loss: 11.985;
# 21:39:48 STEP: 132000; Train loss: 6.268; Validation loss: 7.826;
# 21:39:49 STEP: 133000; Train loss: 13.430; Validation loss: 11.424;
# 21:39:49 STEP: 134000; Train loss: 19.706; Validation loss: 6.867;
# 21:39:50 STEP: 135000; Train loss: 5.360; Validation loss: 44.598;
# 21:39:51 STEP: 136000; Train loss: 21.063; Validation loss: 11.993;
# 21:39:51 STEP: 137000; Train loss: 11.681; Validation loss: 18.629;
# 21:39:52 STEP: 138000; Train loss: 13.963; Validation loss: 10.863;
# 21:39:52 STEP: 139000; Train loss: 12.789; Validation loss: 17.304;
# 21:39:53 STEP: 140000; Train loss: 29.664; Validation loss: 5.545;
# 21:39:53 STEP: 141000; Train loss: 12.963; Validation loss: 7.475;
# 21:39:54 STEP: 142000; Train loss: 9.988; Validation loss: 20.127;
# 21:39:54 STEP: 143000; Train loss: 14.504; Validation loss: 8.281;
# 21:39:55 STEP: 144000; Train loss: 13.493; Validation loss: 23.197;
# 21:39:55 STEP: 145000; Train loss: 6.243; Validation loss: 14.565;
# 21:39:56 STEP: 146000; Train loss: 11.752; Validation loss: 9.241;
# 21:39:56 STEP: 147000; Train loss: 8.138; Validation loss: 18.738;
# 21:39:57 STEP: 148000; Train loss: 10.581; Validation loss: 19.566;
# 21:39:57 STEP: 149000; Train loss: 7.449; Validation loss: 12.415;
# 21:39:58 STEP: 150000; Train loss: 5.748; Validation loss: 15.937;
# 21:39:59 STEP: 151000; Train loss: 18.285; Validation loss: 9.967;
# 21:39:59 STEP: 152000; Train loss: 10.057; Validation loss: 11.938;
# 21:40:00 STEP: 153000; Train loss: 17.516; Validation loss: 7.736;
# 21:40:00 STEP: 154000; Train loss: 10.412; Validation loss: 11.023;
# 21:40:01 STEP: 155000; Train loss: 6.196; Validation loss: 11.043;
# 21:40:01 STEP: 156000; Train loss: 5.207; Validation loss: 8.956;
# 21:40:02 STEP: 157000; Train loss: 26.590; Validation loss: 11.989;
# 21:40:02 STEP: 158000; Train loss: 8.876; Validation loss: 16.422;
# 21:40:03 STEP: 159000; Train loss: 25.670; Validation loss: 7.207;
# 21:40:04 STEP: 160000; Train loss: 11.786; Validation loss: 14.673;
# 21:40:04 STEP: 161000; Train loss: 11.512; Validation loss: 18.520;
# 21:40:05 STEP: 162000; Train loss: 21.213; Validation loss: 11.394;
# 21:40:05 STEP: 163000; Train loss: 9.574; Validation loss: 9.651;
# 21:40:06 STEP: 164000; Train loss: 16.017; Validation loss: 12.245;
# 21:40:06 STEP: 165000; Train loss: 7.158; Validation loss: 6.393;
# 21:40:07 STEP: 166000; Train loss: 7.311; Validation loss: 66.873;
# 21:40:07 STEP: 167000; Train loss: 13.885; Validation loss: 6.976;
# 21:40:08 STEP: 168000; Train loss: 9.551; Validation loss: 6.714;
# 21:40:08 STEP: 169000; Train loss: 7.584; Validation loss: 10.809;
# 21:40:09 STEP: 170000; Train loss: 4.360; Validation loss: 21.819;
# 21:40:09 STEP: 171000; Train loss: 12.102; Validation loss: 9.110;
# 21:40:10 STEP: 172000; Train loss: 8.217; Validation loss: 17.654;
# 21:40:11 STEP: 173000; Train loss: 14.856; Validation loss: 38.055;
# 21:40:11 STEP: 174000; Train loss: 10.949; Validation loss: 15.463;
# 21:40:12 STEP: 175000; Train loss: 12.888; Validation loss: 19.227;
# 21:40:12 STEP: 176000; Train loss: 36.243; Validation loss: 17.837;
# 21:40:13 STEP: 177000; Train loss: 26.971; Validation loss: 24.097;
# 21:40:13 STEP: 178000; Train loss: 14.791; Validation loss: 13.096;
# 21:40:14 STEP: 179000; Train loss: 11.794; Validation loss: 8.707;
# 21:40:14 STEP: 180000; Train loss: 14.240; Validation loss: 6.196;
# 21:40:15 STEP: 181000; Train loss: 17.595; Validation loss: 14.373;
# 21:40:15 STEP: 182000; Train loss: 25.281; Validation loss: 12.057;
# 21:40:16 STEP: 183000; Train loss: 5.589; Validation loss: 7.244;
# 21:40:16 STEP: 184000; Train loss: 7.204; Validation loss: 12.697;
# 21:40:17 STEP: 185000; Train loss: 13.410; Validation loss: 12.396;
# 21:40:17 STEP: 186000; Train loss: 12.457; Validation loss: 11.597;
# 21:40:18 STEP: 187000; Train loss: 11.338; Validation loss: 7.136;
# 21:40:18 STEP: 188000; Train loss: 12.152; Validation loss: 15.648;
# 21:40:19 STEP: 189000; Train loss: 17.184; Validation loss: 17.920;
# 21:40:19 STEP: 190000; Train loss: 9.557; Validation loss: 76.298;
# 21:40:20 STEP: 191000; Train loss: 21.143; Validation loss: 31.723;
# 21:40:20 STEP: 192000; Train loss: 43.772; Validation loss: 10.545;
# 21:40:21 STEP: 193000; Train loss: 54.126; Validation loss: 12.950;
# 21:40:21 STEP: 194000; Train loss: 5.557; Validation loss: 15.366;
# 21:40:22 STEP: 195000; Train loss: 8.513; Validation loss: 17.135;
# 21:40:22 STEP: 196000; Train loss: 31.297; Validation loss: 9.837;
# 21:40:23 STEP: 197000; Train loss: 9.063; Validation loss: 21.523;
# 21:40:24 STEP: 198000; Train loss: 27.492; Validation loss: 8.513;
# 21:40:24 STEP: 199000; Train loss: 16.142; Validation loss: 15.429;
# 21:40:25 STEP: 200000; Train loss: 11.091; Validation loss: 7.964;
# 21:40:25 STEP: 201000; Train loss: 6.674; Validation loss: 23.847;
# 21:40:26 STEP: 202000; Train loss: 8.545; Validation loss: 18.027;
# 21:40:26 STEP: 203000; Train loss: 8.024; Validation loss: 12.498;
# 21:40:27 STEP: 204000; Train loss: 8.798; Validation loss: 5.562;
# 21:40:27 STEP: 205000; Train loss: 24.497; Validation loss: 4.619;
# 21:40:28 STEP: 206000; Train loss: 12.287; Validation loss: 5.931;
# 21:40:28 STEP: 207000; Train loss: 16.342; Validation loss: 53.708;
# 21:40:29 STEP: 208000; Train loss: 18.383; Validation loss: 6.069;
# 21:40:29 STEP: 209000; Train loss: 8.241; Validation loss: 20.808;
# 21:40:30 STEP: 210000; Train loss: 5.693; Validation loss: 16.080;
# 21:40:30 STEP: 211000; Train loss: 9.858; Validation loss: 17.653;
# 21:40:31 STEP: 212000; Train loss: 11.212; Validation loss: 11.475;
# 21:40:31 STEP: 213000; Train loss: 9.541; Validation loss: 16.114;
# 21:40:32 STEP: 214000; Train loss: 52.647; Validation loss: 11.508;
# 21:40:32 STEP: 215000; Train loss: 10.711; Validation loss: 9.695;
# 21:40:33 STEP: 216000; Train loss: 8.313; Validation loss: 8.151;
# 21:40:33 STEP: 217000; Train loss: 10.068; Validation loss: 10.507;
# 21:40:34 STEP: 218000; Train loss: 19.197; Validation loss: 8.734;
# 21:40:34 STEP: 219000; Train loss: 11.319; Validation loss: 21.932;
# 21:40:35 STEP: 220000; Train loss: 11.235; Validation loss: 9.972;
# 21:40:35 STEP: 221000; Train loss: 8.408; Validation loss: 7.707;
# 21:40:36 STEP: 222000; Train loss: 12.344; Validation loss: 41.717;
# 21:40:37 STEP: 223000; Train loss: 11.933; Validation loss: 21.033;
# 21:40:37 STEP: 224000; Train loss: 10.916; Validation loss: 43.196;
# 21:40:38 STEP: 225000; Train loss: 34.035; Validation loss: 10.370;
# 21:40:38 STEP: 226000; Train loss: 8.807; Validation loss: 7.576;
# 21:40:39 STEP: 227000; Train loss: 8.321; Validation loss: 11.186;
# 21:40:39 STEP: 228000; Train loss: 4.678; Validation loss: 14.670;
# 21:40:40 STEP: 229000; Train loss: 10.177; Validation loss: 12.680;
# 21:40:40 STEP: 230000; Train loss: 7.989; Validation loss: 9.463;
# 21:40:41 STEP: 231000; Train loss: 5.649; Validation loss: 7.870;
# 21:40:41 STEP: 232000; Train loss: 11.620; Validation loss: 17.563;
# 21:40:42 STEP: 233000; Train loss: 12.077; Validation loss: 16.163;
# 21:40:42 STEP: 234000; Train loss: 5.256; Validation loss: 17.222;
# 21:40:43 STEP: 235000; Train loss: 27.912; Validation loss: 8.834;
# 21:40:43 STEP: 236000; Train loss: 27.665; Validation loss: 24.554;
# 21:40:44 STEP: 237000; Train loss: 6.150; Validation loss: 7.945;
# 21:40:44 STEP: 238000; Train loss: 9.455; Validation loss: 10.024;
# 21:40:45 STEP: 239000; Train loss: 20.605; Validation loss: 17.774;
# 21:40:45 STEP: 240000; Train loss: 15.359; Validation loss: 17.042;
# 21:40:46 STEP: 241000; Train loss: 12.544; Validation loss: 8.146;
# 21:40:47 STEP: 242000; Train loss: 7.099; Validation loss: 7.461;
# 21:40:47 STEP: 243000; Train loss: 15.400; Validation loss: 11.666;
# 21:40:48 STEP: 244000; Train loss: 11.525; Validation loss: 8.384;
# 21:40:48 STEP: 245000; Train loss: 9.614; Validation loss: 6.530;
# 21:40:49 STEP: 246000; Train loss: 24.548; Validation loss: 11.127;
# 21:40:49 STEP: 247000; Train loss: 7.882; Validation loss: 19.793;
# 21:40:50 STEP: 248000; Train loss: 22.285; Validation loss: 9.900;
# 21:40:50 STEP: 249000; Train loss: 29.463; Validation loss: 7.175;
# 21:40:51 STEP: 250000; Train loss: 9.035; Validation loss: 29.601;
# 21:40:51 STEP: 251000; Train loss: 15.831; Validation loss: 15.046;
# 21:40:52 STEP: 252000; Train loss: 6.507; Validation loss: 12.435;
# 21:40:52 STEP: 253000; Train loss: 13.077; Validation loss: 8.847;
# 21:40:53 STEP: 254000; Train loss: 21.245; Validation loss: 21.695;
# 21:40:54 STEP: 255000; Train loss: 22.388; Validation loss: 12.303;
# 21:40:54 STEP: 256000; Train loss: 16.990; Validation loss: 11.598;
# 21:40:55 STEP: 257000; Train loss: 6.171; Validation loss: 11.549;
# 21:40:55 STEP: 258000; Train loss: 17.203; Validation loss: 11.998;
# 21:40:56 STEP: 259000; Train loss: 52.243; Validation loss: 8.641;
# 21:40:56 STEP: 260000; Train loss: 7.971; Validation loss: 13.624;
# 21:40:57 STEP: 261000; Train loss: 7.894; Validation loss: 18.876;
# 21:40:57 STEP: 262000; Train loss: 7.392; Validation loss: 8.273;
# 21:40:58 STEP: 263000; Train loss: 11.650; Validation loss: 12.231;
# 21:40:58 STEP: 264000; Train loss: 15.686; Validation loss: 8.352;
# 21:40:59 STEP: 265000; Train loss: 8.594; Validation loss: 17.856;
# 21:40:59 STEP: 266000; Train loss: 29.762; Validation loss: 11.417;
# 21:41:00 STEP: 267000; Train loss: 7.425; Validation loss: 19.794;
# 21:41:00 STEP: 268000; Train loss: 9.975; Validation loss: 7.629;
# 21:41:01 STEP: 269000; Train loss: 8.000; Validation loss: 12.375;
# 21:41:01 STEP: 270000; Train loss: 7.250; Validation loss: 10.159;
# 21:41:02 STEP: 271000; Train loss: 15.301; Validation loss: 11.359;
# 21:41:02 STEP: 272000; Train loss: 66.496; Validation loss: 6.823;
# 21:41:03 STEP: 273000; Train loss: 8.777; Validation loss: 5.296;
# 21:41:04 STEP: 274000; Train loss: 28.273; Validation loss: 18.365;
# 21:41:04 STEP: 275000; Train loss: 17.397; Validation loss: 8.438;
# 21:41:05 STEP: 276000; Train loss: 8.330; Validation loss: 8.959;
# 21:41:05 STEP: 277000; Train loss: 11.820; Validation loss: 6.305;
# 21:41:06 STEP: 278000; Train loss: 9.794; Validation loss: 10.490;
# 21:41:06 STEP: 279000; Train loss: 9.295; Validation loss: 15.127;
# 21:41:07 STEP: 280000; Train loss: 9.291; Validation loss: 11.139;
# 21:41:07 STEP: 281000; Train loss: 9.687; Validation loss: 31.981;
# 21:41:08 STEP: 282000; Train loss: 23.520; Validation loss: 10.496;
# 21:41:08 STEP: 283000; Train loss: 10.230; Validation loss: 19.565;
# 21:41:09 STEP: 284000; Train loss: 10.791; Validation loss: 23.917;
# 21:41:09 STEP: 285000; Train loss: 15.347; Validation loss: 8.858;
# 21:41:10 STEP: 286000; Train loss: 16.366; Validation loss: 14.844;
# 21:41:11 STEP: 287000; Train loss: 6.823; Validation loss: 24.088;
# 21:41:11 STEP: 288000; Train loss: 7.305; Validation loss: 9.837;
# 21:41:12 STEP: 289000; Train loss: 12.557; Validation loss: 6.758;
# 21:41:12 STEP: 290000; Train loss: 22.102; Validation loss: 48.207;
# 21:41:13 STEP: 291000; Train loss: 14.774; Validation loss: 11.834;
# 21:41:13 STEP: 292000; Train loss: 7.936; Validation loss: 7.577;
# 21:41:14 STEP: 293000; Train loss: 12.168; Validation loss: 8.934;
# 21:41:14 STEP: 294000; Train loss: 9.355; Validation loss: 17.915;
# 21:41:15 STEP: 295000; Train loss: 15.807; Validation loss: 6.499;
# 21:41:15 STEP: 296000; Train loss: 9.383; Validation loss: 11.175;
# 21:41:16 STEP: 297000; Train loss: 9.693; Validation loss: 7.401;
# 21:41:16 STEP: 298000; Train loss: 5.909; Validation loss: 7.880;
# 21:41:17 STEP: 299000; Train loss: 9.574; Validation loss: 8.530;
# 21:41:17 STEP: 300000; Train loss: 10.557; Validation loss: 15.537;
# 21:41:18 STEP: 301000; Train loss: 22.202; Validation loss: 9.649;
# 21:41:18 STEP: 302000; Train loss: 27.355; Validation loss: 5.912;
# 21:41:19 STEP: 303000; Train loss: 7.407; Validation loss: 9.482;
# 21:41:20 STEP: 304000; Train loss: 12.736; Validation loss: 10.608;
# 21:41:20 STEP: 305000; Train loss: 22.307; Validation loss: 11.551;
# 21:41:21 STEP: 306000; Train loss: 16.702; Validation loss: 14.336;
# 21:41:21 STEP: 307000; Train loss: 30.988; Validation loss: 19.715;
# 21:41:22 STEP: 308000; Train loss: 21.108; Validation loss: 12.750;
# 21:41:22 STEP: 309000; Train loss: 16.901; Validation loss: 5.663;
# 21:41:23 STEP: 310000; Train loss: 8.764; Validation loss: 17.487;
# 21:41:23 STEP: 311000; Train loss: 13.061; Validation loss: 14.169;
# 21:41:24 STEP: 312000; Train loss: 12.494; Validation loss: 20.254;
# 21:41:24 STEP: 313000; Train loss: 15.228; Validation loss: 12.664;
# 21:41:25 STEP: 314000; Train loss: 13.830; Validation loss: 5.613;
# 21:41:25 STEP: 315000; Train loss: 6.831; Validation loss: 15.936;
# 21:41:26 STEP: 316000; Train loss: 24.347; Validation loss: 9.354;
# 21:41:26 STEP: 317000; Train loss: 19.985; Validation loss: 5.089;
# 21:41:27 STEP: 318000; Train loss: 10.889; Validation loss: 10.336;
# 21:41:27 STEP: 319000; Train loss: 13.010; Validation loss: 6.411;
# 21:41:28 STEP: 320000; Train loss: 9.644; Validation loss: 12.514;
# 21:41:29 STEP: 321000; Train loss: 12.657; Validation loss: 9.560;
# 21:41:29 STEP: 322000; Train loss: 10.268; Validation loss: 11.185;
# 21:41:30 STEP: 323000; Train loss: 10.751; Validation loss: 18.170;
# 21:41:30 STEP: 324000; Train loss: 9.466; Validation loss: 10.319;
# 21:41:31 STEP: 325000; Train loss: 17.047; Validation loss: 21.723;
# 21:41:31 STEP: 326000; Train loss: 10.891; Validation loss: 24.401;
# 21:41:32 STEP: 327000; Train loss: 5.656; Validation loss: 11.926;
# 21:41:32 STEP: 328000; Train loss: 7.525; Validation loss: 6.262;
# 21:41:33 STEP: 329000; Train loss: 11.728; Validation loss: 7.969;
# 21:41:33 STEP: 330000; Train loss: 17.545; Validation loss: 23.796;
# 21:41:34 STEP: 331000; Train loss: 38.066; Validation loss: 12.150;
# 21:41:34 STEP: 332000; Train loss: 5.390; Validation loss: 7.080;
# 21:41:35 STEP: 333000; Train loss: 22.325; Validation loss: 21.999;
# 21:41:36 STEP: 334000; Train loss: 10.307; Validation loss: 11.440;
# 21:41:36 STEP: 335000; Train loss: 9.873; Validation loss: 9.667;
# 21:41:37 STEP: 336000; Train loss: 12.617; Validation loss: 8.027;
# 21:41:37 STEP: 337000; Train loss: 8.929; Validation loss: 8.110;
# 21:41:38 STEP: 338000; Train loss: 6.143; Validation loss: 7.082;
# 21:41:38 STEP: 339000; Train loss: 6.903; Validation loss: 24.207;
# 21:41:39 STEP: 340000; Train loss: 8.198; Validation loss: 8.970;
# 21:41:39 STEP: 341000; Train loss: 9.738; Validation loss: 20.138;
# 21:41:40 STEP: 342000; Train loss: 11.518; Validation loss: 11.137;
# 21:41:40 STEP: 343000; Train loss: 8.550; Validation loss: 10.560;
# 21:41:41 STEP: 344000; Train loss: 16.205; Validation loss: 26.487;
# 21:41:42 STEP: 345000; Train loss: 13.048; Validation loss: 7.562;
# 21:41:42 STEP: 346000; Train loss: 13.656; Validation loss: 7.587;
# 21:41:43 STEP: 347000; Train loss: 16.511; Validation loss: 15.231;
# 21:41:43 STEP: 348000; Train loss: 22.589; Validation loss: 11.584;
# 21:41:44 STEP: 349000; Train loss: 23.252; Validation loss: 8.849;
# 21:41:44 STEP: 350000; Train loss: 15.736; Validation loss: 15.894;
# 21:41:45 STEP: 351000; Train loss: 14.209; Validation loss: 26.848;
# 21:41:45 STEP: 352000; Train loss: 12.801; Validation loss: 8.418;
# 21:41:46 STEP: 353000; Train loss: 16.677; Validation loss: 18.943;
# 21:41:47 STEP: 354000; Train loss: 12.456; Validation loss: 5.355;
# 21:41:47 STEP: 355000; Train loss: 26.003; Validation loss: 13.270;
# 21:41:48 STEP: 356000; Train loss: 16.828; Validation loss: 20.668;
# 21:41:48 STEP: 357000; Train loss: 8.605; Validation loss: 8.027;
# 21:41:49 STEP: 358000; Train loss: 10.290; Validation loss: 10.077;
# 21:41:49 STEP: 359000; Train loss: 10.358; Validation loss: 7.132;
# 21:41:50 STEP: 360000; Train loss: 7.312; Validation loss: 9.883;
# 21:41:50 STEP: 361000; Train loss: 21.425; Validation loss: 9.664;
# 21:41:51 STEP: 362000; Train loss: 6.515; Validation loss: 24.140;
# 21:41:51 STEP: 363000; Train loss: 7.633; Validation loss: 9.198;
# 21:41:52 STEP: 364000; Train loss: 21.973; Validation loss: 12.545;
# 21:41:53 STEP: 365000; Train loss: 14.361; Validation loss: 7.600;
# 21:41:53 STEP: 366000; Train loss: 18.593; Validation loss: 15.489;
# 21:41:54 STEP: 367000; Train loss: 19.965; Validation loss: 12.584;
# 21:41:54 STEP: 368000; Train loss: 15.963; Validation loss: 7.441;
# 21:41:55 STEP: 369000; Train loss: 11.250; Validation loss: 13.028;
# 21:41:55 STEP: 370000; Train loss: 8.327; Validation loss: 12.083;
# 21:41:56 STEP: 371000; Train loss: 24.660; Validation loss: 11.239;
# 21:41:56 STEP: 372000; Train loss: 10.696; Validation loss: 4.268;
# 21:41:57 STEP: 373000; Train loss: 7.673; Validation loss: 6.816;
# 21:41:57 STEP: 374000; Train loss: 5.436; Validation loss: 5.618;
# 21:41:58 STEP: 375000; Train loss: 15.998; Validation loss: 7.484;
# 21:41:58 STEP: 376000; Train loss: 12.729; Validation loss: 7.282;
# 21:41:59 STEP: 377000; Train loss: 54.068; Validation loss: 12.501;
# 21:41:59 STEP: 378000; Train loss: 19.719; Validation loss: 4.320;
# 21:42:00 STEP: 379000; Train loss: 9.600; Validation loss: 6.164;
# 21:42:00 STEP: 380000; Train loss: 57.179; Validation loss: 7.936;
# 21:42:01 STEP: 381000; Train loss: 34.526; Validation loss: 12.309;
# 21:42:01 STEP: 382000; Train loss: 13.101; Validation loss: 14.327;
# 21:42:02 STEP: 383000; Train loss: 8.047; Validation loss: 14.905;
# 21:42:03 STEP: 384000; Train loss: 6.923; Validation loss: 18.951;
# 21:42:03 STEP: 385000; Train loss: 10.882; Validation loss: 11.323;
# 21:42:04 STEP: 386000; Train loss: 11.626; Validation loss: 12.427;
# 21:42:04 STEP: 387000; Train loss: 10.037; Validation loss: 13.750;
# 21:42:05 STEP: 388000; Train loss: 12.806; Validation loss: 9.612;
# 21:42:05 STEP: 389000; Train loss: 38.577; Validation loss: 7.842;
# 21:42:06 STEP: 390000; Train loss: 27.728; Validation loss: 24.264;
# 21:42:06 STEP: 391000; Train loss: 7.195; Validation loss: 6.244;
# 21:42:07 STEP: 392000; Train loss: 8.735; Validation loss: 7.784;
# 21:42:07 STEP: 393000; Train loss: 10.812; Validation loss: 10.423;
# 21:42:08 STEP: 394000; Train loss: 16.318; Validation loss: 20.961;
# 21:42:08 STEP: 395000; Train loss: 13.983; Validation loss: 8.101;
# 21:42:09 STEP: 396000; Train loss: 6.844; Validation loss: 19.644;
# 21:42:09 STEP: 397000; Train loss: 14.490; Validation loss: 12.651;
# 21:42:10 STEP: 398000; Train loss: 14.489; Validation loss: 6.899;
# 21:42:10 STEP: 399000; Train loss: 10.137; Validation loss: 11.680;
# 21:42:11 STEP: 400000; Train loss: 11.344; Validation loss: 11.585;
# 21:42:11 STEP: 401000; Train loss: 5.065; Validation loss: 5.745;
# 21:42:12 STEP: 402000; Train loss: 26.178; Validation loss: 12.154;
# 21:42:12 STEP: 403000; Train loss: 13.774; Validation loss: 7.757;
# 21:42:13 STEP: 404000; Train loss: 9.907; Validation loss: 9.975;
# 21:42:13 STEP: 405000; Train loss: 25.668; Validation loss: 6.497;
# 21:42:14 STEP: 406000; Train loss: 9.145; Validation loss: 8.174;
# 21:42:14 STEP: 407000; Train loss: 20.486; Validation loss: 9.036;
# 21:42:15 STEP: 408000; Train loss: 11.343; Validation loss: 6.887;
# 21:42:16 STEP: 409000; Train loss: 5.605; Validation loss: 7.459;
# 21:42:16 STEP: 410000; Train loss: 5.342; Validation loss: 53.152;
# 21:42:17 STEP: 411000; Train loss: 9.780; Validation loss: 8.063;
# 21:42:17 STEP: 412000; Train loss: 4.275; Validation loss: 10.888;
# 21:42:18 STEP: 413000; Train loss: 22.825; Validation loss: 9.988;
# 21:42:18 STEP: 414000; Train loss: 11.535; Validation loss: 29.413;
# 21:42:19 STEP: 415000; Train loss: 7.994; Validation loss: 11.529;
# 21:42:19 STEP: 416000; Train loss: 13.509; Validation loss: 6.258;
# 21:42:20 STEP: 417000; Train loss: 10.692; Validation loss: 17.883;
# 21:42:20 STEP: 418000; Train loss: 8.156; Validation loss: 8.240;
# 21:42:21 STEP: 419000; Train loss: 9.619; Validation loss: 10.397;
# 21:42:21 STEP: 420000; Train loss: 7.152; Validation loss: 23.580;
# 21:42:22 STEP: 421000; Train loss: 7.653; Validation loss: 8.956;
# 21:42:22 STEP: 422000; Train loss: 16.680; Validation loss: 9.371;
# 21:42:23 STEP: 423000; Train loss: 8.050; Validation loss: 6.003;
# 21:42:23 STEP: 424000; Train loss: 15.231; Validation loss: 15.403;
# 21:42:24 STEP: 425000; Train loss: 5.893; Validation loss: 8.888;
# 21:42:24 STEP: 426000; Train loss: 15.000; Validation loss: 13.678;
# 21:42:25 STEP: 427000; Train loss: 14.916; Validation loss: 6.480;
# 21:42:26 STEP: 428000; Train loss: 7.923; Validation loss: 7.157;
# 21:42:26 STEP: 429000; Train loss: 18.089; Validation loss: 6.939;
# 21:42:27 STEP: 430000; Train loss: 8.445; Validation loss: 8.861;
# 21:42:27 STEP: 431000; Train loss: 8.740; Validation loss: 13.066;
# 21:42:28 STEP: 432000; Train loss: 8.933; Validation loss: 16.372;
# 21:42:28 STEP: 433000; Train loss: 17.799; Validation loss: 59.613;
# 21:42:29 STEP: 434000; Train loss: 11.543; Validation loss: 17.551;
# 21:42:29 STEP: 435000; Train loss: 5.008; Validation loss: 19.651;
# 21:42:30 STEP: 436000; Train loss: 5.833; Validation loss: 23.853;
# 21:42:30 STEP: 437000; Train loss: 8.271; Validation loss: 11.045;
# 21:42:31 STEP: 438000; Train loss: 6.934; Validation loss: 15.271;
# 21:42:31 STEP: 439000; Train loss: 8.826; Validation loss: 9.723;
# 21:42:32 STEP: 440000; Train loss: 5.424; Validation loss: 14.511;
# 21:42:32 STEP: 441000; Train loss: 11.830; Validation loss: 6.515;
# 21:42:33 STEP: 442000; Train loss: 12.185; Validation loss: 8.463;
# 21:42:33 STEP: 443000; Train loss: 12.314; Validation loss: 10.308;
# 21:42:34 STEP: 444000; Train loss: 11.321; Validation loss: 21.344;
# 21:42:34 STEP: 445000; Train loss: 8.664; Validation loss: 13.549;
# 21:42:35 STEP: 446000; Train loss: 9.523; Validation loss: 6.158;
# 21:42:35 STEP: 447000; Train loss: 16.518; Validation loss: 8.674;
# 21:42:36 STEP: 448000; Train loss: 12.632; Validation loss: 21.746;
# 21:42:36 STEP: 449000; Train loss: 14.543; Validation loss: 7.314;
# 21:42:37 STEP: 450000; Train loss: 6.447; Validation loss: 6.728;
# 21:42:37 STEP: 451000; Train loss: 12.993; Validation loss: 9.595;
# 21:42:38 STEP: 452000; Train loss: 8.293; Validation loss: 8.904;
# 21:42:39 STEP: 453000; Train loss: 13.878; Validation loss: 12.242;
# 21:42:39 STEP: 454000; Train loss: 9.863; Validation loss: 19.495;
# 21:42:40 STEP: 455000; Train loss: 11.711; Validation loss: 6.181;
# 21:42:40 STEP: 456000; Train loss: 10.584; Validation loss: 11.461;
# 21:42:41 STEP: 457000; Train loss: 9.225; Validation loss: 14.841;
# 21:42:41 STEP: 458000; Train loss: 13.462; Validation loss: 10.030;
# 21:42:42 STEP: 459000; Train loss: 8.914; Validation loss: 13.440;
# 21:42:42 STEP: 460000; Train loss: 17.715; Validation loss: 12.492;
# 21:42:43 STEP: 461000; Train loss: 16.117; Validation loss: 34.277;
# 21:42:43 STEP: 462000; Train loss: 9.189; Validation loss: 7.768;
# 21:42:44 STEP: 463000; Train loss: 7.574; Validation loss: 10.469;
# 21:42:44 STEP: 464000; Train loss: 7.508; Validation loss: 13.727;
# 21:42:45 STEP: 465000; Train loss: 10.218; Validation loss: 36.585;
# 21:42:45 STEP: 466000; Train loss: 12.655; Validation loss: 10.712;
# 21:42:46 STEP: 467000; Train loss: 11.792; Validation loss: 4.967;
# 21:42:46 STEP: 468000; Train loss: 6.593; Validation loss: 10.791;
# 21:42:47 STEP: 469000; Train loss: 9.093; Validation loss: 13.616;
# 21:42:47 STEP: 470000; Train loss: 8.379; Validation loss: 7.563;
# 21:42:48 STEP: 471000; Train loss: 13.298; Validation loss: 9.625;
# 21:42:49 STEP: 472000; Train loss: 5.742; Validation loss: 11.701;
# 21:42:49 STEP: 473000; Train loss: 19.421; Validation loss: 8.944;
# 21:42:50 STEP: 474000; Train loss: 8.836; Validation loss: 13.136;
# 21:42:50 STEP: 475000; Train loss: 9.938; Validation loss: 19.166;
# 21:42:51 STEP: 476000; Train loss: 32.784; Validation loss: 27.089;
# 21:42:51 STEP: 477000; Train loss: 8.397; Validation loss: 38.234;
# 21:42:52 STEP: 478000; Train loss: 8.556; Validation loss: 18.298;
# 21:42:52 STEP: 479000; Train loss: 26.229; Validation loss: 22.128;
# 21:42:53 STEP: 480000; Train loss: 7.392; Validation loss: 16.883;
# 21:42:53 STEP: 481000; Train loss: 15.140; Validation loss: 16.758;
# 21:42:54 STEP: 482000; Train loss: 13.247; Validation loss: 28.406;
# 21:42:55 STEP: 483000; Train loss: 25.160; Validation loss: 46.374;
# 21:42:55 STEP: 484000; Train loss: 4.831; Validation loss: 12.760;
# 21:42:56 STEP: 485000; Train loss: 37.114; Validation loss: 6.847;
# 21:42:56 STEP: 486000; Train loss: 7.793; Validation loss: 11.393;
# 21:42:57 STEP: 487000; Train loss: 18.136; Validation loss: 12.892;
# 21:42:58 STEP: 488000; Train loss: 9.384; Validation loss: 10.242;
# 21:42:58 STEP: 489000; Train loss: 11.236; Validation loss: 23.602;
# 21:42:59 STEP: 490000; Train loss: 9.139; Validation loss: 11.095;
# 21:42:59 STEP: 491000; Train loss: 14.901; Validation loss: 20.570;
# 21:43:00 STEP: 492000; Train loss: 14.590; Validation loss: 9.315;
# 21:43:00 STEP: 493000; Train loss: 9.678; Validation loss: 9.803;
# 21:43:01 STEP: 494000; Train loss: 5.757; Validation loss: 15.163;
# 21:43:01 STEP: 495000; Train loss: 6.053; Validation loss: 9.637;
# 21:43:02 STEP: 496000; Train loss: 14.170; Validation loss: 11.027;
# 21:43:02 STEP: 497000; Train loss: 22.878; Validation loss: 12.316;
# 21:43:03 STEP: 498000; Train loss: 16.209; Validation loss: 10.104;
# 21:43:03 STEP: 499000; Train loss: 12.156; Validation loss: 7.110;
# 21:43:04 STEP: 500000; Train loss: 6.961; Validation loss: 14.143;
# 21:43:05 STEP: 501000; Train loss: 11.668; Validation loss: 8.508;
# 21:43:05 STEP: 502000; Train loss: 9.642; Validation loss: 12.308;
# 21:43:06 STEP: 503000; Train loss: 11.915; Validation loss: 30.478;
# 21:43:06 STEP: 504000; Train loss: 8.884; Validation loss: 18.312;
# 21:43:07 STEP: 505000; Train loss: 13.588; Validation loss: 9.151;
# 21:43:07 STEP: 506000; Train loss: 9.539; Validation loss: 13.848;
# 21:43:08 STEP: 507000; Train loss: 8.238; Validation loss: 21.021;
# 21:43:08 STEP: 508000; Train loss: 5.351; Validation loss: 22.902;
# 21:43:09 STEP: 509000; Train loss: 14.343; Validation loss: 9.727;
# 21:43:09 STEP: 510000; Train loss: 8.271; Validation loss: 12.137;
# 21:43:10 STEP: 511000; Train loss: 14.776; Validation loss: 9.796;
# 21:43:10 STEP: 512000; Train loss: 10.085; Validation loss: 29.997;
# 21:43:11 STEP: 513000; Train loss: 14.560; Validation loss: 8.570;
# 21:43:12 STEP: 514000; Train loss: 5.937; Validation loss: 23.254;
# 21:43:12 STEP: 515000; Train loss: 7.933; Validation loss: 9.734;
# 21:43:13 STEP: 516000; Train loss: 15.595; Validation loss: 12.383;
# 21:43:13 STEP: 517000; Train loss: 15.111; Validation loss: 6.306;
# 21:43:14 STEP: 518000; Train loss: 25.274; Validation loss: 7.962;
# 21:43:14 STEP: 519000; Train loss: 12.920; Validation loss: 13.891;
# 21:43:15 STEP: 520000; Train loss: 10.184; Validation loss: 6.484;
# 21:43:15 STEP: 521000; Train loss: 6.846; Validation loss: 13.628;
# 21:43:16 STEP: 522000; Train loss: 10.596; Validation loss: 4.977;
# 21:43:16 STEP: 523000; Train loss: 18.067; Validation loss: 6.890;
# 21:43:17 STEP: 524000; Train loss: 8.570; Validation loss: 4.788;
# 21:43:17 STEP: 525000; Train loss: 9.006; Validation loss: 14.772;
# 21:43:18 STEP: 526000; Train loss: 5.334; Validation loss: 20.113;
# 21:43:18 STEP: 527000; Train loss: 24.200; Validation loss: 8.837;
# 21:43:19 STEP: 528000; Train loss: 5.441; Validation loss: 17.328;
# 21:43:19 STEP: 529000; Train loss: 13.056; Validation loss: 13.326;
# 21:43:20 STEP: 530000; Train loss: 8.621; Validation loss: 11.967;
# 21:43:20 STEP: 531000; Train loss: 13.911; Validation loss: 12.027;
# 21:43:21 STEP: 532000; Train loss: 6.121; Validation loss: 21.502;
# 21:43:21 STEP: 533000; Train loss: 4.625; Validation loss: 14.657;
# 21:43:22 STEP: 534000; Train loss: 5.828; Validation loss: 18.317;
# 21:43:22 STEP: 535000; Train loss: 10.788; Validation loss: 13.146;
# 21:43:23 STEP: 536000; Train loss: 8.349; Validation loss: 7.897;
# 21:43:23 STEP: 537000; Train loss: 10.720; Validation loss: 16.940;
# 21:43:24 STEP: 538000; Train loss: 10.764; Validation loss: 8.187;
# 21:43:24 STEP: 539000; Train loss: 14.283; Validation loss: 6.275;
# 21:43:25 STEP: 540000; Train loss: 8.468; Validation loss: 10.868;
# 21:43:26 STEP: 541000; Train loss: 9.525; Validation loss: 8.395;
# 21:43:26 STEP: 542000; Train loss: 43.525; Validation loss: 7.109;
# 21:43:27 STEP: 543000; Train loss: 19.677; Validation loss: 10.935;
# 21:43:27 STEP: 544000; Train loss: 12.803; Validation loss: 9.657;
# 21:43:28 STEP: 545000; Train loss: 12.498; Validation loss: 8.466;
# 21:43:28 STEP: 546000; Train loss: 10.893; Validation loss: 29.318;
# 21:43:29 STEP: 547000; Train loss: 18.254; Validation loss: 6.052;
# 21:43:29 STEP: 548000; Train loss: 8.875; Validation loss: 15.017;
# 21:43:30 STEP: 549000; Train loss: 6.357; Validation loss: 6.790;
# 21:43:30 STEP: 550000; Train loss: 11.752; Validation loss: 9.823;
# 21:43:31 STEP: 551000; Train loss: 11.910; Validation loss: 22.822;
# 21:43:31 STEP: 552000; Train loss: 17.459; Validation loss: 8.502;
# 21:43:32 STEP: 553000; Train loss: 17.718; Validation loss: 16.006;
# 21:43:32 STEP: 554000; Train loss: 7.428; Validation loss: 9.222;
# 21:43:33 STEP: 555000; Train loss: 16.625; Validation loss: 5.258;
# 21:43:33 STEP: 556000; Train loss: 7.396; Validation loss: 5.559;
# 21:43:34 STEP: 557000; Train loss: 14.678; Validation loss: 19.398;
# 21:43:34 STEP: 558000; Train loss: 11.953; Validation loss: 8.722;
# 21:43:35 STEP: 559000; Train loss: 13.306; Validation loss: 13.205;
# 21:43:35 STEP: 560000; Train loss: 36.936; Validation loss: 11.035;
# 21:43:36 STEP: 561000; Train loss: 4.642; Validation loss: 7.514;
# 21:43:36 STEP: 562000; Train loss: 9.338; Validation loss: 11.305;
# 21:43:37 STEP: 563000; Train loss: 19.785; Validation loss: 5.777;
# 21:43:37 STEP: 564000; Train loss: 4.671; Validation loss: 20.856;
# 21:43:38 STEP: 565000; Train loss: 7.369; Validation loss: 5.068;
# 21:43:38 STEP: 566000; Train loss: 5.654; Validation loss: 66.518;
# 21:43:39 STEP: 567000; Train loss: 14.251; Validation loss: 14.501;
# 21:43:39 STEP: 568000; Train loss: 17.497; Validation loss: 4.348;
# 21:43:40 STEP: 569000; Train loss: 5.505; Validation loss: 12.288;
# 21:43:40 STEP: 570000; Train loss: 9.678; Validation loss: 19.572;
# 21:43:41 STEP: 571000; Train loss: 6.558; Validation loss: 8.528;
# 21:43:41 STEP: 572000; Train loss: 8.076; Validation loss: 7.157;
# 21:43:42 STEP: 573000; Train loss: 9.068; Validation loss: 11.812;
# 21:43:42 STEP: 574000; Train loss: 11.195; Validation loss: 15.598;
# 21:43:43 STEP: 575000; Train loss: 13.672; Validation loss: 8.452;
# 21:43:43 STEP: 576000; Train loss: 8.859; Validation loss: 7.832;
# 21:43:44 STEP: 577000; Train loss: 11.895; Validation loss: 6.923;
# 21:43:45 STEP: 578000; Train loss: 12.781; Validation loss: 12.904;
# 21:43:45 STEP: 579000; Train loss: 10.269; Validation loss: 11.305;
# 21:43:46 STEP: 580000; Train loss: 20.479; Validation loss: 11.076;
# 21:43:46 STEP: 581000; Train loss: 13.757; Validation loss: 9.281;
# 21:43:47 STEP: 582000; Train loss: 34.167; Validation loss: 10.049;
# 21:43:47 STEP: 583000; Train loss: 48.248; Validation loss: 11.602;
# 21:43:48 STEP: 584000; Train loss: 7.663; Validation loss: 9.116;
# 21:43:48 STEP: 585000; Train loss: 18.215; Validation loss: 9.877;
# 21:43:49 STEP: 586000; Train loss: 10.467; Validation loss: 21.494;
# 21:43:49 STEP: 587000; Train loss: 7.977; Validation loss: 7.346;
# 21:43:50 STEP: 588000; Train loss: 6.682; Validation loss: 4.662;
# 21:43:50 STEP: 589000; Train loss: 7.222; Validation loss: 7.154;
# 21:43:51 STEP: 590000; Train loss: 8.388; Validation loss: 45.690;
# 21:43:51 STEP: 591000; Train loss: 7.806; Validation loss: 21.989;
# 21:43:52 STEP: 592000; Train loss: 6.972; Validation loss: 20.577;
# 21:43:52 STEP: 593000; Train loss: 7.374; Validation loss: 13.620;
# 21:43:53 STEP: 594000; Train loss: 27.754; Validation loss: 8.548;
# 21:43:53 STEP: 595000; Train loss: 20.265; Validation loss: 14.315;
# 21:43:54 STEP: 596000; Train loss: 8.735; Validation loss: 7.011;
# 21:43:54 STEP: 597000; Train loss: 9.558; Validation loss: 13.676;
# 21:43:55 STEP: 598000; Train loss: 12.031; Validation loss: 6.188;
# 21:43:55 STEP: 599000; Train loss: 19.930; Validation loss: 9.900;
# 21:43:56 STEP: 600000; Train loss: 8.448; Validation loss: 8.886;
# 21:43:56 STEP: 601000; Train loss: 8.657; Validation loss: 13.754;
# 21:43:57 STEP: 602000; Train loss: 13.911; Validation loss: 9.798;
# 21:43:57 STEP: 603000; Train loss: 9.112; Validation loss: 9.510;
# 21:43:58 STEP: 604000; Train loss: 12.830; Validation loss: 16.230;
# 21:43:59 STEP: 605000; Train loss: 17.652; Validation loss: 8.957;
# 21:43:59 STEP: 606000; Train loss: 6.819; Validation loss: 8.348;
# 21:44:00 STEP: 607000; Train loss: 10.110; Validation loss: 7.846;
# 21:44:00 STEP: 608000; Train loss: 12.976; Validation loss: 11.942;
# 21:44:01 STEP: 609000; Train loss: 17.313; Validation loss: 42.406;
# 21:44:01 STEP: 610000; Train loss: 8.239; Validation loss: 8.367;
# 21:44:02 STEP: 611000; Train loss: 12.591; Validation loss: 20.122;
# 21:44:02 STEP: 612000; Train loss: 14.966; Validation loss: 10.306;
# 21:44:03 STEP: 613000; Train loss: 8.241; Validation loss: 4.945;
# 21:44:04 STEP: 614000; Train loss: 23.617; Validation loss: 5.289;
# 21:44:04 STEP: 615000; Train loss: 12.424; Validation loss: 7.899;
# 21:44:05 STEP: 616000; Train loss: 10.859; Validation loss: 5.180;
# 21:44:05 STEP: 617000; Train loss: 9.594; Validation loss: 9.730;
# 21:44:06 STEP: 618000; Train loss: 37.570; Validation loss: 53.015;
# 21:44:06 STEP: 619000; Train loss: 7.515; Validation loss: 25.585;
# 21:44:07 STEP: 620000; Train loss: 9.450; Validation loss: 16.126;
# 21:44:08 STEP: 621000; Train loss: 9.191; Validation loss: 11.498;
# 21:44:08 STEP: 622000; Train loss: 9.846; Validation loss: 7.098;
# 21:44:09 STEP: 623000; Train loss: 4.738; Validation loss: 17.750;
# 21:44:09 STEP: 624000; Train loss: 7.354; Validation loss: 5.455;
# 21:44:10 STEP: 625000; Train loss: 21.765; Validation loss: 6.097;
# 21:44:10 STEP: 626000; Train loss: 6.681; Validation loss: 10.343;
# 21:44:11 STEP: 627000; Train loss: 13.169; Validation loss: 10.058;
# 21:44:12 STEP: 628000; Train loss: 10.858; Validation loss: 20.812;
# 21:44:12 STEP: 629000; Train loss: 8.370; Validation loss: 11.619;
# 21:44:13 STEP: 630000; Train loss: 13.513; Validation loss: 5.514;
# 21:44:13 STEP: 631000; Train loss: 8.700; Validation loss: 22.258;
# 21:44:14 STEP: 632000; Train loss: 6.480; Validation loss: 9.878;
# 21:44:14 STEP: 633000; Train loss: 4.516; Validation loss: 17.239;
# 21:44:15 STEP: 634000; Train loss: 7.377; Validation loss: 15.179;
# 21:44:15 STEP: 635000; Train loss: 7.667; Validation loss: 35.106;
# 21:44:16 STEP: 636000; Train loss: 9.370; Validation loss: 6.583;
# 21:44:16 STEP: 637000; Train loss: 19.191; Validation loss: 13.413;
# 21:44:17 STEP: 638000; Train loss: 9.346; Validation loss: 9.592;
# 21:44:17 STEP: 639000; Train loss: 6.486; Validation loss: 19.939;
# 21:44:18 STEP: 640000; Train loss: 9.887; Validation loss: 17.577;
# 21:44:18 STEP: 641000; Train loss: 5.289; Validation loss: 20.259;
# 21:44:19 STEP: 642000; Train loss: 22.726; Validation loss: 6.104;
# 21:44:19 STEP: 643000; Train loss: 12.511; Validation loss: 9.237;
# 21:44:20 STEP: 644000; Train loss: 15.545; Validation loss: 8.626;
# 21:44:20 STEP: 645000; Train loss: 17.156; Validation loss: 14.539;
# 21:44:21 STEP: 646000; Train loss: 68.351; Validation loss: 8.904;
# 21:44:21 STEP: 647000; Train loss: 12.469; Validation loss: 5.935;
# 21:44:22 STEP: 648000; Train loss: 11.769; Validation loss: 19.572;
# 21:44:23 STEP: 649000; Train loss: 10.959; Validation loss: 6.986;
# 21:44:23 STEP: 650000; Train loss: 5.943; Validation loss: 8.491;
# 21:44:24 STEP: 651000; Train loss: 20.348; Validation loss: 12.208;
# 21:44:24 STEP: 652000; Train loss: 18.400; Validation loss: 30.917;
# 21:44:25 STEP: 653000; Train loss: 11.416; Validation loss: 13.287;
# 21:44:25 STEP: 654000; Train loss: 8.712; Validation loss: 10.102;
# 21:44:26 STEP: 655000; Train loss: 19.693; Validation loss: 14.837;
# 21:44:26 STEP: 656000; Train loss: 10.054; Validation loss: 7.163;
# 21:44:27 STEP: 657000; Train loss: 11.170; Validation loss: 6.670;
# 21:44:27 STEP: 658000; Train loss: 9.425; Validation loss: 6.850;
# 21:44:28 STEP: 659000; Train loss: 8.225; Validation loss: 12.603;
# 21:44:28 STEP: 660000; Train loss: 6.669; Validation loss: 6.595;
# 21:44:29 STEP: 661000; Train loss: 13.279; Validation loss: 25.623;
# 21:44:29 STEP: 662000; Train loss: 5.000; Validation loss: 15.159;
# 21:44:30 STEP: 663000; Train loss: 14.563; Validation loss: 10.372;
# 21:44:30 STEP: 664000; Train loss: 13.021; Validation loss: 7.252;
# 21:44:31 STEP: 665000; Train loss: 9.397; Validation loss: 12.708;
# 21:44:31 STEP: 666000; Train loss: 13.032; Validation loss: 5.732;
# 21:44:32 STEP: 667000; Train loss: 6.009; Validation loss: 13.555;
# 21:44:32 STEP: 668000; Train loss: 5.865; Validation loss: 22.791;
# 21:44:33 STEP: 669000; Train loss: 6.129; Validation loss: 17.080;
# 21:44:33 STEP: 670000; Train loss: 13.780; Validation loss: 5.613;
# 21:44:34 STEP: 671000; Train loss: 34.777; Validation loss: 58.244;
# 21:44:34 STEP: 672000; Train loss: 6.220; Validation loss: 8.025;
# 21:44:35 STEP: 673000; Train loss: 8.608; Validation loss: 6.974;
# 21:44:35 STEP: 674000; Train loss: 8.049; Validation loss: 13.367;
# 21:44:36 STEP: 675000; Train loss: 15.396; Validation loss: 4.558;
# 21:44:37 STEP: 676000; Train loss: 7.742; Validation loss: 11.841;
# 21:44:37 STEP: 677000; Train loss: 10.624; Validation loss: 12.620;
# 21:44:38 STEP: 678000; Train loss: 10.149; Validation loss: 10.703;
# 21:44:38 STEP: 679000; Train loss: 10.241; Validation loss: 15.636;
# 21:44:39 STEP: 680000; Train loss: 6.789; Validation loss: 15.469;
# 21:44:39 STEP: 681000; Train loss: 8.438; Validation loss: 8.227;
# 21:44:40 STEP: 682000; Train loss: 15.225; Validation loss: 7.387;
# 21:44:40 STEP: 683000; Train loss: 17.225; Validation loss: 8.228;
# 21:44:41 STEP: 684000; Train loss: 21.181; Validation loss: 13.970;
# 21:44:41 STEP: 685000; Train loss: 17.393; Validation loss: 22.221;
# 21:44:42 STEP: 686000; Train loss: 4.725; Validation loss: 10.522;
# 21:44:43 STEP: 687000; Train loss: 8.171; Validation loss: 7.947;
# 21:44:43 STEP: 688000; Train loss: 15.964; Validation loss: 7.561;
# 21:44:44 STEP: 689000; Train loss: 13.145; Validation loss: 6.969;
# 21:44:44 STEP: 690000; Train loss: 10.153; Validation loss: 8.687;
# 21:44:45 STEP: 691000; Train loss: 9.231; Validation loss: 15.901;
# 21:44:45 STEP: 692000; Train loss: 9.781; Validation loss: 32.324;
# 21:44:46 STEP: 693000; Train loss: 21.042; Validation loss: 24.414;
# 21:44:46 STEP: 694000; Train loss: 11.626; Validation loss: 20.894;
# 21:44:47 STEP: 695000; Train loss: 14.359; Validation loss: 12.902;
# 21:44:47 STEP: 696000; Train loss: 7.266; Validation loss: 8.598;
# 21:44:48 STEP: 697000; Train loss: 7.944; Validation loss: 4.941;
# 21:44:48 STEP: 698000; Train loss: 17.512; Validation loss: 5.868;
# 21:44:49 STEP: 699000; Train loss: 6.359; Validation loss: 11.518;
# 21:44:49 STEP: 700000; Train loss: 14.343; Validation loss: 7.320;
# 21:44:50 STEP: 701000; Train loss: 13.674; Validation loss: 6.728;
# 21:44:50 STEP: 702000; Train loss: 8.490; Validation loss: 24.190;
# 21:44:51 STEP: 703000; Train loss: 25.627; Validation loss: 11.054;
# ...
# 21:54:04 STEP: 1771000; Train loss: 7.770; Validation loss: 13.871;
# 21:54:05 STEP: 1772000; Train loss: 7.859; Validation loss: 10.418;
# 21:54:05 STEP: 1773000; Train loss: 10.214; Validation loss: 10.331;
# 21:54:06 STEP: 1774000; Train loss: 15.914; Validation loss: 11.339;
# 21:54:06 STEP: 1775000; Train loss: 12.047; Validation loss: 7.694;
# 21:54:07 STEP: 1776000; Train loss: 7.176; Validation loss: 13.167;
# 21:54:07 STEP: 1777000; Train loss: 6.956; Validation loss: 8.302;
# 21:54:08 STEP: 1778000; Train loss: 8.825; Validation loss: 11.038;
# 21:54:08 STEP: 1779000; Train loss: 10.426; Validation loss: 8.351;
# 21:54:09 STEP: 1780000; Train loss: 9.358; Validation loss: 13.480;
# 21:54:10 STEP: 1781000; Train loss: 13.768; Validation loss: 5.864;
# 21:54:10 STEP: 1782000; Train loss: 6.785; Validation loss: 5.350;
# 21:54:11 STEP: 1783000; Train loss: 15.912; Validation loss: 7.660;
# 21:54:11 STEP: 1784000; Train loss: 7.603; Validation loss: 13.462;
# 21:54:12 STEP: 1785000; Train loss: 13.184; Validation loss: 11.404;
# 21:54:12 STEP: 1786000; Train loss: 5.773; Validation loss: 17.689;
# 21:54:13 STEP: 1787000; Train loss: 6.959; Validation loss: 14.059;
# 21:54:13 STEP: 1788000; Train loss: 4.476; Validation loss: 10.660;
# 21:54:14 STEP: 1789000; Train loss: 6.161; Validation loss: 15.604;
# 21:54:14 STEP: 1790000; Train loss: 8.530; Validation loss: 12.511;
# 21:54:15 STEP: 1791000; Train loss: 5.797; Validation loss: 5.892;
# 21:54:15 STEP: 1792000; Train loss: 12.815; Validation loss: 9.528;
# 21:54:16 STEP: 1793000; Train loss: 18.613; Validation loss: 12.180;
# 21:54:16 STEP: 1794000; Train loss: 8.667; Validation loss: 9.490;
# 21:54:17 STEP: 1795000; Train loss: 24.528; Validation loss: 32.782;
# 21:54:17 STEP: 1796000; Train loss: 11.081; Validation loss: 12.413;
# 21:54:18 STEP: 1797000; Train loss: 5.803; Validation loss: 6.600;
# 21:54:18 STEP: 1798000; Train loss: 9.319; Validation loss: 9.672;
# 21:54:19 STEP: 1799000; Train loss: 12.287; Validation loss: 7.464;
# 21:54:19 STEP: 1800000; Train loss: 9.899; Validation loss: 9.270;
# 21:54:20 STEP: 1801000; Train loss: 8.483; Validation loss: 15.928;
# 21:54:20 STEP: 1802000; Train loss: 13.222; Validation loss: 14.426;
# 21:54:21 STEP: 1803000; Train loss: 9.523; Validation loss: 10.986;
# 21:54:21 STEP: 1804000; Train loss: 11.542; Validation loss: 12.630;
# 21:54:22 STEP: 1805000; Train loss: 13.081; Validation loss: 15.575;
# 21:54:22 STEP: 1806000; Train loss: 15.629; Validation loss: 28.236;
# 21:54:23 STEP: 1807000; Train loss: 13.761; Validation loss: 15.068;
# 21:54:23 STEP: 1808000; Train loss: 15.616; Validation loss: 15.777;
# 21:54:24 STEP: 1809000; Train loss: 23.765; Validation loss: 5.857;
# 21:54:24 STEP: 1810000; Train loss: 13.024; Validation loss: 9.449;
# 21:54:25 STEP: 1811000; Train loss: 5.296; Validation loss: 8.947;
# 21:54:26 STEP: 1812000; Train loss: 6.018; Validation loss: 43.455;
# 21:54:26 STEP: 1813000; Train loss: 9.651; Validation loss: 8.603;
# 21:54:27 STEP: 1814000; Train loss: 15.615; Validation loss: 25.896;
# 21:54:27 STEP: 1815000; Train loss: 7.365; Validation loss: 14.481;
# 21:54:28 STEP: 1816000; Train loss: 11.655; Validation loss: 14.599;
# 21:54:28 STEP: 1817000; Train loss: 6.925; Validation loss: 38.983;
# 21:54:29 STEP: 1818000; Train loss: 10.888; Validation loss: 7.460;
# 21:54:29 STEP: 1819000; Train loss: 14.300; Validation loss: 8.584;
# 21:54:30 STEP: 1820000; Train loss: 8.905; Validation loss: 14.126;
# 21:54:30 STEP: 1821000; Train loss: 7.815; Validation loss: 10.109;
# 21:54:31 STEP: 1822000; Train loss: 6.464; Validation loss: 12.876;
# 21:54:31 STEP: 1823000; Train loss: 6.046; Validation loss: 10.226;
# 21:54:32 STEP: 1824000; Train loss: 11.284; Validation loss: 8.281;
# 21:54:32 STEP: 1825000; Train loss: 8.226; Validation loss: 12.224;
# 21:54:33 STEP: 1826000; Train loss: 10.629; Validation loss: 8.008;
# 21:54:33 STEP: 1827000; Train loss: 6.367; Validation loss: 11.422;
# 21:54:34 STEP: 1828000; Train loss: 10.155; Validation loss: 5.363;
# 21:54:34 STEP: 1829000; Train loss: 9.706; Validation loss: 13.049;
# 21:54:35 STEP: 1830000; Train loss: 11.388; Validation loss: 13.239;
# 21:54:35 STEP: 1831000; Train loss: 39.144; Validation loss: 14.375;
# 21:54:36 STEP: 1832000; Train loss: 19.015; Validation loss: 9.330;
# 21:54:36 STEP: 1833000; Train loss: 22.008; Validation loss: 12.041;
# 21:54:37 STEP: 1834000; Train loss: 7.608; Validation loss: 15.222;
# 21:54:37 STEP: 1835000; Train loss: 17.157; Validation loss: 5.992;
# 21:54:38 STEP: 1836000; Train loss: 7.045; Validation loss: 9.744;
# 21:54:38 STEP: 1837000; Train loss: 13.629; Validation loss: 13.483;
# 21:54:39 STEP: 1838000; Train loss: 9.553; Validation loss: 13.047;
# 21:54:39 STEP: 1839000; Train loss: 14.075; Validation loss: 12.581;
# 21:54:40 STEP: 1840000; Train loss: 10.950; Validation loss: 5.842;
# 21:54:40 STEP: 1841000; Train loss: 7.459; Validation loss: 7.690;
# 21:54:41 STEP: 1842000; Train loss: 9.909; Validation loss: 6.118;
# 21:54:41 STEP: 1843000; Train loss: 7.057; Validation loss: 7.167;
# 21:54:42 STEP: 1844000; Train loss: 8.135; Validation loss: 8.784;
# 21:54:42 STEP: 1845000; Train loss: 8.087; Validation loss: 8.184;
# 21:54:43 STEP: 1846000; Train loss: 9.064; Validation loss: 21.908;
# 21:54:43 STEP: 1847000; Train loss: 7.349; Validation loss: 5.575;
# 21:54:44 STEP: 1848000; Train loss: 17.013; Validation loss: 8.836;
# 21:54:44 STEP: 1849000; Train loss: 11.453; Validation loss: 9.990;
# 21:54:45 STEP: 1850000; Train loss: 10.194; Validation loss: 8.589;
# 21:54:45 STEP: 1851000; Train loss: 6.327; Validation loss: 28.868;
# 21:54:46 STEP: 1852000; Train loss: 7.970; Validation loss: 5.861;
# 21:54:46 STEP: 1853000; Train loss: 13.943; Validation loss: 18.178;
# 21:54:47 STEP: 1854000; Train loss: 10.759; Validation loss: 9.080;
# 21:54:48 STEP: 1855000; Train loss: 9.867; Validation loss: 6.068;
# 21:54:48 STEP: 1856000; Train loss: 27.601; Validation loss: 13.860;
# 21:54:49 STEP: 1857000; Train loss: 5.530; Validation loss: 13.648;
# 21:54:49 STEP: 1858000; Train loss: 10.719; Validation loss: 5.931;
# 21:54:50 STEP: 1859000; Train loss: 6.756; Validation loss: 18.077;
# 21:54:50 STEP: 1860000; Train loss: 5.117; Validation loss: 11.737;
# 21:54:51 STEP: 1861000; Train loss: 6.326; Validation loss: 7.190;
# 21:54:51 STEP: 1862000; Train loss: 5.892; Validation loss: 8.734;
# 21:54:52 STEP: 1863000; Train loss: 8.899; Validation loss: 10.971;
# 21:54:52 STEP: 1864000; Train loss: 7.518; Validation loss: 6.067;
# 21:54:53 STEP: 1865000; Train loss: 10.621; Validation loss: 13.111;
# 21:54:53 STEP: 1866000; Train loss: 19.490; Validation loss: 13.199;
# 21:54:54 STEP: 1867000; Train loss: 7.940; Validation loss: 11.339;
# 21:54:54 STEP: 1868000; Train loss: 4.693; Validation loss: 7.227;
# 21:54:55 STEP: 1869000; Train loss: 15.687; Validation loss: 8.210;
# 21:54:55 STEP: 1870000; Train loss: 8.236; Validation loss: 9.323;
# 21:54:56 STEP: 1871000; Train loss: 12.924; Validation loss: 6.608;
# 21:54:56 STEP: 1872000; Train loss: 17.805; Validation loss: 6.388;
# 21:54:57 STEP: 1873000; Train loss: 27.194; Validation loss: 10.166;
# 21:54:57 STEP: 1874000; Train loss: 13.071; Validation loss: 9.837;
# 21:54:58 STEP: 1875000; Train loss: 13.940; Validation loss: 10.532;
# 21:54:58 STEP: 1876000; Train loss: 11.394; Validation loss: 12.989;
# 21:54:59 STEP: 1877000; Train loss: 11.975; Validation loss: 13.807;
# 21:54:59 STEP: 1878000; Train loss: 10.402; Validation loss: 8.404;
# 21:55:00 STEP: 1879000; Train loss: 9.683; Validation loss: 12.889;
# 21:55:00 STEP: 1880000; Train loss: 9.349; Validation loss: 8.948;
# 21:55:01 STEP: 1881000; Train loss: 10.563; Validation loss: 12.734;
# 21:55:01 STEP: 1882000; Train loss: 12.927; Validation loss: 14.799;
# 21:55:02 STEP: 1883000; Train loss: 21.096; Validation loss: 8.390;
# 21:55:02 STEP: 1884000; Train loss: 13.625; Validation loss: 10.021;
# 21:55:03 STEP: 1885000; Train loss: 6.224; Validation loss: 8.888;
# 21:55:03 STEP: 1886000; Train loss: 99.360; Validation loss: 7.513;
# 21:55:04 STEP: 1887000; Train loss: 13.260; Validation loss: 8.833;
# 21:55:04 STEP: 1888000; Train loss: 6.087; Validation loss: 11.978;
# 21:55:05 STEP: 1889000; Train loss: 8.447; Validation loss: 13.558;
# 21:55:05 STEP: 1890000; Train loss: 14.377; Validation loss: 6.920;
# 21:55:06 STEP: 1891000; Train loss: 9.334; Validation loss: 9.113;
# 21:55:06 STEP: 1892000; Train loss: 11.208; Validation loss: 9.678;
# 21:55:07 STEP: 1893000; Train loss: 13.183; Validation loss: 4.314;
# 21:55:08 STEP: 1894000; Train loss: 16.223; Validation loss: 6.474;
# 21:55:08 STEP: 1895000; Train loss: 5.932; Validation loss: 8.514;
# 21:55:09 STEP: 1896000; Train loss: 18.000; Validation loss: 15.905;
# 21:55:09 STEP: 1897000; Train loss: 29.423; Validation loss: 20.673;
# 21:55:10 STEP: 1898000; Train loss: 13.053; Validation loss: 16.546;
# 21:55:10 STEP: 1899000; Train loss: 8.621; Validation loss: 7.066;
# 21:55:11 STEP: 1900000; Train loss: 13.182; Validation loss: 9.203;
# 21:55:11 STEP: 1901000; Train loss: 7.494; Validation loss: 6.859;
# 21:55:12 STEP: 1902000; Train loss: 17.715; Validation loss: 6.914;
# 21:55:12 STEP: 1903000; Train loss: 10.120; Validation loss: 21.218;
# 21:55:13 STEP: 1904000; Train loss: 7.147; Validation loss: 8.984;
# 21:55:13 STEP: 1905000; Train loss: 11.516; Validation loss: 5.526;
# 21:55:14 STEP: 1906000; Train loss: 4.972; Validation loss: 13.308;
# 21:55:14 STEP: 1907000; Train loss: 7.729; Validation loss: 8.383;
# 21:55:15 STEP: 1908000; Train loss: 8.783; Validation loss: 10.364;
# 21:55:15 STEP: 1909000; Train loss: 10.206; Validation loss: 27.308;
# 21:55:16 STEP: 1910000; Train loss: 11.592; Validation loss: 7.880;
# 21:55:17 STEP: 1911000; Train loss: 9.817; Validation loss: 6.052;
# 21:55:17 STEP: 1912000; Train loss: 9.168; Validation loss: 9.105;
# 21:55:18 STEP: 1913000; Train loss: 8.486; Validation loss: 9.346;
# 21:55:18 STEP: 1914000; Train loss: 12.498; Validation loss: 11.091;
# 21:55:19 STEP: 1915000; Train loss: 21.153; Validation loss: 7.220;
# 21:55:19 STEP: 1916000; Train loss: 11.079; Validation loss: 10.582;
# 21:55:20 STEP: 1917000; Train loss: 7.090; Validation loss: 11.414;
# 21:55:20 STEP: 1918000; Train loss: 8.996; Validation loss: 11.827;
# 21:55:21 STEP: 1919000; Train loss: 10.547; Validation loss: 7.165;
# 21:55:21 STEP: 1920000; Train loss: 14.764; Validation loss: 8.209;
# 21:55:22 STEP: 1921000; Train loss: 22.457; Validation loss: 9.972;
# 21:55:22 STEP: 1922000; Train loss: 11.163; Validation loss: 11.562;
# 21:55:23 STEP: 1923000; Train loss: 20.198; Validation loss: 19.967;
# 21:55:23 STEP: 1924000; Train loss: 9.787; Validation loss: 9.211;
# 21:55:24 STEP: 1925000; Train loss: 22.892; Validation loss: 10.682;
# 21:55:24 STEP: 1926000; Train loss: 8.168; Validation loss: 18.577;
# 21:55:25 STEP: 1927000; Train loss: 8.450; Validation loss: 8.010;
# 21:55:26 STEP: 1928000; Train loss: 23.767; Validation loss: 7.845;
# 21:55:26 STEP: 1929000; Train loss: 7.805; Validation loss: 10.710;
# 21:55:27 STEP: 1930000; Train loss: 14.062; Validation loss: 13.280;
# 21:55:27 STEP: 1931000; Train loss: 29.460; Validation loss: 6.836;
# 21:55:28 STEP: 1932000; Train loss: 16.449; Validation loss: 12.467;
# 21:55:28 STEP: 1933000; Train loss: 8.062; Validation loss: 10.027;
# 21:55:29 STEP: 1934000; Train loss: 6.252; Validation loss: 9.203;
# 21:55:29 STEP: 1935000; Train loss: 15.238; Validation loss: 13.844;
# 21:55:30 STEP: 1936000; Train loss: 31.122; Validation loss: 17.310;
# 21:55:30 STEP: 1937000; Train loss: 25.144; Validation loss: 9.093;
# 21:55:31 STEP: 1938000; Train loss: 9.254; Validation loss: 22.206;
# 21:55:31 STEP: 1939000; Train loss: 12.276; Validation loss: 13.745;
# 21:55:32 STEP: 1940000; Train loss: 11.857; Validation loss: 9.865;
# 21:55:32 STEP: 1941000; Train loss: 14.190; Validation loss: 11.283;
# 21:55:33 STEP: 1942000; Train loss: 15.954; Validation loss: 15.434;
# 21:55:33 STEP: 1943000; Train loss: 6.452; Validation loss: 45.274;
# 21:55:34 STEP: 1944000; Train loss: 12.251; Validation loss: 7.581;
# 21:55:34 STEP: 1945000; Train loss: 21.433; Validation loss: 6.902;
# 21:55:35 STEP: 1946000; Train loss: 9.025; Validation loss: 6.169;
# 21:55:35 STEP: 1947000; Train loss: 19.476; Validation loss: 33.271;
# 21:55:36 STEP: 1948000; Train loss: 6.165; Validation loss: 7.316;
# 21:55:36 STEP: 1949000; Train loss: 21.944; Validation loss: 16.403;
# 21:55:37 STEP: 1950000; Train loss: 9.886; Validation loss: 5.388;
# 21:55:37 STEP: 1951000; Train loss: 18.429; Validation loss: 10.245;
# 21:55:38 STEP: 1952000; Train loss: 14.065; Validation loss: 10.682;
# 21:55:38 STEP: 1953000; Train loss: 6.694; Validation loss: 22.874;
# 21:55:39 STEP: 1954000; Train loss: 17.831; Validation loss: 9.547;
# 21:55:39 STEP: 1955000; Train loss: 5.779; Validation loss: 16.832;
# 21:55:40 STEP: 1956000; Train loss: 9.132; Validation loss: 10.883;
# 21:55:40 STEP: 1957000; Train loss: 10.935; Validation loss: 4.656;
# 21:55:41 STEP: 1958000; Train loss: 7.480; Validation loss: 11.662;
# 21:55:41 STEP: 1959000; Train loss: 11.565; Validation loss: 9.329;
# 21:55:42 STEP: 1960000; Train loss: 25.328; Validation loss: 12.253;
# 21:55:43 STEP: 1961000; Train loss: 6.332; Validation loss: 26.542;
# 21:55:43 STEP: 1962000; Train loss: 10.248; Validation loss: 16.308;
# 21:55:44 STEP: 1963000; Train loss: 9.528; Validation loss: 7.754;
# 21:55:44 STEP: 1964000; Train loss: 10.565; Validation loss: 19.022;
# 21:55:45 STEP: 1965000; Train loss: 11.351; Validation loss: 15.086;
# 21:55:45 STEP: 1966000; Train loss: 10.432; Validation loss: 13.570;
# 21:55:46 STEP: 1967000; Train loss: 19.021; Validation loss: 7.749;
# 21:55:46 STEP: 1968000; Train loss: 8.440; Validation loss: 10.143;
# 21:55:47 STEP: 1969000; Train loss: 14.102; Validation loss: 9.152;
# 21:55:47 STEP: 1970000; Train loss: 8.207; Validation loss: 6.519;
# 21:55:48 STEP: 1971000; Train loss: 17.838; Validation loss: 10.008;
# 21:55:48 STEP: 1972000; Train loss: 8.186; Validation loss: 11.643;
# 21:55:49 STEP: 1973000; Train loss: 12.055; Validation loss: 9.539;
# 21:55:49 STEP: 1974000; Train loss: 17.242; Validation loss: 13.670;
# 21:55:50 STEP: 1975000; Train loss: 19.278; Validation loss: 21.296;
# 21:55:50 STEP: 1976000; Train loss: 10.533; Validation loss: 13.184;
# 21:55:51 STEP: 1977000; Train loss: 41.969; Validation loss: 10.661;
# 21:55:52 STEP: 1978000; Train loss: 11.932; Validation loss: 11.529;
# 21:55:52 STEP: 1979000; Train loss: 7.744; Validation loss: 8.346;
# 21:55:53 STEP: 1980000; Train loss: 6.893; Validation loss: 10.497;
# 21:55:53 STEP: 1981000; Train loss: 30.696; Validation loss: 11.467;
# 21:55:54 STEP: 1982000; Train loss: 22.161; Validation loss: 13.067;
# 21:55:54 STEP: 1983000; Train loss: 9.670; Validation loss: 22.321;
# 21:55:55 STEP: 1984000; Train loss: 7.379; Validation loss: 14.352;
# 21:55:55 STEP: 1985000; Train loss: 15.136; Validation loss: 6.903;
# 21:55:56 STEP: 1986000; Train loss: 8.247; Validation loss: 47.514;
# 21:55:56 STEP: 1987000; Train loss: 20.293; Validation loss: 9.266;
# 21:55:57 STEP: 1988000; Train loss: 22.149; Validation loss: 31.013;
# 21:55:57 STEP: 1989000; Train loss: 44.257; Validation loss: 7.500;
# 21:55:58 STEP: 1990000; Train loss: 11.542; Validation loss: 9.282;
# 21:55:58 STEP: 1991000; Train loss: 6.819; Validation loss: 6.063;
# 21:55:59 STEP: 1992000; Train loss: 9.759; Validation loss: 18.997;
# 21:55:59 STEP: 1993000; Train loss: 11.161; Validation loss: 8.773;
# 21:56:00 STEP: 1994000; Train loss: 13.731; Validation loss: 20.806;
# 21:56:00 STEP: 1995000; Train loss: 9.556; Validation loss: 9.828;
# 21:56:01 STEP: 1996000; Train loss: 11.217; Validation loss: 10.438;
# 21:56:01 STEP: 1997000; Train loss: 7.448; Validation loss: 11.186;
# 21:56:02 STEP: 1998000; Train loss: 23.649; Validation loss: 9.594;
# 21:56:02 STEP: 1999000; Train loss: 33.564; Validation loss: 16.646;
# 21:56:03 STEP: 1999999; Train loss: 8.239; Validation loss: 6.121;
# Training took: (1047.756 secs; equivalently 17.463 mins)

# %%
from matplotlib.ticker import MaxNLocator

# Loss plots
fig, axes = plt.subplots(2, 2, figsize=(14, 10))

# for i in range(2): axes[i].xaxis.set_major_locator(MaxNLocator(integer=True))

xs = np.arange(len(train_losses))*ARGS.eval_frequency
axes[0, 0].plot(xs, train_losses, label='train_loss')
axes[0, 0].plot(xs, val_losses, label='val_loss')
axes[0, 1].plot(xs[1:], train_losses[1:], label='train_loss')
axes[0, 1].plot(xs[1:], val_losses[1:], label='val_loss')
axes[0, 0].set_title('Loss (all epochs)')
axes[0, 1].set_title('Loss (all except first epoch)')

for i in range(2): 
    axes[0, i].set_ylabel('Loss')
    axes[0, i].set_xlabel('Epochs')
    axes[0, i].legend()
    
# KLD plots
xs = np.arange(len(train_klds))*ARGS.eval_frequency
axes[1, 0].plot(xs, train_klds, label='train_kld')
axes[1, 0].plot(xs, val_klds, label='val_kld')
axes[1, 1].plot(xs[1:], train_klds[1:], label='train_kld')
axes[1, 1].plot(xs[1:], val_klds[1:], label='val_kld')
axes[1, 0].set_title('KLD (all epochs)')
axes[1, 1].set_title('KLD (all except first epoch)')

for i in range(2): 
    axes[1, i].set_ylabel('KLD')
    axes[1, i].set_xlabel('Epochs')
    axes[1, i].legend()

fig.suptitle(f'Loss and KLD (left: all epochs; right: all except first epochs) \n{model_params_title}', fontsize='xx-large')

plt.tight_layout()
plt.show()

loss_kld_path = FIG_PATH / 'loss_kld_figures'
loss_kld_path.mkdir(exist_ok=True)
fig.savefig(loss_kld_path / f'{model_name}.jpg', dpi=300)

# %%
# Switch off dropout
ARGS.training = False

# %%
RNG_KEY, rng_recon = jax.random.split(RNG_KEY)

num_to_plot = 5
fig, axes = plt.subplots(num_to_plot, 2, figsize=(15, 25))

for i in range(num_to_plot):
    original_data = val_data[i]
    graph_data = graph_val_data[i]
    
    outputs = net.apply(params, RNG_KEY, graph_data)
    recon_data = outputs.output.nodes.T

    original_gp = jnp.ravel(original_data)
    recon_gp = jnp.ravel(recon_data)

    axes[i, 0].plot(X, original_gp)
    axes[i, 1].plot(X, recon_gp)
    
    axes[i, 0].set_title(f'Example {i} (input)')
    axes[i, 1].set_title(f'Example {i} (recon)')

fig.suptitle(f'Input vs Recon\n{model_params_title}', fontsize='xx-large')

plt.tight_layout()
plt.show()

input_v_recon_path = FIG_PATH / 'recon_figures'
input_v_recon_path.mkdir(exist_ok=True)
fig.savefig(input_v_recon_path / f'{model_name}.jpg', dpi=300)

# %%
from functools import partial

decoder_params_keys = [k for k in list(params.keys()) if k.startswith('vgae/decoder')]
decoder_params = {}
for full_key_name in decoder_params_keys:
    key_name = full_key_name.split('/')[-1]  # remove the 'vgae/' prefix
    decoder_params[key_name] = params[full_key_name]
    
GP1D_ARGS.decoder_params = decoder_params

decoder_net_fn = partial(decoder,
                         hidden_fc_dim=ARGS.hidden_fc_dim,
                         hidden_gnn_dim=ARGS.hidden_gnn_dim,
                         output_dim=ARGS.output_dim,
                         dropout_rate=ARGS.dropout_rate,
                         num_nodes=GP1D_ARGS.num_locations)
decoder_net = hk.without_apply_rng(hk.transform(decoder_net_fn))

# %%
def decoder_predictive_model():
    z = numpyro.sample('z', dist.Normal(0, 1).expand([ARGS.latent_dim]))
    vgae_out = jnp.squeeze(decoder_net.apply(GP1D_ARGS.decoder_params, z).nodes)
    numpyro.deterministic('f', vgae_out)

# %%
# Rough comparison of the shape of GP draws with learnt VGAE priors.

# Drawing VGAE priors.
RNG_KEY, vgae_sample_rng = jax.random.split(RNG_KEY)
vgae_draws = Predictive(
  decoder_predictive_model, num_samples=10)(vgae_sample_rng)['f']

# Plotting the GP draws and VGAE draws.
_, ax = plt.subplots(1, 2, figsize=(18, 5))

plotting.plot_gp_draws(X, gp_draws, num_draws_to_plot=5, 
                     ax=ax[0], title='Example of GP priors to encode', y_label='$y=f_{GP}(x)$')

plotting.plot_gp_draws(X, vgae_draws, num_draws_to_plot=5, 
                     ax=ax[1], title='Example of learnt priors using VGAE', y_label='$y=f_{VGAE}(x)$', )

plt.show()

# %%
# Comparing distribution of GP draws with learnt VGAE priors.
RNG_KEY, gp_rng, vgae_rng = jax.random.split(RNG_KEY, 3)

num_samples = 1000
gp_draws = dataset_1dgp.generate_gp_batch(gp_rng, X, 
                                          batch_size=num_samples, 
                                          kernel=GP1D_ARGS.kernel)
vgae_draws = Predictive(decoder_predictive_model, num_samples=num_samples)(vgae_rng)['f']

# Computing the mean and HPDI of the GP draws and VGAE draws.
gp_draws = gp_draws[~np.isnan(gp_draws).any(axis=1), :]
mean_gp = jnp.nanmean(gp_draws, axis=0)
hpdi_gp = hpdi(gp_draws, 0.9)

vgae_draws = vgae_draws[~np.isnan(vgae_draws).any(axis=1), :]
mean_vgae = jnp.nanmean(vgae_draws, axis=0)
hpdi_vgae = hpdi(vgae_draws, 0.9)

# %%
# Plotting the GP draws and VGAE draws.
fig, axes = plt.subplots(1, 2, figsize=(18, 7))

y_lim = [-2, 2]
lines_alpha_gp = 0.1
lines_alpha_vgae = 0.1
num_draws_to_plot = 15
plotting.plot_gp_draws_with_stats(
    X, gp_draws, 
    mean_gp, hpdi_gp,lines_alpha_gp, 
    num_draws_to_plot, y_lim=y_lim, ax=axes[0],
    title='GP priors to encode', y_label='$y=f_{GP}(x)$')
plotting.plot_gp_draws_with_stats(
    X, vgae_draws, mean_vgae, hpdi_vgae,
    lines_alpha_vgae, num_draws_to_plot, 
    y_lim=y_lim, ax=axes[1],
    title='VGAE priors learnt',
    y_label='$y=f_{VGAE}(x)$')

fig.suptitle(f'GP Priors vs Learnt VGAE Priors \n{model_params_title}', fontsize='xx-large')

plt.tight_layout()
plt.show()

estimate_plot_path = FIG_PATH / 'estimate_figures'
estimate_plot_path.mkdir(exist_ok=True)
fig.savefig(estimate_plot_path / f'{model_name}.jpg', dpi=300)

# %%
assert False, 'Inference is turned off'
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# /Users/salmanfaris/Desktop/ds-projects/msc-proj/PriorVGAE/1dGP_priorVGAE_flatten.ipynb Cell 32 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/Users/salmanfaris/Desktop/ds-projects/msc-proj/PriorVGAE/1dGP_priorVGAE_flatten.ipynb#X42sZmlsZQ%3D%3D?line=0'>1</a> assert False, 'Inference is turned off'
#
# AssertionError: Inference is turned off

# %% [markdown]
# # Inference on Observed Data

# %%
def vgae_mcmc_predictive_model(y=None, obs_idx=None):
    z = numpyro.sample('z', dist.Normal(0, 1).expand([ARGS.latent_dim]))
    vgae_out = jnp.squeeze(decoder_net.apply(decoder_params, z).nodes)
    f = numpyro.deterministic('f', vgae_out)
    sigma = numpyro.sample('noise', dist.HalfNormal(0.1))

    if y is None: # at prediction time
        numpyro.sample('y_pred', dist.Normal(f, sigma))
    else: # at inference time
        numpyro.sample('y', dist.Normal(f[obs_idx], sigma), obs=y)

# %%
def run_mcmc(rng, model_mcmc, y, obs_idx, verbose=False):
    start = time.time()
    init_strategy = init_to_median(num_samples=10)
    kernel = NUTS(model_mcmc, init_strategy=init_strategy)
    mcmc = MCMC(
        kernel,
        num_warmup=1000,
        num_samples=1000,
        num_chains=4,
        thinning=1,
        progress_bar=False if 'NUMPYRO_SPHINXBUILD' in os.environ else True,
    )
    mcmc.run(rng, y, obs_idx)
    if verbose:
        mcmc.print_summary(exclude_deterministic=False)
    print('\nMCMC elapsed time:', time.time() - start)

    return mcmc.get_samples()

# %%
RNG_KEY, gp_rng = jax.random.split(RNG_KEY)

# Generate true data and observed dataset to infer
draws = Predictive(dataset_1dgp.gp_predictive_model, num_samples=1)(
  gp_rng, x=X, gp_kernel=GP1D_ARGS.kernel, noise=True)
gp_draw = draws['f'].T  # True data
y_draw = draws['y'].T  # True data + noise

# Choose indices of datapoints for inference.
obs_locations = [
  jnp.array([122, 321]),  # 2 observed datapoints
  jnp.array([126, 133, 296, 370]),  # 4 observed datapoints
  jnp.array([71, 85, 111, 291, 314, 380]),  # 6 observed datapoints
]

# %%
mean_post_preds_list = []
hpdi_post_preds_list = []
obs_xs = []
obs_ys = []
predictions_list = []

RNG_KEY, inference_rng = jax.random.split(RNG_KEY)

for i, obs_location in enumerate(obs_locations):
    mcmc_rng, pred_rng = jax.random.split(jax.random.fold_in(inference_rng, i), 2)
    
    x_obs = X[obs_location]
    y_obs = jnp.squeeze(y_draw[obs_location])
    
    print(f'Running chain for n_obs = {len(obs_location)}')
    mcmc_samples = run_mcmc(mcmc_rng, vgae_mcmc_predictive_model, y_obs, obs_location)

    predictions = Predictive(vgae_mcmc_predictive_model, mcmc_samples)(pred_rng)['f']
    mean_post_pred = jnp.mean(predictions, axis=0)
    hpdi_post_pred = hpdi(predictions, 0.9)
    
    obs_xs.append(x_obs)
    obs_ys.append(y_obs)
    predictions_list.append(predictions)
    mean_post_preds_list.append(mean_post_pred)
    hpdi_post_preds_list.append(hpdi_post_pred)
# Out:
# Running chain for n_obs = 2
# /var/folders/6h/lf5jg1fn1h163zw3042tmtnc0000gn/T/ipykernel_5109/3494085863.py:5: UserWarning: There are not enough devices to run parallel chains: expected 4 but got 1. Chains will be drawn sequentially. If you are running MCMC in CPU, consider using `numpyro.set_host_device_count(4)` at the beginning of your program. You can double-check how many devices are available in your system using `jax.local_device_count()`.
#   mcmc = MCMC(
# sample: 100%|██████████| 2000/2000 [00:05<00:00, 365.89it/s, 31 steps of size 1.11e-01. acc. prob=0.85]
# sample: 100%|██████████| 2000/2000 [00:03<00:00, 657.97it/s, 31 steps of size 1.76e-01. acc. prob=0.70]
# sample: 100%|██████████| 2000/2000 [00:03<00:00, 539.07it/s, 63 steps of size 8.36e-02. acc. prob=0.57]
# sample: 100%|██████████| 2000/2000 [00:04<00:00, 487.64it/s, 63 steps of size 8.19e-02. acc. prob=0.90]
# MCMC elapsed time: 19.02061104774475
# /var/folders/6h/lf5jg1fn1h163zw3042tmtnc0000gn/T/ipykernel_5109/3494085863.py:5: UserWarning: There are not enough devices to run parallel chains: expected 4 but got 1. Chains will be drawn sequentially. If you are running MCMC in CPU, consider using `numpyro.set_host_device_count(4)` at the beginning of your program. You can double-check how many devices are available in your system using `jax.local_device_count()`.
#   mcmc = MCMC(
# Running chain for n_obs = 4
# sample: 100%|██████████| 2000/2000 [00:04<00:00, 446.76it/s, 31 steps of size 1.74e-01. acc. prob=0.90]
# sample: 100%|██████████| 2000/2000 [00:02<00:00, 800.97it/s, 31 steps of size 1.92e-01. acc. prob=0.87]
# sample: 100%|██████████| 2000/2000 [00:02<00:00, 699.06it/s, 31 steps of size 1.39e-01. acc. prob=0.94]
# sample: 100%|██████████| 2000/2000 [00:02<00:00, 726.34it/s, 15 steps of size 1.87e-01. acc. prob=0.85]
# MCMC elapsed time: 13.353949069976807
# /var/folders/6h/lf5jg1fn1h163zw3042tmtnc0000gn/T/ipykernel_5109/3494085863.py:5: UserWarning: There are not enough devices to run parallel chains: expected 4 but got 1. Chains will be drawn sequentially. If you are running MCMC in CPU, consider using `numpyro.set_host_device_count(4)` at the beginning of your program. You can double-check how many devices are available in your system using `jax.local_device_count()`.
#   mcmc = MCMC(
# Running chain for n_obs = 6
# sample: 100%|██████████| 2000/2000 [00:04<00:00, 430.37it/s, 15 steps of size 1.82e-01. acc. prob=0.95]
# sample: 100%|██████████| 2000/2000 [00:02<00:00, 903.23it/s, 15 steps of size 2.30e-01. acc. prob=0.93]
# sample: 100%|██████████| 2000/2000 [00:02<00:00, 876.46it/s, 15 steps of size 2.66e-01. acc. prob=0.89]
# sample: 100%|██████████| 2000/2000 [00:02<00:00, 858.88it/s, 15 steps of size 2.24e-01. acc. prob=0.91]
# MCMC elapsed time: 12.236498355865479

# %%
# Plotting results after inference using MCMC.
_, axes = plt.subplots(nrows=1, ncols=len(obs_locations)+1, figsize=(25,6))

# Plotting VAE prior predictive.
RNG_KEY, prior_rng = jax.random.split(RNG_KEY)
prior_predictions = Predictive(vgae_mcmc_predictive_model, num_samples=10000)(prior_rng)['f']
mean_prior_pred = jnp.mean(prior_predictions, axis=0)
hpdi_prior_pred = hpdi(prior_predictions, 0.9)

num_draws_to_plot = 30
for j in range(num_draws_to_plot):
    axes[0].plot(X, prior_predictions[j], alpha=0.1, color='darkgreen')
axes[0].plot(X, prior_predictions[0], 
             alpha=0.1, color='darkgreen', label='prior draws')  
axes[0].fill_between(X, hpdi_prior_pred[0], hpdi_prior_pred[1], 
                     alpha=0.1, interpolate=True, label='VAE prior: 95% BCI')
axes[0].plot(X, mean_prior_pred, label='mean')
axes[0].set_title('VAE prior')


# Plotting VAE posterior predictive
num_draws_to_plot = 15
for idx in range(len(obs_locations)):
    axes[idx+1].fill_between(X, hpdi_post_preds_list[idx][0], hpdi_post_preds_list[idx][1], 
                           alpha=0.1, interpolate=True, label='VAE posterior: 95% BCI')
    for j in range(num_draws_to_plot): 
        axes[idx+1].plot(X, predictions_list[idx][j], alpha=0.1, color='darkgreen')
    axes[idx+1].plot(X, predictions_list[idx][0],
                   alpha=0.1, color='darkgreen', label='posterior draws')  
    axes[idx+1].plot(X, mean_post_preds_list[idx], label='predicted mean')
    axes[idx+1].plot(X, gp_draw, label='ground truth', color='orange')
    axes[idx+1].scatter(obs_xs[idx], obs_ys[idx], color='red', label='observed data', s=60)
    axes[idx+1].set_title('n_datapoints = ' + str(len(obs_locations[idx])))


for i in range(len(obs_locations)+1):    
    axes[i].legend(loc=4)
    axes[i].set_ylim([-2.5, 2.5])

plt.tight_layout()
plt.show()
