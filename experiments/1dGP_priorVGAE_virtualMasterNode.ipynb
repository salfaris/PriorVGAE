# %%
# %load_ext autoreload
# %autoreload 2

import os
from pathlib import Path
import time
from typing import Tuple, Type

import haiku as hk
import jax
import jax.numpy as jnp
import jraph
import networkx as nx
import matplotlib.pyplot as plt
import numpy as np
import optax

# Numpyro
import numpyro
import numpyro.distributions as dist
from numpyro.infer import MCMC, NUTS, init_to_median, Predictive
from numpyro.diagnostics import hpdi

# Local imports
import loss
import dataset
import dataset_1dgp
import plotting
import model

print(f"JAX version: {jax.__version__}")
print(f"Numpyro version: {numpyro.__version__}")
# Out:
# /Users/salmanfaris/miniforge3/envs/prior-vgae/lib/python3.9/site-packages/jax/_src/lib/__init__.py:34: UserWarning: JAX on Mac ARM machines is experimental and minimally tested. Please see https://github.com/google/jax/issues/5501 in the event of problems.
#   warnings.warn("JAX on Mac ARM machines is experimental and minimally tested. "
# JAX version: 0.3.13
# Numpyro version: 0.9.2

# %%
FIG_PATH = Path('./figures/1DGP_FullyAdjLayer_figures')
FIG_PATH.mkdir(exist_ok=True)

DATASET_PATH = Path('./dataset.nosync')
DATASET_PATH.mkdir(exist_ok=True)

# %%
RNG_SEED = 44
RNG_KEY = jax.random.PRNGKey(RNG_SEED)

# %%
from dataclasses import dataclass
from typing import Dict, Optional, Callable

LossFun = Callable[[jax.numpy.ndarray, jax.numpy.ndarray], jnp.float32]

@dataclass
class GP1DArgs:
  kernel: Callable = dataset_1dgp.exp_sq_kernel
  num_locations: int = 400
  
@dataclass
class Args:  
  # Training params
  loss_fn: LossFun = loss.compute_mse_loss
  epochs: int = 500_000
  eval_frequency: int = 1000
  learning_rate: float = 1e-3
  beta: float = 1e-2  # beta-VAE
  
  # Model params
  hidden_gnn_dim: int = 3
  hidden_fc_dim: int = 50
  latent_dim: int = 30
  output_dim: int = 1
  act_fn: Callable = jax.nn.elu

GP1D_ARGS = GP1DArgs()
ARGS = Args()

# %%
model_name = (
    f'PriorVGAE_FullyAdjLayer_1DGP_lr{ARGS.learning_rate}_epochs{ARGS.epochs}_'
    f'beta{ARGS.beta}_gnn{ARGS.hidden_gnn_dim}_fc{ARGS.hidden_fc_dim}_z{ARGS.latent_dim}_'
    f'numLocations{GP1D_ARGS.num_locations}'
)

model_params_title = (
    '('
    f'epochs = {plotting.convert_to_string_int(ARGS.epochs)}, '
    f'lr = {ARGS.learning_rate}, '
    f'act_fn = {jax.nn.elu.__name__}, '
    rf'$\beta = {ARGS.beta}$, '
    f'\ngnn_dim = {ARGS.hidden_gnn_dim},  fc_dim = {ARGS.hidden_fc_dim},  z_dim = {ARGS.latent_dim}'
    f'\n num_loc = {GP1D_ARGS.num_locations}'
    ')'
)

print(model_name)
# Out:
# PriorVGAE_FullyAdjLayer_1DGP_lr0.001_epochs500000_beta0.01_gnn3_fc50_z30_numLocations400

# %% [markdown]
# # Dataset: GP priors to be encoded

# %%
# GP priors to encode
X = jnp.arange(0, 1, 1/GP1D_ARGS.num_locations)

num_to_plot = 10
gp_draws = dataset_1dgp.generate_gp_batch(RNG_KEY, 
                                          X, 
                                          batch_size=num_to_plot,
                                          kernel=GP1D_ARGS.kernel)

plotting.plot_gp_draws(
    X, gp_draws,
    num_draws_to_plot=num_to_plot,
    title='Example of GP priors to encode', 
    x_label='$x$', 
    y_label='$y=f_{GP}(x)$',
)

# %% [markdown]
# # Building the model

# %%
data_filepath = DATASET_PATH / f'1DGP_numLoc{GP1D_ARGS.num_locations}_1M_train_data.npy'

OVERRIDE_SAVE = False

# Initial RNG_KEY seed is 44.
RNG_KEY, data_rng = jax.random.split(RNG_KEY)
if data_filepath.exists() and not OVERRIDE_SAVE:
    print(f"Loading dataset from {data_filepath}")
    data = np.load(data_filepath)
else:
    num_samples = 1_000_000
    data = dataset_1dgp.generate_gp_batch(data_rng, X, 
                                          batch_size=num_samples, 
                                          kernel=GP1D_ARGS.kernel)
    print(f"Saving dataset to {data_filepath}")
    np.save(data_filepath, np.asarray(data))
# Out:
# Loading dataset from dataset.nosync/1DGP_numLoc400_1M_train_data.npy

# %%
# Remove NaNs from dataset
data = data[~np.isnan(data).any(axis=1), :]

train_size_limit = 700_000
val_size = 11_000  # + 1000 for the final epoch evaluation and batching

# train_data = data[:train_size_limit]
train_data = data[:]
val_data = data[train_size_limit:train_size_limit+val_size]

# %%
BASE_GRAPH = dataset_1dgp.create_1dgp_graph(GP1D_ARGS.num_locations)

graph_train_data = [BASE_GRAPH._replace(nodes=nodes.reshape(-1, 1)) for nodes in train_data]
graph_val_data = [BASE_GRAPH._replace(nodes=nodes.reshape(-1, 1)) for nodes in val_data]

# %% [markdown]
# Comment: Removing linear (hidden_fc) before latent hidden layer makes samples even NOISIER

# %%
# _, ax = plt.subplots(1, 2, figsize=(15, 7))
# n = GP1D_ARGS.num_locations
# G = nx.path_graph(n)
# nx.draw(G, with_labels=True, node_size=10, ax=ax[0])


# m = len(G)
# radius = 15
# print(m // radius)


# new_edges_0 = [(0, 0+i) for i in range(1, m // radius)]
# G.add_edges_from(new_edges_0)

# new_edges_m = [(m-1, m-1-i) for i in range(1, m // radius)]
# G.add_edges_from(new_edges_m)

# nx.draw(G, with_labels=True, node_size=10, ax=ax[1])

# %%
_, ax = plt.subplots(1, 2, figsize=(15, 7))
n = GP1D_ARGS.num_locations
G = nx.path_graph(n)
nx.draw(G, with_labels=True, node_size=10, ax=ax[0])


m = len(G)
G.add_edge(0, m-1)

nx.draw(G, with_labels=True, node_size=10, ax=ax[1])

# %%
G_adj = nx.to_numpy_array(G)
COMPLETE_GRAPH = dataset.create_grid_graph(G_adj)

# %%
from functools import partial
from model import VGAEOutput
import layer

class VGAE(hk.Module):
    """VGAE network definition."""

    def __init__(
        self,
        hidden_gnn_dim: int,
        hidden_fc_dim: int,
        latent_dim: int,
        output_dim: int,
        num_nodes: int,
    ):
        super().__init__()
        self._hidden_gnn_dim = hidden_gnn_dim
        self._hidden_fc_dim = hidden_fc_dim
        self._latent_dim = latent_dim
        self._output_dim = output_dim
        self._num_nodes = num_nodes
        self.act = ARGS.act_fn

    def __call__(self, graph: jraph.GraphsTuple) -> VGAEOutput:
        mean, log_std = encoder(
            graph,
            self._hidden_gnn_dim,
            self._hidden_fc_dim,
            self._latent_dim,
            self._num_nodes,
            self.act,
        )

        std = jnp.exp(log_std)
        z = mean + std * jax.random.normal(hk.next_rng_key(), mean.shape)

        output = decoder(
            z,
            self._hidden_fc_dim,
            self._hidden_gnn_dim,
            self._output_dim,
            self._num_nodes,
            self.act
        )

        return VGAEOutput(mean, log_std, output)


def encoder(
        graph: jraph.GraphsTuple,
        hidden_gnn_dim: int,
        hidden_fc_dim: int,
        latent_dim: int,
        num_nodes: int,
        act_fn: Callable = jax.nn.elu) -> Tuple[jnp.ndarray, jnp.ndarray]:
    
    # Graph layer
    gn = jraph.GraphConvolution(
        update_node_fn=hk.Sequential([
            hk.Linear(hidden_gnn_dim), act_fn,
        ]),
        add_self_edges=False,
    )
    graph = gn(graph)
    
    # Fully adjacent layer
    graph = COMPLETE_GRAPH._replace(nodes=graph.nodes)
    
    gn = jraph.GraphConvolution(
        update_node_fn=hk.Sequential([
            hk.Linear(hidden_gnn_dim), act_fn,
        ]),
        add_self_edges=False,
    )
    graph = gn(graph)
    
    # Fully-connected layer
    x = graph.nodes.reshape(1, num_nodes, hidden_gnn_dim)
    x = hk.Flatten()(x)  # dim: (1, num_nodes*hidden_gnn_dim)
    
    # x = hk.Linear(hidden_fc_dim)(x)
    # x = act_fn(x)
    
    # No activation
    mean = hk.Linear(latent_dim, name='mean')(x)
    log_std = hk.Linear(latent_dim, name='log_std')(x)
    return mean, log_std


def decoder(
        z: jnp.ndarray,
        hidden_fc_dim: int,
        hidden_gnn_dim: int,
        output_dim: int,
        num_nodes: int,
        act_fn: Callable = jax.nn.elu) -> jraph.GraphsTuple:
    
    z = hk.Linear(num_nodes*hidden_gnn_dim,
                  name='decoder_hidden2_fc')(z)  # (1, num_nodes*hidden_gnn_dim)
    z = act_fn(z)
    
    # Reshape to jraph.batch format: (num_nodes, hidden_gnn_dim)
    z = z.reshape((num_nodes, hidden_gnn_dim))
    graph = BASE_GRAPH._replace(nodes=z)

    gn = layer.GraphConvolutionSharpening(
        update_node_fn=hk.Sequential([
            hk.Linear(hidden_gnn_dim, name='decoder_hidden_gnn1'), act_fn,
        ]),
        add_self_edges=False,
    )
    graph = gn(graph)
    
    # Fully adjacent layer
    graph = COMPLETE_GRAPH._replace(nodes=graph.nodes)
    
    gn = layer.GraphConvolutionSharpening(
        update_node_fn=hk.Sequential([
            hk.Linear(hidden_gnn_dim, name='decoder_hidden_gnn2'), act_fn,
        ]),
        add_self_edges=False,
    )
    graph = gn(graph)
    
    # # Graph normalization
    # NOTE :- Graph normalization on the decoder yields a shrinked GP.
    # # graph = layer.GraphwiseLayerNorm()(graph)
    
    # No activation
    gn = layer.GraphConvolutionSharpening(
        update_node_fn=hk.Linear(output_dim, name='decoder_output'),
        add_self_edges=False,
    )
    graph = gn(graph)


    return graph

# %%
extend_model_params_title = True
    
extension_string = 'using_GAT = False, add_self_edges = True'

if extend_model_params_title:
    model_params_title = model_params_title[:-1] + ', ' + extension_string

# %% [markdown]
# # Training time

# %%
# Initialize network and optimizer.
net = hk.transform(
  lambda x: VGAE(hidden_gnn_dim=ARGS.hidden_gnn_dim,
                 hidden_fc_dim=ARGS.hidden_fc_dim,
                 latent_dim=ARGS.latent_dim, 
                 output_dim=ARGS.output_dim,
                 num_nodes=GP1D_ARGS.num_locations)(x))

# %% [markdown]
# ## Training optimizer

# %%
# optimizer = optax.adam(ARGS.learning_rate)

scheduler = optax.exponential_decay(
    init_value=ARGS.learning_rate,
    transition_steps=2000,
    decay_rate=0.99,
)

# Combining gradient transforms using `optax.chain`
optimizer = optax.chain(
    optax.clip_by_global_norm(1.0),  # Clip by the gradient by the global norm.
    optax.scale_by_adam(),  # Use the updates from adam.
    optax.scale_by_schedule(scheduler),  # Use the learning rate from the scheduler.
    # Scale updates by -1 since optax.apply_updates is additive and we want to descend on the loss.
    optax.scale(-1.0)
)

# %% [markdown]
# ### Loss function and update

# %%
@jax.jit
def loss_fn(
    params: hk.Params, 
    rng_key: jnp.ndarray,
    graph: jraph.GraphsTuple,
) -> jnp.ndarray:
  """Computes VGAE loss."""
  log_likelihood_loss_fn = ARGS.loss_fn
  
  outputs: VGAEOutput = net.apply(params, rng_key, graph)
  log_likelihood = -log_likelihood_loss_fn(outputs.output.nodes, graph.nodes)
  kld = jnp.mean(loss.compute_kl_gaussian(outputs.mean, outputs.log_std), axis=-1)
  elbo = (1.0/ARGS.beta)*log_likelihood - kld
  
  return -elbo, kld
  
@jax.jit
def update(
    params: hk.Params,
    rng_key: jnp.ndarray,
    opt_state: optax.OptState,
    graph: jraph.GraphsTuple,
):
  """Updates the parameters of the network."""
  grads, _ = jax.grad(loss_fn, has_aux=True)(params, rng_key, graph)
  updates, new_opt_state = optimizer.update(grads, opt_state)
  new_params = optax.apply_updates(params, updates)
  return new_params, new_opt_state

# %% [markdown]
# ### Initialize net and optimizer

# %%
# Initialize net with an arbitrary graph
RNG_KEY, params_rng = jax.random.split(RNG_KEY)

init_graph = graph_train_data[0]
params = net.init(params_rng, init_graph)
opt_state = optimizer.init(params)

# %%
RNG_KEY, train_rng = jax.random.split(RNG_KEY)

train_losses = []
val_losses = []
train_klds = []
val_klds = []

train_size = len(graph_train_data)
val_size = len(graph_val_data)

eval_counter: int = 0

training_start_time = time.time()
print('using: ', ARGS.loss_fn)
for epoch in range(ARGS.epochs):
  update_rng = jax.random.fold_in(train_rng, epoch)

  train_graph_batch = graph_train_data[epoch % train_size]
  params, opt_state = update(params, update_rng, opt_state, train_graph_batch)
    
  if epoch % ARGS.eval_frequency == 0 or epoch == (ARGS.epochs - 1):
    evaluate_rng = jax.random.fold_in(update_rng, epoch)
    train_loss_rng, eval_loss_rng = jax.random.split(evaluate_rng)
    
    train_loss, train_kld = loss_fn(params, train_loss_rng, train_graph_batch)
    
    val_graph_batch = graph_val_data[eval_counter]
    val_loss, val_kld = loss_fn(params, eval_loss_rng, val_graph_batch)
    
    print(f'{time.strftime("%H:%M:%S", time.localtime())} STEP: {epoch}; '
          f'Train loss: {train_loss:.3f}; Validation loss: {val_loss:.3f}; '
          # f'Train kld: {train_kld:.3f}; Validation kld: {val_kld:.3f}'
    )
      
    train_losses.append(train_loss.item())
    val_losses.append(val_loss.item())
    train_klds.append(train_kld.item())
    val_klds.append(val_kld.item())
    
    eval_counter += 1

training_end_time = time.time() - training_start_time
print(f'Training took: ({training_end_time:.3f} secs; equivalently {training_end_time/60:.3f} mins)')
# Out:
# using:  <function compute_mse_loss at 0x1583340d0>
# 20:25:27 STEP: 0; Train loss: 78.145; Validation loss: 163.707;
# 20:25:27 STEP: 1000; Train loss: 14.928; Validation loss: 18.625;
# 20:25:28 STEP: 2000; Train loss: 14.513; Validation loss: 18.791;
# 20:25:29 STEP: 3000; Train loss: 15.324; Validation loss: 14.601;
# 20:25:29 STEP: 4000; Train loss: 15.063; Validation loss: 10.723;
# 20:25:30 STEP: 5000; Train loss: 14.533; Validation loss: 19.162;
# 20:25:31 STEP: 6000; Train loss: 7.920; Validation loss: 25.519;
# 20:25:31 STEP: 7000; Train loss: 12.259; Validation loss: 27.714;
# 20:25:32 STEP: 8000; Train loss: 20.975; Validation loss: 7.527;
# 20:25:33 STEP: 9000; Train loss: 11.545; Validation loss: 14.985;
# 20:25:33 STEP: 10000; Train loss: 6.243; Validation loss: 19.405;
# 20:25:34 STEP: 11000; Train loss: 19.482; Validation loss: 9.638;
# 20:25:35 STEP: 12000; Train loss: 11.412; Validation loss: 12.182;
# 20:25:35 STEP: 13000; Train loss: 10.183; Validation loss: 9.376;
# 20:25:36 STEP: 14000; Train loss: 14.525; Validation loss: 6.658;
# 20:25:37 STEP: 15000; Train loss: 13.220; Validation loss: 11.626;
# 20:25:37 STEP: 16000; Train loss: 19.093; Validation loss: 16.909;
# 20:25:38 STEP: 17000; Train loss: 12.096; Validation loss: 15.842;
# 20:25:39 STEP: 18000; Train loss: 22.201; Validation loss: 6.305;
# 20:25:39 STEP: 19000; Train loss: 16.730; Validation loss: 15.360;
# 20:25:40 STEP: 20000; Train loss: 12.301; Validation loss: 9.415;
# 20:25:41 STEP: 21000; Train loss: 13.375; Validation loss: 15.668;
# 20:25:41 STEP: 22000; Train loss: 12.302; Validation loss: 9.993;
# 20:25:42 STEP: 23000; Train loss: 18.721; Validation loss: 16.167;
# 20:25:43 STEP: 24000; Train loss: 18.540; Validation loss: 9.958;
# 20:25:44 STEP: 25000; Train loss: 16.764; Validation loss: 22.461;
# 20:25:44 STEP: 26000; Train loss: 7.832; Validation loss: 10.769;
# 20:25:45 STEP: 27000; Train loss: 11.332; Validation loss: 13.392;
# 20:25:46 STEP: 28000; Train loss: 20.323; Validation loss: 14.211;
# 20:25:46 STEP: 29000; Train loss: 8.710; Validation loss: 14.873;
# 20:25:47 STEP: 30000; Train loss: 13.285; Validation loss: 6.573;
# 20:25:48 STEP: 31000; Train loss: 14.123; Validation loss: 7.622;
# 20:25:48 STEP: 32000; Train loss: 16.250; Validation loss: 20.069;
# 20:25:49 STEP: 33000; Train loss: 9.168; Validation loss: 23.433;
# 20:25:50 STEP: 34000; Train loss: 17.092; Validation loss: 4.577;
# 20:25:50 STEP: 35000; Train loss: 13.545; Validation loss: 36.439;
# 20:25:51 STEP: 36000; Train loss: 9.097; Validation loss: 9.720;
# 20:25:52 STEP: 37000; Train loss: 14.295; Validation loss: 17.138;
# 20:25:52 STEP: 38000; Train loss: 10.291; Validation loss: 7.881;
# 20:25:53 STEP: 39000; Train loss: 11.903; Validation loss: 7.184;
# 20:25:54 STEP: 40000; Train loss: 13.667; Validation loss: 9.220;
# 20:25:54 STEP: 41000; Train loss: 11.218; Validation loss: 21.708;
# 20:25:55 STEP: 42000; Train loss: 10.782; Validation loss: 9.111;
# 20:25:56 STEP: 43000; Train loss: 7.206; Validation loss: 12.283;
# 20:25:56 STEP: 44000; Train loss: 7.825; Validation loss: 10.031;
# 20:25:57 STEP: 45000; Train loss: 12.645; Validation loss: 20.335;
# 20:25:57 STEP: 46000; Train loss: 12.652; Validation loss: 15.237;
# 20:25:58 STEP: 47000; Train loss: 13.382; Validation loss: 11.413;
# 20:25:59 STEP: 48000; Train loss: 13.652; Validation loss: 7.669;
# 20:25:59 STEP: 49000; Train loss: 27.670; Validation loss: 12.292;
# 20:26:00 STEP: 50000; Train loss: 8.776; Validation loss: 11.032;
# 20:26:01 STEP: 51000; Train loss: 10.555; Validation loss: 16.592;
# 20:26:01 STEP: 52000; Train loss: 9.009; Validation loss: 5.623;
# 20:26:02 STEP: 53000; Train loss: 10.671; Validation loss: 16.908;
# 20:26:03 STEP: 54000; Train loss: 7.791; Validation loss: 14.693;
# 20:26:03 STEP: 55000; Train loss: 14.566; Validation loss: 12.703;
# 20:26:04 STEP: 56000; Train loss: 7.159; Validation loss: 14.819;
# 20:26:05 STEP: 57000; Train loss: 24.348; Validation loss: 12.032;
# 20:26:05 STEP: 58000; Train loss: 8.822; Validation loss: 6.389;
# 20:26:06 STEP: 59000; Train loss: 6.625; Validation loss: 10.810;
# 20:26:07 STEP: 60000; Train loss: 21.573; Validation loss: 6.475;
# 20:26:07 STEP: 61000; Train loss: 8.477; Validation loss: 7.509;
# 20:26:08 STEP: 62000; Train loss: 11.925; Validation loss: 12.157;
# 20:26:09 STEP: 63000; Train loss: 10.680; Validation loss: 20.969;
# 20:26:09 STEP: 64000; Train loss: 10.294; Validation loss: 9.641;
# 20:26:10 STEP: 65000; Train loss: 10.899; Validation loss: 17.815;
# 20:26:11 STEP: 66000; Train loss: 7.119; Validation loss: 11.555;
# 20:26:11 STEP: 67000; Train loss: 13.791; Validation loss: 11.359;
# 20:26:12 STEP: 68000; Train loss: 7.821; Validation loss: 7.110;
# 20:26:13 STEP: 69000; Train loss: 9.600; Validation loss: 10.037;
# 20:26:13 STEP: 70000; Train loss: 12.759; Validation loss: 15.931;
# 20:26:14 STEP: 71000; Train loss: 9.864; Validation loss: 16.586;
# 20:26:15 STEP: 72000; Train loss: 34.118; Validation loss: 30.344;
# 20:26:15 STEP: 73000; Train loss: 10.254; Validation loss: 12.793;
# 20:26:16 STEP: 74000; Train loss: 17.342; Validation loss: 10.183;
# 20:26:17 STEP: 75000; Train loss: 16.310; Validation loss: 9.890;
# 20:26:17 STEP: 76000; Train loss: 7.430; Validation loss: 6.849;
# 20:26:18 STEP: 77000; Train loss: 9.455; Validation loss: 11.098;
# 20:26:18 STEP: 78000; Train loss: 12.418; Validation loss: 7.970;
# 20:26:19 STEP: 79000; Train loss: 6.412; Validation loss: 11.847;
# 20:26:20 STEP: 80000; Train loss: 11.373; Validation loss: 10.367;
# 20:26:21 STEP: 81000; Train loss: 25.858; Validation loss: 12.114;
# 20:26:21 STEP: 82000; Train loss: 16.542; Validation loss: 11.257;
# 20:26:22 STEP: 83000; Train loss: 13.192; Validation loss: 14.105;
# 20:26:23 STEP: 84000; Train loss: 6.062; Validation loss: 8.060;
# 20:26:23 STEP: 85000; Train loss: 10.874; Validation loss: 10.155;
# 20:26:24 STEP: 86000; Train loss: 6.935; Validation loss: 14.050;
# 20:26:25 STEP: 87000; Train loss: 15.575; Validation loss: 9.500;
# 20:26:25 STEP: 88000; Train loss: 21.685; Validation loss: 12.478;
# 20:26:26 STEP: 89000; Train loss: 19.778; Validation loss: 6.852;
# 20:26:27 STEP: 90000; Train loss: 30.440; Validation loss: 12.891;
# 20:26:27 STEP: 91000; Train loss: 9.494; Validation loss: 14.420;
# 20:26:28 STEP: 92000; Train loss: 16.887; Validation loss: 8.483;
# 20:26:29 STEP: 93000; Train loss: 9.559; Validation loss: 18.059;
# 20:26:29 STEP: 94000; Train loss: 9.007; Validation loss: 13.635;
# 20:26:30 STEP: 95000; Train loss: 17.023; Validation loss: 10.298;
# 20:26:31 STEP: 96000; Train loss: 10.001; Validation loss: 19.739;
# 20:26:31 STEP: 97000; Train loss: 7.021; Validation loss: 6.956;
# 20:26:32 STEP: 98000; Train loss: 16.384; Validation loss: 8.796;
# 20:26:32 STEP: 99000; Train loss: 10.143; Validation loss: 8.524;
# 20:26:33 STEP: 100000; Train loss: 32.316; Validation loss: 10.592;
# 20:26:34 STEP: 101000; Train loss: 10.111; Validation loss: 8.924;
# 20:26:35 STEP: 102000; Train loss: 8.825; Validation loss: 9.272;
# 20:26:35 STEP: 103000; Train loss: 8.083; Validation loss: 7.564;
# 20:26:36 STEP: 104000; Train loss: 7.428; Validation loss: 10.691;
# 20:26:37 STEP: 105000; Train loss: 11.455; Validation loss: 7.950;
# 20:26:37 STEP: 106000; Train loss: 6.233; Validation loss: 12.091;
# 20:26:38 STEP: 107000; Train loss: 10.791; Validation loss: 17.472;
# 20:26:39 STEP: 108000; Train loss: 10.486; Validation loss: 9.219;
# 20:26:39 STEP: 109000; Train loss: 6.657; Validation loss: 9.206;
# 20:26:40 STEP: 110000; Train loss: 18.429; Validation loss: 23.941;
# 20:26:40 STEP: 111000; Train loss: 20.864; Validation loss: 10.281;
# 20:26:41 STEP: 112000; Train loss: 17.419; Validation loss: 11.591;
# 20:26:42 STEP: 113000; Train loss: 13.538; Validation loss: 24.292;
# 20:26:42 STEP: 114000; Train loss: 18.074; Validation loss: 13.584;
# 20:26:43 STEP: 115000; Train loss: 6.393; Validation loss: 12.657;
# 20:26:44 STEP: 116000; Train loss: 18.251; Validation loss: 15.387;
# 20:26:44 STEP: 117000; Train loss: 13.730; Validation loss: 14.222;
# 20:26:45 STEP: 118000; Train loss: 12.357; Validation loss: 10.096;
# 20:26:46 STEP: 119000; Train loss: 14.889; Validation loss: 7.348;
# 20:26:46 STEP: 120000; Train loss: 10.201; Validation loss: 10.602;
# 20:26:47 STEP: 121000; Train loss: 9.956; Validation loss: 12.357;
# 20:26:48 STEP: 122000; Train loss: 12.985; Validation loss: 10.568;
# 20:26:48 STEP: 123000; Train loss: 7.837; Validation loss: 15.500;
# 20:26:49 STEP: 124000; Train loss: 13.072; Validation loss: 8.079;
# 20:26:50 STEP: 125000; Train loss: 14.650; Validation loss: 7.575;
# 20:26:51 STEP: 126000; Train loss: 9.160; Validation loss: 8.768;
# 20:26:51 STEP: 127000; Train loss: 13.226; Validation loss: 10.514;
# 20:26:52 STEP: 128000; Train loss: 9.733; Validation loss: 22.248;
# 20:26:53 STEP: 129000; Train loss: 6.051; Validation loss: 11.968;
# 20:26:53 STEP: 130000; Train loss: 18.002; Validation loss: 12.238;
# 20:26:54 STEP: 131000; Train loss: 8.747; Validation loss: 11.201;
# 20:26:54 STEP: 132000; Train loss: 16.733; Validation loss: 6.512;
# 20:26:55 STEP: 133000; Train loss: 9.303; Validation loss: 12.055;
# 20:26:56 STEP: 134000; Train loss: 11.136; Validation loss: 9.042;
# 20:26:56 STEP: 135000; Train loss: 6.417; Validation loss: 39.563;
# 20:26:57 STEP: 136000; Train loss: 23.878; Validation loss: 11.497;
# 20:26:58 STEP: 137000; Train loss: 12.553; Validation loss: 21.754;
# 20:26:58 STEP: 138000; Train loss: 11.424; Validation loss: 11.223;
# 20:26:59 STEP: 139000; Train loss: 11.064; Validation loss: 8.095;
# 20:27:00 STEP: 140000; Train loss: 20.976; Validation loss: 9.964;
# 20:27:00 STEP: 141000; Train loss: 7.131; Validation loss: 9.833;
# 20:27:01 STEP: 142000; Train loss: 9.053; Validation loss: 15.781;
# 20:27:02 STEP: 143000; Train loss: 9.928; Validation loss: 6.937;
# 20:27:02 STEP: 144000; Train loss: 11.410; Validation loss: 12.606;
# 20:27:03 STEP: 145000; Train loss: 6.790; Validation loss: 13.665;
# 20:27:03 STEP: 146000; Train loss: 20.516; Validation loss: 10.081;
# 20:27:04 STEP: 147000; Train loss: 8.376; Validation loss: 18.706;
# 20:27:05 STEP: 148000; Train loss: 12.438; Validation loss: 20.221;
# 20:27:05 STEP: 149000; Train loss: 11.957; Validation loss: 15.834;
# 20:27:06 STEP: 150000; Train loss: 14.350; Validation loss: 6.857;
# 20:27:07 STEP: 151000; Train loss: 17.364; Validation loss: 7.967;
# 20:27:07 STEP: 152000; Train loss: 9.748; Validation loss: 12.099;
# 20:27:08 STEP: 153000; Train loss: 10.059; Validation loss: 8.001;
# 20:27:09 STEP: 154000; Train loss: 8.868; Validation loss: 10.966;
# 20:27:09 STEP: 155000; Train loss: 8.790; Validation loss: 9.846;
# 20:27:10 STEP: 156000; Train loss: 5.689; Validation loss: 8.007;
# 20:27:10 STEP: 157000; Train loss: 16.308; Validation loss: 12.019;
# 20:27:11 STEP: 158000; Train loss: 10.441; Validation loss: 12.852;
# 20:27:12 STEP: 159000; Train loss: 19.816; Validation loss: 9.507;
# 20:27:12 STEP: 160000; Train loss: 11.537; Validation loss: 16.884;
# 20:27:13 STEP: 161000; Train loss: 14.248; Validation loss: 19.987;
# 20:27:14 STEP: 162000; Train loss: 12.697; Validation loss: 12.733;
# 20:27:14 STEP: 163000; Train loss: 9.919; Validation loss: 11.044;
# 20:27:15 STEP: 164000; Train loss: 10.730; Validation loss: 13.898;
# 20:27:16 STEP: 165000; Train loss: 7.752; Validation loss: 6.669;
# 20:27:16 STEP: 166000; Train loss: 5.675; Validation loss: 45.506;
# 20:27:17 STEP: 167000; Train loss: 14.078; Validation loss: 11.663;
# 20:27:17 STEP: 168000; Train loss: 8.678; Validation loss: 7.037;
# 20:27:18 STEP: 169000; Train loss: 6.979; Validation loss: 7.014;
# 20:27:19 STEP: 170000; Train loss: 7.908; Validation loss: 24.113;
# 20:27:19 STEP: 171000; Train loss: 14.681; Validation loss: 7.207;
# 20:27:20 STEP: 172000; Train loss: 7.485; Validation loss: 12.724;
# 20:27:21 STEP: 173000; Train loss: 15.454; Validation loss: 18.354;
# 20:27:21 STEP: 174000; Train loss: 13.537; Validation loss: 12.120;
# 20:27:22 STEP: 175000; Train loss: 9.722; Validation loss: 14.228;
# 20:27:23 STEP: 176000; Train loss: 25.769; Validation loss: 16.747;
# 20:27:23 STEP: 177000; Train loss: 18.249; Validation loss: 12.997;
# 20:27:24 STEP: 178000; Train loss: 12.293; Validation loss: 9.504;
# 20:27:24 STEP: 179000; Train loss: 21.627; Validation loss: 9.661;
# 20:27:25 STEP: 180000; Train loss: 14.398; Validation loss: 14.336;
# 20:27:26 STEP: 181000; Train loss: 23.439; Validation loss: 11.391;
# 20:27:26 STEP: 182000; Train loss: 15.259; Validation loss: 12.893;
# 20:27:27 STEP: 183000; Train loss: 5.275; Validation loss: 8.037;
# 20:27:28 STEP: 184000; Train loss: 12.120; Validation loss: 14.108;
# 20:27:28 STEP: 185000; Train loss: 11.638; Validation loss: 9.722;
# 20:27:29 STEP: 186000; Train loss: 13.096; Validation loss: 11.330;
# 20:27:30 STEP: 187000; Train loss: 11.618; Validation loss: 7.637;
# 20:27:30 STEP: 188000; Train loss: 10.068; Validation loss: 13.483;
# 20:27:31 STEP: 189000; Train loss: 11.828; Validation loss: 10.440;
# 20:27:31 STEP: 190000; Train loss: 14.711; Validation loss: 59.381;
# 20:27:32 STEP: 191000; Train loss: 10.775; Validation loss: 25.384;
# 20:27:33 STEP: 192000; Train loss: 17.978; Validation loss: 12.527;
# 20:27:33 STEP: 193000; Train loss: 35.206; Validation loss: 7.849;
# 20:27:34 STEP: 194000; Train loss: 7.685; Validation loss: 19.266;
# 20:27:35 STEP: 195000; Train loss: 27.136; Validation loss: 7.438;
# 20:27:35 STEP: 196000; Train loss: 19.064; Validation loss: 13.655;
# 20:27:36 STEP: 197000; Train loss: 9.602; Validation loss: 12.631;
# 20:27:37 STEP: 198000; Train loss: 16.368; Validation loss: 7.704;
# 20:27:37 STEP: 199000; Train loss: 17.332; Validation loss: 14.570;
# 20:27:38 STEP: 200000; Train loss: 23.589; Validation loss: 7.071;
# 20:27:38 STEP: 201000; Train loss: 9.106; Validation loss: 12.182;
# 20:27:39 STEP: 202000; Train loss: 10.294; Validation loss: 9.779;
# 20:27:40 STEP: 203000; Train loss: 9.499; Validation loss: 12.579;
# 20:27:40 STEP: 204000; Train loss: 9.490; Validation loss: 7.056;
# 20:27:41 STEP: 205000; Train loss: 15.949; Validation loss: 6.913;
# 20:27:42 STEP: 206000; Train loss: 10.673; Validation loss: 9.658;
# 20:27:42 STEP: 207000; Train loss: 15.162; Validation loss: 33.366;
# 20:27:43 STEP: 208000; Train loss: 22.125; Validation loss: 8.752;
# 20:27:44 STEP: 209000; Train loss: 7.540; Validation loss: 18.395;
# 20:27:44 STEP: 210000; Train loss: 7.075; Validation loss: 10.959;
# 20:27:45 STEP: 211000; Train loss: 18.033; Validation loss: 11.915;
# 20:27:45 STEP: 212000; Train loss: 8.314; Validation loss: 9.163;
# 20:27:46 STEP: 213000; Train loss: 13.383; Validation loss: 11.162;
# 20:27:47 STEP: 214000; Train loss: 15.008; Validation loss: 9.667;
# 20:27:47 STEP: 215000; Train loss: 6.562; Validation loss: 11.449;
# 20:27:48 STEP: 216000; Train loss: 13.049; Validation loss: 13.386;
# 20:27:49 STEP: 217000; Train loss: 10.430; Validation loss: 13.593;
# 20:27:49 STEP: 218000; Train loss: 18.563; Validation loss: 7.562;
# 20:27:50 STEP: 219000; Train loss: 8.144; Validation loss: 11.840;
# 20:27:50 STEP: 220000; Train loss: 21.973; Validation loss: 9.434;
# 20:27:51 STEP: 221000; Train loss: 11.733; Validation loss: 11.291;
# 20:27:52 STEP: 222000; Train loss: 10.808; Validation loss: 21.801;
# 20:27:52 STEP: 223000; Train loss: 7.685; Validation loss: 23.656;
# 20:27:53 STEP: 224000; Train loss: 9.758; Validation loss: 36.641;
# 20:27:54 STEP: 225000; Train loss: 29.984; Validation loss: 10.180;
# 20:27:54 STEP: 226000; Train loss: 7.992; Validation loss: 9.731;
# 20:27:55 STEP: 227000; Train loss: 7.522; Validation loss: 8.059;
# 20:27:56 STEP: 228000; Train loss: 10.466; Validation loss: 8.220;
# 20:27:56 STEP: 229000; Train loss: 12.245; Validation loss: 8.268;
# 20:27:57 STEP: 230000; Train loss: 16.613; Validation loss: 6.916;
# 20:27:57 STEP: 231000; Train loss: 9.309; Validation loss: 7.584;
# 20:27:58 STEP: 232000; Train loss: 11.805; Validation loss: 13.139;
# 20:27:59 STEP: 233000; Train loss: 18.521; Validation loss: 15.776;
# 20:27:59 STEP: 234000; Train loss: 6.443; Validation loss: 9.529;
# 20:28:00 STEP: 235000; Train loss: 18.000; Validation loss: 13.003;
# 20:28:01 STEP: 236000; Train loss: 20.241; Validation loss: 11.977;
# 20:28:01 STEP: 237000; Train loss: 6.750; Validation loss: 10.995;
# 20:28:02 STEP: 238000; Train loss: 10.735; Validation loss: 9.916;
# 20:28:03 STEP: 239000; Train loss: 19.973; Validation loss: 14.977;
# 20:28:03 STEP: 240000; Train loss: 12.078; Validation loss: 15.790;
# 20:28:04 STEP: 241000; Train loss: 13.367; Validation loss: 10.376;
# 20:28:05 STEP: 242000; Train loss: 11.523; Validation loss: 10.454;
# 20:28:05 STEP: 243000; Train loss: 13.277; Validation loss: 9.226;
# 20:28:06 STEP: 244000; Train loss: 11.949; Validation loss: 6.925;
# 20:28:06 STEP: 245000; Train loss: 11.050; Validation loss: 5.570;
# 20:28:07 STEP: 246000; Train loss: 16.382; Validation loss: 11.654;
# 20:28:08 STEP: 247000; Train loss: 7.333; Validation loss: 13.612;
# 20:28:08 STEP: 248000; Train loss: 14.358; Validation loss: 9.784;
# 20:28:09 STEP: 249000; Train loss: 19.627; Validation loss: 11.622;
# 20:28:10 STEP: 250000; Train loss: 11.775; Validation loss: 25.797;
# 20:28:10 STEP: 251000; Train loss: 10.878; Validation loss: 11.639;
# 20:28:11 STEP: 252000; Train loss: 8.402; Validation loss: 12.692;
# 20:28:12 STEP: 253000; Train loss: 10.592; Validation loss: 17.673;
# 20:28:12 STEP: 254000; Train loss: 16.239; Validation loss: 18.205;
# 20:28:13 STEP: 255000; Train loss: 21.029; Validation loss: 9.028;
# 20:28:13 STEP: 256000; Train loss: 21.460; Validation loss: 7.291;
# 20:28:14 STEP: 257000; Train loss: 7.981; Validation loss: 9.890;
# 20:28:15 STEP: 258000; Train loss: 15.582; Validation loss: 8.119;
# 20:28:15 STEP: 259000; Train loss: 26.075; Validation loss: 14.215;
# 20:28:16 STEP: 260000; Train loss: 7.934; Validation loss: 10.320;
# 20:28:17 STEP: 261000; Train loss: 6.103; Validation loss: 11.168;
# 20:28:17 STEP: 262000; Train loss: 9.254; Validation loss: 12.554;
# 20:28:18 STEP: 263000; Train loss: 16.075; Validation loss: 12.090;
# 20:28:19 STEP: 264000; Train loss: 14.995; Validation loss: 9.630;
# 20:28:19 STEP: 265000; Train loss: 9.878; Validation loss: 19.584;
# 20:28:20 STEP: 266000; Train loss: 28.018; Validation loss: 11.657;
# 20:28:20 STEP: 267000; Train loss: 7.494; Validation loss: 10.333;
# 20:28:21 STEP: 268000; Train loss: 12.281; Validation loss: 10.272;
# 20:28:22 STEP: 269000; Train loss: 6.395; Validation loss: 8.765;
# 20:28:22 STEP: 270000; Train loss: 8.530; Validation loss: 10.994;
# 20:28:23 STEP: 271000; Train loss: 13.990; Validation loss: 13.687;
# 20:28:24 STEP: 272000; Train loss: 34.717; Validation loss: 9.168;
# 20:28:24 STEP: 273000; Train loss: 6.760; Validation loss: 10.605;
# 20:28:25 STEP: 274000; Train loss: 14.679; Validation loss: 7.448;
# 20:28:26 STEP: 275000; Train loss: 9.885; Validation loss: 9.328;
# 20:28:26 STEP: 276000; Train loss: 9.501; Validation loss: 11.077;
# 20:28:27 STEP: 277000; Train loss: 12.050; Validation loss: 7.277;
# 20:28:27 STEP: 278000; Train loss: 10.852; Validation loss: 10.040;
# 20:28:28 STEP: 279000; Train loss: 8.165; Validation loss: 9.270;
# 20:28:29 STEP: 280000; Train loss: 12.842; Validation loss: 14.216;
# 20:28:29 STEP: 281000; Train loss: 7.719; Validation loss: 24.591;
# 20:28:30 STEP: 282000; Train loss: 18.641; Validation loss: 10.662;
# 20:28:31 STEP: 283000; Train loss: 10.610; Validation loss: 12.283;
# 20:28:31 STEP: 284000; Train loss: 7.763; Validation loss: 18.872;
# 20:28:32 STEP: 285000; Train loss: 13.505; Validation loss: 13.650;
# 20:28:33 STEP: 286000; Train loss: 11.175; Validation loss: 9.754;
# 20:28:33 STEP: 287000; Train loss: 10.308; Validation loss: 18.903;
# 20:28:34 STEP: 288000; Train loss: 8.238; Validation loss: 12.176;
# 20:28:34 STEP: 289000; Train loss: 14.392; Validation loss: 11.350;
# 20:28:35 STEP: 290000; Train loss: 16.671; Validation loss: 18.822;
# 20:28:36 STEP: 291000; Train loss: 11.238; Validation loss: 14.975;
# 20:28:36 STEP: 292000; Train loss: 9.178; Validation loss: 9.432;
# 20:28:37 STEP: 293000; Train loss: 8.223; Validation loss: 9.945;
# 20:28:38 STEP: 294000; Train loss: 8.865; Validation loss: 9.701;
# 20:28:38 STEP: 295000; Train loss: 14.477; Validation loss: 6.526;
# 20:28:39 STEP: 296000; Train loss: 9.010; Validation loss: 9.351;
# 20:28:40 STEP: 297000; Train loss: 8.923; Validation loss: 8.664;
# 20:28:40 STEP: 298000; Train loss: 7.905; Validation loss: 6.829;
# 20:28:41 STEP: 299000; Train loss: 10.977; Validation loss: 13.480;
# 20:28:41 STEP: 300000; Train loss: 12.910; Validation loss: 11.816;
# 20:28:42 STEP: 301000; Train loss: 15.173; Validation loss: 10.852;
# 20:28:43 STEP: 302000; Train loss: 21.581; Validation loss: 5.804;
# 20:28:43 STEP: 303000; Train loss: 8.087; Validation loss: 12.519;
# 20:28:44 STEP: 304000; Train loss: 16.099; Validation loss: 7.252;
# 20:28:45 STEP: 305000; Train loss: 13.510; Validation loss: 10.498;
# 20:28:45 STEP: 306000; Train loss: 15.220; Validation loss: 18.255;
# 20:28:46 STEP: 307000; Train loss: 22.149; Validation loss: 14.616;
# 20:28:47 STEP: 308000; Train loss: 14.665; Validation loss: 9.307;
# 20:28:47 STEP: 309000; Train loss: 14.312; Validation loss: 6.994;
# 20:28:48 STEP: 310000; Train loss: 15.136; Validation loss: 15.790;
# 20:28:48 STEP: 311000; Train loss: 13.893; Validation loss: 8.337;
# 20:28:49 STEP: 312000; Train loss: 9.740; Validation loss: 10.453;
# 20:28:50 STEP: 313000; Train loss: 11.427; Validation loss: 14.037;
# 20:28:50 STEP: 314000; Train loss: 11.590; Validation loss: 12.579;
# 20:28:51 STEP: 315000; Train loss: 6.867; Validation loss: 15.146;
# 20:28:52 STEP: 316000; Train loss: 18.910; Validation loss: 9.824;
# 20:28:52 STEP: 317000; Train loss: 18.003; Validation loss: 7.635;
# 20:28:53 STEP: 318000; Train loss: 11.245; Validation loss: 12.477;
# 20:28:54 STEP: 319000; Train loss: 13.767; Validation loss: 7.242;
# 20:28:54 STEP: 320000; Train loss: 11.509; Validation loss: 9.752;
# 20:28:55 STEP: 321000; Train loss: 13.498; Validation loss: 8.949;
# 20:28:56 STEP: 322000; Train loss: 10.102; Validation loss: 13.179;
# 20:28:56 STEP: 323000; Train loss: 14.787; Validation loss: 17.730;
# 20:28:57 STEP: 324000; Train loss: 6.302; Validation loss: 10.641;
# 20:28:57 STEP: 325000; Train loss: 13.014; Validation loss: 15.628;
# 20:28:58 STEP: 326000; Train loss: 11.207; Validation loss: 17.645;
# 20:28:59 STEP: 327000; Train loss: 7.855; Validation loss: 12.873;
# 20:28:59 STEP: 328000; Train loss: 6.696; Validation loss: 8.398;
# 20:29:00 STEP: 329000; Train loss: 11.802; Validation loss: 8.564;
# 20:29:01 STEP: 330000; Train loss: 16.320; Validation loss: 19.774;
# 20:29:01 STEP: 331000; Train loss: 27.791; Validation loss: 12.219;
# 20:29:02 STEP: 332000; Train loss: 7.587; Validation loss: 7.922;
# 20:29:03 STEP: 333000; Train loss: 14.164; Validation loss: 15.868;
# 20:29:03 STEP: 334000; Train loss: 11.420; Validation loss: 10.107;
# 20:29:04 STEP: 335000; Train loss: 11.408; Validation loss: 13.558;
# 20:29:04 STEP: 336000; Train loss: 12.831; Validation loss: 7.049;
# 20:29:05 STEP: 337000; Train loss: 11.574; Validation loss: 7.132;
# 20:29:06 STEP: 338000; Train loss: 9.576; Validation loss: 9.374;
# 20:29:06 STEP: 339000; Train loss: 10.446; Validation loss: 21.005;
# 20:29:07 STEP: 340000; Train loss: 9.917; Validation loss: 12.221;
# 20:29:08 STEP: 341000; Train loss: 7.836; Validation loss: 20.953;
# 20:29:08 STEP: 342000; Train loss: 8.276; Validation loss: 9.677;
# 20:29:09 STEP: 343000; Train loss: 14.364; Validation loss: 8.738;
# 20:29:10 STEP: 344000; Train loss: 7.864; Validation loss: 19.408;
# 20:29:10 STEP: 345000; Train loss: 16.025; Validation loss: 9.301;
# 20:29:11 STEP: 346000; Train loss: 9.887; Validation loss: 6.361;
# 20:29:11 STEP: 347000; Train loss: 10.187; Validation loss: 11.629;
# 20:29:12 STEP: 348000; Train loss: 13.182; Validation loss: 12.716;
# 20:29:13 STEP: 349000; Train loss: 18.685; Validation loss: 12.865;
# 20:29:13 STEP: 350000; Train loss: 9.454; Validation loss: 11.453;
# 20:29:14 STEP: 351000; Train loss: 15.506; Validation loss: 19.167;
# 20:29:15 STEP: 352000; Train loss: 13.320; Validation loss: 11.950;
# 20:29:15 STEP: 353000; Train loss: 14.895; Validation loss: 15.572;
# 20:29:16 STEP: 354000; Train loss: 8.096; Validation loss: 11.902;
# 20:29:17 STEP: 355000; Train loss: 18.204; Validation loss: 11.856;
# 20:29:17 STEP: 356000; Train loss: 13.637; Validation loss: 18.863;
# 20:29:18 STEP: 357000; Train loss: 6.741; Validation loss: 16.225;
# 20:29:18 STEP: 358000; Train loss: 12.077; Validation loss: 8.943;
# 20:29:19 STEP: 359000; Train loss: 19.294; Validation loss: 8.840;
# 20:29:20 STEP: 360000; Train loss: 7.794; Validation loss: 9.310;
# 20:29:20 STEP: 361000; Train loss: 10.790; Validation loss: 8.415;
# 20:29:21 STEP: 362000; Train loss: 7.171; Validation loss: 13.121;
# 20:29:22 STEP: 363000; Train loss: 10.436; Validation loss: 8.914;
# 20:29:22 STEP: 364000; Train loss: 17.495; Validation loss: 12.294;
# 20:29:23 STEP: 365000; Train loss: 17.579; Validation loss: 6.856;
# 20:29:24 STEP: 366000; Train loss: 12.143; Validation loss: 21.406;
# 20:29:24 STEP: 367000; Train loss: 18.619; Validation loss: 9.894;
# 20:29:25 STEP: 368000; Train loss: 12.572; Validation loss: 8.716;
# 20:29:26 STEP: 369000; Train loss: 10.930; Validation loss: 20.846;
# 20:29:26 STEP: 370000; Train loss: 8.088; Validation loss: 7.962;
# 20:29:27 STEP: 371000; Train loss: 21.874; Validation loss: 13.667;
# 20:29:28 STEP: 372000; Train loss: 9.739; Validation loss: 6.955;
# 20:29:28 STEP: 373000; Train loss: 10.561; Validation loss: 9.838;
# 20:29:29 STEP: 374000; Train loss: 6.735; Validation loss: 8.905;
# 20:29:30 STEP: 375000; Train loss: 11.024; Validation loss: 17.704;
# 20:29:30 STEP: 376000; Train loss: 16.971; Validation loss: 7.388;
# 20:29:31 STEP: 377000; Train loss: 52.395; Validation loss: 11.681;
# 20:29:31 STEP: 378000; Train loss: 21.639; Validation loss: 6.550;
# 20:29:32 STEP: 379000; Train loss: 11.391; Validation loss: 10.601;
# 20:29:33 STEP: 380000; Train loss: 23.733; Validation loss: 10.191;
# 20:29:33 STEP: 381000; Train loss: 19.001; Validation loss: 7.675;
# 20:29:34 STEP: 382000; Train loss: 12.851; Validation loss: 14.568;
# 20:29:35 STEP: 383000; Train loss: 7.208; Validation loss: 12.080;
# 20:29:35 STEP: 384000; Train loss: 6.529; Validation loss: 15.297;
# 20:29:36 STEP: 385000; Train loss: 10.637; Validation loss: 13.549;
# 20:29:37 STEP: 386000; Train loss: 13.266; Validation loss: 14.649;
# 20:29:37 STEP: 387000; Train loss: 8.162; Validation loss: 9.038;
# 20:29:38 STEP: 388000; Train loss: 17.209; Validation loss: 13.315;
# 20:29:39 STEP: 389000; Train loss: 31.636; Validation loss: 8.253;
# 20:29:39 STEP: 390000; Train loss: 19.582; Validation loss: 19.774;
# 20:29:40 STEP: 391000; Train loss: 6.890; Validation loss: 8.188;
# 20:29:40 STEP: 392000; Train loss: 8.888; Validation loss: 7.842;
# 20:29:41 STEP: 393000; Train loss: 9.336; Validation loss: 18.118;
# 20:29:42 STEP: 394000; Train loss: 12.905; Validation loss: 19.982;
# 20:29:42 STEP: 395000; Train loss: 13.669; Validation loss: 9.779;
# 20:29:43 STEP: 396000; Train loss: 7.324; Validation loss: 18.764;
# 20:29:44 STEP: 397000; Train loss: 10.786; Validation loss: 19.988;
# 20:29:44 STEP: 398000; Train loss: 9.241; Validation loss: 8.020;
# 20:29:45 STEP: 399000; Train loss: 10.287; Validation loss: 6.913;
# 20:29:46 STEP: 400000; Train loss: 8.863; Validation loss: 8.528;
# 20:29:46 STEP: 401000; Train loss: 11.215; Validation loss: 9.687;
# 20:29:47 STEP: 402000; Train loss: 13.789; Validation loss: 12.643;
# 20:29:47 STEP: 403000; Train loss: 13.093; Validation loss: 8.600;
# 20:29:48 STEP: 404000; Train loss: 9.983; Validation loss: 12.350;
# 20:29:49 STEP: 405000; Train loss: 20.150; Validation loss: 19.488;
# 20:29:49 STEP: 406000; Train loss: 15.832; Validation loss: 6.514;
# 20:29:50 STEP: 407000; Train loss: 20.000; Validation loss: 10.523;
# 20:29:51 STEP: 408000; Train loss: 14.152; Validation loss: 8.102;
# 20:29:51 STEP: 409000; Train loss: 7.740; Validation loss: 6.005;
# 20:29:52 STEP: 410000; Train loss: 9.927; Validation loss: 25.685;
# 20:29:53 STEP: 411000; Train loss: 9.296; Validation loss: 10.125;
# 20:29:53 STEP: 412000; Train loss: 6.105; Validation loss: 9.389;
# 20:29:54 STEP: 413000; Train loss: 22.168; Validation loss: 12.663;
# 20:29:54 STEP: 414000; Train loss: 11.101; Validation loss: 21.973;
# 20:29:55 STEP: 415000; Train loss: 12.466; Validation loss: 11.599;
# 20:29:56 STEP: 416000; Train loss: 10.184; Validation loss: 7.219;
# 20:29:56 STEP: 417000; Train loss: 8.808; Validation loss: 11.003;
# 20:29:57 STEP: 418000; Train loss: 8.269; Validation loss: 7.556;
# 20:29:58 STEP: 419000; Train loss: 8.276; Validation loss: 7.213;
# 20:29:58 STEP: 420000; Train loss: 7.292; Validation loss: 18.151;
# 20:29:59 STEP: 421000; Train loss: 8.291; Validation loss: 7.879;
# 20:30:00 STEP: 422000; Train loss: 21.652; Validation loss: 11.114;
# 20:30:00 STEP: 423000; Train loss: 7.572; Validation loss: 8.243;
# 20:30:01 STEP: 424000; Train loss: 12.751; Validation loss: 14.688;
# 20:30:02 STEP: 425000; Train loss: 11.141; Validation loss: 12.371;
# 20:30:02 STEP: 426000; Train loss: 10.364; Validation loss: 11.963;
# 20:30:03 STEP: 427000; Train loss: 16.020; Validation loss: 10.439;
# 20:30:03 STEP: 428000; Train loss: 9.254; Validation loss: 15.771;
# 20:30:04 STEP: 429000; Train loss: 15.905; Validation loss: 7.825;
# 20:30:05 STEP: 430000; Train loss: 10.095; Validation loss: 8.578;
# 20:30:05 STEP: 431000; Train loss: 8.143; Validation loss: 9.263;
# 20:30:06 STEP: 432000; Train loss: 7.512; Validation loss: 8.576;
# 20:30:07 STEP: 433000; Train loss: 15.603; Validation loss: 32.896;
# 20:30:07 STEP: 434000; Train loss: 11.918; Validation loss: 7.770;
# 20:30:08 STEP: 435000; Train loss: 8.526; Validation loss: 17.449;
# 20:30:09 STEP: 436000; Train loss: 6.678; Validation loss: 20.972;
# 20:30:09 STEP: 437000; Train loss: 11.668; Validation loss: 8.237;
# 20:30:10 STEP: 438000; Train loss: 6.582; Validation loss: 11.501;
# 20:30:10 STEP: 439000; Train loss: 9.722; Validation loss: 11.009;
# 20:30:11 STEP: 440000; Train loss: 5.260; Validation loss: 19.045;
# 20:30:12 STEP: 441000; Train loss: 9.135; Validation loss: 6.295;
# 20:30:12 STEP: 442000; Train loss: 8.297; Validation loss: 10.850;
# 20:30:13 STEP: 443000; Train loss: 19.282; Validation loss: 6.690;
# 20:30:14 STEP: 444000; Train loss: 10.616; Validation loss: 14.787;
# 20:30:14 STEP: 445000; Train loss: 7.472; Validation loss: 8.303;
# 20:30:15 STEP: 446000; Train loss: 14.956; Validation loss: 8.712;
# 20:30:16 STEP: 447000; Train loss: 10.261; Validation loss: 12.270;
# 20:30:16 STEP: 448000; Train loss: 8.286; Validation loss: 11.541;
# 20:30:17 STEP: 449000; Train loss: 20.934; Validation loss: 9.897;
# 20:30:17 STEP: 450000; Train loss: 8.072; Validation loss: 9.584;
# 20:30:18 STEP: 451000; Train loss: 14.360; Validation loss: 12.321;
# 20:30:19 STEP: 452000; Train loss: 6.961; Validation loss: 9.220;
# 20:30:19 STEP: 453000; Train loss: 19.825; Validation loss: 11.907;
# 20:30:20 STEP: 454000; Train loss: 17.639; Validation loss: 11.422;
# 20:30:21 STEP: 455000; Train loss: 15.268; Validation loss: 9.663;
# 20:30:21 STEP: 456000; Train loss: 11.716; Validation loss: 9.839;
# 20:30:22 STEP: 457000; Train loss: 15.784; Validation loss: 11.784;
# 20:30:23 STEP: 458000; Train loss: 21.061; Validation loss: 11.200;
# 20:30:23 STEP: 459000; Train loss: 10.014; Validation loss: 5.824;
# 20:30:24 STEP: 460000; Train loss: 14.641; Validation loss: 10.504;
# 20:30:24 STEP: 461000; Train loss: 18.070; Validation loss: 23.094;
# 20:30:25 STEP: 462000; Train loss: 9.079; Validation loss: 6.700;
# 20:30:26 STEP: 463000; Train loss: 7.734; Validation loss: 11.619;
# 20:30:26 STEP: 464000; Train loss: 8.888; Validation loss: 19.914;
# 20:30:27 STEP: 465000; Train loss: 9.267; Validation loss: 13.818;
# 20:30:28 STEP: 466000; Train loss: 10.086; Validation loss: 18.420;
# 20:30:28 STEP: 467000; Train loss: 10.655; Validation loss: 5.586;
# 20:30:29 STEP: 468000; Train loss: 9.228; Validation loss: 8.009;
# 20:30:30 STEP: 469000; Train loss: 10.025; Validation loss: 12.358;
# 20:30:30 STEP: 470000; Train loss: 16.397; Validation loss: 8.382;
# 20:30:31 STEP: 471000; Train loss: 11.622; Validation loss: 11.897;
# 20:30:32 STEP: 472000; Train loss: 9.395; Validation loss: 11.742;
# 20:30:32 STEP: 473000; Train loss: 18.331; Validation loss: 7.776;
# 20:30:33 STEP: 474000; Train loss: 9.179; Validation loss: 10.740;
# 20:30:33 STEP: 475000; Train loss: 10.333; Validation loss: 13.195;
# 20:30:34 STEP: 476000; Train loss: 19.001; Validation loss: 30.162;
# 20:30:35 STEP: 477000; Train loss: 8.587; Validation loss: 21.339;
# 20:30:35 STEP: 478000; Train loss: 8.652; Validation loss: 15.474;
# 20:30:36 STEP: 479000; Train loss: 16.117; Validation loss: 21.076;
# 20:30:37 STEP: 480000; Train loss: 7.627; Validation loss: 17.406;
# 20:30:37 STEP: 481000; Train loss: 10.377; Validation loss: 12.245;
# 20:30:38 STEP: 482000; Train loss: 14.375; Validation loss: 26.257;
# 20:30:39 STEP: 483000; Train loss: 40.955; Validation loss: 19.719;
# 20:30:39 STEP: 484000; Train loss: 8.563; Validation loss: 17.287;
# 20:30:40 STEP: 485000; Train loss: 21.290; Validation loss: 7.818;
# 20:30:40 STEP: 486000; Train loss: 10.129; Validation loss: 11.810;
# 20:30:41 STEP: 487000; Train loss: 15.623; Validation loss: 10.335;
# 20:30:42 STEP: 488000; Train loss: 10.429; Validation loss: 11.059;
# 20:30:42 STEP: 489000; Train loss: 9.879; Validation loss: 18.023;
# 20:30:43 STEP: 490000; Train loss: 9.255; Validation loss: 11.688;
# 20:30:44 STEP: 491000; Train loss: 16.528; Validation loss: 19.497;
# 20:30:44 STEP: 492000; Train loss: 16.825; Validation loss: 9.528;
# 20:30:45 STEP: 493000; Train loss: 8.061; Validation loss: 8.044;
# 20:30:46 STEP: 494000; Train loss: 8.448; Validation loss: 13.421;
# 20:30:46 STEP: 495000; Train loss: 6.790; Validation loss: 12.593;
# 20:30:47 STEP: 496000; Train loss: 14.403; Validation loss: 12.948;
# 20:30:48 STEP: 497000; Train loss: 12.988; Validation loss: 9.329;
# 20:30:48 STEP: 498000; Train loss: 11.269; Validation loss: 10.995;
# 20:30:49 STEP: 499000; Train loss: 9.916; Validation loss: 8.858;
# 20:30:50 STEP: 499999; Train loss: 9.391; Validation loss: 10.822;
# Training took: (325.153 secs; equivalently 5.419 mins)

# %%
from matplotlib.ticker import MaxNLocator

# Loss plots
fig, axes = plt.subplots(2, 2, figsize=(14, 10))

# for i in range(2): axes[i].xaxis.set_major_locator(MaxNLocator(integer=True))

xs = np.arange(len(train_losses))*ARGS.eval_frequency
axes[0, 0].plot(xs, train_losses, label='train_loss')
axes[0, 0].plot(xs, val_losses, label='val_loss')
axes[0, 1].plot(xs[1:], train_losses[1:], label='train_loss')
axes[0, 1].plot(xs[1:], val_losses[1:], label='val_loss')
axes[0, 0].set_title('Loss (all epochs)')
axes[0, 1].set_title('Loss (all except first epoch)')

for i in range(2): 
    axes[0, i].set_ylabel('Loss')
    axes[0, i].set_xlabel('Epochs')
    axes[0, i].legend()
    
# KLD plots
xs = np.arange(len(train_klds))*ARGS.eval_frequency
axes[1, 0].plot(xs, train_klds, label='train_kld')
axes[1, 0].plot(xs, val_klds, label='val_kld')
axes[1, 1].plot(xs[1:], train_klds[1:], label='train_kld')
axes[1, 1].plot(xs[1:], val_klds[1:], label='val_kld')
axes[1, 0].set_title('KLD (all epochs)')
axes[1, 1].set_title('KLD (all except first epoch)')

for i in range(2): 
    axes[1, i].set_ylabel('KLD')
    axes[1, i].set_xlabel('Epochs')
    axes[1, i].legend()

fig.suptitle(f'Loss and KLD (left: all epochs; right: all except first epochs) \n{model_params_title}', fontsize='xx-large')

plt.tight_layout()
plt.show()

loss_kld_path = FIG_PATH / 'loss_kld_figures'
loss_kld_path.mkdir(exist_ok=True)
fig.savefig(loss_kld_path / f'{model_name}.jpg', dpi=300)

# %%
RNG_KEY, rng_recon = jax.random.split(RNG_KEY)

num_to_plot = 5
fig, axes = plt.subplots(num_to_plot, 2, figsize=(15, 25))

for i in range(num_to_plot):
    original_data = val_data[i]
    graph_data = graph_val_data[i]
    
    outputs = net.apply(params, RNG_KEY, graph_data)
    recon_data = outputs.output.nodes.T

    original_gp = jnp.ravel(original_data)
    recon_gp = jnp.ravel(recon_data)

    axes[i, 0].plot(X, original_gp)
    axes[i, 1].plot(X, recon_gp)
    
    axes[i, 0].set_title(f'Example {i} (input)')
    axes[i, 1].set_title(f'Example {i} (recon)')

fig.suptitle(f'Input vs Recon\n{model_params_title}', fontsize='xx-large')

plt.tight_layout()
plt.show()

input_v_recon_path = FIG_PATH / 'recon_figures'
input_v_recon_path.mkdir(exist_ok=True)
fig.savefig(input_v_recon_path / f'{model_name}.jpg', dpi=300)

# %%
from functools import partial

decoder_params_keys = [k for k in list(params.keys()) if k.startswith('vgae/decoder')]
decoder_params = {}
for full_key_name in decoder_params_keys:
    key_name = full_key_name.split('/')[-1]  # remove the 'vgae/' prefix
    decoder_params[key_name] = params[full_key_name]
    
GP1D_ARGS.decoder_params = decoder_params

decoder_net_fn = partial(decoder,
                         hidden_fc_dim=ARGS.hidden_fc_dim,
                         hidden_gnn_dim=ARGS.hidden_gnn_dim,
                         output_dim=ARGS.output_dim,
                         num_nodes=GP1D_ARGS.num_locations)
decoder_net = hk.without_apply_rng(hk.transform(decoder_net_fn))

# %%
def decoder_predictive_model():
    z = numpyro.sample('z', dist.Normal(0, 1).expand([ARGS.latent_dim]))
    vgae_out = jnp.squeeze(decoder_net.apply(GP1D_ARGS.decoder_params, z).nodes)
    numpyro.deterministic('f', vgae_out)

# %%
# Rough comparison of the shape of GP draws with learnt VGAE priors.

# Drawing VGAE priors.
RNG_KEY, vgae_sample_rng = jax.random.split(RNG_KEY)
vgae_draws = Predictive(
  decoder_predictive_model, num_samples=10)(vgae_sample_rng)['f']

# Plotting the GP draws and VGAE draws.
_, ax = plt.subplots(1, 2, figsize=(18, 5))

plotting.plot_gp_draws(X, gp_draws, num_draws_to_plot=5, 
                     ax=ax[0], title='Example of GP priors to encode', y_label='$y=f_{GP}(x)$')

plotting.plot_gp_draws(X, vgae_draws, num_draws_to_plot=5, 
                     ax=ax[1], title='Example of learnt priors using VGAE', y_label='$y=f_{VGAE}(x)$', )

plt.show()

# %%
# Comparing distribution of GP draws with learnt VGAE priors.
RNG_KEY, gp_rng, vgae_rng = jax.random.split(RNG_KEY, 3)

num_samples = 1000
gp_draws = dataset_1dgp.generate_gp_batch(gp_rng, X, 
                                          batch_size=num_samples, 
                                          kernel=GP1D_ARGS.kernel)
vgae_draws = Predictive(decoder_predictive_model, num_samples=num_samples)(vgae_rng)['f']

# Computing the mean and HPDI of the GP draws and VGAE draws.
gp_draws = gp_draws[~np.isnan(gp_draws).any(axis=1), :]
mean_gp = jnp.nanmean(gp_draws, axis=0)
hpdi_gp = hpdi(gp_draws, 0.9)

vgae_draws = vgae_draws[~np.isnan(vgae_draws).any(axis=1), :]
mean_vgae = jnp.nanmean(vgae_draws, axis=0)
hpdi_vgae = hpdi(vgae_draws, 0.9)

# %%
# Plotting the GP draws and VGAE draws.
fig, axes = plt.subplots(1, 2, figsize=(18, 7))

y_lim = [-2, 2]
lines_alpha_gp = 0.1
lines_alpha_vgae = 0.1
num_draws_to_plot = 15
plotting.plot_gp_draws_with_stats(
    X, gp_draws, 
    mean_gp, hpdi_gp,lines_alpha_gp, 
    num_draws_to_plot, y_lim=y_lim, ax=axes[0],
    title='GP priors to be learnt', y_label='$y=f_{GP}(x)$')
plotting.plot_gp_draws_with_stats(
    X, vgae_draws, mean_vgae, hpdi_vgae,
    lines_alpha_vgae, num_draws_to_plot, 
    y_lim=y_lim, ax=axes[1],
    title='Priors learnt by VGAE',
    y_label=r'$y=f_{VGAE}(x)$')

# fig.suptitle(f'GP Priors vs Learnt VGAE Priors \n{model_params_title}', fontsize='xx-large')
# fig.suptitle(f'GP Priors vs Learnt VGAE Priors', fontsize='xx-large')

plt.tight_layout()
plt.show()

estimate_plot_path = FIG_PATH / 'estimate_figures'  
estimate_plot_path.mkdir(exist_ok=True)
fig.savefig(estimate_plot_path / f'{model_name}.jpg', dpi=300)

# %%
# Plotting the GP draws.
fig, ax = plt.subplots(1, 1, figsize=(10, 7))

y_lim = [-2, 2]
lines_alpha_gp = 0.1
num_draws_to_plot = 15
plotting.plot_gp_draws_with_stats(
    X, gp_draws, 
    mean_gp, hpdi_gp,lines_alpha_gp, 
    num_draws_to_plot, y_lim=y_lim, ax=ax)

ax.tick_params(axis='both', which='major', labelsize=15)

# ax.set_title('GP priors to be learnt', fontsize=18)
ax.set_ylabel('$y=f_{\mathrm{GP}}(x)$', fontsize=18)
ax.set_xlabel('$x$', fontsize=18)

plt.tight_layout()
plt.show()

save_to_dir = FIG_PATH / 'publication'
save_to_dir.mkdir(exist_ok=True)
fig.savefig(save_to_dir / '1DGP_priors_GP.jpg', dpi=300)

# %%
# Plotting the GP draws and VGAE draws.
fig, ax = plt.subplots(1, 1, figsize=(10, 7))

y_lim = [-2, 2]
lines_alpha_vgae = 0.1
num_draws_to_plot = 15
plotting.plot_gp_draws_with_stats(
    X, vgae_draws, 
    mean_vgae, hpdi_vgae,lines_alpha_vgae, 
    num_draws_to_plot, y_lim=y_lim, ax=ax)

ax.tick_params(axis='both', which='major', labelsize=15)

# ax.set_title('Priors learnt by VGAE', fontsize=18)
ax.set_ylabel('$y=f_{\mathrm{VGAE}}(x)$', fontsize=18)
ax.set_xlabel('$x$', fontsize=18)

plt.tight_layout()
plt.show()

save_to_dir = FIG_PATH / 'publication'
fig.savefig(save_to_dir / '1DGP_priors_VGAE.jpg', dpi=300)

# %%
assert False, 'Inference is turned off'
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# /Users/salmanfaris/Desktop/ds-projects/msc-proj/PriorVGAE/1dGP_priorVGAE_FullyAdjLayer.ipynb Cell 36 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/Users/salmanfaris/Desktop/ds-projects/msc-proj/PriorVGAE/1dGP_priorVGAE_FullyAdjLayer.ipynb#X44sZmlsZQ%3D%3D?line=0'>1</a> assert False, 'Inference is turned off'
#
# AssertionError: Inference is turned off

# %% [markdown]
# # Inference on Observed Data

# %%
def vgae_mcmc_predictive_model(y=None, obs_idx=None):
    z = numpyro.sample('z', dist.Normal(0, 1).expand([ARGS.latent_dim]))
    vgae_out = jnp.squeeze(decoder_net.apply(GP1D_ARGS.decoder_params, z).nodes)
    f = numpyro.deterministic('f', vgae_out)
    sigma = numpyro.sample('noise', dist.HalfNormal(0.1))

    if y is None: # at prediction time
        numpyro.sample('y_pred', dist.Normal(f, sigma))
    else: # at inference time
        numpyro.sample('y', dist.Normal(f[obs_idx], sigma), obs=y)

# %% [markdown]
# ## Ground truth and observed data

# %%
RNG_KEY, gp_rng = jax.random.split(jax.random.PRNGKey(10))
# RNG_KEY, gp_rng = jax.random.split(jax.random.PRNGKey(8))
# RNG_KEY, gp_rng = jax.random.split(jax.random.PRNGKey(6))
# RNG_KEY, gp_rng = jax.random.split(RNG_KEY)

# Generate true data and observed dataset to infer
draws = Predictive(dataset_1dgp.gp_predictive_model, num_samples=1)(
  gp_rng, x=X, gp_kernel=GP1D_ARGS.kernel, noise=True)
gp_draw = draws['f'].T  # True data
y_draw = draws['y'].T  # True data + noise

assert not jnp.isnan(y_draw).any(), 'NaNs in y_draw'

# Choose indices of datapoints for inference.
# obs_locations = [
#   jnp.array([122, 321]),  # 2 observed datapoints
#   jnp.array([126, 133, 296, 370]),  # 4 observed datapoints
#   jnp.array([71, 85, 111, 291, 314, 380]),  # 6 observed datapoints
# ]
# obs_locations = [
#   jnp.array([122, 321]),  # 2 observed datapoints
#   jnp.array([126, 133, 296, 370]),  # 4 observed datapoints
#   jnp.array([71, 85, 147, 291, 314, 380]),  # 6 observed datapoints
# ]
obs_locations = [
  jnp.array([122, 321]),  # 2 observed datapoints
  jnp.array([126, 133, 296, 370]),  # 4 observed datapoints
  jnp.array([71, 85, 147, 275, 314, 380]),  # 6 observed datapoints
]

# %%
mean_post_preds_list = []
hpdi_post_preds_list = []
obs_xs = []
obs_ys = []
predictions_list = []
mcmc_objs = []

RNG_KEY, inference_rng = jax.random.split(RNG_KEY)

for i, obs_location in enumerate(obs_locations):
    mcmc_rng, pred_rng = jax.random.split(jax.random.fold_in(inference_rng, i))
    
    x_obs = X[obs_location]
    y_obs = jnp.squeeze(y_draw[obs_location])
    
    print(f'Running chain for n_obs = {len(obs_location)}')
    
    # MCMC sampling
    start = time.time()
    init_strategy = init_to_median(num_samples=10)
    kernel = NUTS(vgae_mcmc_predictive_model, init_strategy=init_strategy)
    mcmc = MCMC(
        kernel,
        num_warmup=1000,
        num_samples=1000,
        num_chains=4,
        thinning=1,
        progress_bar=False if 'NUMPYRO_SPHINXBUILD' in os.environ else True,
    )
    mcmc.run(mcmc_rng, y_obs, obs_location)
    print('\nMCMC elapsed time:', time.time() - start)
    
    mcmc_samples = mcmc.get_samples()
    mcmc_objs.append(mcmc)

    predictions = Predictive(vgae_mcmc_predictive_model, mcmc_samples)(pred_rng)['f']
    mean_post_pred = jnp.mean(predictions, axis=0)
    hpdi_post_pred = hpdi(predictions, 0.9)
    
    obs_xs.append(x_obs)
    obs_ys.append(y_obs)
    predictions_list.append(predictions)
    mean_post_preds_list.append(mean_post_pred)
    hpdi_post_preds_list.append(hpdi_post_pred)
# Out:
# Running chain for n_obs = 2
# /var/folders/6h/lf5jg1fn1h163zw3042tmtnc0000gn/T/ipykernel_13680/2587952414.py:22: UserWarning: There are not enough devices to run parallel chains: expected 4 but got 1. Chains will be drawn sequentially. If you are running MCMC in CPU, consider using `numpyro.set_host_device_count(4)` at the beginning of your program. You can double-check how many devices are available in your system using `jax.local_device_count()`.
#   mcmc = MCMC(
# sample: 100%|██████████| 2000/2000 [00:08<00:00, 247.96it/s, 51 steps of size 9.33e-02. acc. prob=0.85]
# sample: 100%|██████████| 2000/2000 [00:05<00:00, 349.41it/s, 3 steps of size 9.05e-02. acc. prob=0.78]
# sample: 100%|██████████| 2000/2000 [00:05<00:00, 335.79it/s, 63 steps of size 8.49e-02. acc. prob=0.84]
# sample: 100%|██████████| 2000/2000 [00:04<00:00, 461.20it/s, 63 steps of size 9.42e-02. acc. prob=0.49]
# MCMC elapsed time: 26.391108989715576
# /var/folders/6h/lf5jg1fn1h163zw3042tmtnc0000gn/T/ipykernel_13680/2587952414.py:22: UserWarning: There are not enough devices to run parallel chains: expected 4 but got 1. Chains will be drawn sequentially. If you are running MCMC in CPU, consider using `numpyro.set_host_device_count(4)` at the beginning of your program. You can double-check how many devices are available in your system using `jax.local_device_count()`.
#   mcmc = MCMC(
# Running chain for n_obs = 4
# sample: 100%|██████████| 2000/2000 [00:09<00:00, 210.42it/s, 8 steps of size 5.03e-02. acc. prob=0.81]
# sample: 100%|██████████| 2000/2000 [00:04<00:00, 411.27it/s, 31 steps of size 1.37e-01. acc. prob=0.58]
# sample: 100%|██████████| 2000/2000 [00:07<00:00, 265.52it/s, 63 steps of size 8.06e-02. acc. prob=0.77]
# sample: 100%|██████████| 2000/2000 [00:05<00:00, 364.38it/s, 63 steps of size 9.59e-02. acc. prob=0.68]
# MCMC elapsed time: 28.08649492263794
# /var/folders/6h/lf5jg1fn1h163zw3042tmtnc0000gn/T/ipykernel_13680/2587952414.py:22: UserWarning: There are not enough devices to run parallel chains: expected 4 but got 1. Chains will be drawn sequentially. If you are running MCMC in CPU, consider using `numpyro.set_host_device_count(4)` at the beginning of your program. You can double-check how many devices are available in your system using `jax.local_device_count()`.
#   mcmc = MCMC(
# Running chain for n_obs = 6
# sample: 100%|██████████| 2000/2000 [00:04<00:00, 414.45it/s, 15 steps of size 2.09e-01. acc. prob=0.88]
# sample: 100%|██████████| 2000/2000 [00:02<00:00, 694.76it/s, 15 steps of size 2.76e-01. acc. prob=0.82]
# sample: 100%|██████████| 2000/2000 [00:02<00:00, 691.99it/s, 15 steps of size 2.40e-01. acc. prob=0.87]
# sample: 100%|██████████| 2000/2000 [00:03<00:00, 529.33it/s, 31 steps of size 1.75e-01. acc. prob=0.93]
# MCMC elapsed time: 15.081664085388184

# %%
def compute_ess(mcmc_obj):
    ss = numpyro.diagnostics.summary(mcmc_obj.get_samples(group_by_chain=True))
    r = np.mean(ss['f']['n_eff'])
    print("Average ESS for all effects : " + str(round(r)))
    
for mcmc in mcmc_objs:
    compute_ess(mcmc)
# Out:
# Average ESS for all effects : 500
# Average ESS for all effects : 1251
# Average ESS for all effects : 3053

# %%
mcmc_objs[-1].print_summary(exclude_deterministic=False)
# Out:
#                 mean       std    median      5.0%     95.0%     n_eff     r_hat
#       f[0]     -2.60      0.78     -2.60     -3.96     -1.39   2059.78      1.00
#       f[1]     -1.46      0.42     -1.45     -2.16     -0.78   2073.79      1.00
#       f[2]     -0.85      0.21     -0.87     -1.20     -0.56   2077.67      1.00
#       f[3]     -1.33      0.41     -1.33     -2.03     -0.68   2076.55      1.00
#       f[4]     -1.59      0.39     -1.60     -2.25     -0.98   2064.17      1.00
#       f[5]     -1.26      0.36     -1.26     -1.86     -0.71   2066.88      1.00
#       f[6]     -1.33      0.38     -1.33     -1.96     -0.73   2069.10      1.00
#       f[7]     -1.43      0.40     -1.42     -2.14     -0.80   2063.80      1.00
#       f[8]     -1.26      0.35     -1.25     -1.87     -0.71   2066.37      1.00
#       f[9]     -1.36      0.39     -1.35     -1.96     -0.69   2068.84      1.00
#      f[10]     -1.48      0.40     -1.48     -2.16     -0.85   2063.84      1.00
#      f[11]     -1.39      0.37     -1.39     -2.04     -0.82   2068.49      1.00
#      f[12]     -1.38      0.37     -1.37     -2.01     -0.78   2064.31      1.00
#      f[13]     -1.43      0.36     -1.43     -2.05     -0.86   2055.92      1.00
#      f[14]     -1.40      0.35     -1.40     -2.01     -0.85   2055.91      1.00
#      f[15]     -1.42      0.35     -1.42     -2.02     -0.86   2051.12      1.00
#      f[16]     -1.45      0.35     -1.46     -2.05     -0.92   2051.46      1.00
#      f[17]     -1.41      0.34     -1.41     -1.99     -0.87   2054.62      1.00
#      f[18]     -1.43      0.34     -1.43     -2.00     -0.89   2049.52      1.00
#      f[19]     -1.44      0.32     -1.45     -2.01     -0.96   2043.73      1.00
#      f[20]     -1.45      0.34     -1.45     -2.05     -0.92   2048.35      1.00
#      f[21]     -1.47      0.30     -1.49     -1.95     -0.99   2022.34      1.00
#      f[22]     -1.47      0.33     -1.47     -2.02     -0.95   2049.59      1.00
#      f[23]     -1.37      0.29     -1.38     -1.87     -0.93   2021.96      1.00
#      f[24]     -1.52      0.32     -1.52     -2.07     -1.01   2049.53      1.00
#      f[25]     -1.63      0.36     -1.64     -2.24     -1.06   2042.21      1.00
#      f[26]     -1.41      0.29     -1.41     -1.92     -0.95   2052.81      1.00
#      f[27]     -1.52      0.32     -1.52     -2.07     -1.02   2051.40      1.00
#      f[28]     -1.66      0.34     -1.65     -2.26     -1.14   2053.27      1.00
#      f[29]     -1.57      0.32     -1.56     -2.13     -1.06   2051.98      1.00
#      f[30]     -1.51      0.30     -1.51     -2.04     -1.03   2048.07      1.00
#      f[31]     -1.58      0.31     -1.57     -2.11     -1.09   2044.71      1.00
#      f[32]     -1.61      0.31     -1.60     -2.10     -1.07   2051.43      1.00
#      f[33]     -1.57      0.29     -1.57     -2.08     -1.12   2036.42      1.00
#      f[34]     -1.59      0.29     -1.59     -2.09     -1.13   2047.88      1.00
#      f[35]     -1.60      0.29     -1.60     -2.07     -1.12   2035.82      1.00
#      f[36]     -1.58      0.27     -1.58     -2.05     -1.15   2038.37      1.00
#      f[37]     -1.61      0.28     -1.60     -2.06     -1.14   2042.39      1.00
#      f[38]     -1.62      0.27     -1.61     -2.07     -1.18   2039.31      1.00
#      f[39]     -1.61      0.26     -1.60     -2.05     -1.18   2037.73      1.00
#      f[40]     -1.60      0.25     -1.60     -2.02     -1.19   2039.16      1.00
#      f[41]     -1.62      0.25     -1.61     -2.04     -1.21   2034.30      1.00
#      f[42]     -1.62      0.24     -1.61     -2.03     -1.22   2048.46      1.00
#      f[43]     -1.61      0.24     -1.61     -2.02     -1.24   2048.28      1.00
#      f[44]     -1.62      0.23     -1.62     -2.02     -1.25   2047.27      1.00
#      f[45]     -1.62      0.23     -1.62     -2.01     -1.26   2057.55      1.00
#      f[46]     -1.62      0.22     -1.61     -1.99     -1.26   2042.79      1.00
#      f[47]     -1.63      0.22     -1.63     -1.99     -1.27   2061.55      1.00
#      f[48]     -1.63      0.21     -1.63     -1.97     -1.30   2055.22      1.00
#      f[49]     -1.62      0.20     -1.62     -1.98     -1.31   2054.75      1.00
#      f[50]     -1.63      0.20     -1.62     -1.96     -1.32   2060.34      1.00
#      f[51]     -1.63      0.19     -1.63     -1.95     -1.32   2057.00      1.00
#      f[52]     -1.62      0.19     -1.62     -1.91     -1.30   2078.11      1.00
#      f[53]     -1.62      0.18     -1.62     -1.91     -1.33   2080.57      1.00
#      f[54]     -1.63      0.17     -1.64     -1.93     -1.36   2098.12      1.00
#      f[55]     -1.62      0.17     -1.62     -1.91     -1.36   2100.86      1.00
#      f[56]     -1.63      0.16     -1.63     -1.90     -1.37   2107.44      1.00
#      f[57]     -1.63      0.16     -1.63     -1.87     -1.36   2137.58      1.00
#      f[58]     -1.63      0.15     -1.63     -1.87     -1.36   2156.65      1.00
#      f[59]     -1.63      0.15     -1.63     -1.88     -1.39   2173.77      1.00
#      f[60]     -1.62      0.14     -1.63     -1.86     -1.39   2208.83      1.00
#      f[61]     -1.62      0.14     -1.63     -1.86     -1.40   2213.69      1.00
#      f[62]     -1.62      0.13     -1.62     -1.84     -1.40   2241.35      1.00
#      f[63]     -1.62      0.13     -1.62     -1.85     -1.43   2298.20      1.00
#      f[64]     -1.61      0.13     -1.62     -1.83     -1.42   2316.98      1.00
#      f[65]     -1.61      0.12     -1.61     -1.81     -1.42   2384.53      1.00
#      f[66]     -1.61      0.12     -1.61     -1.80     -1.43   2431.58      1.00
#      f[67]     -1.60      0.11     -1.61     -1.80     -1.43   2501.45      1.00
#      f[68]     -1.60      0.11     -1.60     -1.78     -1.42   2554.16      1.00
#      f[69]     -1.60      0.11     -1.60     -1.77     -1.42   2700.81      1.00
#      f[70]     -1.59      0.11     -1.60     -1.77     -1.43   2674.82      1.00
#      f[71]     -1.58      0.10     -1.59     -1.74     -1.41   2857.62      1.00
#      f[72]     -1.58      0.10     -1.58     -1.73     -1.41   2898.42      1.00
#      f[73]     -1.57      0.10     -1.58     -1.72     -1.41   3059.23      1.00
#      f[74]     -1.57      0.10     -1.58     -1.73     -1.42   3162.89      1.00
#      f[75]     -1.57      0.09     -1.57     -1.71     -1.41   3344.93      1.00
#      f[76]     -1.57      0.09     -1.57     -1.71     -1.41   3388.72      1.00
#      f[77]     -1.55      0.09     -1.56     -1.70     -1.41   3596.79      1.00
#      f[78]     -1.54      0.09     -1.55     -1.68     -1.39   3696.70      1.00
#      f[79]     -1.54      0.09     -1.54     -1.69     -1.39   3865.89      1.00
#      f[80]     -1.53      0.09     -1.54     -1.67     -1.38   3930.26      1.00
#      f[81]     -1.53      0.09     -1.54     -1.67     -1.38   4139.25      1.00
#      f[82]     -1.52      0.09     -1.53     -1.66     -1.36   4203.33      1.00
#      f[83]     -1.51      0.09     -1.52     -1.65     -1.36   4322.97      1.00
#      f[84]     -1.50      0.09     -1.51     -1.65     -1.36   4377.59      1.00
#      f[85]     -1.49      0.09     -1.50     -1.63     -1.34   4531.06      1.00
#      f[86]     -1.49      0.09     -1.50     -1.63     -1.33   4449.82      1.00
#      f[87]     -1.48      0.09     -1.48     -1.62     -1.32   4618.80      1.00
#      f[88]     -1.47      0.09     -1.47     -1.61     -1.31   4518.75      1.00
#      f[89]     -1.46      0.09     -1.47     -1.60     -1.30   4558.96      1.00
#      f[90]     -1.45      0.09     -1.45     -1.59     -1.28   4479.36      1.00
#      f[91]     -1.45      0.10     -1.45     -1.60     -1.29   4452.87      1.00
#      f[92]     -1.43      0.10     -1.44     -1.59     -1.28   4459.74      1.00
#      f[93]     -1.43      0.10     -1.43     -1.59     -1.27   4249.81      1.00
#      f[94]     -1.41      0.10     -1.42     -1.56     -1.24   4250.97      1.00
#      f[95]     -1.41      0.10     -1.41     -1.56     -1.23   4104.16      1.00
#      f[96]     -1.39      0.10     -1.39     -1.54     -1.21   4185.46      1.00
#      f[97]     -1.39      0.10     -1.39     -1.54     -1.21   4061.59      1.00
#      f[98]     -1.37      0.10     -1.38     -1.53     -1.20   4050.44      1.00
#      f[99]     -1.36      0.10     -1.36     -1.52     -1.19   3971.62      1.00
#     f[100]     -1.35      0.10     -1.35     -1.52     -1.18   3869.44      1.00
#     f[101]     -1.34      0.10     -1.34     -1.50     -1.16   3892.01      1.00
#     f[102]     -1.32      0.10     -1.33     -1.49     -1.15   3896.25      1.00
#     f[103]     -1.32      0.11     -1.32     -1.49     -1.14   3861.30      1.00
#     f[104]     -1.30      0.11     -1.30     -1.48     -1.13   3790.96      1.00
#     f[105]     -1.29      0.11     -1.29     -1.46     -1.12   3793.23      1.00
#     f[106]     -1.28      0.11     -1.28     -1.45     -1.09   3752.44      1.00
#     f[107]     -1.27      0.11     -1.27     -1.44     -1.09   3773.90      1.00
#     f[108]     -1.25      0.11     -1.25     -1.42     -1.07   3752.53      1.00
#     f[109]     -1.24      0.11     -1.25     -1.42     -1.06   3697.62      1.00
#     f[110]     -1.23      0.11     -1.23     -1.40     -1.04   3659.86      1.00
#     f[111]     -1.22      0.11     -1.22     -1.40     -1.04   3678.13      1.00
#     f[112]     -1.21      0.11     -1.21     -1.38     -1.02   3660.80      1.00
#     f[113]     -1.19      0.11     -1.19     -1.37     -1.01   3630.04      1.00
#     f[114]     -1.18      0.11     -1.18     -1.35     -1.00   3648.03      1.00
#     f[115]     -1.17      0.11     -1.16     -1.34     -0.98   3580.04      1.00
#     f[116]     -1.15      0.11     -1.15     -1.32     -0.96   3600.86      1.00
#     f[117]     -1.14      0.11     -1.14     -1.31     -0.95   3627.64      1.00
#     f[118]     -1.12      0.11     -1.12     -1.29     -0.94   3588.58      1.00
#     f[119]     -1.11      0.11     -1.11     -1.30     -0.93   3618.37      1.00
#     f[120]     -1.10      0.11     -1.10     -1.27     -0.91   3560.41      1.00
#     f[121]     -1.09      0.11     -1.09     -1.25     -0.89   3599.01      1.00
#     f[122]     -1.07      0.11     -1.07     -1.23     -0.88   3586.65      1.00
#     f[123]     -1.06      0.11     -1.06     -1.23     -0.87   3622.23      1.00
#     f[124]     -1.05      0.11     -1.04     -1.22     -0.86   3598.92      1.00
#     f[125]     -1.03      0.11     -1.03     -1.19     -0.83   3620.86      1.00
#     f[126]     -1.02      0.11     -1.02     -1.20     -0.84   3608.20      1.00
#     f[127]     -1.01      0.11     -1.01     -1.19     -0.83   3604.33      1.00
#     f[128]     -0.99      0.11     -0.99     -1.16     -0.81   3627.78      1.00
#     f[129]     -0.98      0.11     -0.98     -1.16     -0.80   3604.75      1.00
#     f[130]     -0.96      0.11     -0.96     -1.15     -0.79   3594.61      1.00
#     f[131]     -0.95      0.11     -0.94     -1.13     -0.77   3619.36      1.00
#     f[132]     -0.94      0.11     -0.93     -1.12     -0.77   3587.78      1.00
#     f[133]     -0.92      0.11     -0.92     -1.09     -0.74   3630.71      1.00
#     f[134]     -0.91      0.11     -0.90     -1.09     -0.73   3582.84      1.00
#     f[135]     -0.89      0.11     -0.88     -1.06     -0.71   3629.99      1.00
#     f[136]     -0.88      0.11     -0.88     -1.06     -0.71   3582.76      1.00
#     f[137]     -0.86      0.11     -0.86     -1.04     -0.68   3595.89      1.00
#     f[138]     -0.85      0.11     -0.85     -1.03     -0.68   3562.45      1.00
#     f[139]     -0.83      0.11     -0.83     -1.01     -0.66   3536.99      1.00
#     f[140]     -0.82      0.11     -0.82     -0.99     -0.63   3525.76      1.00
#     f[141]     -0.80      0.11     -0.80     -0.97     -0.61   3513.28      1.00
#     f[142]     -0.79      0.11     -0.79     -0.96     -0.60   3517.99      1.00
#     f[143]     -0.78      0.11     -0.78     -0.97     -0.60   3480.31      1.00
#     f[144]     -0.77      0.11     -0.76     -0.94     -0.58   3494.53      1.00
#     f[145]     -0.75      0.11     -0.75     -0.94     -0.57   3419.70      1.00
#     f[146]     -0.74      0.11     -0.74     -0.92     -0.56   3445.26      1.00
#     f[147]     -0.71      0.12     -0.71     -0.90     -0.53   3404.26      1.00
#     f[148]     -0.70      0.12     -0.71     -0.89     -0.52   3351.21      1.00
#     f[149]     -0.69      0.12     -0.69     -0.90     -0.51   3375.40      1.00
#     f[150]     -0.68      0.12     -0.68     -0.88     -0.49   3258.31      1.00
#     f[151]     -0.65      0.12     -0.65     -0.86     -0.46   3320.07      1.00
#     f[152]     -0.64      0.12     -0.65     -0.85     -0.45   3210.69      1.00
#     f[153]     -0.63      0.12     -0.63     -0.83     -0.43   3263.96      1.00
#     f[154]     -0.61      0.12     -0.62     -0.82     -0.42   3158.77      1.00
#     f[155]     -0.60      0.13     -0.60     -0.81     -0.40   3160.71      1.00
#     f[156]     -0.59      0.13     -0.59     -0.80     -0.39   3102.94      1.00
#     f[157]     -0.57      0.13     -0.58     -0.80     -0.38   3086.78      1.00
#     f[158]     -0.56      0.13     -0.56     -0.77     -0.35   3056.47      1.00
#     f[159]     -0.54      0.13     -0.54     -0.76     -0.33   3039.70      1.00
#     f[160]     -0.52      0.13     -0.53     -0.75     -0.32   3005.55      1.00
#     f[161]     -0.50      0.14     -0.51     -0.74     -0.29   2988.08      1.00
#     f[162]     -0.49      0.14     -0.50     -0.72     -0.27   2947.44      1.00
#     f[163]     -0.47      0.14     -0.48     -0.71     -0.24   2950.95      1.00
#     f[164]     -0.46      0.14     -0.47     -0.69     -0.23   2892.52      1.00
#     f[165]     -0.44      0.15     -0.45     -0.67     -0.20   2874.07      1.00
#     f[166]     -0.43      0.15     -0.43     -0.67     -0.19   2848.49      1.00
#     f[167]     -0.41      0.15     -0.42     -0.64     -0.16   2796.51      1.00
#     f[168]     -0.39      0.15     -0.40     -0.63     -0.13   2801.33      1.00
#     f[169]     -0.38      0.16     -0.39     -0.62     -0.12   2752.36      1.00
#     f[170]     -0.35      0.16     -0.36     -0.62     -0.10   2745.54      1.00
#     f[171]     -0.34      0.16     -0.35     -0.59     -0.07   2705.76      1.00
#     f[172]     -0.32      0.16     -0.33     -0.58     -0.05   2691.04      1.00
#     f[173]     -0.31      0.16     -0.32     -0.56     -0.03   2675.61      1.00
#     f[174]     -0.28      0.17     -0.30     -0.55     -0.01   2648.06      1.00
#     f[175]     -0.28      0.17     -0.29     -0.56     -0.01   2632.66      1.00
#     f[176]     -0.25      0.17     -0.27     -0.52      0.04   2617.75      1.00
#     f[177]     -0.24      0.17     -0.26     -0.53      0.03   2583.58      1.00
#     f[178]     -0.22      0.18     -0.24     -0.50      0.07   2576.09      1.00
#     f[179]     -0.20      0.18     -0.22     -0.49      0.09   2556.95      1.00
#     f[180]     -0.18      0.18     -0.20     -0.47      0.12   2541.48      1.00
#     f[181]     -0.17      0.19     -0.18     -0.44      0.16   2523.70      1.00
#     f[182]     -0.14      0.19     -0.16     -0.42      0.19   2527.04      1.00
#     f[183]     -0.13      0.19     -0.15     -0.44      0.17   2495.64      1.00
#     f[184]     -0.10      0.19     -0.12     -0.38      0.23   2506.99      1.00
#     f[185]     -0.09      0.19     -0.11     -0.38      0.25   2483.29      1.00
#     f[186]     -0.07      0.19     -0.09     -0.38      0.25   2479.11      1.00
#     f[187]     -0.05      0.19     -0.06     -0.34      0.29   2468.51      1.00
#     f[188]     -0.04      0.20     -0.06     -0.35      0.28   2455.21      1.00
#     f[189]     -0.01      0.19     -0.02     -0.29      0.33   2449.08      1.00
#     f[190]      0.00      0.20     -0.02     -0.32      0.34   2434.24      1.00
#     f[191]      0.03      0.20      0.01     -0.28      0.36   2423.52      1.00
#     f[192]      0.04      0.20      0.02     -0.30      0.36   2407.16      1.00
#     f[193]      0.06      0.20      0.04     -0.25      0.40   2393.99      1.00
#     f[194]      0.07      0.21      0.05     -0.26      0.40   2390.38      1.00
#     f[195]      0.09      0.21      0.07     -0.23      0.43   2384.41      1.00
#     f[196]      0.11      0.21      0.09     -0.22      0.45   2386.41      1.00
#     f[197]      0.13      0.21      0.11     -0.20      0.48   2393.48      1.00
#     f[198]      0.14      0.21      0.12     -0.19      0.49   2377.25      1.00
#     f[199]      0.17      0.21      0.15     -0.15      0.52   2384.52      1.00
#     f[200]      0.19      0.21      0.17     -0.15      0.53   2369.66      1.00
#     f[201]      0.21      0.21      0.19     -0.10      0.58   2362.05      1.00
#     f[202]      0.22      0.21      0.20     -0.11      0.57   2359.26      1.00
#     f[203]      0.25      0.21      0.22     -0.07      0.60   2341.28      1.00
#     f[204]      0.26      0.21      0.24     -0.08      0.61   2348.84      1.00
#     f[205]      0.28      0.21      0.26     -0.03      0.65   2314.25      1.00
#     f[206]      0.30      0.22      0.28     -0.03      0.66   2336.89      1.00
#     f[207]      0.32      0.21      0.30      0.01      0.69   2302.57      1.00
#     f[208]      0.34      0.22      0.32     -0.00      0.69   2323.82      1.00
#     f[209]      0.36      0.22      0.34      0.04      0.72   2297.57      1.00
#     f[210]      0.37      0.22      0.35      0.05      0.75   2319.14      1.00
#     f[211]      0.39      0.22      0.37      0.05      0.74   2297.16      1.00
#     f[212]      0.41      0.22      0.39      0.09      0.78   2308.96      1.00
#     f[213]      0.43      0.22      0.40      0.10      0.79   2298.96      1.00
#     f[214]      0.45      0.22      0.43      0.13      0.82   2296.07      1.00
#     f[215]      0.47      0.22      0.45      0.13      0.82   2285.06      1.00
#     f[216]      0.49      0.22      0.47      0.16      0.84   2291.69      1.00
#     f[217]      0.50      0.22      0.48      0.16      0.85   2271.50      1.00
#     f[218]      0.52      0.22      0.50      0.20      0.88   2288.88      1.00
#     f[219]      0.53      0.22      0.51      0.21      0.90   2260.91      1.00
#     f[220]      0.56      0.22      0.54      0.24      0.92   2280.94      1.00
#     f[221]      0.58      0.21      0.56      0.22      0.90   2265.26      1.00
#     f[222]      0.60      0.21      0.57      0.24      0.93   2279.43      1.00
#     f[223]      0.61      0.21      0.59      0.26      0.94   2277.87      1.00
#     f[224]      0.63      0.21      0.60      0.28      0.96   2273.23      1.00
#     f[225]      0.65      0.21      0.62      0.35      1.02   2269.87      1.00
#     f[226]      0.67      0.21      0.64      0.32      0.99   2266.80      1.00
#     f[227]      0.69      0.21      0.66      0.38      1.05   2263.54      1.00
#     f[228]      0.71      0.21      0.68      0.38      1.04   2268.42      1.00
#     f[229]      0.72      0.21      0.69      0.41      1.07   2267.68      1.00
#     f[230]      0.74      0.21      0.72      0.43      1.08   2256.28      1.00
#     f[231]      0.77      0.20      0.74      0.47      1.13   2273.86      1.00
#     f[232]      0.79      0.20      0.76      0.48      1.12   2262.25      1.00
#     f[233]      0.80      0.20      0.78      0.49      1.13   2282.60      1.00
#     f[234]      0.82      0.20      0.79      0.51      1.15   2275.76      1.00
#     f[235]      0.84      0.20      0.81      0.53      1.16   2287.23      1.00
#     f[236]      0.85      0.20      0.83      0.56      1.19   2281.46      1.00
#     f[237]      0.88      0.19      0.86      0.59      1.20   2286.63      1.00
#     f[238]      0.89      0.19      0.87      0.60      1.22   2306.07      1.00
#     f[239]      0.91      0.19      0.89      0.62      1.22   2287.64      1.00
#     f[240]      0.93      0.19      0.90      0.65      1.25   2312.93      1.00
#     f[241]      0.96      0.19      0.93      0.67      1.27   2303.56      1.00
#     f[242]      0.97      0.18      0.95      0.70      1.28   2323.02      1.00
#     f[243]      0.99      0.18      0.97      0.72      1.31   2333.54      1.00
#     f[244]      1.00      0.18      0.98      0.74      1.31   2347.33      1.00
#     f[245]      1.03      0.18      1.01      0.75      1.32   2369.12      1.00
#     f[246]      1.04      0.17      1.02      0.77      1.33   2354.53      1.00
#     f[247]      1.07      0.17      1.05      0.80      1.35   2395.91      1.00
#     f[248]      1.08      0.17      1.06      0.82      1.36   2387.39      1.00
#     f[249]      1.09      0.17      1.07      0.86      1.39   2427.58      1.00
#     f[250]      1.11      0.17      1.10      0.84      1.37   2437.07      1.00
#     f[251]      1.13      0.16      1.11      0.89      1.41   2443.84      1.00
#     f[252]      1.15      0.16      1.13      0.92      1.44   2467.73      1.00
#     f[253]      1.16      0.16      1.14      0.93      1.43   2456.93      1.00
#     f[254]      1.18      0.16      1.16      0.95      1.45   2499.85      1.00
#     f[255]      1.20      0.15      1.18      0.97      1.46   2509.76      1.00
#     f[256]      1.21      0.15      1.20      0.98      1.47   2546.58      1.00
#     f[257]      1.23      0.15      1.22      0.99      1.47   2565.11      1.00
#     f[258]      1.24      0.15      1.23      1.01      1.49   2596.75      1.00
#     f[259]      1.26      0.15      1.25      1.03      1.49   2643.35      1.00
#     f[260]      1.27      0.14      1.26      1.06      1.52   2667.84      1.00
#     f[261]      1.30      0.14      1.28      1.07      1.52   2724.28      1.00
#     f[262]      1.31      0.14      1.30      1.11      1.55   2777.03      1.00
#     f[263]      1.32      0.14      1.31      1.10      1.54   2784.40      1.00
#     f[264]      1.34      0.13      1.33      1.13      1.56   2862.85      1.00
#     f[265]      1.36      0.13      1.35      1.16      1.58   2873.25      1.00
#     f[266]      1.37      0.13      1.36      1.16      1.57   2977.77      1.00
#     f[267]      1.38      0.13      1.38      1.19      1.60   2943.68      1.00
#     f[268]      1.40      0.12      1.39      1.21      1.61   3089.62      1.00
#     f[269]      1.41      0.12      1.41      1.23      1.62   3049.91      1.00
#     f[270]      1.42      0.12      1.41      1.24      1.62   3184.67      1.00
#     f[271]      1.44      0.12      1.43      1.26      1.64   3187.35      1.00
#     f[272]      1.45      0.12      1.45      1.26      1.64   3376.94      1.00
#     f[273]      1.46      0.11      1.45      1.27      1.64   3338.50      1.00
#     f[274]      1.48      0.11      1.47      1.30      1.66   3456.08      1.00
#     f[275]      1.48      0.11      1.48      1.29      1.65   3556.02      1.00
#     f[276]      1.49      0.11      1.49      1.31      1.67   3640.78      1.00
#     f[277]      1.51      0.11      1.51      1.34      1.68   3755.66      1.00
#     f[278]      1.52      0.11      1.52      1.36      1.70   3876.18      1.00
#     f[279]      1.53      0.11      1.53      1.36      1.70   3882.40      1.00
#     f[280]      1.54      0.10      1.54      1.36      1.70   3876.13      1.00
#     f[281]      1.56      0.10      1.56      1.40      1.73   4014.58      1.00
#     f[282]      1.56      0.10      1.56      1.40      1.72   4051.01      1.00
#     f[283]      1.57      0.10      1.58      1.40      1.73   4155.42      1.00
#     f[284]      1.58      0.10      1.59      1.42      1.75   4113.28      1.00
#     f[285]      1.59      0.10      1.60      1.43      1.75   4249.31      1.00
#     f[286]      1.59      0.10      1.60      1.43      1.75   4115.23      1.00
#     f[287]      1.61      0.10      1.62      1.44      1.76   4185.48      1.00
#     f[288]      1.61      0.10      1.62      1.45      1.76   4157.38      1.00
#     f[289]      1.62      0.10      1.63      1.46      1.78   4141.84      1.00
#     f[290]      1.62      0.10      1.63      1.45      1.77   4030.21      1.00
#     f[291]      1.63      0.10      1.64      1.47      1.78   4080.89      1.00
#     f[292]      1.64      0.10      1.65      1.48      1.80   3896.79      1.00
#     f[293]      1.64      0.10      1.65      1.48      1.79   3882.00      1.00
#     f[294]      1.65      0.10      1.66      1.48      1.80   3697.29      1.00
#     f[295]      1.65      0.10      1.66      1.49      1.81   3701.21      1.00
#     f[296]      1.66      0.10      1.67      1.49      1.82   3573.96      1.00
#     f[297]      1.66      0.10      1.68      1.49      1.81   3529.03      1.00
#     f[298]      1.67      0.10      1.68      1.50      1.83   3489.38      1.00
#     f[299]      1.66      0.10      1.68      1.49      1.83   3365.07      1.00
#     f[300]      1.67      0.11      1.69      1.50      1.83   3357.63      1.00
#     f[301]      1.67      0.11      1.69      1.51      1.84   3266.70      1.00
#     f[302]      1.68      0.11      1.70      1.50      1.84   3239.85      1.00
#     f[303]      1.68      0.11      1.69      1.50      1.84   3153.83      1.00
#     f[304]      1.68      0.11      1.69      1.50      1.84   3082.27      1.00
#     f[305]      1.68      0.11      1.69      1.51      1.84   3051.73      1.00
#     f[306]      1.68      0.11      1.69      1.50      1.84   2960.66      1.00
#     f[307]      1.69      0.11      1.70      1.50      1.85   2963.63      1.00
#     f[308]      1.68      0.11      1.70      1.50      1.85   2880.15      1.00
#     f[309]      1.68      0.11      1.70      1.49      1.85   2862.29      1.00
#     f[310]      1.68      0.11      1.69      1.49      1.85   2796.65      1.00
#     f[311]      1.67      0.11      1.69      1.49      1.85   2792.28      1.00
#     f[312]      1.67      0.11      1.69      1.48      1.84   2750.37      1.00
#     f[313]      1.67      0.11      1.69      1.49      1.85   2727.71      1.00
#     f[314]      1.67      0.12      1.68      1.48      1.84   2680.13      1.00
#     f[315]      1.66      0.12      1.68      1.47      1.84   2684.91      1.00
#     f[316]      1.66      0.12      1.68      1.47      1.83   2629.09      1.00
#     f[317]      1.65      0.12      1.67      1.46      1.82   2670.20      1.00
#     f[318]      1.65      0.12      1.66      1.46      1.83   2595.59      1.00
#     f[319]      1.65      0.12      1.66      1.45      1.82   2630.11      1.00
#     f[320]      1.64      0.12      1.65      1.44      1.81   2544.20      1.00
#     f[321]      1.63      0.12      1.65      1.43      1.80   2594.41      1.00
#     f[322]      1.62      0.12      1.64      1.43      1.80   2522.81      1.00
#     f[323]      1.62      0.12      1.64      1.42      1.79   2557.81      1.00
#     f[324]      1.61      0.12      1.62      1.42      1.78   2531.36      1.00
#     f[325]      1.61      0.12      1.62      1.41      1.78   2526.78      1.00
#     f[326]      1.60      0.12      1.62      1.41      1.78   2540.01      1.00
#     f[327]      1.59      0.12      1.61      1.39      1.76   2517.65      1.00
#     f[328]      1.58      0.12      1.60      1.39      1.76   2545.59      1.00
#     f[329]      1.58      0.12      1.59      1.39      1.76   2507.99      1.00
#     f[330]      1.57      0.12      1.59      1.37      1.74   2526.15      1.00
#     f[331]      1.56      0.12      1.57      1.36      1.73   2540.65      1.00
#     f[332]      1.55      0.12      1.57      1.37      1.74   2493.77      1.00
#     f[333]      1.54      0.12      1.56      1.36      1.72   2568.48      1.00
#     f[334]      1.53      0.12      1.55      1.35      1.72   2565.72      1.00
#     f[335]      1.52      0.11      1.54      1.33      1.70   2525.23      1.00
#     f[336]      1.51      0.11      1.53      1.32      1.68   2588.60      1.00
#     f[337]      1.50      0.11      1.51      1.30      1.67   2601.91      1.00
#     f[338]      1.49      0.11      1.50      1.31      1.67   2621.49      1.00
#     f[339]      1.48      0.11      1.50      1.29      1.65   2640.82      1.00
#     f[340]      1.47      0.11      1.48      1.29      1.64   2656.16      1.00
#     f[341]      1.46      0.11      1.47      1.27      1.62   2691.11      1.00
#     f[342]      1.45      0.11      1.46      1.26      1.62   2719.46      1.00
#     f[343]      1.43      0.11      1.45      1.26      1.61   2749.33      1.00
#     f[344]      1.42      0.11      1.43      1.25      1.60   2797.82      1.00
#     f[345]      1.41      0.11      1.43      1.24      1.59   2823.54      1.00
#     f[346]      1.41      0.11      1.42      1.23      1.57   2856.16      1.00
#     f[347]      1.39      0.11      1.40      1.21      1.56   2901.59      1.00
#     f[348]      1.38      0.11      1.39      1.20      1.54   2954.80      1.00
#     f[349]      1.37      0.11      1.38      1.19      1.53   3000.21      1.00
#     f[350]      1.35      0.11      1.36      1.17      1.52   3039.35      1.00
#     f[351]      1.34      0.10      1.35      1.17      1.51   3130.52      1.00
#     f[352]      1.33      0.11      1.34      1.16      1.51   3137.49      1.00
#     f[353]      1.31      0.11      1.33      1.14      1.48   3199.97      1.00
#     f[354]      1.30      0.10      1.31      1.13      1.46   3318.98      1.00
#     f[355]      1.30      0.11      1.31      1.12      1.46   3363.68      1.00
#     f[356]      1.27      0.10      1.28      1.11      1.44   3452.93      1.00
#     f[357]      1.27      0.10      1.28      1.11      1.45   3512.08      1.00
#     f[358]      1.25      0.10      1.26      1.08      1.41   3598.35      1.00
#     f[359]      1.23      0.10      1.24      1.07      1.41   3683.69      1.00
#     f[360]      1.22      0.10      1.22      1.05      1.38   3847.02      1.00
#     f[361]      1.22      0.10      1.23      1.04      1.38   3977.24      1.00
#     f[362]      1.19      0.10      1.20      1.02      1.35   3991.31      1.00
#     f[363]      1.18      0.10      1.19      1.02      1.35   4061.16      1.00
#     f[364]      1.17      0.10      1.18      1.00      1.33   4191.37      1.00
#     f[365]      1.15      0.10      1.15      0.98      1.31   4284.71      1.00
#     f[366]      1.13      0.10      1.13      0.96      1.29   4441.28      1.00
#     f[367]      1.15      0.11      1.15      0.98      1.32   4444.32      1.00
#     f[368]      1.12      0.10      1.12      0.95      1.28   4567.54      1.00
#     f[369]      1.06      0.10      1.06      0.90      1.22   4551.67      1.00
#     f[370]      1.09      0.11      1.09      0.90      1.24   4724.43      1.00
#     f[371]      1.15      0.11      1.15      0.96      1.33   4851.49      1.00
#     f[372]      1.04      0.10      1.04      0.89      1.21   4821.27      1.00
#     f[373]      0.93      0.10      0.93      0.78      1.11   4827.01      1.00
#     f[374]      1.08      0.12      1.07      0.88      1.27   4976.44      1.00
#     f[375]      0.97      0.12      0.96      0.78      1.17   4962.27      1.00
#     f[376]      0.86      0.11      0.86      0.69      1.04   4922.97      1.00
#     f[377]      0.92      0.11      0.92      0.74      1.10   4952.59      1.00
#     f[378]      0.93      0.12      0.93      0.74      1.13   4936.98      1.00
#     f[379]      0.89      0.11      0.89      0.71      1.08   4931.89      1.00
#     f[380]      0.88      0.12      0.87      0.68      1.07   4915.23      1.00
#     f[381]      0.86      0.12      0.85      0.68      1.05   4980.63      1.00
#     f[382]      0.83      0.12      0.82      0.64      1.02   4862.23      1.00
#     f[383]      0.84      0.12      0.84      0.65      1.05   4993.41      1.00
#     f[384]      0.82      0.12      0.81      0.62      1.01   4822.12      1.00
#     f[385]      0.82      0.13      0.81      0.63      1.04   4910.03      1.00
#     f[386]      0.81      0.13      0.80      0.60      1.01   4738.51      1.00
#     f[387]      0.76      0.13      0.75      0.57      0.98   4781.62      1.00
#     f[388]      0.76      0.13      0.75      0.54      0.96   4617.52      1.00
#     f[389]      0.80      0.13      0.79      0.57      1.00   4835.06      1.00
#     f[390]      0.71      0.13      0.70      0.49      0.91   4598.26      1.00
#     f[391]      0.72      0.13      0.71      0.51      0.92   4629.97      1.00
#     f[392]      0.77      0.14      0.75      0.52      0.98   4589.31      1.00
#     f[393]      0.70      0.12      0.68      0.50      0.89   4394.36      1.00
#     f[394]      0.69      0.13      0.68      0.48      0.90   4562.24      1.00
#     f[395]      0.85      0.13      0.83      0.63      1.05   4552.26      1.00
#     f[396]      0.67      0.14      0.66      0.44      0.89   4519.59      1.00
#     f[397]      0.50      0.11      0.48      0.31      0.67   4332.54      1.00
#     f[398]      0.80      0.14      0.79      0.55      1.02   4648.36      1.00
#     f[399]      1.12      0.25      1.10      0.70      1.48   4652.93      1.00
#      noise      0.12      0.05      0.11      0.04      0.19   1265.25      1.00
#       z[0]      0.00      1.02      0.00     -1.70      1.62   3581.83      1.00
#       z[1]      0.12      0.99      0.12     -1.52      1.70   5492.82      1.00
#       z[2]     -0.11      1.00     -0.10     -1.74      1.49   4057.28      1.00
#       z[3]     -0.02      1.01     -0.02     -1.79      1.55   4332.90      1.00
#       z[4]     -0.06      1.01     -0.06     -1.82      1.50   4573.04      1.00
#       z[5]     -1.11      0.95     -1.14     -2.54      0.54   1738.76      1.00
#       z[6]     -0.11      0.97     -0.12     -1.71      1.47   5722.87      1.00
#       z[7]     -0.62      0.42     -0.61     -1.28      0.09   2457.83      1.00
#       z[8]      0.08      1.00      0.07     -1.67      1.60   4742.74      1.00
#       z[9]      0.15      1.00      0.14     -1.49      1.79   4424.43      1.00
#      z[10]      0.10      0.99      0.08     -1.53      1.71   4494.06      1.00
#      z[11]     -0.09      1.00     -0.08     -1.71      1.58   5354.10      1.00
#      z[12]     -0.03      1.01     -0.02     -1.76      1.56   4078.54      1.00
#      z[13]     -0.05      1.00     -0.03     -1.75      1.54   4482.37      1.00
#      z[14]     -0.02      1.00     -0.02     -1.73      1.55   4679.86      1.00
#      z[15]     -0.01      1.02     -0.01     -1.65      1.68   5400.38      1.00
#      z[16]      0.11      0.99      0.10     -1.53      1.70   4753.73      1.00
#      z[17]      0.10      0.20      0.09     -0.20      0.46   2108.91      1.00
#      z[18]     -0.15      1.01     -0.15     -1.74      1.57   5104.08      1.00
#      z[19]     -0.07      1.00     -0.08     -1.85      1.46   4875.93      1.00
#      z[20]      0.01      1.03      0.01     -1.79      1.61   5696.31      1.00
#      z[21]      0.06      1.01      0.04     -1.52      1.78   3397.04      1.00
#      z[22]      2.56      0.15      2.56      2.31      2.79   2188.49      1.00
#      z[23]     -0.00      1.00     -0.02     -1.65      1.64   5591.55      1.00
#      z[24]      0.01      0.98      0.02     -1.59      1.61   5079.90      1.00
#      z[25]      0.06      0.99      0.04     -1.54      1.66   4872.07      1.00
#      z[26]      0.01      1.02      0.01     -1.78      1.57   4845.86      1.00
#      z[27]      0.81      0.74      0.84     -0.41      2.01   2422.71      1.00
#      z[28]     -0.01      0.97     -0.01     -1.57      1.63   5189.39      1.00
#      z[29]     -0.84      0.15     -0.86     -1.07     -0.60   2358.82      1.00
#
# Number of divergences: 55

# %%
# Plotting results after inference using MCMC.
_, axes = plt.subplots(nrows=1, ncols=len(obs_locations)+1, figsize=(25,6))

# Plotting VGAE prior predictive.
RNG_KEY, prior_rng = jax.random.split(RNG_KEY)
prior_predictions = Predictive(vgae_mcmc_predictive_model, num_samples=10000)(prior_rng)['f']
mean_prior_pred = jnp.mean(prior_predictions, axis=0)
hpdi_prior_pred = hpdi(prior_predictions, 0.9)

num_draws_to_plot = 30
for j in range(num_draws_to_plot):
    axes[0].plot(X, prior_predictions[j], alpha=0.1, color='darkgreen')
axes[0].plot(X, prior_predictions[0], 
             alpha=0.1, color='darkgreen', label='prior draws')  
axes[0].fill_between(X, hpdi_prior_pred[0], hpdi_prior_pred[1], 
                     alpha=0.1, interpolate=True, label='VGAE prior: 95% BCI')
axes[0].plot(X, mean_prior_pred, label='mean')
axes[0].set_title('VGAE prior')


# Plotting VGAE posterior predictive
num_draws_to_plot = 15
for idx in range(len(obs_locations)):
    axes[idx+1].fill_between(X, hpdi_post_preds_list[idx][0], hpdi_post_preds_list[idx][1], 
                           alpha=0.1, interpolate=True, label='VGAE posterior: 95% BCI')
    for j in range(num_draws_to_plot): 
        axes[idx+1].plot(X, predictions_list[idx][j], alpha=0.1, color='darkgreen')
    axes[idx+1].plot(X, predictions_list[idx][0],
                   alpha=0.1, color='darkgreen', label='posterior draws')  
    axes[idx+1].plot(X, mean_post_preds_list[idx], label='predicted mean')
    axes[idx+1].plot(X, gp_draw, label='ground truth', color='orange')
    axes[idx+1].scatter(obs_xs[idx], obs_ys[idx], color='red', label='observed data', s=60)
    axes[idx+1].set_title('n_datapoints = ' + str(len(obs_locations[idx])))


for i in range(len(obs_locations)+1):    
    axes[i].legend(loc=4)
    axes[i].set_ylim([-2.5, 2.5])

plt.tight_layout()
plt.show()

# %%
# Plotting results after inference using MCMC.
fig, ax = plt.subplots(1, 1, figsize=(10, 7))

num_draws_to_plot = 15
for j in range(num_draws_to_plot):
    ax.plot(X, prior_predictions[j], alpha=0.1, color='darkgreen')
ax.plot(X, prior_predictions[0], 
             alpha=0.1, color='darkgreen', label='prior draws')  
ax.fill_between(X, hpdi_prior_pred[0], hpdi_prior_pred[1], 
                     alpha=0.1, interpolate=True, label='VAE prior: 95% BCI')
ax.plot(X, mean_prior_pred, label='mean')
# ax.set_title('VAE prior')

ax.set_xlabel('Locations', fontsize=18)
ax.set_ylabel(r'$y$', fontsize=18)
ax.tick_params(axis='both', which='major', labelsize=15)

plt.tight_layout()
plt.show();

save_to_dir = FIG_PATH / 'publication'
fig.savefig(save_to_dir / '1DGP_inference_1.jpg', dpi=300)

# %%
# Plotting VAE posterior predictive
fig, ax = plt.subplots(1, 1, figsize=(10, 7))

ax.plot(X, gp_draw, label='ground truth', color='orange')
# ax.set_title('n_datapoints = ' + str(len(obs_locations[idx])))

ax.legend(loc=4)
ax.set_ylim([-2.5, 2.5])

ax.set_xlabel('Locations', fontsize=18)
ax.set_ylabel(r'$y$', fontsize=18)
ax.tick_params(axis='both', which='major', labelsize=15)

plt.tight_layout()
plt.show()

save_to_dir = FIG_PATH / 'publication'
fig.savefig(save_to_dir / f'1DGP_inference_00.jpg', dpi=300)

# %%
# Plotting VAE posterior predictive
num_draws_to_plot = 15
for idx in range(len(obs_locations)):
    print(f'n_datapoints = {len(obs_locations[idx])}')
    fig, ax = plt.subplots(1, 1, figsize=(10, 7))
    
    ax.fill_between(X, hpdi_post_preds_list[idx][0], hpdi_post_preds_list[idx][1], 
                           alpha=0.1, interpolate=True, label='VAE posterior: 95% BCI')
    for j in range(num_draws_to_plot): 
        ax.plot(X, predictions_list[idx][j], alpha=0.1, color='darkgreen')
    ax.plot(X, predictions_list[idx][0],
                   alpha=0.1, color='darkgreen', label='posterior draws')  
    ax.plot(X, mean_post_preds_list[idx], label='predicted mean')
    ax.plot(X, gp_draw, label='ground truth', color='orange')
    ax.scatter(obs_xs[idx], obs_ys[idx], color='red', label='observed data', s=60)
    # ax.set_title('n_datapoints = ' + str(len(obs_locations[idx])))
    
    ax.legend(loc=4)
    ax.set_ylim([-2.5, 2.5])
    
    ax.set_xlabel('Locations', fontsize=18)
    ax.set_ylabel(r'$y$', fontsize=18)
    ax.tick_params(axis='both', which='major', labelsize=15)
    
    plt.tight_layout()
    plt.show()
    
    save_to_dir = FIG_PATH / 'publication'
    fig.savefig(save_to_dir / f'1DGP_inference_{idx+2}.jpg', dpi=300)
# Out:
# n_datapoints = 2
# n_datapoints = 4
# n_datapoints = 6

# %%
for idx, mean in enumerate(mean_post_preds_list):
    mse_vgae = np.mean((gp_draw.flatten() -  mean)**2)
    print(f'mse_vgae ({len(obs_locations[idx])}) = {mse_vgae}')
# Out:
# mse_vgae (2) = 0.24173979461193085
# mse_vgae (4) = 0.050907135009765625
# mse_vgae (6) = 0.024274328723549843

# %%
# RNG_KEY, gp_rng, vgae_rng = jax.random.split(jax.random.PRNGKey(44), 3)
RNG_KEY, gp_rng, vgae_rng = jax.random.split(jax.random.PRNGKey(6), 3)
# RNG_KEY, gp_rng, vgae_rng = jax.random.split(jax.random.PRNGKey(16), 3)

gp_predictive = Predictive(dataset_1dgp.gp_predictive_model, num_samples=100)
gp_draws = gp_predictive(gp_rng, x=X, gp_kernel=GP1D_ARGS.kernel, kernel_jitter=1e-5)['y']
gp_draws = dataset_1dgp.remove_nans_from_gp(gp_draws)

vgae_predictive = Predictive(vgae_mcmc_predictive_model, num_samples=100)
vgae_draws = vgae_predictive(vgae_rng)['f']
vgae_draws = dataset_1dgp.remove_nans_from_gp(vgae_draws)

m_vgae = np.cov(np.transpose(vgae_draws))
m_gp = np.cov(np.transpose(gp_draws))

cmap_choice = 'plasma'

#'plasma'
#'inferno'
fig, axs = plt.subplots(nrows=1, ncols=2, figsize = (8,4))
axs[0].imshow(m_gp, cmap=cmap_choice)
axs[0].axis('off')
axs[0].set_title('GP covariance matrix')

axs[1].imshow(m_vgae, cmap=cmap_choice)
axs[1].axis('off')
axs[1].set_title('VGAE covariance matrix')
# Out:
# Text(0.5, 1.0, 'VGAE covariance matrix')

# %%
assert False
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# /Users/salmanfaris/Desktop/ds-projects/msc-proj/PriorVGAE/1dGP_priorVGAE_FullyAdjLayer.ipynb Cell 50 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/Users/salmanfaris/Desktop/ds-projects/msc-proj/PriorVGAE/1dGP_priorVGAE_FullyAdjLayer.ipynb#Y164sZmlsZQ%3D%3D?line=0'>1</a> assert False
#
# AssertionError:

# %% [markdown]
# ## Priors learnt by VAE

# %%
vae_model_name = '1DGP_PriorVAE_0.01lr_5000epochs_50h1Dim_50h2Dim_30latentDim_400numLocations_100batchSize'
model_path = Path('./models/') / vae_model_name

print(f"Loading VAE model from {model_path}")
vae_params = model.restore_params(model_path)
# Out:
# Loading VAE model from models/1DGP_PriorVAE_0.01lr_5000epochs_50h1Dim_50h2Dim_30latentDim_400numLocations_100batchSize

# %%
vae_decoder_params_keys = [k for k in list(vae_params.keys()) if k.startswith('variational_auto_encoder/decoder')]
vae_decoder_params = {}
for full_key_name in vae_decoder_params_keys:
    key_name = ('/').join(full_key_name.split('/')[2:])  # remove the 'variational_auto_encoder/' prefix
    vae_decoder_params[key_name] = vae_params[full_key_name]

vae_decoder_net = hk.without_apply_rng(
    hk.transform(  
      lambda z: model.priorvae_decoder(
        z,
        hidden1_dim=50,
        hidden2_dim=50,
        output_dim=GP1D_ARGS.num_locations
    )
))

def vae_decoder_predictive_model():
    z = numpyro.sample('z', dist.Normal(0, 1).expand([30]))
    vae_out = jnp.squeeze(vae_decoder_net.apply(vae_decoder_params, z))
    numpyro.deterministic('f', vae_out)

# %%
# Comparing distribution of GP draws with learnt VAE priors.

RNG_KEY, rng_gp, rng_vae = jax.random.split(RNG_KEY, 3)
gp_draws = dataset_1dgp.generate_gp_batch(
    rng_gp, X, batch_size=1000, kernel=GP1D_ARGS.kernel)  # batch_size is equivalent to `num_samples`.
vae_draws = Predictive(vae_decoder_predictive_model, num_samples=1000)(rng_vae)['f']

# Computing the mean and HPDI of the GP draws and VAE draws.
gp_draws = gp_draws[~np.isnan(gp_draws).any(axis=1), :]
mean_gp = jnp.nanmean(gp_draws, axis=0)
hpdi_gp = hpdi(gp_draws, 0.9)

vae_draws = vae_draws[~np.isnan(vae_draws).any(axis=1), :]
mean_vae = jnp.nanmean(vae_draws, axis=0)
hpdi_vae = hpdi(vae_draws, 0.9)

# Plotting the GP draws and VAE draws.
_, axes = plt.subplots(1, 2, figsize=(18, 5))

y_lim = [-2, 2]
lines_alpha_gp = 0.1
lines_alpha_vae = 0.1
num_draws_to_plot = 15
plotting.plot_gp_draws_with_stats(
    X, gp_draws, 
    mean_gp, hpdi_gp,lines_alpha_gp, 
    num_draws_to_plot, y_lim=y_lim, ax=axes[0],
    title='GP priors to encode', y_label='$y=f_{GP}(x)$')
plotting.plot_gp_draws_with_stats(
    X, vae_draws, mean_vae, hpdi_vae,
    lines_alpha_vae, num_draws_to_plot, 
    y_lim=y_lim, ax=axes[1],
    title='VAE learnt priors', y_label='$y=f_{VAE}(x)$')

plt.show()

# %%
# Plotting the GP draws and VAE draws.
fig, ax = plt.subplots(1, 1, figsize=(10, 7))

y_lim = [-2, 2]
lines_alpha_vae = 0.1
num_draws_to_plot = 15
plotting.plot_gp_draws_with_stats(
    X, vae_draws, 
    mean_vae, hpdi_vae,lines_alpha_vae, 
    num_draws_to_plot, y_lim=y_lim, ax=ax)

ax.tick_params(axis='both', which='major', labelsize=15)

# ax.set_title('Priors learnt by VAE', fontsize=18)
ax.set_ylabel('$y=f_{\mathrm{VAE}}(x)$', fontsize=18)
ax.set_xlabel('$x$', fontsize=18)

plt.tight_layout()
plt.show()

save_to_dir = FIG_PATH / 'publication'
fig.savefig(save_to_dir / '1DGP_priors_VAE.jpg', dpi=300)

# %%
def vae_model_mcmc(y=None, obs_idx=None):
    z = numpyro.sample('z', dist.Normal(0, 1).expand([30]))
    vae_out = jnp.squeeze(vae_decoder_net.apply(vae_decoder_params, z))
    f = numpyro.deterministic('f', vae_out)
    sigma = numpyro.sample('noise', dist.HalfNormal(0.1))

    if y is None: # at prediction time
        numpyro.sample('y_pred', dist.Normal(f, sigma))
    else: # at inference time
        numpyro.sample('y', dist.Normal(f[obs_idx], sigma), obs=y)

# %%
vae_mean_post_preds_list = []
vae_hpdi_post_preds_list = []
obs_xs = []
obs_ys = []
vae_predictions_list = []
vae_mcmc_objs = []

RNG_KEY, inference_rng = jax.random.split(RNG_KEY)

for i, obs_location in enumerate(obs_locations):
    mcmc_rng, pred_rng = jax.random.split(jax.random.fold_in(inference_rng, i))
    
    x_obs = X[obs_location]
    y_obs = jnp.squeeze(y_draw[obs_location])
    
    print(f'Running chain for n_obs = {len(obs_location)}')
    
    # MCMC sampling
    start = time.time()
    init_strategy = init_to_median(num_samples=10)
    kernel = NUTS(vae_model_mcmc, init_strategy=init_strategy)
    mcmc = MCMC(
        kernel,
        num_warmup=1000,
        num_samples=1000,
        num_chains=4,
        thinning=1,
        progress_bar=False if 'NUMPYRO_SPHINXBUILD' in os.environ else True,
    )
    mcmc.run(mcmc_rng, y_obs, obs_location)
    print('\nMCMC elapsed time:', time.time() - start)
    
    mcmc_samples = mcmc.get_samples()
    vae_mcmc_objs.append(mcmc)

    predictions = Predictive(vae_model_mcmc, mcmc_samples)(pred_rng)['f']
    mean_post_pred = jnp.mean(predictions, axis=0)
    hpdi_post_pred = hpdi(predictions, 0.9)
    
    obs_xs.append(x_obs)
    obs_ys.append(y_obs)
    vae_predictions_list.append(predictions)
    vae_mean_post_preds_list.append(mean_post_pred)
    vae_hpdi_post_preds_list.append(hpdi_post_pred)
# Out:
# Running chain for n_obs = 2
# /var/folders/6h/lf5jg1fn1h163zw3042tmtnc0000gn/T/ipykernel_13485/338970312.py:22: UserWarning: There are not enough devices to run parallel chains: expected 4 but got 1. Chains will be drawn sequentially. If you are running MCMC in CPU, consider using `numpyro.set_host_device_count(4)` at the beginning of your program. You can double-check how many devices are available in your system using `jax.local_device_count()`.
#   mcmc = MCMC(
# sample: 100%|██████████| 2000/2000 [00:02<00:00, 938.29it/s, 63 steps of size 9.82e-02. acc. prob=0.81]
# sample: 100%|██████████| 2000/2000 [00:00<00:00, 2310.77it/s, 9 steps of size 1.34e-01. acc. prob=0.77]
# sample: 100%|██████████| 2000/2000 [00:00<00:00, 2188.09it/s, 63 steps of size 1.01e-01. acc. prob=0.85]
# sample: 100%|██████████| 2000/2000 [00:00<00:00, 2345.17it/s, 31 steps of size 1.29e-01. acc. prob=0.72]
# MCMC elapsed time: 5.257370948791504
# /var/folders/6h/lf5jg1fn1h163zw3042tmtnc0000gn/T/ipykernel_13485/338970312.py:22: UserWarning: There are not enough devices to run parallel chains: expected 4 but got 1. Chains will be drawn sequentially. If you are running MCMC in CPU, consider using `numpyro.set_host_device_count(4)` at the beginning of your program. You can double-check how many devices are available in your system using `jax.local_device_count()`.
#   mcmc = MCMC(
# Running chain for n_obs = 4
# sample: 100%|██████████| 2000/2000 [00:02<00:00, 887.56it/s, 63 steps of size 7.09e-02. acc. prob=0.85]
# sample: 100%|██████████| 2000/2000 [00:00<00:00, 2107.36it/s, 31 steps of size 1.13e-01. acc. prob=0.78]
# sample: 100%|██████████| 2000/2000 [00:00<00:00, 2274.65it/s, 31 steps of size 1.02e-01. acc. prob=0.66]
# sample: 100%|██████████| 2000/2000 [00:00<00:00, 2026.01it/s, 63 steps of size 5.82e-02. acc. prob=0.89]
# MCMC elapsed time: 5.265931129455566
# /var/folders/6h/lf5jg1fn1h163zw3042tmtnc0000gn/T/ipykernel_13485/338970312.py:22: UserWarning: There are not enough devices to run parallel chains: expected 4 but got 1. Chains will be drawn sequentially. If you are running MCMC in CPU, consider using `numpyro.set_host_device_count(4)` at the beginning of your program. You can double-check how many devices are available in your system using `jax.local_device_count()`.
#   mcmc = MCMC(
# Running chain for n_obs = 6
# sample: 100%|██████████| 2000/2000 [00:02<00:00, 914.89it/s, 7 steps of size 4.59e-01. acc. prob=0.84]
# sample: 100%|██████████| 2000/2000 [00:00<00:00, 2673.77it/s, 7 steps of size 4.07e-01. acc. prob=0.89]
# sample: 100%|██████████| 2000/2000 [00:00<00:00, 2724.60it/s, 7 steps of size 4.35e-01. acc. prob=0.88]
# sample: 100%|██████████| 2000/2000 [00:00<00:00, 2783.88it/s, 7 steps of size 4.09e-01. acc. prob=0.89]
# MCMC elapsed time: 4.591670036315918

# %%
for mcmc in vae_mcmc_objs:
    compute_ess(mcmc)
# Out:
# Average ESS for all effects : 1833
# Average ESS for all effects : 1922
# Average ESS for all effects : 3465

# %%
# Plotting results after inference using MCMC.
_, axes = plt.subplots(nrows=1, ncols=len(obs_locations)+1, figsize=(25,6))

# Plotting VAE prior predictive.
RNG_KEY, prior_rng = jax.random.split(RNG_KEY)
vae_prior_predictions = Predictive(vae_model_mcmc, num_samples=10000)(prior_rng)['f']
vae_mean_prior_pred = jnp.mean(vae_prior_predictions, axis=0)
vae_hpdi_prior_pred = hpdi(vae_prior_predictions, 0.9)

num_draws_to_plot = 30
for j in range(num_draws_to_plot):
    axes[0].plot(X, vae_prior_predictions[j], alpha=0.1, color='darkgreen')
axes[0].plot(X, vae_prior_predictions[0], 
             alpha=0.1, color='darkgreen', label='prior draws')  
axes[0].fill_between(X, vae_hpdi_prior_pred[0], vae_hpdi_prior_pred[1], 
                     alpha=0.1, interpolate=True, label='VAE prior: 95% BCI')
axes[0].plot(X, vae_mean_prior_pred, label='mean')
axes[0].set_title('VAE prior')


# Plotting VAE posterior predictive
num_draws_to_plot = 15
for idx in range(len(obs_locations)):
    axes[idx+1].fill_between(X, vae_hpdi_post_preds_list[idx][0], vae_hpdi_post_preds_list[idx][1], 
                           alpha=0.1, interpolate=True, label='VAE posterior: 95% BCI')
    for j in range(num_draws_to_plot): 
        axes[idx+1].plot(X, vae_predictions_list[idx][j], alpha=0.1, color='darkgreen')
    axes[idx+1].plot(X, vae_predictions_list[idx][0],
                   alpha=0.1, color='darkgreen', label='posterior draws')  
    axes[idx+1].plot(X, vae_mean_post_preds_list[idx], label='predicted mean')
    axes[idx+1].plot(X, gp_draw, label='ground truth', color='orange')
    axes[idx+1].scatter(obs_xs[idx], obs_ys[idx], color='red', label='observed data', s=60)
    axes[idx+1].set_title('n_datapoints = ' + str(len(obs_locations[idx])))


for i in range(len(obs_locations)+1):    
    axes[i].legend(loc=4)
    axes[i].set_ylim([-2.5, 2.5])

plt.tight_layout()
plt.show()

# %%
# Plotting VAE posterior predictive
num_draws_to_plot = 15
for idx in range(len(obs_locations)):
    print(f'n_datapoints = {len(obs_locations[idx])}')
    fig, ax = plt.subplots(1, 1, figsize=(10, 7))
    
    ax.fill_between(X, vae_hpdi_post_preds_list[idx][0], vae_hpdi_post_preds_list[idx][1], 
                           alpha=0.1, interpolate=True, label='VAE posterior: 95% BCI')
    for j in range(num_draws_to_plot): 
        ax.plot(X, vae_predictions_list[idx][j], alpha=0.1, color='darkgreen')
    ax.plot(X, vae_predictions_list[idx][0],
                   alpha=0.1, color='darkgreen', label='posterior draws')  
    ax.plot(X, vae_mean_post_preds_list[idx], label='predicted mean')
    ax.plot(X, gp_draw, label='ground truth', color='orange')
    ax.scatter(obs_xs[idx], obs_ys[idx], color='red', label='observed data', s=60)
    # ax.set_title('n_datapoints = ' + str(len(obs_locations[idx])))
    
    ax.legend(loc=4)
    ax.set_ylim([-2.5, 2.5])
    
    ax.set_xlabel('Locations', fontsize=18)
    ax.set_ylabel(r'$y$', fontsize=18)
    ax.tick_params(axis='both', which='major', labelsize=15)
    
    plt.tight_layout()
    plt.show()
    
    save_to_dir = FIG_PATH / 'publication'
    fig.savefig(save_to_dir / f'1DGP_inference_PriorVAE_{idx+2}.jpg', dpi=300)
# Out:
# n_datapoints = 2
# n_datapoints = 4
# n_datapoints = 6

# %% [markdown]
# ## Both plots

# %%
# Plotting results after inference using MCMC.
_, axes = plt.subplots(nrows=1, ncols=len(obs_locations)+1, figsize=(25,6))

# Plotting VAE prior predictive.
RNG_KEY, prior_rng = jax.random.split(RNG_KEY)
vae_prior_predictions = Predictive(vae_model_mcmc, num_samples=10000)(prior_rng)['f']
vae_mean_prior_pred = jnp.mean(vae_prior_predictions, axis=0)
vae_hpdi_prior_pred = hpdi(vae_prior_predictions, 0.9)

num_draws_to_plot = 30
for j in range(num_draws_to_plot):
    axes[0].plot(X, vae_prior_predictions[j], alpha=0.1, color='darkgreen')
axes[0].plot(X, vae_prior_predictions[0], 
             alpha=0.1, color='darkgreen', label='prior draws')  
axes[0].fill_between(X, vae_hpdi_prior_pred[0], vae_hpdi_prior_pred[1], 
                     alpha=0.1, interpolate=True, label='VAE prior: 95% BCI')
axes[0].plot(X, vae_mean_prior_pred, label='mean')
axes[0].set_title('VAE prior')


# Plotting VAE posterior predictive
num_draws_to_plot = 15
for idx in range(len(obs_locations)):
    axes[idx+1].fill_between(X, vae_hpdi_post_preds_list[idx][0], vae_hpdi_post_preds_list[idx][1], 
                           alpha=0.1, interpolate=True, label='VAE posterior: 95% BCI')
    for j in range(num_draws_to_plot): 
        axes[idx+1].plot(X, vae_predictions_list[idx][j], alpha=0.1, color='darkgreen')
    axes[idx+1].plot(X, vae_predictions_list[idx][0],
                   alpha=0.1, color='darkgreen', label='posterior draws')  
    axes[idx+1].plot(X, vae_mean_post_preds_list[idx], label='predicted mean')
    axes[idx+1].plot(X, gp_draw, label='ground truth', color='orange')
    axes[idx+1].scatter(obs_xs[idx], obs_ys[idx], color='red', label='observed data', s=60)
    axes[idx+1].set_title('n_datapoints = ' + str(len(obs_locations[idx])))


for i in range(len(obs_locations)+1):    
    axes[i].legend(loc=4)
    axes[i].set_ylim([-2.5, 2.5])

plt.tight_layout()
plt.show()

# Plotting results after inference using MCMC.
_, axes = plt.subplots(nrows=1, ncols=len(obs_locations)+1, figsize=(25,6))

# Plotting VAE prior predictive.
RNG_KEY, prior_rng = jax.random.split(RNG_KEY)
prior_predictions = Predictive(vgae_mcmc_predictive_model, num_samples=10000)(prior_rng)['f']
mean_prior_pred = jnp.mean(prior_predictions, axis=0)
hpdi_prior_pred = hpdi(prior_predictions, 0.9)

num_draws_to_plot = 15
for j in range(num_draws_to_plot):
    axes[0].plot(X, prior_predictions[j], alpha=0.1, color='darkgreen')
axes[0].plot(X, prior_predictions[0], 
             alpha=0.1, color='darkgreen', label='prior draws')  
axes[0].fill_between(X, hpdi_prior_pred[0], hpdi_prior_pred[1], 
                     alpha=0.1, interpolate=True, label='VAE prior: 95% BCI')
axes[0].plot(X, mean_prior_pred, label='mean')
axes[0].set_title('VGAE prior')


# Plotting VAE posterior predictive
num_draws_to_plot = 15
for idx in range(len(obs_locations)):
    axes[idx+1].fill_between(X, hpdi_post_preds_list[idx][0], hpdi_post_preds_list[idx][1], 
                           alpha=0.1, interpolate=True, label='VAE posterior: 95% BCI')
    for j in range(num_draws_to_plot): 
        axes[idx+1].plot(X, predictions_list[idx][j], alpha=0.1, color='darkgreen')
    axes[idx+1].plot(X, predictions_list[idx][0],
                   alpha=0.1, color='darkgreen', label='posterior draws')  
    axes[idx+1].plot(X, mean_post_preds_list[idx], label='predicted mean')
    axes[idx+1].plot(X, gp_draw, label='ground truth', color='orange')
    axes[idx+1].scatter(obs_xs[idx], obs_ys[idx], color='red', label='observed data', s=60)
    axes[idx+1].set_title('n_datapoints = ' + str(len(obs_locations[idx])))


for i in range(len(obs_locations)+1):    
    axes[i].legend(loc=4)
    axes[i].set_ylim([-2.5, 2.5])

plt.tight_layout()
plt.show()

# %%
for idx, mean in enumerate(mean_post_preds_list):
    mse_vgae = np.mean((gp_draw.flatten() -  mean)**2)
    print(f'mse_vgae ({len(obs_locations[idx])}) = {mse_vgae}')
# Out:
# mse_vgae (2) = 0.19861756265163422
# mse_vgae (4) = 0.04748225957155228
# mse_vgae (6) = 0.04018291458487511

# %%
for idx, mean in enumerate(vae_mean_post_preds_list):
    mse_vae = np.mean((gp_draw.flatten() -  mean)**2)
    print(f'mse_vae ({len(obs_locations[idx])}) = {mse_vae}')
# Out:
# mse_vae (2) = 0.166422501206398
# mse_vae (4) = 0.05720733106136322
# mse_vae (6) = 0.023716256022453308

# %%
mean_post_pred_vae = vae_mean_post_preds_list[-1]
mean_post_pred_vgae = mean_post_preds_list[-1]

mse_vgae = np.mean((gp_draw.flatten() -  mean_post_pred_vgae)**2)
mse_vae = np.mean((gp_draw.flatten() -  mean_post_pred_vae)**2)
print(f'mse_vgae = {mse_vgae}')
print(f'mse_vae = {mse_vae}')
# Out:
# mse_vgae = 0.04018291458487511
# mse_vae = 0.023716256022453308

# %% [markdown]
# mse_vgae_encoderGraphNorm = 0.03129349276423454
#
# mse_vgae = 0.014667835086584091
#
# mse_vae = 0.023716256022453308

# %% [markdown]
# compute mse vgae when using GraphNormalization and see if it reduces, put in table.
