# %%
# %load_ext autoreload
# %autoreload 2

import os
from pathlib import Path
import time
from typing import Tuple, Type

import haiku as hk
import jax
import jax.numpy as jnp
import jraph
import networkx as nx
import matplotlib.pyplot as plt
import numpy as np
import optax

# Numpyro
import numpyro
import numpyro.distributions as dist
from numpyro.infer import MCMC, NUTS, init_to_median, Predictive
from numpyro.diagnostics import hpdi

# Local imports
import loss
import dataset_1dgp
import plotting
import model

print(f"JAX version: {jax.__version__}")
print(f"Numpyro version: {numpyro.__version__}")
# Out:
# /Users/salmanfaris/miniforge3/envs/prior-vgae/lib/python3.9/site-packages/jax/_src/lib/__init__.py:34: UserWarning: JAX on Mac ARM machines is experimental and minimally tested. Please see https://github.com/google/jax/issues/5501 in the event of problems.
#   warnings.warn("JAX on Mac ARM machines is experimental and minimally tested. "
# JAX version: 0.3.13
# Numpyro version: 0.9.2

# %%
FIG_PATH = Path('./figures/1DGP_figures')
FIG_PATH.mkdir(exist_ok=True)

DATASET_PATH = Path('./dataset.nosync')
DATASET_PATH.mkdir(exist_ok=True)

# %%
RNG_SEED = 44
RNG_KEY = jax.random.PRNGKey(RNG_SEED)

# %%
from dataclasses import dataclass
from typing import Dict, Optional, Callable

LossFun = Callable[[jax.numpy.ndarray, jax.numpy.ndarray], jnp.float32]

@dataclass
class GP1DArgs:
  kernel: Callable = dataset_1dgp.exp_sq_kernel
  num_locations: int = 400
  
@dataclass
class Args:
  batch_size: int = 100
  
  # Training params
  loss_fn: LossFun = loss.compute_mse_loss
  epochs: int =  10_000 # 500_000
  eval_frequency: int = 50
  learning_rate: float = 1e-3
  beta: float = 1e-2  # beta-VAE
  
  # Model params
  hidden_gnn_dim: int = 3
  hidden_fc_dim: int = 50
  latent_dim: int = 30
  output_dim: int = 1
  act_fn: Callable = jax.nn.elu

GP1D_ARGS = GP1DArgs()
ARGS = Args()

# %%
model_name = (
    f'PriorVGAE_asymmetric_1DGP_batched_lr{ARGS.learning_rate}_epochs{ARGS.epochs}_'
    f'beta{ARGS.beta}_gnn{ARGS.hidden_gnn_dim}_fc{ARGS.hidden_fc_dim}_z{ARGS.latent_dim}_'
    f'numLocations{GP1D_ARGS.num_locations}'
)

model_params_title = (
    '('
    f'epochs = {plotting.convert_to_string_int(ARGS.epochs)}, '
    f'lr = {ARGS.learning_rate}, '
    f'act_fn = {jax.nn.elu.__name__}, '
    rf'$\beta = {ARGS.beta}$, '
    f'\ngnn_dim = {ARGS.hidden_gnn_dim},  fc_dim = {ARGS.hidden_fc_dim},  z_dim = {ARGS.latent_dim}'
    f'\n num_loc = {GP1D_ARGS.num_locations}'
    ')'
)

print(model_name)
# Out:
# PriorVGAE_asymmetric_1DGP_batched_lr0.001_epochs10000_beta0.01_gnn3_fc50_z30_numLocations400

# %% [markdown]
# # Dataset: GP priors to be encoded

# %%
# GP priors to encode
X = jnp.arange(0, 1, 1/GP1D_ARGS.num_locations)

num_to_plot = 10
gp_draws = dataset_1dgp.generate_gp_batch(RNG_KEY, 
                                          X, 
                                          batch_size=num_to_plot,
                                          kernel=GP1D_ARGS.kernel)

plotting.plot_gp_draws(
    X, gp_draws,
    num_draws_to_plot=num_to_plot,
    title='Example of GP priors to encode', 
    x_label='$x$', 
    y_label='$y=f_{GP}(x)$',
)

# %% [markdown]
# # Building the model

# %%
data_filepath = DATASET_PATH / f'1DGP_numLoc{GP1D_ARGS.num_locations}_1M_train_data.npy'

OVERRIDE_SAVE = False

# Initial RNG_KEY seed is 44.
RNG_KEY, data_rng = jax.random.split(RNG_KEY)
if data_filepath.exists() and not OVERRIDE_SAVE:
    print(f"Loading dataset from {data_filepath}")
    data = np.load(data_filepath)
else:
    num_samples = 1_000_000
    data = dataset_1dgp.generate_gp_batch(data_rng, X, 
                                          batch_size=1_000_000, 
                                          kernel=GP1D_ARGS.kernel)
    print(f"Saving dataset to {data_filepath}")
    np.save(data_filepath, np.asarray(data))
# Out:
# Loading dataset from dataset.nosync/1DGP_numLoc400_1M_train_data.npy

# %%
# Remove NaNs from dataset
data = data[~np.isnan(data).any(axis=1), :]

train_size_limit = 900_000
val_size = 20_000  # + 1000 for the final epoch evaluation and batching

train_data = data[:train_size_limit]
val_data = data[train_size_limit:train_size_limit+val_size]

# %%
batched_train_data = train_data.reshape(-1, ARGS.batch_size, GP1D_ARGS.num_locations)
batched_val_data = val_data.reshape(-1, ARGS.batch_size, GP1D_ARGS.num_locations)
print(batched_train_data.shape)
print(batched_val_data.shape)
# Out:
# (9000, 100, 400)
# (200, 100, 400)

# %%
BASE_GRAPH = dataset_1dgp.create_1dgp_graph(GP1D_ARGS.num_locations)

# %%
graph_batched_train_data = []
graph_batched_val_data = []

for batch in batched_train_data:
    graph_batch = [BASE_GRAPH._replace(nodes=draw.reshape(-1, 1)) for draw in batch]
    graph_batched_train_data.append(jraph.batch(graph_batch))
    
for batch in batched_val_data:
    graph_batch = [BASE_GRAPH._replace(nodes=draw.reshape(-1, 1)) for draw in batch]
    graph_batched_val_data.append(jraph.batch(graph_batch))
# Out:
# /Users/salmanfaris/miniforge3/envs/prior-vgae/lib/python3.9/site-packages/jax/_src/tree_util.py:188: FutureWarning: jax.tree_util.tree_multimap() is deprecated. Please use jax.tree_util.tree_map() instead as a drop-in replacement.
#   warnings.warn('jax.tree_util.tree_multimap() is deprecated. Please use jax.tree_util.tree_map() '

# %%
BASE_BATCHED_GRAPH = graph_batched_train_data[0]

# %%
graph_train_data = [BASE_GRAPH._replace(nodes=nodes.reshape(-1, 1)) for nodes in train_data]
graph_val_data = [BASE_GRAPH._replace(nodes=nodes.reshape(-1, 1)) for nodes in val_data]

# %% [markdown]
# Comment: Removing linear (hidden_fc) before latent hidden layer makes samples even NOISIER

# %%
from functools import partial
from model import VGAEOutput
import layer

class VGAE(hk.Module):
    """VGAE network definition."""

    def __init__(
        self,
        hidden_gnn_dim: int,
        hidden_fc_dim: int,
        latent_dim: int,
        output_dim: int,
        num_nodes: int,
    ):
        super().__init__()
        self._hidden_gnn_dim = hidden_gnn_dim
        self._hidden_fc_dim = hidden_fc_dim
        self._latent_dim = latent_dim
        self._output_dim = output_dim
        self._num_nodes = num_nodes
        self.act = ARGS.act_fn

    def __call__(self, graph: jraph.GraphsTuple) -> VGAEOutput:
        mean, log_std = encoder(
            graph,
            self._hidden_gnn_dim,
            self._hidden_fc_dim,
            self._latent_dim,
            self._num_nodes,
            self.act,
        )

        std = jnp.exp(log_std)
        z = mean + std * jax.random.normal(hk.next_rng_key(), mean.shape)

        output = decoder(
            z,
            self._hidden_fc_dim,
            self._hidden_gnn_dim,
            self._output_dim,
            self._num_nodes,
            self.act
        )

        return VGAEOutput(mean, log_std, output)


def encoder(
        graph: jraph.GraphsTuple,
        hidden_gnn_dim: int,
        hidden_fc_dim: int,
        latent_dim: int,
        num_nodes: int,
        act_fn: Callable = jax.nn.elu) -> Tuple[jnp.ndarray, jnp.ndarray]:
    
    # Graph layer
    gn = jraph.GraphConvolution(
        update_node_fn=hk.Sequential([
            hk.Linear(hidden_gnn_dim), act_fn,
        ]),
        add_self_edges=True,
    )
    graph = gn(graph)
    
    gn = jraph.GraphConvolution(
        update_node_fn=hk.Sequential([
            hk.Linear(hidden_gnn_dim), act_fn,
        ]),
        add_self_edges=True,
    )
    graph = gn(graph)
    
    # Fully-connected layer
    x = graph.nodes.reshape(ARGS.batch_size, num_nodes, hidden_gnn_dim)
    x = hk.Flatten()(x)  # dim: (ARGS.batch_size, num_nodes*hidden_gnn_dim)
    
    # No activation
    mean = hk.Linear(latent_dim, name='mean')(x)
    log_std = hk.Linear(latent_dim, name='log_std')(x)
    return mean, log_std


def decoder(
        z: jnp.ndarray,
        hidden_fc_dim: int,
        hidden_gnn_dim: int,
        output_dim: int,
        num_nodes: int,
        act_fn: Callable = jax.nn.elu) -> jraph.GraphsTuple:
    
    z = hk.Linear(num_nodes*hidden_gnn_dim,
                  name='decoder_hidden2_fc')(z)  # (1, num_nodes*hidden_gnn_dim)
    z = act_fn(z)
    
    # Reshape to jraph.batch format: (num_nodes, hidden_gnn_dim)
    z = z.reshape((ARGS.batch_size*num_nodes, hidden_gnn_dim))
    graph = BASE_BATCHED_GRAPH._replace(nodes=z)

    gn = layer.GraphConvolutionSharpening(
        update_node_fn=hk.Sequential([
            hk.Linear(hidden_gnn_dim, name='decoder_hidden_gnn1'), act_fn,
        ]),
        add_self_edges=True,
    )
    graph = gn(graph)
    
    gn = layer.GraphConvolutionSharpening(
        update_node_fn=hk.Sequential([
            hk.Linear(hidden_gnn_dim, name='decoder_hidden_gnn2'), act_fn,
        ]),
        add_self_edges=True,
    )
    graph = gn(graph)
    
    # # Graph normalization
    # NOTE :- Graph normalization on the decoder yields a shrinked GP.
    # # graph = layer.GraphwiseLayerNorm()(graph)
    
    # # No activation
    # gn = layer.GraphConvolutionSharpening(
    #     update_node_fn=hk.Linear(output_dim, name='decoder_output'),
    #     add_self_edges=False,
    # )
    # graph = gn(graph)
    
    x = graph.nodes.reshape(ARGS.batch_size, num_nodes, hidden_gnn_dim)
    x = hk.Flatten()(x)  # dim: (batch_size, num_nodes*hidden_gnn_dim)

    x = hk.Linear(num_nodes, name='decoder_output')(x)
    # graph = graph._replace(nodes=x.T)

    # return graph
    return jnp.reshape(x, (ARGS.batch_size*num_nodes, 1))

# %%
extend_model_params_title = False
    
extension_string = 'add_self_edges = True'

if extend_model_params_title:
    model_params_title = model_params_title[:-1] + ', ' + extension_string

# %% [markdown]
# # Training time

# %%
# Initialize network and optimizer.
net = hk.transform(
  lambda x: VGAE(hidden_gnn_dim=ARGS.hidden_gnn_dim,
                 hidden_fc_dim=ARGS.hidden_fc_dim,
                 latent_dim=ARGS.latent_dim, 
                 output_dim=ARGS.output_dim,
                 num_nodes=GP1D_ARGS.num_locations)(x))

# %% [markdown]
# ## Training optimizer

# %%
# optimizer = optax.adam(ARGS.learning_rate)

scheduler = optax.exponential_decay(
    init_value=ARGS.learning_rate,
    transition_steps=2000,
    decay_rate=0.99,
)

# Combining gradient transforms using `optax.chain`
optimizer = optax.chain(
    optax.clip_by_global_norm(1.0),  # Clip by the gradient by the global norm.
    optax.scale_by_adam(),  # Use the updates from adam.
    optax.scale_by_schedule(scheduler),  # Use the learning rate from the scheduler.
    # Scale updates by -1 since optax.apply_updates is additive and we want to descend on the loss.
    optax.scale(-1.0)
)

# %% [markdown]
# ### Loss function and update

# %%
@jax.jit
def loss_fn(
    params: hk.Params, 
    rng_key: jnp.ndarray,
    graph: jraph.GraphsTuple,
) -> jnp.ndarray:
  """Computes VGAE loss."""
  log_likelihood_loss_fn = ARGS.loss_fn
  
  outputs: VGAEOutput = net.apply(params, rng_key, graph)
  log_likelihood = -log_likelihood_loss_fn(outputs.output, graph.nodes)
  # log_likelihood = -log_likelihood_loss_fn(outputs.output.nodes, graph.nodes)
  kld = jnp.mean(loss.compute_kl_gaussian(outputs.mean, outputs.log_std), axis=-1)
  elbo = (1.0/ARGS.beta)*log_likelihood - kld
  
  return -elbo, kld
  
@jax.jit
def update(
    params: hk.Params,
    rng_key: jnp.ndarray,
    opt_state: optax.OptState,
    graph: jraph.GraphsTuple,
):
  """Updates the parameters of the network."""
  grads, _ = jax.grad(loss_fn, has_aux=True)(params, rng_key, graph)
  updates, new_opt_state = optimizer.update(grads, opt_state)
  new_params = optax.apply_updates(params, updates)
  return new_params, new_opt_state

# %% [markdown]
# ### Initialize net and optimizer

# %%
# Initialize net with an arbitrary graph
RNG_KEY, params_rng = jax.random.split(RNG_KEY)

# init_graph = graph_train_data[0]
init_graph = graph_batched_train_data[0]
params = net.init(params_rng, init_graph)
opt_state = optimizer.init(params)

# %%
RNG_KEY, train_rng = jax.random.split(RNG_KEY)

train_losses = []
val_losses = []
train_klds = []
val_klds = []

# train_size = len(graph_train_data)
# val_size = len(graph_val_data)
train_size = len(graph_batched_train_data)
val_size = len(graph_batched_val_data)

eval_counter: int = 0

training_start_time = time.time()
print('using: ', ARGS.loss_fn)
for epoch in range(ARGS.epochs):
  update_rng = jax.random.fold_in(train_rng, epoch)

  # train_graph_batch = graph_train_data[epoch % train_size]
  train_graph_batch = graph_batched_train_data[epoch % train_size]
  params, opt_state = update(params, update_rng, opt_state, train_graph_batch)
    
  if epoch % ARGS.eval_frequency == 0 or epoch == (ARGS.epochs - 1):
    evaluate_rng = jax.random.fold_in(update_rng, epoch)
    train_loss_rng, eval_loss_rng = jax.random.split(evaluate_rng)
    
    train_loss, train_kld = loss_fn(params, train_loss_rng, train_graph_batch)
    
    # val_graph_batch = graph_val_data[eval_counter]
    val_graph_batch = graph_batched_val_data[eval_counter % val_size]
    val_loss, val_kld = loss_fn(params, eval_loss_rng, val_graph_batch)
    
    print(f'{time.strftime("%H:%M:%S", time.localtime())} STEP: {epoch}; '
          f'Train loss: {train_loss:.3f}; Validation loss: {val_loss:.3f}; '
          # f'Train kld: {train_kld:.3f}; Validation kld: {val_kld:.3f}'
    )
      
    train_losses.append(train_loss.item())
    val_losses.append(val_loss.item())
    train_klds.append(train_kld.item())
    val_klds.append(val_kld.item())
    
    eval_counter += 1

training_end_time = time.time() - training_start_time
print(f'Training took: ({training_end_time:.3f} secs; equivalently {training_end_time/60:.3f} mins)')
# Out:
# using:  <function compute_mse_loss at 0x143232040>
# 19:24:49 STEP: 0; Train loss: 110.912; Validation loss: 105.098;
# 19:24:50 STEP: 50; Train loss: 26.539; Validation loss: 26.423;
# 19:24:51 STEP: 100; Train loss: 22.969; Validation loss: 23.482;
# 19:24:52 STEP: 150; Train loss: 19.569; Validation loss: 19.203;
# 19:24:53 STEP: 200; Train loss: 15.109; Validation loss: 15.754;
# 19:24:54 STEP: 250; Train loss: 13.226; Validation loss: 14.261;
# 19:24:55 STEP: 300; Train loss: 13.429; Validation loss: 13.488;
# 19:24:56 STEP: 350; Train loss: 12.789; Validation loss: 12.381;
# 19:24:57 STEP: 400; Train loss: 13.265; Validation loss: 12.557;
# 19:24:58 STEP: 450; Train loss: 14.341; Validation loss: 12.924;
# 19:24:59 STEP: 500; Train loss: 13.983; Validation loss: 12.464;
# 19:25:00 STEP: 550; Train loss: 12.605; Validation loss: 11.534;
# 19:25:01 STEP: 600; Train loss: 13.358; Validation loss: 12.496;
# 19:25:01 STEP: 650; Train loss: 11.992; Validation loss: 12.268;
# 19:25:02 STEP: 700; Train loss: 12.623; Validation loss: 12.230;
# 19:25:03 STEP: 750; Train loss: 12.438; Validation loss: 11.862;
# 19:25:04 STEP: 800; Train loss: 11.667; Validation loss: 12.012;
# 19:25:05 STEP: 850; Train loss: 12.625; Validation loss: 12.629;
# 19:25:06 STEP: 900; Train loss: 12.899; Validation loss: 11.851;
# 19:25:07 STEP: 950; Train loss: 12.079; Validation loss: 11.481;
# 19:25:08 STEP: 1000; Train loss: 12.540; Validation loss: 13.552;
# 19:25:09 STEP: 1050; Train loss: 12.439; Validation loss: 11.783;
# 19:25:10 STEP: 1100; Train loss: 11.600; Validation loss: 11.592;
# 19:25:10 STEP: 1150; Train loss: 12.557; Validation loss: 12.318;
# 19:25:11 STEP: 1200; Train loss: 11.972; Validation loss: 12.174;
# 19:25:12 STEP: 1250; Train loss: 11.758; Validation loss: 12.287;
# 19:25:13 STEP: 1300; Train loss: 12.235; Validation loss: 11.729;
# 19:25:14 STEP: 1350; Train loss: 12.029; Validation loss: 11.885;
# 19:25:15 STEP: 1400; Train loss: 12.245; Validation loss: 11.738;
# 19:25:16 STEP: 1450; Train loss: 12.111; Validation loss: 12.623;
# 19:25:17 STEP: 1500; Train loss: 11.313; Validation loss: 12.348;
# 19:25:18 STEP: 1550; Train loss: 11.190; Validation loss: 12.846;
# 19:25:18 STEP: 1600; Train loss: 11.688; Validation loss: 12.309;
# 19:25:19 STEP: 1650; Train loss: 12.665; Validation loss: 11.354;
# 19:25:20 STEP: 1700; Train loss: 12.146; Validation loss: 12.193;
# 19:25:21 STEP: 1750; Train loss: 12.587; Validation loss: 12.294;
# 19:25:22 STEP: 1800; Train loss: 12.621; Validation loss: 11.981;
# 19:25:23 STEP: 1850; Train loss: 11.222; Validation loss: 12.447;
# 19:25:24 STEP: 1900; Train loss: 11.888; Validation loss: 11.126;
# 19:25:24 STEP: 1950; Train loss: 11.386; Validation loss: 12.052;
# 19:25:25 STEP: 2000; Train loss: 13.019; Validation loss: 12.764;
# 19:25:26 STEP: 2050; Train loss: 11.673; Validation loss: 11.368;
# 19:25:27 STEP: 2100; Train loss: 11.624; Validation loss: 11.787;
# 19:25:28 STEP: 2150; Train loss: 11.800; Validation loss: 11.771;
# 19:25:29 STEP: 2200; Train loss: 11.603; Validation loss: 12.839;
# 19:25:30 STEP: 2250; Train loss: 11.688; Validation loss: 11.988;
# 19:25:31 STEP: 2300; Train loss: 11.374; Validation loss: 11.486;
# 19:25:32 STEP: 2350; Train loss: 12.427; Validation loss: 11.434;
# 19:25:32 STEP: 2400; Train loss: 12.145; Validation loss: 11.785;
# 19:25:33 STEP: 2450; Train loss: 11.785; Validation loss: 11.693;
# 19:25:34 STEP: 2500; Train loss: 12.023; Validation loss: 11.408;
# 19:25:35 STEP: 2550; Train loss: 11.566; Validation loss: 12.877;
# 19:25:36 STEP: 2600; Train loss: 11.568; Validation loss: 11.992;
# 19:25:37 STEP: 2650; Train loss: 11.160; Validation loss: 11.899;
# 19:25:38 STEP: 2700; Train loss: 12.264; Validation loss: 13.219;
# 19:25:39 STEP: 2750; Train loss: 11.845; Validation loss: 11.377;
# 19:25:40 STEP: 2800; Train loss: 13.030; Validation loss: 11.912;
# 19:25:41 STEP: 2850; Train loss: 12.882; Validation loss: 11.744;
# 19:25:41 STEP: 2900; Train loss: 11.709; Validation loss: 11.291;
# 19:25:42 STEP: 2950; Train loss: 11.438; Validation loss: 11.963;
# 19:25:43 STEP: 3000; Train loss: 11.354; Validation loss: 11.617;
# 19:25:44 STEP: 3050; Train loss: 13.115; Validation loss: 12.586;
# 19:25:45 STEP: 3100; Train loss: 12.603; Validation loss: 12.541;
# 19:25:46 STEP: 3150; Train loss: 11.441; Validation loss: 11.741;
# 19:25:47 STEP: 3200; Train loss: 12.626; Validation loss: 12.121;
# 19:25:48 STEP: 3250; Train loss: 10.946; Validation loss: 11.050;
# 19:25:49 STEP: 3300; Train loss: 11.713; Validation loss: 11.978;
# 19:25:49 STEP: 3350; Train loss: 11.662; Validation loss: 11.558;
# 19:25:50 STEP: 3400; Train loss: 12.111; Validation loss: 11.901;
# 19:25:51 STEP: 3450; Train loss: 12.283; Validation loss: 11.473;
# 19:25:52 STEP: 3500; Train loss: 11.265; Validation loss: 12.655;
# 19:25:53 STEP: 3550; Train loss: 11.603; Validation loss: 11.480;
# 19:25:54 STEP: 3600; Train loss: 11.132; Validation loss: 11.619;
# 19:25:55 STEP: 3650; Train loss: 11.199; Validation loss: 11.385;
# 19:25:56 STEP: 3700; Train loss: 12.362; Validation loss: 12.497;
# 19:25:57 STEP: 3750; Train loss: 11.545; Validation loss: 12.028;
# 19:25:58 STEP: 3800; Train loss: 13.144; Validation loss: 13.705;
# 19:25:59 STEP: 3850; Train loss: 12.340; Validation loss: 11.249;
# 19:25:59 STEP: 3900; Train loss: 11.491; Validation loss: 11.949;
# 19:26:00 STEP: 3950; Train loss: 12.376; Validation loss: 11.308;
# 19:26:01 STEP: 4000; Train loss: 12.802; Validation loss: 11.112;
# 19:26:02 STEP: 4050; Train loss: 12.163; Validation loss: 11.761;
# 19:26:03 STEP: 4100; Train loss: 12.212; Validation loss: 11.587;
# 19:26:04 STEP: 4150; Train loss: 11.927; Validation loss: 11.115;
# 19:26:05 STEP: 4200; Train loss: 13.215; Validation loss: 10.892;
# 19:26:06 STEP: 4250; Train loss: 11.140; Validation loss: 12.195;
# 19:26:06 STEP: 4300; Train loss: 11.474; Validation loss: 12.539;
# 19:26:07 STEP: 4350; Train loss: 11.301; Validation loss: 11.435;
# 19:26:08 STEP: 4400; Train loss: 11.005; Validation loss: 10.976;
# 19:26:09 STEP: 4450; Train loss: 11.666; Validation loss: 11.529;
# 19:26:10 STEP: 4500; Train loss: 12.062; Validation loss: 11.972;
# 19:26:11 STEP: 4550; Train loss: 11.603; Validation loss: 12.397;
# 19:26:12 STEP: 4600; Train loss: 11.869; Validation loss: 10.739;
# 19:26:13 STEP: 4650; Train loss: 11.409; Validation loss: 11.558;
# 19:26:14 STEP: 4700; Train loss: 11.071; Validation loss: 11.074;
# 19:26:15 STEP: 4750; Train loss: 11.767; Validation loss: 11.897;
# 19:26:16 STEP: 4800; Train loss: 11.600; Validation loss: 11.392;
# 19:26:16 STEP: 4850; Train loss: 11.636; Validation loss: 11.250;
# 19:26:17 STEP: 4900; Train loss: 11.810; Validation loss: 12.086;
# 19:26:18 STEP: 4950; Train loss: 12.345; Validation loss: 11.999;
# 19:26:19 STEP: 5000; Train loss: 11.409; Validation loss: 12.120;
# 19:26:20 STEP: 5050; Train loss: 11.601; Validation loss: 11.182;
# 19:26:21 STEP: 5100; Train loss: 12.042; Validation loss: 10.799;
# 19:26:22 STEP: 5150; Train loss: 11.504; Validation loss: 11.706;
# 19:26:23 STEP: 5200; Train loss: 13.142; Validation loss: 11.434;
# 19:26:23 STEP: 5250; Train loss: 12.171; Validation loss: 12.016;
# 19:26:24 STEP: 5300; Train loss: 10.909; Validation loss: 11.281;
# 19:26:25 STEP: 5350; Train loss: 11.904; Validation loss: 11.657;
# 19:26:26 STEP: 5400; Train loss: 11.718; Validation loss: 12.073;
# 19:26:27 STEP: 5450; Train loss: 10.892; Validation loss: 11.397;
# 19:26:28 STEP: 5500; Train loss: 12.333; Validation loss: 11.317;
# 19:26:29 STEP: 5550; Train loss: 12.221; Validation loss: 11.116;
# 19:26:29 STEP: 5600; Train loss: 13.289; Validation loss: 12.018;
# 19:26:30 STEP: 5650; Train loss: 11.681; Validation loss: 11.560;
# 19:26:31 STEP: 5700; Train loss: 11.484; Validation loss: 12.371;
# 19:26:32 STEP: 5750; Train loss: 11.811; Validation loss: 11.756;
# 19:26:33 STEP: 5800; Train loss: 12.370; Validation loss: 10.977;
# 19:26:34 STEP: 5850; Train loss: 11.390; Validation loss: 13.387;
# 19:26:35 STEP: 5900; Train loss: 12.307; Validation loss: 11.648;
# 19:26:35 STEP: 5950; Train loss: 12.566; Validation loss: 12.954;
# 19:26:36 STEP: 6000; Train loss: 11.848; Validation loss: 11.841;
# 19:26:37 STEP: 6050; Train loss: 11.710; Validation loss: 11.960;
# 19:26:38 STEP: 6100; Train loss: 11.495; Validation loss: 12.069;
# 19:26:39 STEP: 6150; Train loss: 12.020; Validation loss: 12.334;
# 19:26:40 STEP: 6200; Train loss: 11.403; Validation loss: 11.835;
# 19:26:41 STEP: 6250; Train loss: 12.969; Validation loss: 12.257;
# 19:26:41 STEP: 6300; Train loss: 11.131; Validation loss: 11.853;
# 19:26:42 STEP: 6350; Train loss: 11.425; Validation loss: 12.022;
# 19:26:43 STEP: 6400; Train loss: 12.887; Validation loss: 11.076;
# 19:26:44 STEP: 6450; Train loss: 12.400; Validation loss: 12.103;
# 19:26:45 STEP: 6500; Train loss: 11.332; Validation loss: 13.438;
# 19:26:46 STEP: 6550; Train loss: 12.127; Validation loss: 11.509;
# 19:26:46 STEP: 6600; Train loss: 10.798; Validation loss: 13.418;
# 19:26:47 STEP: 6650; Train loss: 11.307; Validation loss: 10.642;
# 19:26:48 STEP: 6700; Train loss: 12.279; Validation loss: 11.248;
# 19:26:49 STEP: 6750; Train loss: 11.733; Validation loss: 11.834;
# 19:26:50 STEP: 6800; Train loss: 11.838; Validation loss: 11.766;
# 19:26:51 STEP: 6850; Train loss: 12.087; Validation loss: 11.228;
# 19:26:52 STEP: 6900; Train loss: 11.103; Validation loss: 12.269;
# 19:26:53 STEP: 6950; Train loss: 12.761; Validation loss: 10.975;
# 19:26:53 STEP: 7000; Train loss: 11.101; Validation loss: 11.947;
# 19:26:54 STEP: 7050; Train loss: 11.966; Validation loss: 11.886;
# 19:26:55 STEP: 7100; Train loss: 12.325; Validation loss: 11.812;
# 19:26:56 STEP: 7150; Train loss: 11.808; Validation loss: 11.503;
# 19:26:57 STEP: 7200; Train loss: 11.843; Validation loss: 11.923;
# 19:26:58 STEP: 7250; Train loss: 11.579; Validation loss: 11.180;
# 19:26:59 STEP: 7300; Train loss: 10.894; Validation loss: 11.992;
# 19:27:00 STEP: 7350; Train loss: 11.308; Validation loss: 10.837;
# 19:27:01 STEP: 7400; Train loss: 11.905; Validation loss: 11.469;
# 19:27:02 STEP: 7450; Train loss: 11.552; Validation loss: 11.698;
# 19:27:02 STEP: 7500; Train loss: 11.748; Validation loss: 12.671;
# 19:27:03 STEP: 7550; Train loss: 11.502; Validation loss: 11.530;
# 19:27:04 STEP: 7600; Train loss: 11.093; Validation loss: 11.113;
# 19:27:05 STEP: 7650; Train loss: 11.652; Validation loss: 11.993;
# 19:27:06 STEP: 7700; Train loss: 11.861; Validation loss: 11.162;
# 19:27:07 STEP: 7750; Train loss: 11.141; Validation loss: 11.771;
# 19:27:08 STEP: 7800; Train loss: 11.485; Validation loss: 11.363;
# 19:27:08 STEP: 7850; Train loss: 11.675; Validation loss: 11.798;
# 19:27:09 STEP: 7900; Train loss: 11.368; Validation loss: 12.278;
# 19:27:10 STEP: 7950; Train loss: 11.132; Validation loss: 11.047;
# 19:27:11 STEP: 8000; Train loss: 10.938; Validation loss: 11.106;
# 19:27:12 STEP: 8050; Train loss: 12.147; Validation loss: 11.031;
# 19:27:13 STEP: 8100; Train loss: 11.271; Validation loss: 11.822;
# 19:27:14 STEP: 8150; Train loss: 11.503; Validation loss: 10.770;
# 19:27:15 STEP: 8200; Train loss: 11.423; Validation loss: 12.607;
# 19:27:15 STEP: 8250; Train loss: 10.945; Validation loss: 11.669;
# 19:27:16 STEP: 8300; Train loss: 10.871; Validation loss: 11.811;
# 19:27:17 STEP: 8350; Train loss: 11.609; Validation loss: 11.304;
# 19:27:18 STEP: 8400; Train loss: 12.060; Validation loss: 11.013;
# 19:27:19 STEP: 8450; Train loss: 11.050; Validation loss: 11.592;
# 19:27:20 STEP: 8500; Train loss: 11.208; Validation loss: 12.143;
# 19:27:20 STEP: 8550; Train loss: 11.912; Validation loss: 10.387;
# 19:27:21 STEP: 8600; Train loss: 11.719; Validation loss: 11.369;
# 19:27:22 STEP: 8650; Train loss: 11.507; Validation loss: 11.637;
# 19:27:23 STEP: 8700; Train loss: 11.190; Validation loss: 11.186;
# 19:27:24 STEP: 8750; Train loss: 11.659; Validation loss: 11.500;
# 19:27:25 STEP: 8800; Train loss: 11.941; Validation loss: 12.827;
# 19:27:26 STEP: 8850; Train loss: 10.872; Validation loss: 10.939;
# 19:27:27 STEP: 8900; Train loss: 11.237; Validation loss: 11.357;
# 19:27:27 STEP: 8950; Train loss: 11.475; Validation loss: 11.320;
# 19:27:28 STEP: 9000; Train loss: 11.521; Validation loss: 10.671;
# 19:27:29 STEP: 9050; Train loss: 11.455; Validation loss: 12.457;
# 19:27:30 STEP: 9100; Train loss: 11.386; Validation loss: 11.585;
# 19:27:31 STEP: 9150; Train loss: 11.186; Validation loss: 11.133;
# 19:27:32 STEP: 9200; Train loss: 11.254; Validation loss: 11.274;
# 19:27:33 STEP: 9250; Train loss: 11.178; Validation loss: 11.277;
# 19:27:34 STEP: 9300; Train loss: 11.680; Validation loss: 11.588;
# 19:27:34 STEP: 9350; Train loss: 11.228; Validation loss: 11.571;
# 19:27:35 STEP: 9400; Train loss: 12.017; Validation loss: 11.003;
# 19:27:36 STEP: 9450; Train loss: 12.049; Validation loss: 11.543;
# 19:27:37 STEP: 9500; Train loss: 12.923; Validation loss: 11.613;
# 19:27:38 STEP: 9550; Train loss: 11.206; Validation loss: 11.682;
# 19:27:39 STEP: 9600; Train loss: 11.796; Validation loss: 12.447;
# 19:27:40 STEP: 9650; Train loss: 11.217; Validation loss: 11.928;
# 19:27:41 STEP: 9700; Train loss: 11.875; Validation loss: 12.329;
# 19:27:41 STEP: 9750; Train loss: 11.549; Validation loss: 11.461;
# 19:27:42 STEP: 9800; Train loss: 11.107; Validation loss: 11.202;
# 19:27:43 STEP: 9850; Train loss: 11.515; Validation loss: 11.427;
# 19:27:44 STEP: 9900; Train loss: 11.534; Validation loss: 11.472;
# 19:27:45 STEP: 9950; Train loss: 11.225; Validation loss: 11.684;
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /Users/salmanfaris/Desktop/ds-projects/msc-proj/PriorVGAE/1dGP_asymmetric_priorVGAE_flatten_batched.ipynb Cell 27 in <cell line: 17>()
#      <a href='vscode-notebook-cell:/Users/salmanfaris/Desktop/ds-projects/msc-proj/PriorVGAE/1dGP_asymmetric_priorVGAE_flatten_batched.ipynb#X35sZmlsZQ%3D%3D?line=27'>28</a> train_loss, train_kld = loss_fn(params, train_loss_rng, train_graph_batch)
#      <a href='vscode-notebook-cell:/Users/salmanfaris/Desktop/ds-projects/msc-proj/PriorVGAE/1dGP_asymmetric_priorVGAE_flatten_batched.ipynb#X35sZmlsZQ%3D%3D?line=29'>30</a> # val_graph_batch = graph_val_data[eval_counter]
# ---> <a href='vscode-notebook-cell:/Users/salmanfaris/Desktop/ds-projects/msc-proj/PriorVGAE/1dGP_asymmetric_priorVGAE_flatten_batched.ipynb#X35sZmlsZQ%3D%3D?line=30'>31</a> val_graph_batch = graph_batched_val_data[eval_counter]
#      <a href='vscode-notebook-cell:/Users/salmanfaris/Desktop/ds-projects/msc-proj/PriorVGAE/1dGP_asymmetric_priorVGAE_flatten_batched.ipynb#X35sZmlsZQ%3D%3D?line=31'>32</a> val_loss, val_kld = loss_fn(params, eval_loss_rng, val_graph_batch)
#      <a href='vscode-notebook-cell:/Users/salmanfaris/Desktop/ds-projects/msc-proj/PriorVGAE/1dGP_asymmetric_priorVGAE_flatten_batched.ipynb#X35sZmlsZQ%3D%3D?line=33'>34</a> print(f'{time.strftime("%H:%M:%S", time.localtime())} STEP: {epoch}; '
#      <a href='vscode-notebook-cell:/Users/salmanfaris/Desktop/ds-projects/msc-proj/PriorVGAE/1dGP_asymmetric_priorVGAE_flatten_batched.ipynb#X35sZmlsZQ%3D%3D?line=34'>35</a>       f'Train loss: {train_loss:.3f}; Validation loss: {val_loss:.3f}; '
#      <a href='vscode-notebook-cell:/Users/salmanfaris/Desktop/ds-projects/msc-proj/PriorVGAE/1dGP_asymmetric_priorVGAE_flatten_batched.ipynb#X35sZmlsZQ%3D%3D?line=35'>36</a>       # f'Train kld: {train_kld:.3f}; Validation kld: {val_kld:.3f}'
#      <a href='vscode-notebook-cell:/Users/salmanfaris/Desktop/ds-projects/msc-proj/PriorVGAE/1dGP_asymmetric_priorVGAE_flatten_batched.ipynb#X35sZmlsZQ%3D%3D?line=36'>37</a> )
#
# IndexError: list index out of range

# %%
from matplotlib.ticker import MaxNLocator

# Loss plots
fig, axes = plt.subplots(2, 2, figsize=(14, 10))

# for i in range(2): axes[i].xaxis.set_major_locator(MaxNLocator(integer=True))

xs = np.arange(len(train_losses))*ARGS.eval_frequency
axes[0, 0].plot(xs, train_losses, label='train_loss')
axes[0, 0].plot(xs, val_losses, label='val_loss')
axes[0, 1].plot(xs[1:], train_losses[1:], label='train_loss')
axes[0, 1].plot(xs[1:], val_losses[1:], label='val_loss')
axes[0, 0].set_title('Loss (all epochs)')
axes[0, 1].set_title('Loss (all except first epoch)')

for i in range(2): 
    axes[0, i].set_ylabel('Loss')
    axes[0, i].set_xlabel('Epochs')
    axes[0, i].legend()
    
# KLD plots
xs = np.arange(len(train_klds))*ARGS.eval_frequency
axes[1, 0].plot(xs, train_klds, label='train_kld')
axes[1, 0].plot(xs, val_klds, label='val_kld')
axes[1, 1].plot(xs[1:], train_klds[1:], label='train_kld')
axes[1, 1].plot(xs[1:], val_klds[1:], label='val_kld')
axes[1, 0].set_title('KLD (all epochs)')
axes[1, 1].set_title('KLD (all except first epoch)')

for i in range(2): 
    axes[1, i].set_ylabel('KLD')
    axes[1, i].set_xlabel('Epochs')
    axes[1, i].legend()

fig.suptitle(f'Loss and KLD (left: all epochs; right: all except first epochs) \n{model_params_title}', fontsize='xx-large')

plt.tight_layout()
plt.show()

loss_kld_path = FIG_PATH / 'loss_kld_figures'
loss_kld_path.mkdir(exist_ok=True)
fig.savefig(loss_kld_path / f'{model_name}.jpg', dpi=300)

# %%
RNG_KEY, rng_recon = jax.random.split(RNG_KEY)

num_to_plot = 5
fig, axes = plt.subplots(num_to_plot, 2, figsize=(15, 25))

original_data = graph_batched_val_data[0]

outputs = net.apply(params, rng_recon, original_data)
recon_data = outputs.output
recon_data = jnp.reshape(recon_data, (ARGS.batch_size, GP1D_ARGS.num_locations))

for i in range(num_to_plot):
    original_gp = jnp.ravel(jraph.unbatch(original_data)[i].nodes)
    recon_gp = jnp.ravel(recon_data[i])

    axes[i, 0].plot(X, original_gp)
    axes[i, 1].plot(X, recon_gp)
    
    axes[i, 0].set_title(f'Example {i} (input)')
    axes[i, 1].set_title(f'Example {i} (recon)')

fig.suptitle(f'Input vs Recon\n{model_params_title}', fontsize='xx-large')

plt.tight_layout()
plt.show()

input_v_recon_path = FIG_PATH / 'recon_figures'
input_v_recon_path.mkdir(exist_ok=True)
fig.savefig(input_v_recon_path / f'{model_name}.jpg', dpi=300)
# Out:
# /Users/salmanfaris/miniforge3/envs/prior-vgae/lib/python3.9/site-packages/jax/_src/tree_util.py:188: FutureWarning: jax.tree_util.tree_multimap() is deprecated. Please use jax.tree_util.tree_map() instead as a drop-in replacement.
#   warnings.warn('jax.tree_util.tree_multimap() is deprecated. Please use jax.tree_util.tree_map() '
# /Users/salmanfaris/miniforge3/envs/prior-vgae/lib/python3.9/site-packages/jax/_src/tree_util.py:188: FutureWarning: jax.tree_util.tree_multimap() is deprecated. Please use jax.tree_util.tree_map() instead as a drop-in replacement.
#   warnings.warn('jax.tree_util.tree_multimap() is deprecated. Please use jax.tree_util.tree_map() '
# /Users/salmanfaris/miniforge3/envs/prior-vgae/lib/python3.9/site-packages/jax/_src/tree_util.py:188: FutureWarning: jax.tree_util.tree_multimap() is deprecated. Please use jax.tree_util.tree_map() instead as a drop-in replacement.
#   warnings.warn('jax.tree_util.tree_multimap() is deprecated. Please use jax.tree_util.tree_map() '
# /Users/salmanfaris/miniforge3/envs/prior-vgae/lib/python3.9/site-packages/jax/_src/tree_util.py:188: FutureWarning: jax.tree_util.tree_multimap() is deprecated. Please use jax.tree_util.tree_map() instead as a drop-in replacement.
#   warnings.warn('jax.tree_util.tree_multimap() is deprecated. Please use jax.tree_util.tree_map() '
# /Users/salmanfaris/miniforge3/envs/prior-vgae/lib/python3.9/site-packages/jax/_src/tree_util.py:188: FutureWarning: jax.tree_util.tree_multimap() is deprecated. Please use jax.tree_util.tree_map() instead as a drop-in replacement.
#   warnings.warn('jax.tree_util.tree_multimap() is deprecated. Please use jax.tree_util.tree_map() '

# %%
def decoder_1(
        z: jnp.ndarray,
        hidden_fc_dim: int,
        hidden_gnn_dim: int,
        output_dim: int,
        num_nodes: int,
        act_fn: Callable = jax.nn.elu) -> jraph.GraphsTuple:
    
    z = hk.Linear(num_nodes*hidden_gnn_dim,
                  name='decoder_hidden2_fc')(z)  # (1, num_nodes*hidden_gnn_dim)
    z = act_fn(z)
    
    # Reshape to jraph.batch format: (num_nodes, hidden_gnn_dim)
    z = z.reshape((1*num_nodes, hidden_gnn_dim))
    graph = BASE_GRAPH._replace(nodes=z)

    gn = layer.GraphConvolutionSharpening(
        update_node_fn=hk.Sequential([
            hk.Linear(hidden_gnn_dim, name='decoder_hidden_gnn1'), act_fn,
        ]),
        add_self_edges=True,
    )
    graph = gn(graph)
    
    gn = layer.GraphConvolutionSharpening(
        update_node_fn=hk.Sequential([
            hk.Linear(hidden_gnn_dim, name='decoder_hidden_gnn2'), act_fn,
        ]),
        add_self_edges=True,
    )
    graph = gn(graph)
    
    # # Graph normalization
    # NOTE :- Graph normalization on the decoder yields a shrinked GP.
    # # graph = layer.GraphwiseLayerNorm()(graph)
    
    # # No activation
    # gn = layer.GraphConvolutionSharpening(
    #     update_node_fn=hk.Linear(output_dim, name='decoder_output'),
    #     add_self_edges=False,
    # )
    # graph = gn(graph)
    
    x = graph.nodes.reshape(1, num_nodes, hidden_gnn_dim)
    x = hk.Flatten()(x)  # dim: (batch_size, num_nodes*hidden_gnn_dim)

    x = hk.Linear(num_nodes, name='decoder_output')(x)
    # graph = graph._replace(nodes=x.T)

    # return graph
    return jnp.reshape(x, (1*num_nodes, 1))

# %%
from functools import partial

decoder_params_keys = [k for k in list(params.keys()) if k.startswith('vgae/decoder')]
decoder_params = {}
for full_key_name in decoder_params_keys:
    key_name = full_key_name.split('/')[-1]  # remove the 'vgae/' prefix
    decoder_params[key_name] = params[full_key_name]
    
GP1D_ARGS.decoder_params = decoder_params

decoder_net_fn = partial(decoder_1,
                         hidden_fc_dim=ARGS.hidden_fc_dim,
                         hidden_gnn_dim=ARGS.hidden_gnn_dim,
                         output_dim=ARGS.output_dim,
                         num_nodes=GP1D_ARGS.num_locations)
decoder_net = hk.without_apply_rng(hk.transform(decoder_net_fn))

# %%
# def decoder_predictive_model():
#     z = numpyro.sample('z', dist.Normal(0, 1).expand([ARGS.batch_size, ARGS.latent_dim]))
#     vgae_out = jraph.unbatch(decoder_net.apply(GP1D_ARGS.decoder_params, z))
#     vgae_out = [out.nodes for out in vgae_out]
#     numpyro.deterministic('f', vgae_out)
def decoder_predictive_model():
    z = numpyro.sample('z', dist.Normal(0, 1).expand([ARGS.latent_dim]))
    vgae_out = jnp.squeeze(decoder_net.apply(GP1D_ARGS.decoder_params, z))
    numpyro.deterministic('f', vgae_out)

# %%
# Rough comparison of the shape of GP draws with learnt VGAE priors.

# Drawing VGAE priors.
RNG_KEY, vgae_sample_rng = jax.random.split(RNG_KEY)
vgae_draws = Predictive(
  decoder_predictive_model, num_samples=10)(vgae_sample_rng)['f']
vgae_draws = vgae_draws[:,:400]

# Plotting the GP draws and VGAE draws.
_, ax = plt.subplots(1, 2, figsize=(18, 5))

plotting.plot_gp_draws(X, gp_draws, num_draws_to_plot=5, 
                     ax=ax[0], title='Example of GP priors to encode', y_label='$y=f_{GP}(x)$')

plotting.plot_gp_draws(X, vgae_draws, num_draws_to_plot=5, 
                     ax=ax[1], title='Example of learnt priors using VGAE', y_label='$y=f_{VGAE}(x)$', )

plt.show()

# %%
# Comparing distribution of GP draws with learnt VGAE priors.
RNG_KEY, gp_rng, vgae_rng = jax.random.split(RNG_KEY, 3)

num_samples = 1000
gp_draws = dataset_1dgp.generate_gp_batch(gp_rng, X, 
                                          batch_size=num_samples, 
                                          kernel=GP1D_ARGS.kernel)
vgae_draws = Predictive(decoder_predictive_model, num_samples=num_samples)(vgae_rng)['f']
vgae_draws = vgae_draws[:,:400]

# Computing the mean and HPDI of the GP draws and VGAE draws.
gp_draws = gp_draws[~np.isnan(gp_draws).any(axis=1), :]
mean_gp = jnp.nanmean(gp_draws, axis=0)
hpdi_gp = hpdi(gp_draws, 0.9)

vgae_draws = vgae_draws[~np.isnan(vgae_draws).any(axis=1), :]
mean_vgae = jnp.nanmean(vgae_draws, axis=0)
hpdi_vgae = hpdi(vgae_draws, 0.9)

# %%
# Plotting the GP draws and VGAE draws.
fig, axes = plt.subplots(1, 2, figsize=(18, 7))

y_lim = [-2, 2]
lines_alpha_gp = 0.1
lines_alpha_vgae = 0.1
num_draws_to_plot = 15
plotting.plot_gp_draws_with_stats(
    X, gp_draws, 
    mean_gp, hpdi_gp,lines_alpha_gp, 
    num_draws_to_plot, y_lim=y_lim, ax=axes[0],
    title='GP priors to encode', y_label='$y=f_{GP}(x)$')
plotting.plot_gp_draws_with_stats(
    X, vgae_draws, mean_vgae, hpdi_vgae,
    lines_alpha_vgae, num_draws_to_plot, 
    y_lim=y_lim, ax=axes[1],
    title='VGAE priors learnt',
    y_label='$y=f_{VGAE}(x)$')

fig.suptitle(f'GP Priors vs Learnt VGAE Priors \n{model_params_title}', fontsize='xx-large')

plt.tight_layout()
plt.show()

estimate_plot_path = FIG_PATH / 'estimate_figures'
estimate_plot_path.mkdir(exist_ok=True)
fig.savefig(estimate_plot_path / f'{model_name}.jpg', dpi=300)

# %%
assert False
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# /Users/salmanfaris/Desktop/ds-projects/msc-proj/PriorVGAE/1dGP_priorVGAE_flatten_batched.ipynb Cell 35 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/Users/salmanfaris/Desktop/ds-projects/msc-proj/PriorVGAE/1dGP_priorVGAE_flatten_batched.ipynb#X46sZmlsZQ%3D%3D?line=0'>1</a> assert False
#
# AssertionError:

# %% [markdown]
# # Inference on Observed Data

# %%
def vgae_mcmc_predictive_model(y=None, obs_idx=None):
    z = numpyro.sample('z', dist.Normal(0, 1).expand([ARGS.latent_dim]))
    vgae_out = jnp.squeeze(decoder_net.apply(decoder_params, z))
    f = numpyro.deterministic('f', vgae_out)
    sigma = numpyro.sample('noise', dist.HalfNormal(0.1))

    if y is None: # at prediction time
        numpyro.sample('y_pred', dist.Normal(f, sigma))
    else: # at inference time
        numpyro.sample('y', dist.Normal(f[obs_idx], sigma), obs=y)

# %%
def run_mcmc(rng, model_mcmc, y, obs_idx, verbose=False):
    start = time.time()
    init_strategy = init_to_median(num_samples=10)
    kernel = NUTS(model_mcmc, init_strategy=init_strategy)
    mcmc = MCMC(
        kernel,
        num_warmup=1000,
        num_samples=1000,
        num_chains=4,
        thinning=1,
        progress_bar=False if 'NUMPYRO_SPHINXBUILD' in os.environ else True,
    )
    mcmc.run(rng, y, obs_idx)
    if verbose:
        mcmc.print_summary(exclude_deterministic=False)
    print('\nMCMC elapsed time:', time.time() - start)

    return mcmc.get_samples()

# %%
RNG_KEY, gp_rng = jax.random.split(RNG_KEY)

# Generate true data and observed dataset to infer
draws = Predictive(dataset_1dgp.gp_predictive_model, num_samples=1)(
  gp_rng, x=X, gp_kernel=GP1D_ARGS.kernel, noise=True)
gp_draw = draws['f'].T  # True data
y_draw = draws['y'].T  # True data + noise

# Choose indices of datapoints for inference.
obs_locations = [
  jnp.array([122, 321]),  # 2 observed datapoints
  jnp.array([126, 133, 296, 370]),  # 4 observed datapoints
  jnp.array([71, 85, 111, 291, 314, 380]),  # 6 observed datapoints
]

# %%
mean_post_preds_list = []
hpdi_post_preds_list = []
obs_xs = []
obs_ys = []
predictions_list = []

RNG_KEY, inference_rng = jax.random.split(RNG_KEY)

for i, obs_location in enumerate(obs_locations):
    mcmc_rng, pred_rng = jax.random.split(jax.random.fold_in(inference_rng, i), 2)
    
    x_obs = X[obs_location]
    y_obs = jnp.squeeze(y_draw[obs_location])
    
    print(f'Running chain for n_obs = {len(obs_location)}')
    mcmc_samples = run_mcmc(mcmc_rng, vgae_mcmc_predictive_model, y_obs, obs_location)

    predictions = Predictive(vgae_mcmc_predictive_model, mcmc_samples)(pred_rng)['f']
    mean_post_pred = jnp.mean(predictions, axis=0)
    hpdi_post_pred = hpdi(predictions, 0.9)
    
    obs_xs.append(x_obs)
    obs_ys.append(y_obs)
    predictions_list.append(predictions)
    mean_post_preds_list.append(mean_post_pred)
    hpdi_post_preds_list.append(hpdi_post_pred)
# Out:
# Running chain for n_obs = 2
# /var/folders/6h/lf5jg1fn1h163zw3042tmtnc0000gn/T/ipykernel_17659/3494085863.py:5: UserWarning: There are not enough devices to run parallel chains: expected 4 but got 1. Chains will be drawn sequentially. If you are running MCMC in CPU, consider using `numpyro.set_host_device_count(4)` at the beginning of your program. You can double-check how many devices are available in your system using `jax.local_device_count()`.
#   mcmc = MCMC(
# sample: 100%|██████████| 2000/2000 [00:16<00:00, 124.19it/s, 29 steps of size 8.27e-02. acc. prob=0.86]
# sample: 100%|██████████| 2000/2000 [00:09<00:00, 211.54it/s, 31 steps of size 1.65e-01. acc. prob=0.78]
# sample: 100%|██████████| 2000/2000 [00:09<00:00, 219.82it/s, 6 steps of size 1.67e-01. acc. prob=0.58]
# sample: 100%|██████████| 2000/2000 [00:09<00:00, 220.69it/s, 31 steps of size 1.89e-01. acc. prob=0.72]
# MCMC elapsed time: 45.84728002548218
# /var/folders/6h/lf5jg1fn1h163zw3042tmtnc0000gn/T/ipykernel_17659/3494085863.py:5: UserWarning: There are not enough devices to run parallel chains: expected 4 but got 1. Chains will be drawn sequentially. If you are running MCMC in CPU, consider using `numpyro.set_host_device_count(4)` at the beginning of your program. You can double-check how many devices are available in your system using `jax.local_device_count()`.
#   mcmc = MCMC(
# Running chain for n_obs = 4
# sample: 100%|██████████| 2000/2000 [00:19<00:00, 103.63it/s, 63 steps of size 8.24e-02. acc. prob=0.85]
# sample: 100%|██████████| 2000/2000 [00:14<00:00, 137.79it/s, 63 steps of size 6.79e-02. acc. prob=0.89]
# sample: 100%|██████████| 2000/2000 [00:09<00:00, 210.28it/s, 31 steps of size 1.14e-01. acc. prob=0.30]
# sample: 100%|██████████| 2000/2000 [00:10<00:00, 183.98it/s, 31 steps of size 1.25e-01. acc. prob=0.75]
# MCMC elapsed time: 56.220380783081055
# /var/folders/6h/lf5jg1fn1h163zw3042tmtnc0000gn/T/ipykernel_17659/3494085863.py:5: UserWarning: There are not enough devices to run parallel chains: expected 4 but got 1. Chains will be drawn sequentially. If you are running MCMC in CPU, consider using `numpyro.set_host_device_count(4)` at the beginning of your program. You can double-check how many devices are available in your system using `jax.local_device_count()`.
#   mcmc = MCMC(
# Running chain for n_obs = 6
# sample: 100%|██████████| 2000/2000 [00:06<00:00, 302.90it/s, 15 steps of size 2.67e-01. acc. prob=0.90]
# sample: 100%|██████████| 2000/2000 [00:04<00:00, 406.33it/s, 15 steps of size 2.88e-01. acc. prob=0.84]
# sample: 100%|██████████| 2000/2000 [00:05<00:00, 335.12it/s, 31 steps of size 1.99e-01. acc. prob=0.94]
# sample: 100%|██████████| 2000/2000 [00:05<00:00, 396.58it/s, 15 steps of size 2.54e-01. acc. prob=0.88]
# MCMC elapsed time: 23.45701003074646

# %%
# Plotting results after inference using MCMC.
_, axes = plt.subplots(nrows=1, ncols=len(obs_locations)+1, figsize=(25,6))

# Plotting VAE prior predictive.
RNG_KEY, prior_rng = jax.random.split(RNG_KEY)
prior_predictions = Predictive(vgae_mcmc_predictive_model, num_samples=10000)(prior_rng)['f']
mean_prior_pred = jnp.mean(prior_predictions, axis=0)
hpdi_prior_pred = hpdi(prior_predictions, 0.9)

num_draws_to_plot = 30
for j in range(num_draws_to_plot):
    axes[0].plot(X, prior_predictions[j], alpha=0.1, color='darkgreen')
axes[0].plot(X, prior_predictions[0], 
             alpha=0.1, color='darkgreen', label='prior draws')  
axes[0].fill_between(X, hpdi_prior_pred[0], hpdi_prior_pred[1], 
                     alpha=0.1, interpolate=True, label='VAE prior: 95% BCI')
axes[0].plot(X, mean_prior_pred, label='mean')
axes[0].set_title('VAE prior')


# Plotting VAE posterior predictive
num_draws_to_plot = 15
for idx in range(len(obs_locations)):
    axes[idx+1].fill_between(X, hpdi_post_preds_list[idx][0], hpdi_post_preds_list[idx][1], 
                           alpha=0.1, interpolate=True, label='VAE posterior: 95% BCI')
    for j in range(num_draws_to_plot): 
        axes[idx+1].plot(X, predictions_list[idx][j], alpha=0.1, color='darkgreen')
    axes[idx+1].plot(X, predictions_list[idx][0],
                   alpha=0.1, color='darkgreen', label='posterior draws')  
    axes[idx+1].plot(X, mean_post_preds_list[idx], label='predicted mean')
    axes[idx+1].plot(X, gp_draw, label='ground truth', color='orange')
    axes[idx+1].scatter(obs_xs[idx], obs_ys[idx], color='red', label='observed data', s=60)
    axes[idx+1].set_title('n_datapoints = ' + str(len(obs_locations[idx])))


for i in range(len(obs_locations)+1):    
    axes[i].legend(loc=4)
    axes[i].set_ylim([-2.5, 2.5])

plt.tight_layout()
plt.show()
