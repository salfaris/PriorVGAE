# %%
# %load_ext autoreload
# %autoreload 2

# %%
# general libraries
import time
import math
import numpy as np
from shapely import geometry
from shapely.geometry import Polygon
import matplotlib.pyplot as plt
import pickle
import os
import geopandas as gpd
import matplotlib.pyplot as plt
from mpl_toolkits.axes_grid1 import make_axes_locatable
import pandas as pd
import arviz as az
import dill

# JAX
import haiku as hk
import jax
import jax.numpy as jnp
import jraph
import optax


# Numpyro
import numpyro
from numpyro.infer import SVI, MCMC, NUTS, init_to_median, Predictive, RenyiELBO
import numpyro.distributions as dist
from numpyro.diagnostics import hpdi
from numpyro import optim

from model import VGAEOutput

#plt.style.use('bmh')
# Out:
# /Users/salmanfaris/miniforge3/envs/prior-vgae-zimbabwe/lib/python3.9/site-packages/jax/_src/lib/__init__.py:34: UserWarning: JAX on Mac ARM machines is experimental and minimally tested. Please see https://github.com/google/jax/issues/5501 in the event of problems.
#   warnings.warn("JAX on Mac ARM machines is experimental and minimally tested. "

# %%
RNG_KEY = jax.random.PRNGKey(3)

# %%
from pathlib import Path
data_path = Path('./dataset.nosync/zwe2016phia.geojson')

df = gpd.read_file(data_path)

_, ax = plt.subplots(figsize=(6, 6))
df.plot(column='area_id', ax=ax)
plt.show()

# %%
df.columns
# Out:
# Index(['indicator', 'survey_id', 'survey_mid_calendar_quarter', 'area_id',
#        'area_name', 'res_type', 'sex', 'age_group', 'n_clusters',
#        'n_observations', 'n_eff_kish', 'estimate', 'std_error', 'ci_lower',
#        'ci_upper', 'y', 'n_obs', 'iso3', 'area_level', 'parent_area_id',
#        'spectrum_region_code', 'area_sort_order', 'center_x', 'center_y',
#        'area_level_label', 'display', 'spectrum_level', 'epp_level',
#        'naomi_level', 'pepfar_psnu_level', 'geometry'],
#       dtype='object')

# %%
df = df[[
    'area_id',
    'geometry',
    'y',
    'n_obs',
    'estimate',
]]

df['y'] = round(df.y).astype(int)
df['n_obs'] = round(df.n_obs).astype(int)

print(f'Number of NaNs in n_obs = {np.sum(np.isnan(df.n_obs))}')
# Out:
# Number of NaNs in n_obs = 0
# /Users/salmanfaris/miniforge3/envs/prior-vgae-zimbabwe/lib/python3.9/site-packages/geopandas/geodataframe.py:1322: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)

# %%
_, ax = plt.subplots(1, 3, figsize=(12, 4))
df.plot(column='y', ax=ax[0], legend=True)
df.plot(column='n_obs', ax=ax[1], legend=True)
df.plot(column='estimate', ax=ax[2], cmap='plasma', legend=True)

ax[0].set_title('y')
ax[1].set_title('n_obs')
ax[2].set_title('estimate')

plt.tight_layout()
plt.show()

# %%
polygons = df['geometry'].copy()
A = polygons.geometry.apply(lambda g: polygons.intersects(g))
A = np.array(A * 1)
A = A - np.eye(A.shape[0])

assert np.all(A.sum(axis=0) == A.sum(axis=1))
d = A.sum(axis=0)

# %%
import networkx as nx
g = nx.from_numpy_matrix(A)
nx.draw(g, with_labels=True)

# %%
from dataclasses import dataclass
from typing import Dict, Optional

Params = Dict[str, Dict[str, jnp.ndarray]]

@dataclass
class CARArgs:
  adj_matrix: np.ndarray = A
  degree_vector: jnp.ndarray = d
  n_obs_vector: jnp.ndarray = jnp.array(df.n_obs)
  num_regions: int = len(polygons)
  
  decoder_params: Optional[Params] = None
  scaler: Optional[callable] = None
  
CAR_ARGS = CARArgs()

# %% [markdown]
# # Creating dataset

# %%
def car_predictive_model(args: CARArgs) -> None:
  A = jnp.array(args.adj_matrix)
  D = jnp.diag(args.degree_vector)

  alpha = numpyro.sample('alpha', dist.Uniform(low=0.01, high=0.999))

  Q_std = (D - alpha*A)
  numpyro.sample('car_std', dist.MultivariateNormal(loc=jnp.zeros(args.num_regions), precision_matrix=Q_std))

# %%
# CAR: prior predictive
RNG_KEY, rng_pred = jax.random.split(RNG_KEY)

num_to_plot = 5
car_preds = Predictive(car_predictive_model, num_samples=num_to_plot)(rng_pred, CAR_ARGS)
car_draws = car_preds['car_std']

_, axes = plt.subplots(1, num_to_plot, figsize=(20, 3))

df_plot_samples = df.copy()
for i in range(5):
    title = f'CAR_prior_{i}'
    df_plot_samples[title] = car_draws[i]
    df_plot_samples.plot(column=title, ax=axes[i], legend=True)
    axes[i].set_title(title)
    
plt.tight_layout()
plt.show()

# %%
import dataset

def generate_car_batch(
        rng: jax.random.PRNGKey, 
        batch_size: int = 1,
        model_args: CARArgs = CAR_ARGS) -> jnp.ndarray:
    car_preds = Predictive(
        car_predictive_model, num_samples=batch_size)(rng, model_args)
    car_draws = car_preds['car_std']  # (batch_size, num_regions)
    return car_draws

# %% [markdown]
# # VGAE-CAR

# %%
from dataclasses import dataclass
import loss
from typing import Callable, NamedTuple

LossFun = Callable[[jax.numpy.ndarray, jax.numpy.ndarray], jnp.float32]

# class Args(NamedTuple):
#   loss_fn: LossFun = loss.compute_mse_loss
#   num_nodes: int = A.shape[0]  
#   batch_size: int = 1
#   scale: int = 3.0
  
#   act_fn = jax.nn.leaky_relu
#   hidden_dim: int = 20
#   latent_dim: int = 20
#   output_dim: int = 1
  
#   learning_rate: float = 1e-3
#   epochs: int = 200_000
  
#   eval_frequency: int = 5000

@dataclass
class Args:  
  # Training params
  loss_fn: LossFun = loss.compute_mse_loss
  epochs: int = 200_000
  eval_frequency: int = 1000
  learning_rate: float = 1e-2
  beta: float = 1.0  # beta-VAE
  
  # Model params
  hidden_gnn_dim: int = 10
  hidden_fc_dim: int = 100
  latent_dim: int = 50
  output_dim: int = 1
  act_fn: Callable = jax.nn.elu  

ARGS = Args()
print(ARGS)
# Out:
# Args(loss_fn=<function compute_mse_loss at 0x287716550>, epochs=200000, eval_frequency=1000, learning_rate=0.01, beta=1.0, hidden_gnn_dim=10, hidden_fc_dim=100, latent_dim=50, output_dim=1, act_fn=<CompiledFunction of <function elu at 0x179b34310>>)

# %%
from pathlib import Path
train_path = Path.cwd() / 'dataset.nosync/zimbabwe_car_train_data.npy'
val_path = Path.cwd() / 'dataset.nosync/zimbabwe_car_val_data.npy'

OVERRIDE_SAVE = False

RNG_KEY, train_rng, val_rng = jax.random.split(RNG_KEY, 3)
if (train_path.exists() and val_path.exists()) and not OVERRIDE_SAVE:
    train_data = jnp.array(np.load(train_path))
    val_data = jnp.array(np.load(val_path))
else:
    train_data = generate_car_batch(train_rng, batch_size=200_000)
    val_data = generate_car_batch(val_rng, batch_size=200_000)
    np.save(train_path, np.asarray(train_data))
    np.save(val_path, np.asarray(val_data))

# %%
train_data = jnp.concatenate((train_data, val_data[:195_000]))
val_data = val_data[195_000:]

# %%
from preprocess import LinearScaler, NoScaler

# DO NOT APPLY SCALING, JUST USE BETA
scaler = NoScaler()
scaled_train_data = scaler.fit_transform(train_data)
scaled_val_data = scaler.transform(val_data)

BASE_GRAPH = dataset.create_grid_graph(CAR_ARGS.adj_matrix)
scaled_graph_train_data = [
    BASE_GRAPH._replace(nodes=draw.reshape(-1, 1)) 
        for draw in scaled_train_data
]
scaled_graph_val_data = [
    BASE_GRAPH._replace(nodes=draw.reshape(-1, 1)) 
        for draw in scaled_val_data
]

CAR_ARGS.scaler = scaler

# %%
from typing import Tuple
from model import VGAEOutput
import layer

class VGAE(hk.Module):
    """VGAE network definition."""

    def __init__(
        self,
        hidden_gnn_dim: int,
        hidden_fc_dim: int,
        latent_dim: int,
        output_dim: int,
        num_nodes: int,
    ):
        super().__init__()
        self._hidden_gnn_dim = hidden_gnn_dim
        self._hidden_fc_dim = hidden_fc_dim
        self._latent_dim = latent_dim
        self._output_dim = output_dim
        self._num_nodes = num_nodes
        self.act = ARGS.act_fn

    def __call__(self, graph: jraph.GraphsTuple) -> VGAEOutput:
        mean, log_std = encoder(
            graph,
            self._hidden_gnn_dim,
            self._hidden_fc_dim,
            self._latent_dim,
            self._num_nodes,
            self.act,
        )

        std = jnp.exp(log_std)
        z = mean + std * jax.random.normal(hk.next_rng_key(), mean.shape)

        output = decoder(
            z,
            self._hidden_fc_dim,
            self._hidden_gnn_dim,
            self._output_dim,
            self._num_nodes,
            self.act
        )

        return VGAEOutput(mean, log_std, output)

def encoder(
        graph: jraph.GraphsTuple,
        hidden_gnn_dim: int,
        hidden_fc_dim: int,
        latent_dim: int,
        num_nodes: int,
        act_fn: Callable = jax.nn.elu) -> Tuple[jnp.ndarray, jnp.ndarray]:
    
    # Graph layer
    gn = jraph.GraphConvolution(
        update_node_fn=hk.Sequential([
            hk.Linear(hidden_gnn_dim), act_fn,
        ]),
        add_self_edges=False,
    )
    graph = gn(graph)
    # graph = layer.GraphwiseLayerNorm()(graph)
    
    x = graph.nodes.reshape(1, num_nodes, hidden_gnn_dim)
    x = hk.Flatten()(x)  # dim: (1, num_nodes*hidden_gnn_dim)

    # x = hk.Linear(hidden_fc_dim)(x)
    # x = act_fn(x)
    
    # No activation
    mean = hk.Linear(latent_dim, name='mean')(x)
    log_std = hk.Linear(latent_dim, name='log_std')(x)
    return mean, log_std


def decoder(
        z: jnp.ndarray,
        hidden_fc_dim: int,
        hidden_gnn_dim: int,
        output_dim: int,
        num_nodes: int,
        act_fn: Callable = jax.nn.elu) -> jraph.GraphsTuple:
    
    # z = hk.Linear(hidden_fc_dim, name='decoder_hidden_fc')(z)
    # z = act_fn(z)
    
    z = hk.Linear(num_nodes*hidden_gnn_dim,
                  name='decoder_hidden2_fc')(z)  # (1, num_nodes*hidden_gnn_dim)
    z = act_fn(z)
    
    # Reshape to jraph.batch format: (num_nodes, hidden_gnn_dim)
    z = z.reshape((num_nodes, hidden_gnn_dim))
    # graph = BASE_GRAPH._replace(nodes=z)
    graph = BASE_GRAPH._replace(nodes=z)
    
    gn = layer.GraphConvolutionSharpening(
        update_node_fn=hk.Sequential([
            hk.Linear(hidden_gnn_dim, name='decoder_hidden_gnn'), act_fn,
        ]),
        add_self_edges=False,
    )
    graph = gn(graph)
    # graph = layer.GraphwiseLayerNorm()(graph)
    
    # Layer normalization
    # NOTE :- Layer normalization on the decoder yields a shrinked GP.
    # graph = layer.GraphwiseLayerNorm()(graph)
    
    # No activation
    gn = layer.GraphConvolutionSharpening(
        update_node_fn=hk.Linear(output_dim, name='decoder_output'),
        add_self_edges=False,
    )
    graph = gn(graph)

    return graph

# %%
# Initialize network and optimizer.
net = hk.transform(
  lambda x: VGAE(hidden_gnn_dim=ARGS.hidden_gnn_dim,
                 hidden_fc_dim=ARGS.hidden_fc_dim,
                 latent_dim=ARGS.latent_dim, 
                 output_dim=ARGS.output_dim,
                 num_nodes=CAR_ARGS.num_regions)(x))

# optimizer = optax.adam(ARGS.learning_rate)

scheduler = optax.exponential_decay(
    init_value=ARGS.learning_rate,
    transition_steps=1000,
    decay_rate=0.75,
)

# Combining gradient transforms using `optax.chain`
optimizer = optax.chain(
    optax.clip_by_global_norm(1.0),  # Clip by the gradient by the global norm.
    optax.scale_by_adam(),  # Use the updates from adam.
    optax.scale_by_schedule(scheduler),  # Use the learning rate from the scheduler.
    # Scale updates by -1 since optax.apply_updates is additive and we want to descend on the loss.
    optax.scale(-1.0)
)

# %%
@jax.jit
def loss_fn(
    params: hk.Params, 
    rng_key: jnp.ndarray,
    graph: jraph.GraphsTuple,
) -> jnp.ndarray:
  """Computes VGAE loss."""
  log_likelihood_loss_fn = ARGS.loss_fn
  
  outputs: VGAEOutput = net.apply(params, rng_key, graph)
  log_likelihood = -log_likelihood_loss_fn(outputs.output.nodes, graph.nodes)
  kld = jnp.mean(loss.compute_kl_gaussian(outputs.mean, outputs.log_std), axis=-1)
  elbo = (1.0/ARGS.beta)*log_likelihood - kld
  
  return -elbo, kld
  
@jax.jit
def update(
    params: hk.Params,
    rng_key: jnp.ndarray,
    opt_state: optax.OptState,
    graph: jraph.GraphsTuple,
):
  """Updates the parameters of the network."""
  grads, _ = jax.grad(loss_fn, has_aux=True)(params, rng_key, graph)
  updates, new_opt_state = optimizer.update(grads, opt_state)
  new_params = optax.apply_updates(params, updates)
  return new_params, new_opt_state

# %% [markdown]
# ### Initialize net and optimizer

# %%
# Initialize net with an arbitrary graph
RNG_KEY, params_rng = jax.random.split(RNG_KEY)

init_graph = scaled_graph_train_data[0]
params = net.init(params_rng, init_graph)
opt_state = optimizer.init(params)

# %%
RNG_KEY, train_rng = jax.random.split(RNG_KEY)

train_losses = []
val_losses = []
train_klds = []
val_klds = []

train_size = len(scaled_graph_train_data)
val_size = len(scaled_graph_val_data)

eval_counter: int = 0

training_start_time = time.time()
print('using: ', ARGS.loss_fn)
for epoch in range(ARGS.epochs):
  update_rng = jax.random.fold_in(train_rng, epoch)

  train_graph_batch = scaled_graph_train_data[epoch % train_size]
  params, opt_state = update(params, update_rng, opt_state, train_graph_batch)
    
  if epoch % ARGS.eval_frequency == 0 or epoch == (ARGS.epochs - 1):
    evaluate_rng = jax.random.fold_in(update_rng, epoch)
    train_loss_rng, eval_loss_rng = jax.random.split(evaluate_rng)
    
    train_loss, train_kld = loss_fn(params, train_loss_rng, train_graph_batch)
    
    val_graph_batch = scaled_graph_val_data[eval_counter]
    val_loss, val_kld = loss_fn(params, eval_loss_rng, val_graph_batch)
    
    print(f'{time.strftime("%H:%M:%S", time.localtime())} STEP: {epoch}; '
          f'Train loss: {train_loss:.3f}; Validation loss: {val_loss:.3f}; '
          # f'Train kld: {train_kld:.3f}; Validation kld: {val_kld:.3f}'
    )
      
    train_losses.append(train_loss.item())
    val_losses.append(val_loss.item())
    train_klds.append(train_kld.item())
    val_klds.append(val_kld.item())
    
    eval_counter += 1

training_end_time = time.time() - training_start_time
print(f'Training took: ({training_end_time:.3f} secs; equivalently {training_end_time/60:.3f} mins)')
# Out:
# using:  <function compute_mse_loss at 0x287716550>
# 12:42:39 STEP: 0; Train loss: 1372491.750; Validation loss: 58800.523;
# 12:42:39 STEP: 1000; Train loss: 26.454; Validation loss: 18.044;
# 12:42:40 STEP: 2000; Train loss: 40.229; Validation loss: 19.517;
# 12:42:41 STEP: 3000; Train loss: 21.326; Validation loss: 21.432;
# 12:42:41 STEP: 4000; Train loss: 29.534; Validation loss: 23.256;
# 12:42:42 STEP: 5000; Train loss: 22.275; Validation loss: 25.820;
# 12:42:42 STEP: 6000; Train loss: 21.450; Validation loss: 21.582;
# 12:42:43 STEP: 7000; Train loss: 15.700; Validation loss: 30.891;
# 12:42:44 STEP: 8000; Train loss: 40.928; Validation loss: 28.265;
# 12:42:44 STEP: 9000; Train loss: 24.862; Validation loss: 24.976;
# 12:42:45 STEP: 10000; Train loss: 21.494; Validation loss: 22.025;
# 12:42:45 STEP: 11000; Train loss: 31.673; Validation loss: 36.013;
# 12:42:46 STEP: 12000; Train loss: 32.968; Validation loss: 23.312;
# 12:42:46 STEP: 13000; Train loss: 30.338; Validation loss: 22.520;
# 12:42:47 STEP: 14000; Train loss: 28.191; Validation loss: 43.005;
# 12:42:48 STEP: 15000; Train loss: 21.624; Validation loss: 20.512;
# 12:42:48 STEP: 16000; Train loss: 25.752; Validation loss: 26.068;
# 12:42:49 STEP: 17000; Train loss: 35.111; Validation loss: 23.402;
# 12:42:49 STEP: 18000; Train loss: 21.858; Validation loss: 19.053;
# 12:42:50 STEP: 19000; Train loss: 24.007; Validation loss: 27.282;
# 12:42:51 STEP: 20000; Train loss: 24.401; Validation loss: 27.233;
# 12:42:51 STEP: 21000; Train loss: 18.367; Validation loss: 22.655;
# 12:42:52 STEP: 22000; Train loss: 33.425; Validation loss: 25.057;
# 12:42:52 STEP: 23000; Train loss: 30.262; Validation loss: 20.493;
# 12:42:53 STEP: 24000; Train loss: 34.455; Validation loss: 20.820;
# 12:42:53 STEP: 25000; Train loss: 28.729; Validation loss: 43.813;
# 12:42:54 STEP: 26000; Train loss: 25.325; Validation loss: 22.992;
# 12:42:55 STEP: 27000; Train loss: 60.545; Validation loss: 35.912;
# 12:42:55 STEP: 28000; Train loss: 30.316; Validation loss: 29.059;
# 12:42:56 STEP: 29000; Train loss: 23.978; Validation loss: 20.996;
# 12:42:56 STEP: 30000; Train loss: 27.037; Validation loss: 21.010;
# 12:42:57 STEP: 31000; Train loss: 19.806; Validation loss: 24.934;
# 12:42:58 STEP: 32000; Train loss: 23.519; Validation loss: 24.041;
# 12:42:58 STEP: 33000; Train loss: 27.994; Validation loss: 17.505;
# 12:42:59 STEP: 34000; Train loss: 155.914; Validation loss: 25.716;
# 12:42:59 STEP: 35000; Train loss: 21.516; Validation loss: 18.614;
# 12:43:00 STEP: 36000; Train loss: 29.507; Validation loss: 17.974;
# 12:43:00 STEP: 37000; Train loss: 20.448; Validation loss: 52.493;
# 12:43:01 STEP: 38000; Train loss: 18.862; Validation loss: 22.382;
# 12:43:02 STEP: 39000; Train loss: 21.723; Validation loss: 23.856;
# 12:43:02 STEP: 40000; Train loss: 30.308; Validation loss: 29.422;
# 12:43:03 STEP: 41000; Train loss: 26.329; Validation loss: 29.935;
# 12:43:03 STEP: 42000; Train loss: 25.993; Validation loss: 26.276;
# 12:43:04 STEP: 43000; Train loss: 22.584; Validation loss: 22.670;
# 12:43:05 STEP: 44000; Train loss: 13.264; Validation loss: 18.852;
# 12:43:05 STEP: 45000; Train loss: 39.171; Validation loss: 35.243;
# 12:43:06 STEP: 46000; Train loss: 19.492; Validation loss: 37.682;
# 12:43:06 STEP: 47000; Train loss: 16.216; Validation loss: 25.781;
# 12:43:07 STEP: 48000; Train loss: 20.676; Validation loss: 19.186;
# 12:43:07 STEP: 49000; Train loss: 19.114; Validation loss: 31.971;
# 12:43:08 STEP: 50000; Train loss: 25.638; Validation loss: 20.056;
# 12:43:09 STEP: 51000; Train loss: 19.657; Validation loss: 28.958;
# 12:43:09 STEP: 52000; Train loss: 20.749; Validation loss: 21.081;
# 12:43:10 STEP: 53000; Train loss: 38.874; Validation loss: 24.011;
# 12:43:10 STEP: 54000; Train loss: 22.345; Validation loss: 31.887;
# 12:43:11 STEP: 55000; Train loss: 26.790; Validation loss: 38.602;
# 12:43:11 STEP: 56000; Train loss: 29.274; Validation loss: 27.869;
# 12:43:12 STEP: 57000; Train loss: 19.290; Validation loss: 29.579;
# 12:43:13 STEP: 58000; Train loss: 24.893; Validation loss: 35.114;
# 12:43:13 STEP: 59000; Train loss: 24.216; Validation loss: 30.190;
# 12:43:14 STEP: 60000; Train loss: 12.323; Validation loss: 22.158;
# 12:43:14 STEP: 61000; Train loss: 13.539; Validation loss: 27.876;
# 12:43:15 STEP: 62000; Train loss: 14.223; Validation loss: 30.340;
# 12:43:16 STEP: 63000; Train loss: 27.675; Validation loss: 26.265;
# 12:43:16 STEP: 64000; Train loss: 18.749; Validation loss: 23.178;
# 12:43:17 STEP: 65000; Train loss: 23.967; Validation loss: 29.845;
# 12:43:17 STEP: 66000; Train loss: 30.162; Validation loss: 42.135;
# 12:43:18 STEP: 67000; Train loss: 21.094; Validation loss: 21.322;
# 12:43:18 STEP: 68000; Train loss: 19.544; Validation loss: 32.797;
# 12:43:19 STEP: 69000; Train loss: 24.865; Validation loss: 16.823;
# 12:43:20 STEP: 70000; Train loss: 24.417; Validation loss: 25.161;
# 12:43:20 STEP: 71000; Train loss: 23.979; Validation loss: 21.106;
# 12:43:21 STEP: 72000; Train loss: 21.906; Validation loss: 18.456;
# 12:43:21 STEP: 73000; Train loss: 25.168; Validation loss: 27.273;
# 12:43:22 STEP: 74000; Train loss: 23.754; Validation loss: 24.028;
# 12:43:23 STEP: 75000; Train loss: 20.481; Validation loss: 31.424;
# 12:43:23 STEP: 76000; Train loss: 25.836; Validation loss: 23.928;
# 12:43:24 STEP: 77000; Train loss: 22.445; Validation loss: 26.211;
# 12:43:24 STEP: 78000; Train loss: 18.745; Validation loss: 19.381;
# 12:43:25 STEP: 79000; Train loss: 19.069; Validation loss: 29.345;
# 12:43:26 STEP: 80000; Train loss: 49.028; Validation loss: 27.543;
# 12:43:26 STEP: 81000; Train loss: 22.665; Validation loss: 17.587;
# 12:43:27 STEP: 82000; Train loss: 37.456; Validation loss: 42.257;
# 12:43:27 STEP: 83000; Train loss: 20.957; Validation loss: 24.495;
# 12:43:28 STEP: 84000; Train loss: 25.814; Validation loss: 26.543;
# 12:43:28 STEP: 85000; Train loss: 17.917; Validation loss: 21.092;
# 12:43:29 STEP: 86000; Train loss: 24.669; Validation loss: 22.245;
# 12:43:30 STEP: 87000; Train loss: 19.894; Validation loss: 18.476;
# 12:43:30 STEP: 88000; Train loss: 28.381; Validation loss: 21.403;
# 12:43:31 STEP: 89000; Train loss: 32.446; Validation loss: 24.450;
# 12:43:31 STEP: 90000; Train loss: 13.692; Validation loss: 25.971;
# 12:43:32 STEP: 91000; Train loss: 23.011; Validation loss: 26.198;
# 12:43:33 STEP: 92000; Train loss: 29.242; Validation loss: 19.073;
# 12:43:33 STEP: 93000; Train loss: 27.423; Validation loss: 24.284;
# 12:43:34 STEP: 94000; Train loss: 45.517; Validation loss: 31.635;
# 12:43:34 STEP: 95000; Train loss: 15.049; Validation loss: 43.521;
# 12:43:35 STEP: 96000; Train loss: 20.410; Validation loss: 32.653;
# 12:43:36 STEP: 97000; Train loss: 76.854; Validation loss: 26.417;
# 12:43:36 STEP: 98000; Train loss: 22.384; Validation loss: 19.744;
# 12:43:37 STEP: 99000; Train loss: 17.309; Validation loss: 19.880;
# 12:43:37 STEP: 100000; Train loss: 28.777; Validation loss: 37.541;
# 12:43:38 STEP: 101000; Train loss: 32.216; Validation loss: 44.013;
# 12:43:39 STEP: 102000; Train loss: 40.724; Validation loss: 19.583;
# 12:43:39 STEP: 103000; Train loss: 20.336; Validation loss: 18.167;
# 12:43:40 STEP: 104000; Train loss: 24.683; Validation loss: 22.263;
# 12:43:41 STEP: 105000; Train loss: 37.320; Validation loss: 18.762;
# 12:43:41 STEP: 106000; Train loss: 28.096; Validation loss: 21.299;
# 12:43:42 STEP: 107000; Train loss: 14.250; Validation loss: 22.584;
# 12:43:42 STEP: 108000; Train loss: 17.364; Validation loss: 21.222;
# 12:43:43 STEP: 109000; Train loss: 32.521; Validation loss: 20.557;
# 12:43:43 STEP: 110000; Train loss: 20.512; Validation loss: 31.420;
# 12:43:44 STEP: 111000; Train loss: 21.907; Validation loss: 24.145;
# 12:43:45 STEP: 112000; Train loss: 16.796; Validation loss: 30.622;
# 12:43:45 STEP: 113000; Train loss: 76.248; Validation loss: 28.119;
# 12:43:46 STEP: 114000; Train loss: 21.862; Validation loss: 18.820;
# 12:43:46 STEP: 115000; Train loss: 19.334; Validation loss: 20.313;
# 12:43:47 STEP: 116000; Train loss: 21.316; Validation loss: 35.890;
# 12:43:48 STEP: 117000; Train loss: 30.868; Validation loss: 30.883;
# 12:43:48 STEP: 118000; Train loss: 20.415; Validation loss: 26.400;
# 12:43:49 STEP: 119000; Train loss: 20.385; Validation loss: 18.597;
# 12:43:49 STEP: 120000; Train loss: 26.766; Validation loss: 31.421;
# 12:43:50 STEP: 121000; Train loss: 20.343; Validation loss: 17.675;
# 12:43:50 STEP: 122000; Train loss: 35.204; Validation loss: 21.595;
# 12:43:51 STEP: 123000; Train loss: 25.927; Validation loss: 23.202;
# 12:43:52 STEP: 124000; Train loss: 40.557; Validation loss: 22.762;
# 12:43:52 STEP: 125000; Train loss: 23.168; Validation loss: 22.706;
# 12:43:53 STEP: 126000; Train loss: 30.070; Validation loss: 29.899;
# 12:43:53 STEP: 127000; Train loss: 24.204; Validation loss: 24.551;
# 12:43:54 STEP: 128000; Train loss: 19.926; Validation loss: 31.900;
# 12:43:55 STEP: 129000; Train loss: 26.264; Validation loss: 19.186;
# 12:43:55 STEP: 130000; Train loss: 26.279; Validation loss: 23.916;
# 12:43:56 STEP: 131000; Train loss: 18.093; Validation loss: 22.036;
# 12:43:56 STEP: 132000; Train loss: 20.593; Validation loss: 65.891;
# 12:43:57 STEP: 133000; Train loss: 34.766; Validation loss: 93.986;
# 12:43:57 STEP: 134000; Train loss: 19.304; Validation loss: 24.004;
# 12:43:58 STEP: 135000; Train loss: 23.923; Validation loss: 17.747;
# 12:43:59 STEP: 136000; Train loss: 21.851; Validation loss: 19.698;
# 12:44:00 STEP: 137000; Train loss: 20.086; Validation loss: 21.026;
# 12:44:01 STEP: 138000; Train loss: 31.487; Validation loss: 24.283;
# 12:44:02 STEP: 139000; Train loss: 25.020; Validation loss: 19.979;
# 12:44:03 STEP: 140000; Train loss: 16.183; Validation loss: 20.949;
# 12:44:04 STEP: 141000; Train loss: 29.094; Validation loss: 67.047;
# 12:44:04 STEP: 142000; Train loss: 26.087; Validation loss: 20.157;
# 12:44:05 STEP: 143000; Train loss: 23.867; Validation loss: 23.275;
# 12:44:06 STEP: 144000; Train loss: 20.404; Validation loss: 19.349;
# 12:44:07 STEP: 145000; Train loss: 22.582; Validation loss: 35.833;
# 12:44:08 STEP: 146000; Train loss: 22.635; Validation loss: 28.838;
# 12:44:08 STEP: 147000; Train loss: 29.391; Validation loss: 18.902;
# 12:44:09 STEP: 148000; Train loss: 26.238; Validation loss: 25.291;
# 12:44:10 STEP: 149000; Train loss: 54.690; Validation loss: 22.419;
# 12:44:10 STEP: 150000; Train loss: 24.462; Validation loss: 28.700;
# 12:44:11 STEP: 151000; Train loss: 35.791; Validation loss: 17.274;
# 12:44:12 STEP: 152000; Train loss: 30.155; Validation loss: 18.357;
# 12:44:12 STEP: 153000; Train loss: 22.097; Validation loss: 21.230;
# 12:44:13 STEP: 154000; Train loss: 19.193; Validation loss: 20.360;
# 12:44:13 STEP: 155000; Train loss: 26.659; Validation loss: 30.850;
# 12:44:14 STEP: 156000; Train loss: 61.536; Validation loss: 27.266;
# 12:44:15 STEP: 157000; Train loss: 25.923; Validation loss: 20.183;
# 12:44:15 STEP: 158000; Train loss: 19.134; Validation loss: 20.118;
# 12:44:16 STEP: 159000; Train loss: 17.595; Validation loss: 18.701;
# 12:44:17 STEP: 160000; Train loss: 16.258; Validation loss: 19.208;
# 12:44:17 STEP: 161000; Train loss: 21.104; Validation loss: 30.712;
# 12:44:18 STEP: 162000; Train loss: 21.871; Validation loss: 21.914;
# 12:44:19 STEP: 163000; Train loss: 24.602; Validation loss: 22.518;
# 12:44:19 STEP: 164000; Train loss: 28.780; Validation loss: 32.484;
# 12:44:20 STEP: 165000; Train loss: 19.794; Validation loss: 11.501;
# 12:44:21 STEP: 166000; Train loss: 17.449; Validation loss: 31.764;
# 12:44:21 STEP: 167000; Train loss: 27.764; Validation loss: 39.757;
# 12:44:22 STEP: 168000; Train loss: 22.658; Validation loss: 23.840;
# 12:44:22 STEP: 169000; Train loss: 22.853; Validation loss: 25.474;
# 12:44:23 STEP: 170000; Train loss: 32.119; Validation loss: 25.887;
# 12:44:24 STEP: 171000; Train loss: 19.647; Validation loss: 28.692;
# 12:44:24 STEP: 172000; Train loss: 17.394; Validation loss: 22.774;
# 12:44:25 STEP: 173000; Train loss: 20.524; Validation loss: 26.920;
# 12:44:26 STEP: 174000; Train loss: 17.510; Validation loss: 20.006;
# 12:44:26 STEP: 175000; Train loss: 16.623; Validation loss: 23.424;
# 12:44:27 STEP: 176000; Train loss: 37.296; Validation loss: 19.807;
# 12:44:27 STEP: 177000; Train loss: 21.516; Validation loss: 40.643;
# 12:44:28 STEP: 178000; Train loss: 20.587; Validation loss: 25.670;
# 12:44:29 STEP: 179000; Train loss: 25.241; Validation loss: 18.667;
# 12:44:29 STEP: 180000; Train loss: 29.025; Validation loss: 18.332;
# 12:44:30 STEP: 181000; Train loss: 23.224; Validation loss: 29.325;
# 12:44:30 STEP: 182000; Train loss: 26.307; Validation loss: 19.053;
# 12:44:31 STEP: 183000; Train loss: 19.534; Validation loss: 26.894;
# 12:44:32 STEP: 184000; Train loss: 21.401; Validation loss: 25.308;
# 12:44:32 STEP: 185000; Train loss: 24.753; Validation loss: 17.500;
# 12:44:33 STEP: 186000; Train loss: 25.953; Validation loss: 25.640;
# 12:44:34 STEP: 187000; Train loss: 19.172; Validation loss: 19.247;
# 12:44:34 STEP: 188000; Train loss: 24.189; Validation loss: 24.538;
# 12:44:35 STEP: 189000; Train loss: 19.303; Validation loss: 23.037;
# 12:44:35 STEP: 190000; Train loss: 23.712; Validation loss: 22.733;
# 12:44:36 STEP: 191000; Train loss: 26.439; Validation loss: 20.247;
# 12:44:37 STEP: 192000; Train loss: 24.482; Validation loss: 24.590;
# 12:44:37 STEP: 193000; Train loss: 21.462; Validation loss: 19.123;
# 12:44:38 STEP: 194000; Train loss: 25.991; Validation loss: 27.710;
# 12:44:38 STEP: 195000; Train loss: 19.806; Validation loss: 19.303;
# 12:44:39 STEP: 196000; Train loss: 23.105; Validation loss: 27.290;
# 12:44:40 STEP: 197000; Train loss: 26.515; Validation loss: 21.201;
# 12:44:40 STEP: 198000; Train loss: 18.294; Validation loss: 21.314;
# 12:44:41 STEP: 199000; Train loss: 22.638; Validation loss: 17.364;
# 12:44:41 STEP: 199999; Train loss: 26.950; Validation loss: 19.015;
# Training took: (124.195 secs; equivalently 2.070 mins)

# %%
from matplotlib.ticker import MaxNLocator

_, axes = plt.subplots(1, 2, figsize=(14, 5))

# for i in range(2): axes[i].xaxis.set_major_locator(MaxNLocator(integer=True))

xs = np.arange(len(train_losses))*ARGS.eval_frequency
axes[0].plot(xs, train_losses, label='train_loss')
axes[0].plot(xs, val_losses, label='val_loss')
axes[1].plot(xs[1:], train_losses[1:], label='train_loss')
axes[1].plot(xs[1:], val_losses[1:], label='val_loss')
axes[0].set_title('Loss (all epochs)')
axes[1].set_title('Loss (all except first epoch)')

for i in range(2): 
    axes[i].set_ylabel('Loss')
    axes[i].set_xlabel('Epochs')
    axes[i].legend()
plt.show()

# %%
# Check whether the network is learning at all.

RNG_KEY, rng_recon = jax.random.split(RNG_KEY)

num_examples = 5
fig, axes = plt.subplots(num_examples, 2, figsize=(10, 20))
for i in range(num_examples):
    original_data = val_data[i]
    scaled_data_graph = scaled_graph_val_data[i]
    outputs = net.apply(params, RNG_KEY, scaled_data_graph)

    # Unscaling
    recon_data = scaler.inverse_transform(jnp.ravel(outputs.output.nodes))

    original_image = jnp.ravel(original_data)
    recon_image = jnp.ravel(recon_data)

    # Plotting
    t = df.copy()
    title_original = f'original_{i}'
    title_recon = f'recon_{i}'
    t[title_original] = original_image
    t[title_recon] = recon_image
    
    vmin = np.amin([original_image, recon_image])
    vmax = np.amax([original_image, recon_image])
      
    t.plot(column=title_original, ax=axes[i, 0], 
           legend=True, vmin=vmin, vmax=vmax)
    t.plot(column=title_recon, ax=axes[i, 1], 
           legend=True, vmin=vmin, vmax=vmax)
    axes[i, 0].set_title(f'Example {i+1} (input)')
    axes[i, 1].set_title(f'Example {i+1} (recon)')

plt.tight_layout()
plt.show()

# %%
fig_path = Path('./figures/zimbabwe_figures/')
model_name = (
    f'carZ_synthetic_VGAE-GCN_flattened_lr{ARGS.learning_rate}_epochs{ARGS.epochs}_'
    f'beta{ARGS.beta}_gnn{ARGS.hidden_gnn_dim}_fc{ARGS.hidden_fc_dim}_z{ARGS.latent_dim}'
)
fig_name = model_name +  '.jpg'
fig.savefig(fig_path/fig_name)

# %%
print(ARGS)
# Out:
# Args(loss_fn=<function compute_mse_loss at 0x287716550>, epochs=200000, eval_frequency=1000, learning_rate=0.01, beta=1.0, hidden_gnn_dim=10, hidden_fc_dim=100, latent_dim=50, output_dim=1, act_fn=<CompiledFunction of <function elu at 0x179b34310>>)

# %%
from functools import partial

decoder_params_keys = [k for k in list(params.keys()) if k.startswith('vgae/decoder')]
decoder_params = {}
for full_key_name in decoder_params_keys:
    key_name = full_key_name.split('/')[-1]  # remove the 'vgae/' prefix
    decoder_params[key_name] = params[full_key_name]
    
CAR_ARGS.decoder_params = decoder_params

decoder_net_fn = partial(decoder,
                         hidden_fc_dim=ARGS.hidden_fc_dim,
                         hidden_gnn_dim=ARGS.hidden_gnn_dim,
                         output_dim=ARGS.output_dim,
                         num_nodes=CAR_ARGS.num_regions)
decoder_net = hk.without_apply_rng(hk.transform(decoder_net_fn))

# %%
def vgae_predictive_model():
    z = numpyro.sample('z', dist.Normal(0, 1).expand([ARGS.latent_dim]))
    vgae_out = jnp.squeeze(decoder_net.apply(CAR_ARGS.decoder_params, z).nodes)
    numpyro.deterministic('car_std', vgae_out)

# %%
#Prior predictive

RNG_KEY, rng_car, rng_vgae = jax.random.split(RNG_KEY, 3)

num_to_plot = 5
car_preds = Predictive(car_predictive_model, num_samples=num_to_plot)(rng_car, CAR_ARGS)
car_draws = car_preds['car_std']

vgae_preds = Predictive(vgae_predictive_model, num_samples=num_to_plot)(rng_vgae)
vgae_draws = vgae_preds['car_std']

_, axes = plt.subplots(2, num_to_plot, figsize=(20, 7))
df_plot_samples = df.copy()
for i in range(5):
    title = f'CAR_prior_{i}'
    df_plot_samples[title] = car_draws[i]
    df_plot_samples.plot(column=title, ax=axes[0, i], legend=True)
    axes[0, i].set_title(title)
    
    title = f'VGAE-CAR_prior_{i}'
    df_plot_samples[title] = vgae_draws[i]
    df_plot_samples.plot(column=title, ax=axes[1, i], legend=True)
    axes[1, i].set_title(title)
    
plt.tight_layout()
plt.show()

# %% [markdown]
# # Ground truth and inference

# %%
def car_predictive_model_with_noise(
    args: CARArgs, y=None, alpha=None, noise=None) -> None:
    A = args.adj_matrix
    D = jnp.diag(args.degree_vector)

    if alpha is None:
        alpha = numpyro.sample('alpha', dist.Uniform(low=0.4, high=0.999))
        
    if noise is None:
        noise = numpyro.sample('noise', dist.Uniform(low=0.01, high=1))
    
    Q = (D - alpha*A)
    
    car = numpyro.sample(
        'car', dist.MultivariateNormal(
            loc=jnp.zeros(args.num_regions), precision_matrix=Q))
    numpyro.deterministic('car_samples', car)
    
    if y is None: # during prediction
        numpyro.sample('y_pred', dist.Normal(car, noise))
    else: # during inference
        numpyro.sample('y', dist.Normal(car, noise), obs=y)

# %%
# generate ground truth - fix alpha
RNG_KEY, rng_pred = jax.random.split(RNG_KEY)

car_predictive = Predictive(car_predictive_model_with_noise, num_samples=1)
car_preds = car_predictive(rng_pred, CAR_ARGS, alpha=0.7, noise=0.5)
y_data = car_preds['y_pred'][0,:]
y_truth = car_preds['car'][0,:]

# %%
df2 = df.copy()

# %%
df2['y_truth'] = y_truth
df2['y_data'] = y_data

_max = np.max([y_truth, y_data])
_min = np.min([y_truth, y_data])

fig, ax = plt.subplots(1, 2, figsize=(12, 6))
df2.plot(column='y_truth', ax=ax[0], vmin=_min, vmax=_max, legend=True, cmap='viridis')
df2.plot(column='y_data', ax=ax[1], vmin=_min, vmax=_max, legend=True, cmap='viridis')

ax[0].set_title('Ground truth')
ax[1].set_title('Ground truth + noise')

plt.show()

# %% [markdown]
# ## Inference

# %%
def vgae_predictive_model(args: CARArgs, y=None, noise=None):
    z = numpyro.sample("z", dist.Normal(0, 1).expand([ARGS.latent_dim]))
    
    # The transpose is because we initially used 
        # more than one samples ~ N(0, 1) as features for each node
    out = jnp.squeeze(decoder_net.apply(args.decoder_params, z).nodes.T)
    # out = 1.0/SCALE * out
    car_vgae = numpyro.deterministic("vgae_car", out)
    
    if noise is None:
        noise = numpyro.sample('noise', dist.Uniform(low=0.01, high=1))
    
    if y is None: # during prediction
        numpyro.sample("y_pred", dist.Normal(car_vgae, noise))
    else: # during inference
        numpyro.sample("y", dist.Normal(car_vgae, noise), obs=y)

# %%
RNG_KEY, rng_mcmc = jax.random.split(RNG_KEY)

# Inference time
start = time.time()
init_strategy = init_to_median(num_samples=10)
kernel = NUTS(vgae_predictive_model, init_strategy=init_strategy)
mcmc = MCMC(
    kernel, 
    num_warmup=1000, 
    num_samples=2000,
)
mcmc.run(rng_mcmc, CAR_ARGS, y=y_data)
# mcmc.run(rng_mcmc, CAR_ARGS, y=y_truth)
mcmc_samples = mcmc.get_samples()
mcmc.print_summary(exclude_deterministic=False)
t_elapsed = time.time() - start
# Out:
# sample: 100%|██████████| 3000/3000 [00:03<00:00, 767.00it/s, 15 steps of size 3.37e-01. acc. prob=0.87]
#                   mean       std    median      5.0%     95.0%     n_eff     r_hat
#        noise      0.68      0.07      0.68      0.57      0.78   1706.74      1.00
#  vgae_car[0]      0.09      0.17      0.08     -0.18      0.36   2519.44      1.00
#  vgae_car[1]      0.02      0.16      0.03     -0.23      0.29   2625.18      1.00
#  vgae_car[2]      0.11      0.20      0.12     -0.20      0.43   2363.64      1.00
#  vgae_car[3]     -0.02      0.20     -0.02     -0.35      0.32   2109.19      1.00
#  vgae_car[4]     -0.03      0.16     -0.03     -0.28      0.23   2200.97      1.00
#  vgae_car[5]     -0.00      0.18     -0.00     -0.29      0.29   2350.27      1.00
#  vgae_car[6]      0.10      0.20      0.11     -0.20      0.46   2135.03      1.00
#  vgae_car[7]     -0.01      0.19     -0.01     -0.34      0.27   2148.03      1.00
#  vgae_car[8]      0.03      0.17      0.03     -0.26      0.31   2051.03      1.00
#  vgae_car[9]      0.20      0.18      0.20     -0.11      0.48   2139.94      1.00
# vgae_car[10]      0.32      0.16      0.32      0.07      0.59   2188.12      1.00
# vgae_car[11]      0.33      0.16      0.34      0.07      0.58   2374.86      1.00
# vgae_car[12]      0.29      0.17      0.30      0.03      0.57   2375.09      1.00
# vgae_car[13]      0.32      0.19      0.33      0.04      0.64   2294.02      1.00
# vgae_car[14]      0.28      0.17      0.29      0.02      0.55   2581.50      1.00
# vgae_car[15]      0.39      0.18      0.40      0.11      0.70   2111.16      1.00
# vgae_car[16]      0.35      0.18      0.35      0.04      0.63   2353.31      1.00
# vgae_car[17]      0.33      0.18      0.34      0.03      0.61   2029.65      1.00
# vgae_car[18]      0.00      0.17      0.00     -0.26      0.27   2584.78      1.00
# vgae_car[19]      0.23      0.19      0.23     -0.07      0.55   2215.11      1.00
# vgae_car[20]     -0.02      0.15     -0.02     -0.27      0.23   2746.88      1.00
# vgae_car[21]      0.08      0.17      0.08     -0.20      0.37   2429.43      1.00
# vgae_car[22]      0.26      0.19      0.27     -0.05      0.58   2166.16      1.00
# vgae_car[23]      0.26      0.17      0.27     -0.03      0.53   2027.64      1.00
# vgae_car[24]      0.25      0.20      0.26     -0.07      0.57   2157.21      1.00
# vgae_car[25]      0.05      0.22      0.05     -0.30      0.41   2564.75      1.00
# vgae_car[26]      0.41      0.22      0.41      0.05      0.75   2198.81      1.00
# vgae_car[27]      0.03      0.15      0.03     -0.21      0.29   2649.84      1.00
# vgae_car[28]      0.23      0.20      0.23     -0.07      0.59   2732.65      1.00
# vgae_car[29]      0.15      0.18      0.16     -0.13      0.47   2567.15      1.00
# vgae_car[30]      0.24      0.20      0.24     -0.06      0.57   2473.34      1.00
# vgae_car[31]      0.03      0.16      0.03     -0.22      0.31   3031.61      1.00
# vgae_car[32]      0.16      0.19      0.16     -0.13      0.49   2529.05      1.00
# vgae_car[33]      0.18      0.19      0.18     -0.12      0.49   2669.66      1.00
# vgae_car[34]      0.04      0.18      0.04     -0.26      0.34   2328.07      1.00
# vgae_car[35]      0.11      0.19      0.11     -0.18      0.44   2340.20      1.00
# vgae_car[36]      0.16      0.18      0.16     -0.11      0.49   2591.07      1.00
# vgae_car[37]     -0.01      0.14     -0.01     -0.23      0.22   2398.91      1.00
# vgae_car[38]      0.10      0.18      0.09     -0.20      0.39   2390.94      1.00
# vgae_car[39]      0.16      0.18      0.16     -0.15      0.44   2558.72      1.00
# vgae_car[40]      0.05      0.14      0.05     -0.17      0.29   2353.29      1.00
# vgae_car[41]      0.20      0.19      0.21     -0.10      0.51   2380.28      1.00
# vgae_car[42]      0.18      0.17      0.19     -0.09      0.49   2845.46      1.00
# vgae_car[43]      0.12      0.18      0.12     -0.17      0.42   2036.85      1.00
# vgae_car[44]      0.22      0.20      0.22     -0.10      0.55   2363.24      1.00
# vgae_car[45]      0.16      0.16      0.16     -0.14      0.40   2357.25      1.00
# vgae_car[46]      0.15      0.18      0.15     -0.14      0.46   2371.51      1.00
# vgae_car[47]      0.13      0.23      0.14     -0.25      0.51   2521.74      1.00
# vgae_car[48]      0.13      0.14      0.13     -0.12      0.35   2457.70      1.00
# vgae_car[49]      0.15      0.24      0.15     -0.25      0.54   2591.08      1.00
# vgae_car[50]      0.16      0.17      0.16     -0.10      0.44   2537.69      1.00
# vgae_car[51]      0.18      0.18      0.18     -0.11      0.47   3088.88      1.00
# vgae_car[52]      0.07      0.17      0.07     -0.20      0.36   2584.71      1.00
# vgae_car[53]      0.13      0.23      0.13     -0.26      0.48   2675.64      1.00
# vgae_car[54]      0.16      0.17      0.16     -0.10      0.43   2587.68      1.00
# vgae_car[55]      0.08      0.17      0.08     -0.18      0.37   2457.47      1.00
# vgae_car[56]      0.20      0.21      0.20     -0.15      0.52   2236.74      1.00
# vgae_car[57]      0.18      0.18      0.18     -0.12      0.47   2335.68      1.00
# vgae_car[58]      0.14      0.14      0.15     -0.12      0.36   2462.98      1.00
# vgae_car[59]      0.14      0.18      0.15     -0.17      0.41   2441.96      1.00
# vgae_car[60]      0.17      0.17      0.17     -0.11      0.46   2718.68      1.00
# vgae_car[61]      0.14      0.16      0.13     -0.12      0.38   2558.25      1.00
# vgae_car[62]      0.15      0.16      0.15     -0.09      0.42   2804.29      1.00
#         z[0]      0.37      0.98      0.37     -1.17      2.05   3825.51      1.00
#         z[1]      0.16      0.96      0.14     -1.33      1.83   3349.73      1.00
#         z[2]      0.15      0.97      0.13     -1.54      1.64   4037.57      1.00
#         z[3]     -0.49      0.89     -0.51     -1.84      1.03   4693.04      1.00
#         z[4]      0.07      0.92      0.07     -1.45      1.60   3476.63      1.00
#         z[5]     -0.56      0.97     -0.54     -2.21      0.97   4107.94      1.00
#         z[6]     -0.23      0.95     -0.22     -1.79      1.33   4324.87      1.00
#         z[7]     -0.40      0.91     -0.37     -1.79      1.12   3706.46      1.00
#         z[8]      0.40      0.95      0.41     -1.04      2.05   3909.03      1.00
#         z[9]      0.31      0.96      0.33     -1.30      1.83   4093.22      1.00
#        z[10]      0.05      0.91      0.05     -1.41      1.50   4523.40      1.00
#        z[11]     -0.08      0.95     -0.07     -1.66      1.47   4343.96      1.00
#        z[12]      0.27      0.90      0.27     -1.06      1.86   4736.46      1.00
#        z[13]     -0.09      0.96     -0.07     -1.50      1.58   4163.14      1.00
#        z[14]      0.27      0.93      0.24     -1.29      1.76   4448.39      1.00
#        z[15]      0.30      0.94      0.31     -1.31      1.77   3981.35      1.00
#        z[16]      0.11      0.91      0.11     -1.31      1.60   3947.81      1.00
#        z[17]      0.16      0.98      0.17     -1.37      1.78   3470.86      1.00
#        z[18]     -0.12      0.97     -0.11     -1.64      1.48   3969.32      1.00
#        z[19]     -0.49      0.97     -0.49     -2.10      1.10   4901.01      1.00
#        z[20]     -0.36      0.98     -0.35     -1.90      1.30   3698.17      1.00
#        z[21]     -0.08      1.00     -0.07     -1.87      1.45   3920.18      1.00
#        z[22]      0.21      0.98      0.22     -1.24      1.95   3727.52      1.00
#        z[23]      0.45      0.96      0.42     -1.15      1.97   4279.51      1.00
#        z[24]     -0.02      0.87     -0.02     -1.50      1.34   3578.63      1.00
#        z[25]      0.42      0.97      0.42     -1.16      1.99   5375.81      1.00
#        z[26]     -0.13      1.00     -0.15     -1.66      1.58   4539.29      1.00
#        z[27]     -0.06      0.95     -0.06     -1.55      1.53   4830.85      1.00
#        z[28]     -0.17      0.91     -0.19     -1.68      1.32   3982.58      1.00
#        z[29]      0.18      0.96      0.19     -1.37      1.79   3357.87      1.00
#        z[30]     -0.37      0.97     -0.40     -2.04      1.15   4005.93      1.00
#        z[31]      0.00      1.03     -0.02     -1.70      1.67   3973.37      1.00
#        z[32]     -0.15      0.96     -0.14     -1.75      1.37   3224.26      1.00
#        z[33]     -0.16      1.01     -0.17     -1.79      1.59   5504.74      1.00
#        z[34]     -0.21      0.88     -0.19     -1.76      1.05   4014.85      1.00
#        z[35]     -0.06      0.94     -0.07     -1.64      1.43   3631.57      1.00
#        z[36]      0.29      0.95      0.27     -1.23      1.83   4192.47      1.00
#        z[37]      0.01      0.97      0.02     -1.61      1.55   4381.43      1.00
#        z[38]     -0.22      0.97     -0.23     -1.93      1.22   3704.03      1.00
#        z[39]      0.04      0.91      0.04     -1.55      1.43   4578.23      1.00
#        z[40]     -0.37      0.92     -0.38     -1.88      1.16   3669.88      1.00
#        z[41]      0.07      0.94      0.08     -1.41      1.59   3192.34      1.00
#        z[42]     -0.00      0.93     -0.00     -1.50      1.52   3719.82      1.00
#        z[43]      0.16      0.96      0.14     -1.52      1.67   5110.40      1.00
#        z[44]      0.11      0.98      0.10     -1.43      1.75   4516.94      1.00
#        z[45]      0.07      0.91      0.06     -1.34      1.58   3611.23      1.00
#        z[46]      0.05      0.92      0.08     -1.53      1.40   3711.03      1.00
#        z[47]     -0.16      0.98     -0.17     -1.66      1.58   3916.46      1.00
#        z[48]     -0.40      0.94     -0.42     -1.92      1.16   4486.52      1.00
#        z[49]      0.21      0.97      0.19     -1.28      1.86   4360.73      1.00
#
# Number of divergences: 0

# %%
print("\nMCMC elapsed time:", round(t_elapsed), "s")
ss = numpyro.diagnostics.summary(mcmc.get_samples(group_by_chain=True))
r = np.mean(ss['vgae_car']['n_eff'])
print("Average ESS for all CAR effects : " + str(round(r)))
# Out:
# MCMC elapsed time: 6 s
# Average ESS for all CAR effects : 2430

# %%
# posterior predictive
RNG_KEY, rng_pred = jax.random.split(RNG_KEY)
posterior_predictions = Predictive(vgae_predictive_model, mcmc_samples)(rng_pred, CAR_ARGS)

post_obs = posterior_predictions['vgae_car']
mean_post_pred_vgae = np.mean(post_obs, axis=0)
bci_vgae_2_5 = np.quantile(post_obs, 0.025, axis=0)
bci_vgae_97_5 = np.quantile(post_obs, 0.975, axis=0)
hpdi_post_pred_vgae = hpdi(post_obs, 0.9)

# %%
df2['vgae_estimate'] = mean_post_pred_vgae

_max = np.max([y_truth, y_data, mean_post_pred_vgae])
_min = np.min([y_truth, y_data, mean_post_pred_vgae])

fig, ax = plt.subplots(1, 3, figsize=(18, 6))
df2.plot(column='y_truth', ax=ax[0], vmin=_min, vmax=_max, legend=True, cmap='viridis')
df2.plot(column='y_data', ax=ax[1], vmin=_min, vmax=_max, legend=True, cmap='viridis')
df2.plot(column='vgae_estimate', ax=ax[2], vmin=_min, vmax=_max, legend=True, cmap='viridis')

ax[0].set_title('Ground truth')
ax[1].set_title('Ground truth + noise')
ax[2].set_title('VGAE estimate')

plt.show()

# %%
assert False
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# /Users/salmanfaris/Desktop/ds-projects/msc-proj/PriorVGAE/carZimbabwe_synthetic_PriorVGAE_flatten.ipynb Cell 44 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/Users/salmanfaris/Desktop/ds-projects/msc-proj/PriorVGAE/carZimbabwe_synthetic_PriorVGAE_flatten.ipynb#Y210sZmlsZQ%3D%3D?line=0'>1</a> assert False
#
# AssertionError:

# %% [markdown]
# # Prevalence VGAE-CAR

# %%
def prevalence_vgae_predictive_model(args: CARArgs, y=None) -> None:
  n_obs = args.n_obs_vector
  
  z = numpyro.sample('z', dist.Normal(0, 1).expand([ARGS.latent_dim]))
  
  # The transpose is because we initially used 
  # more than one samples ~ N(0, 1) as features for each node
  out = jnp.squeeze(decoder_net.apply(args.decoder_params, z).nodes)
  car_std_vgae = numpyro.deterministic('car_std_vgae', out)
  
  # Fixed effects
  b0 = numpyro.sample('b0', dist.Normal(0, 1))
  tau = numpyro.sample('tau', dist.Gamma(6, 4)) 

  sigma = numpyro.deterministic('sigma', 1./jnp.sqrt(tau))
  car_vgae = numpyro.deterministic('car_vgae', sigma * car_std_vgae)
  _ = numpyro.deterministic('VGAE-CAR 1', car_vgae[0])

  lp = b0 + car_vgae
  numpyro.deterministic("theta", jax.nn.sigmoid(lp))
      
  numpyro.sample("obs", dist.BinomialLogits(total_count=n_obs, logits=lp), obs=y)

# %%
RNG_KEY, rng_mcmc_vgae = jax.random.split(RNG_KEY)

# Inference
start = time.time()
kernel = NUTS(prevalence_vgae_predictive_model)
mcmc_vgae = MCMC(
    kernel, 
    num_warmup=1000, 
    num_samples=2000,
)
mcmc_vgae.run(rng_mcmc_vgae, CAR_ARGS, y=jnp.array(df.y))
t_elapsed = time.time() - start

prevalence_vgae_samples = mcmc_vgae.get_samples()
# Out:
# sample: 100%|██████████| 3000/3000 [00:05<00:00, 503.55it/s, 31 steps of size 1.47e-01. acc. prob=0.94]

# %%
print("\nMCMC elapsed time:", round(t_elapsed), "s")
ss = numpyro.diagnostics.summary(mcmc_vgae.get_samples(group_by_chain=True))
r = np.mean(ss['car_vgae']['n_eff'])
print("Average ESS for all VAE-CAR effects : " + str(round(r)))
# Out:
# MCMC elapsed time: 9 s
# Average ESS for all VAE-CAR effects : 1947

# %%
RNG_KEY, predictive_rng = jax.random.split(RNG_KEY)

# posterior predictive
prev_posterior_predictive_vae = Predictive(
    prevalence_vgae_predictive_model, 
    prevalence_vgae_samples)(predictive_rng, CAR_ARGS)

theta_sams_vae_car = prev_posterior_predictive_vae['theta']
theta_mean_vae_car = theta_sams_vae_car.mean(axis=0)
bci_vae_car_25 = np.quantile(theta_sams_vae_car, 0.25, axis=0)
bci_vae_car_75 = np.quantile(theta_sams_vae_car, 0.75, axis=0)

df['theta_vae_car'] = theta_mean_vae_car

theta_observed = df['estimate']
theta_estimated = df['theta_vae_car']

_max = np.max([theta_observed, theta_estimated])
_min = np.min([theta_observed, theta_estimated])

fig, ax = plt.subplots(1, 2, figsize=(12,6))
df.plot(column="estimate", ax=ax[0], legend=True, cmap='plasma', vmin=_min, vmax =_max)
df.plot(column="theta_vae_car", ax=ax[1], legend=True, cmap='plasma', vmin=_min, vmax =_max)
ax[0].set_title( 'Observed prevalence')
ax[1].set_title( 'Estimated prevalence (VGAE-CAR)')

plt.show()

# %%
import plotting

vmax = np.max([theta_observed, theta_estimated])
vmin = np.min([theta_observed, theta_estimated])

plotting.plot_compare_estimates(
    data_x=theta_observed, data_y=theta_estimated,
    x_label=r'observed $\theta$', 
    y_label=r'VGAE-CAR estimated $\theta$',
    xlim=(vmin-0.02, vmax+0.02),
    ylim=(vmin-0.02, vmax+0.02),
    figsize=(6, 6),
)

mse_vgae = np.mean((theta_observed -  theta_estimated)**2)
print(f'mse_vgae = {mse_vgae}')
# Out:
# mse_vgae = 0.0007846155074125547

# %% [markdown]
# # Prevalence CAR

# %%
def prevalence_car_predictive_model(args: CARArgs, y=None) -> None:
  A = jnp.array(args.adj_matrix)
  D = jnp.diag(args.degree_vector)
  n_obs = args.n_obs_vector

  # Fixed effects
  b0 = numpyro.sample('b0', dist.Normal(0, 1))
  tau = numpyro.sample('tau', dist.Gamma(6, 4)) 
  alpha = numpyro.sample('alpha', dist.Uniform(low=0., high=1.))

  Q_std = (D - alpha*A)
  car_std = numpyro.sample('car_std', dist.MultivariateNormal(loc=jnp.zeros(args.num_regions), precision_matrix=Q_std))
  sigma = numpyro.deterministic('sigma', 1./jnp.sqrt(tau))
  car = numpyro.deterministic('car', sigma * car_std)

  numpyro.deterministic('CAR 1', car[0])

  lp = b0 + car
  numpyro.deterministic("theta", jax.nn.sigmoid(lp))
      
  numpyro.sample("obs", dist.BinomialLogits(total_count = n_obs, logits=lp), obs=y)

# %%
import dill
mcmc_path = Path.cwd() / 'models/zimbabwe_car_mcmc_sampler.pkl'

OVERRIDE_LOAD = False

RNG_KEY, mcmc_rng = jax.random.split(RNG_KEY)
start = time.time()
if mcmc_path.exists():
    # Load sampler.
    with open(mcmc_path, 'rb') as f:
        mcmc_car = dill.load(f)
else:
    kernel = NUTS(prevalence_car_predictive_model)
    mcmc_car = MCMC(kernel, num_warmup=1000, num_samples=2000)
    mcmc_car.run(mcmc_rng, CAR_ARGS, y=jnp.array(df.y))
    
    # Save sampler.
    with open(mcmc_path, 'wb') as f:
        dill.dump(mcmc_car, f)
        
prevalence_car_samples = mcmc_car.get_samples()
mcmc_car.print_summary(exclude_deterministic=False)
t_elapsed = time.time() - start
# Out:
#                  mean       std    median      5.0%     95.0%     n_eff     r_hat
#       CAR 1      0.14      0.18      0.16     -0.14      0.42    115.93      1.02
#       alpha      0.92      0.08      0.94      0.81      1.00    472.52      1.00
#          b0     -1.77      0.17     -1.78     -2.02     -1.53     98.41      1.03
#      car[0]      0.14      0.18      0.16     -0.14      0.42    115.93      1.02
#      car[1]      0.07      0.23      0.08     -0.30      0.43    181.30      1.01
#      car[2]     -0.22      0.19     -0.20     -0.48      0.09    119.73      1.02
#      car[3]     -0.33      0.23     -0.32     -0.65      0.06    161.68      1.02
#      car[4]     -0.50      0.30     -0.49     -0.95     -0.00    265.22      1.01
#      car[5]     -0.29      0.23     -0.28     -0.67      0.05    170.63      1.02
#      car[6]     -0.28      0.21     -0.27     -0.59      0.08    146.97      1.01
#      car[7]     -0.41      0.22     -0.39     -0.73     -0.04    158.47      1.01
#      car[8]     -0.76      0.31     -0.76     -1.32     -0.30    333.22      1.01
#      car[9]     -0.41      0.29     -0.40     -0.90      0.02    292.75      1.01
#     car[10]     -0.35      0.25     -0.34     -0.72      0.07    203.09      1.01
#     car[11]     -0.25      0.25     -0.25     -0.61      0.18    189.25      1.01
#     car[12]     -0.12      0.24     -0.12     -0.49      0.27    225.92      1.01
#     car[13]      0.10      0.21      0.11     -0.21      0.43    143.63      1.02
#     car[14]     -0.28      0.28     -0.26     -0.70      0.22    258.84      1.01
#     car[15]     -0.20      0.22     -0.19     -0.54      0.15    166.14      1.02
#     car[16]     -0.62      0.31     -0.61     -1.14     -0.13    284.85      1.01
#     car[17]     -0.19      0.25     -0.17     -0.62      0.18    191.37      1.01
#     car[18]      0.01      0.23      0.03     -0.36      0.38    176.80      1.01
#     car[19]     -0.14      0.22     -0.12     -0.45      0.26    158.13      1.01
#     car[20]     -0.21      0.28     -0.20     -0.62      0.28    254.75      1.01
#     car[21]      0.00      0.23      0.01     -0.33      0.39    178.87      1.01
#     car[22]     -0.31      0.28     -0.31     -0.76      0.13    275.80      1.02
#     car[23]     -0.19      0.23     -0.17     -0.52      0.19    169.92      1.01
#     car[24]     -0.18      0.24     -0.17     -0.56      0.19    162.59      1.01
#     car[25]      0.12      0.21      0.13     -0.21      0.45    145.18      1.02
#     car[26]     -0.56      0.27     -0.54     -1.01     -0.14    244.58      1.02
#     car[27]      0.03      0.22      0.04     -0.30      0.38    164.38      1.02
#     car[28]     -0.65      0.22     -0.64     -1.00     -0.30    160.83      1.02
#     car[29]     -0.51      0.31     -0.50     -1.03     -0.03    354.06      1.00
#     car[30]     -0.32      0.22     -0.31     -0.65      0.04    155.29      1.01
#     car[31]      0.08      0.26      0.10     -0.37      0.47    211.48      1.01
#     car[32]     -0.11      0.22     -0.10     -0.44      0.24    142.56      1.02
#     car[33]     -0.15      0.21     -0.14     -0.47      0.18    156.62      1.01
#     car[34]     -0.49      0.26     -0.47     -0.91     -0.08    207.10      1.01
#     car[35]      0.24      0.21      0.25     -0.08      0.57    137.25      1.02
#     car[36]     -0.01      0.23      0.00     -0.36      0.38    201.84      1.01
#     car[37]     -0.11      0.23     -0.10     -0.44      0.29    175.64      1.02
#     car[38]     -0.33      0.22     -0.33     -0.65      0.04    160.79      1.02
#     car[39]      0.09      0.22      0.10     -0.26      0.43    170.95      1.01
#     car[40]      0.03      0.23      0.05     -0.35      0.39    178.47      1.01
#     car[41]     -0.28      0.23     -0.27     -0.67      0.06    166.89      1.02
#     car[42]      0.35      0.23      0.36      0.00      0.73    172.46      1.02
#     car[43]      0.24      0.22      0.25     -0.12      0.57    173.67      1.01
#     car[44]      0.56      0.22      0.56      0.23      0.95    148.48      1.02
#     car[45]      0.08      0.23      0.09     -0.25      0.46    162.60      1.02
#     car[46]      0.66      0.22      0.67      0.31      1.01    173.52      1.01
#     car[47]      0.49      0.22      0.49      0.13      0.82    156.53      1.02
#     car[48]      0.41      0.23      0.41      0.08      0.81    194.46      1.01
#     car[49]      0.42      0.23      0.42      0.04      0.78    188.17      1.01
#     car[50]      0.31      0.22      0.32     -0.00      0.66    159.83      1.02
#     car[51]      0.50      0.23      0.51      0.16      0.89    181.42      1.01
#     car[52]      0.44      0.29      0.45     -0.02      0.90    292.67      1.01
#     car[53]      0.27      0.23      0.28     -0.08      0.64    189.20      1.02
#     car[54]      0.17      0.26      0.18     -0.22      0.61    243.74      1.01
#     car[55]     -0.05      0.25     -0.03     -0.40      0.39    239.48      1.01
#     car[56]     -0.80      0.27     -0.78     -1.22     -0.35    242.17      1.01
#     car[57]     -0.27      0.22     -0.26     -0.63      0.08    158.95      1.01
#     car[58]     -0.10      0.22     -0.09     -0.47      0.23    169.23      1.01
#     car[59]     -0.03      0.21     -0.02     -0.37      0.30    149.67      1.02
#     car[60]      0.24      0.23      0.25     -0.11      0.63    185.12      1.01
#     car[61]     -0.04      0.26     -0.04     -0.46      0.39    238.45      1.01
#     car[62]      0.17      0.27      0.17     -0.25      0.61    265.23      1.01
#  car_std[0]      0.22      0.29      0.24     -0.20      0.68    114.87      1.02
#  car_std[1]      0.10      0.36      0.12     -0.44      0.70    179.60      1.01
#  car_std[2]     -0.34      0.30     -0.31     -0.79      0.13    115.54      1.02
#  car_std[3]     -0.52      0.36     -0.50     -1.04      0.09    153.41      1.02
#  car_std[4]     -0.78      0.47     -0.76     -1.50      0.01    254.78      1.01
#  car_std[5]     -0.46      0.36     -0.43     -1.10      0.06    162.75      1.02
#  car_std[6]     -0.44      0.34     -0.41     -0.93      0.14    140.24      1.01
#  car_std[7]     -0.64      0.35     -0.62     -1.17     -0.05    150.32      1.01
#  car_std[8]     -1.19      0.49     -1.17     -1.99     -0.43    273.80      1.01
#  car_std[9]     -0.64      0.45     -0.62     -1.37      0.08    270.13      1.01
# car_std[10]     -0.54      0.38     -0.52     -1.12      0.11    190.79      1.01
# car_std[11]     -0.40      0.39     -0.38     -1.05      0.20    174.49      1.01
# car_std[12]     -0.20      0.38     -0.18     -0.77      0.43    217.91      1.01
# car_std[13]      0.15      0.32      0.17     -0.35      0.66    141.65      1.02
# car_std[14]     -0.44      0.45     -0.41     -1.13      0.30    246.34      1.01
# car_std[15]     -0.32      0.35     -0.29     -0.88      0.23    161.96      1.02
# car_std[16]     -0.96      0.49     -0.93     -1.76     -0.18    249.18      1.01
# car_std[17]     -0.30      0.40     -0.27     -0.91      0.36    186.77      1.01
# car_std[18]      0.01      0.37      0.04     -0.58      0.59    170.25      1.01
# car_std[19]     -0.21      0.35     -0.19     -0.76      0.32    152.00      1.02
# car_std[20]     -0.32      0.43     -0.31     -0.99      0.41    237.00      1.01
# car_std[21]      0.00      0.36      0.02     -0.56      0.57    176.58      1.01
# car_std[22]     -0.49      0.45     -0.47     -1.24      0.19    266.13      1.02
# car_std[23]     -0.30      0.36     -0.27     -0.86      0.26    162.85      1.01
# car_std[24]     -0.28      0.37     -0.26     -0.90      0.30    156.33      1.01
# car_std[25]      0.18      0.33      0.20     -0.35      0.71    143.61      1.02
# car_std[26]     -0.86      0.42     -0.82     -1.53     -0.18    216.72      1.02
# car_std[27]      0.04      0.34      0.06     -0.43      0.64    159.27      1.02
# car_std[28]     -1.02      0.37     -0.98     -1.58     -0.43    154.62      1.01
# car_std[29]     -0.79      0.49     -0.78     -1.64     -0.05    327.60      1.00
# car_std[30]     -0.50      0.35     -0.49     -1.01      0.08    141.52      1.01
# car_std[31]      0.12      0.40      0.15     -0.56      0.74    204.59      1.01
# car_std[32]     -0.18      0.34     -0.16     -0.69      0.38    136.46      1.02
# car_std[33]     -0.24      0.33     -0.22     -0.69      0.33    149.77      1.01
# car_std[34]     -0.76      0.41     -0.73     -1.38     -0.09    186.07      1.01
# car_std[35]      0.37      0.32      0.38     -0.12      0.89    137.07      1.02
# car_std[36]     -0.01      0.36      0.01     -0.57      0.57    195.33      1.01
# car_std[37]     -0.17      0.37     -0.15     -0.71      0.47    169.57      1.02
# car_std[38]     -0.51      0.34     -0.51     -1.06      0.00    145.70      1.02
# car_std[39]      0.14      0.35      0.16     -0.37      0.70    168.51      1.01
# car_std[40]      0.05      0.36      0.07     -0.51      0.63    174.15      1.01
# car_std[41]     -0.44      0.36     -0.42     -1.03      0.14    158.08      1.02
# car_std[42]      0.55      0.35      0.56      0.00      1.13    173.61      1.02
# car_std[43]      0.37      0.34      0.39     -0.16      0.91    174.50      1.01
# car_std[44]      0.87      0.35      0.87      0.37      1.47    161.40      1.02
# car_std[45]      0.12      0.35      0.14     -0.42      0.69    159.71      1.02
# car_std[46]      1.03      0.35      1.03      0.43      1.54    185.27      1.01
# car_std[47]      0.76      0.34      0.78      0.24      1.33    167.68      1.02
# car_std[48]      0.63      0.36      0.64      0.07      1.22    199.59      1.01
# car_std[49]      0.65      0.36      0.65      0.08      1.25    197.56      1.01
# car_std[50]      0.48      0.34      0.48     -0.00      1.03    163.04      1.02
# car_std[51]      0.77      0.35      0.79      0.24      1.38    183.97      1.01
# car_std[52]      0.69      0.45      0.70     -0.05      1.39    311.72      1.01
# car_std[53]      0.42      0.35      0.44     -0.11      1.01    193.79      1.02
# car_std[54]      0.27      0.40      0.28     -0.33      0.97    243.23      1.01
# car_std[55]     -0.08      0.38     -0.05     -0.65      0.58    226.24      1.01
# car_std[56]     -1.24      0.42     -1.23     -1.84     -0.51    212.97      1.01
# car_std[57]     -0.42      0.35     -0.40     -0.95      0.16    148.67      1.02
# car_std[58]     -0.16      0.34     -0.13     -0.68      0.43    159.64      1.01
# car_std[59]     -0.04      0.33     -0.03     -0.53      0.54    144.11      1.02
# car_std[60]      0.38      0.36      0.39     -0.21      0.94    186.67      1.01
# car_std[61]     -0.07      0.40     -0.06     -0.72      0.60    227.58      1.01
# car_std[62]      0.26      0.42      0.27     -0.46      0.89    263.73      1.01
#       sigma      0.65      0.07      0.64      0.53      0.77    640.63      1.00
#         tau      2.47      0.55      2.42      1.58      3.31    680.90      1.00
#    theta[0]      0.16      0.01      0.16      0.15      0.18   2596.43      1.00
#    theta[1]      0.16      0.02      0.15      0.12      0.19   3457.28      1.00
#    theta[2]      0.12      0.01      0.12      0.11      0.13   2587.22      1.00
#    theta[3]      0.11      0.01      0.11      0.09      0.13   2521.05      1.00
#    theta[4]      0.10      0.02      0.09      0.07      0.13   2936.88      1.00
#    theta[5]      0.11      0.02      0.11      0.09      0.14   3527.63      1.00
#    theta[6]      0.11      0.01      0.11      0.09      0.14   3324.14      1.00
#    theta[7]      0.10      0.01      0.10      0.08      0.12   3118.44      1.00
#    theta[8]      0.08      0.02      0.07      0.04      0.10   3083.60      1.00
#    theta[9]      0.10      0.02      0.10      0.07      0.14   2668.16      1.00
#   theta[10]      0.11      0.02      0.11      0.08      0.14   3304.73      1.00
#   theta[11]      0.12      0.02      0.12      0.09      0.15   3732.90      1.00
#   theta[12]      0.13      0.02      0.13      0.10      0.16   3468.44      1.00
#   theta[13]      0.16      0.02      0.16      0.13      0.18   3719.54      1.00
#   theta[14]      0.12      0.02      0.11      0.08      0.15   2933.44      1.00
#   theta[15]      0.12      0.02      0.12      0.10      0.15   3509.33      1.00
#   theta[16]      0.09      0.02      0.08      0.05      0.12   2686.38      1.00
#   theta[17]      0.13      0.02      0.12      0.09      0.15   2736.94      1.00
#   theta[18]      0.15      0.02      0.15      0.11      0.18   3177.28      1.00
#   theta[19]      0.13      0.02      0.13      0.10      0.16   3081.78      1.00
#   theta[20]      0.12      0.02      0.12      0.09      0.16   2591.53      1.00
#   theta[21]      0.15      0.02      0.15      0.11      0.18   2961.96      1.00
#   theta[22]      0.11      0.02      0.11      0.08      0.15   2926.16      1.00
#   theta[23]      0.12      0.02      0.12      0.10      0.15   3308.15      1.00
#   theta[24]      0.13      0.02      0.13      0.09      0.15   3163.19      1.00
#   theta[25]      0.16      0.02      0.16      0.13      0.19   3226.83      1.00
#   theta[26]      0.09      0.02      0.09      0.06      0.12   3031.81      1.00
#   theta[27]      0.15      0.02      0.15      0.12      0.18   2961.63      1.00
#   theta[28]      0.08      0.01      0.08      0.06      0.10   2986.80      1.00
#   theta[29]      0.10      0.02      0.09      0.06      0.13   2273.03      1.00
#   theta[30]      0.11      0.01      0.11      0.09      0.13   3445.17      1.00
#   theta[31]      0.16      0.03      0.16      0.11      0.20   3579.57      1.00
#   theta[32]      0.13      0.02      0.13      0.11      0.16   3185.88      1.00
#   theta[33]      0.13      0.01      0.13      0.11      0.15   3294.76      1.00
#   theta[34]      0.10      0.02      0.10      0.07      0.13   2610.63      1.00
#   theta[35]      0.18      0.02      0.18      0.15      0.21   3000.33      1.00
#   theta[36]      0.15      0.02      0.15      0.11      0.18   3254.05      1.00
#   theta[37]      0.13      0.02      0.13      0.10      0.16   3956.82      1.00
#   theta[38]      0.11      0.01      0.11      0.09      0.13   3172.89      1.00
#   theta[39]      0.16      0.02      0.16      0.13      0.19   3196.84      1.00
#   theta[40]      0.15      0.02      0.15      0.12      0.18   3133.16      1.00
#   theta[41]      0.11      0.02      0.11      0.09      0.14   3356.96      1.00
#   theta[42]      0.20      0.03      0.20      0.16      0.24   3072.54      1.00
#   theta[43]      0.18      0.02      0.18      0.14      0.21   3261.09      1.00
#   theta[44]      0.23      0.03      0.23      0.19      0.28   2767.15      1.00
#   theta[45]      0.16      0.02      0.16      0.12      0.19   3383.21      1.00
#   theta[46]      0.25      0.03      0.25      0.20      0.29   2864.95      1.00
#   theta[47]      0.22      0.02      0.22      0.18      0.26   2967.05      1.00
#   theta[48]      0.21      0.03      0.20      0.16      0.25   3574.77      1.00
#   theta[49]      0.21      0.03      0.21      0.16      0.25   3801.01      1.00
#   theta[50]      0.19      0.02      0.19      0.15      0.22   3499.57      1.00
#   theta[51]      0.22      0.03      0.22      0.17      0.26   3390.09      1.00
#   theta[52]      0.21      0.04      0.21      0.15      0.28   2741.06      1.00
#   theta[53]      0.18      0.02      0.18      0.14      0.22   3222.53      1.00
#   theta[54]      0.17      0.03      0.17      0.12      0.22   2292.70      1.00
#   theta[55]      0.14      0.02      0.14      0.11      0.18   3284.81      1.00
#   theta[56]      0.07      0.01      0.07      0.05      0.10   2142.74      1.00
#   theta[57]      0.12      0.01      0.12      0.09      0.14   3299.07      1.00
#   theta[58]      0.13      0.02      0.13      0.11      0.16   3875.02      1.00
#   theta[59]      0.14      0.02      0.14      0.12      0.17   2717.94      1.00
#   theta[60]      0.18      0.02      0.18      0.14      0.22   3572.60      1.00
#   theta[61]      0.14      0.02      0.14      0.10      0.18   3389.56      1.00
#   theta[62]      0.17      0.03      0.17      0.12      0.22   2847.74      1.00
#
# Number of divergences: 0

# %% [markdown]
# 1 min 22 seconds roughly

# %%
print("\nMCMC elapsed time:", round(t_elapsed), "s")
ss = numpyro.diagnostics.summary(mcmc_car.get_samples(group_by_chain=True))
r = np.mean(ss['car']['n_eff'])
print("Average ESS for all CAR effects : " + str(round(r)))
# Out:
# MCMC elapsed time: 0 s
# Average ESS for all CAR effects : 194

# %%
RNG_KEY, predictive_rng = jax.random.split(RNG_KEY)

# Posterior predictive.
prev_posterior_predictive = Predictive(
    prevalence_car_predictive_model, prevalence_car_samples)(predictive_rng, CAR_ARGS)

theta_samps_car = prev_posterior_predictive['theta']
theta_mean_car = theta_samps_car.mean(axis=0)
bci_car_25 = np.quantile(theta_samps_car, 0.25, axis=0)
bci_car_75 = np.quantile(theta_samps_car, 0.75, axis=0)

df['theta_car'] = theta_mean_car

theta_observed = df['estimate']
theta_estimated_car = df['theta_car']

_max = np.max([theta_observed, theta_estimated_car])
_min = np.min([theta_observed, theta_estimated_car])

fig, ax = plt.subplots(1, 2, figsize=(12,6))
df.plot(column="estimate", ax=ax[0], legend=True, cmap='plasma', vmin=_min, vmax =_max)
df.plot(column="theta_car", ax=ax[1], legend=True, cmap='plasma', vmin=_min, vmax =_max)
ax[0].set_title( 'Observed prevalence')
ax[1].set_title( 'Estimated prevalence (CAR model)')
# Out:
# Text(0.5, 1.0, 'Estimated prevalence (CAR model)')

# %%
import plotting

vmin = np.min([theta_observed, theta_estimated_car])
vmax = np.max([theta_observed, theta_estimated_car])

plotting.plot_compare_estimates(
    data_x=theta_observed, data_y=theta_estimated_car,
    x_label=r'observed $\theta$', 
    y_label=r'CAR-estimated $\theta$',
    xlim=(vmin-0.02, vmax+0.02),
    ylim=(vmin-0.02, vmax+0.02),
    figsize=(6, 6),
)

mse_car = np.mean((theta_observed -  theta_estimated_car)**2)
print(f'mse_car = {mse_car}')
# Out:
# mse_car = 0.00023834566416662024

# %%
prevalance_car_samples_az = az.from_numpyro(mcmc_car)
az.plot_trace(prevalance_car_samples_az,  var_names=("CAR 1"))

prevalance_vgae_samples_az = az.from_numpyro(mcmc_vgae)
az.plot_trace(prevalance_vgae_samples_az,  var_names=("VGAE-CAR 1"))

plt.show()

# %%
vgaecar0_samps = prev_posterior_predictive_vae['VGAE-CAR 1']
n_samps = vgaecar0_samps.shape[0]
car0_samps = prev_posterior_predictive['CAR 1']
n_samps = car0_samps.shape[0]

import pandas as pd
df_plt = pd.DataFrame({'VGAE-CAR':vgaecar0_samps, 'CAR': car0_samps})
df_plt.head()
df_plt.plot(lw = 0.6, alpha=0.9, figsize=(10, 5))
plt.legend(loc='upper right')
plt.xlabel("Iteration")
plt.ylabel("Parameter estimate")
#plt.show()

#plt.rcParams['figure.dpi'] = 300
#plt.rcParams['savefig.dpi'] = 300
#plt.savefig("../res/Zimbabwe_traceplots.pdf")
# Out:
# Text(0, 0.5, 'Parameter estimate')

# %%
_max = np.max([df['estimate'], df['theta_car'], df['theta_vae_car']])
_min = np.min([df['estimate'], df['theta_car'], df['theta_vae_car']])

fig, ax = plt.subplots(1, 3, figsize=(18,6))
df.plot(column="estimate", ax=ax[0], legend=True, cmap='plasma', vmin=_min, vmax =_max)
df.plot(column="theta_car", ax=ax[1], legend=True, cmap='plasma', vmin=_min, vmax =_max)
df.plot(column="theta_vae_car", ax=ax[2], legend=True, cmap='plasma', vmin=_min, vmax =_max)
ax[0].set_title( 'Observed prevalence')
ax[1].set_title( 'Estimated prevalence (CAR)')
ax[2].set_title( 'Estimated prevalence (VGAE-CAR)')
# Out:
# Text(0.5, 1.0, 'Estimated prevalence (VGAE-CAR)')

# %%
_max = np.max([ theta_mean_vae_car, theta_mean_car, bci_car_25, bci_car_75, bci_vae_car_25, bci_vae_car_75])
_min = np.min([ theta_mean_vae_car, theta_mean_car])

plt.rcParams["figure.figsize"] = (6,6)

plt.ylim(_min, _max)
plt.xlim(_min, _max)
plt.plot([_min, _max], [_min, _max], ls="--", c=".3")
plt.xlabel("predicted prevalence, VAE-CAR")
plt.ylabel("predicted prevalence, CAR")

plt.vlines(x=theta_mean_car, 
           ymin=bci_car_25,
           ymax=bci_car_75,
           color="orange", 
           label="50% BCI, CAR", 
           linewidth=0.8)
plt.hlines(y=theta_mean_vae_car, 
           xmin=bci_vae_car_25,
           xmax=bci_vae_car_75,
           color="steelblue", 
           label="50% BCI, VAE-CAR", 
           linewidth=0.8)

plt.scatter(theta_mean_vae_car, theta_mean_car, color="teal")
plt.legend(loc="upper left")

# %%
print(f'{mse_car}')
print(f'{mse_vgae}')
# Out:
# 0.00023834566416662024
# 0.0007846155074125547
