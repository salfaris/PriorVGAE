# %%
# %load_ext autoreload
# %autoreload 2

import os
from pathlib import Path
import time
from typing import Tuple, Type

import haiku as hk
import jax
import jax.numpy as jnp
import jraph
import networkx as nx
import matplotlib.pyplot as plt
import numpy as np
import optax

# Numpyro
import numpyro
import numpyro.distributions as dist
from numpyro.infer import MCMC, NUTS, init_to_median, Predictive
from numpyro.diagnostics import hpdi

# Local imports
import loss
import dataset_1dgp
import plotting
import model

print(f"JAX version: {jax.__version__}")
print(f"Numpyro version: {numpyro.__version__}")
# Out:
# /Users/salmanfaris/miniforge3/envs/prior-vgae/lib/python3.9/site-packages/jax/_src/lib/__init__.py:34: UserWarning: JAX on Mac ARM machines is experimental and minimally tested. Please see https://github.com/google/jax/issues/5501 in the event of problems.
#   warnings.warn("JAX on Mac ARM machines is experimental and minimally tested. "
# JAX version: 0.3.13
# Numpyro version: 0.9.2

# %%
FIG_PATH = Path('./figures/1DGP_figures')
FIG_PATH.mkdir(exist_ok=True)

DATASET_PATH = Path('./dataset.nosync')
DATASET_PATH.mkdir(exist_ok=True)

# %%
RNG_SEED = 44
RNG_KEY = jax.random.PRNGKey(RNG_SEED)

# %%
from dataclasses import dataclass
from typing import Dict, Optional, Callable

LossFun = Callable[[jax.numpy.ndarray, jax.numpy.ndarray], jnp.float32]

@dataclass
class GP1DArgs:
  kernel: Callable = dataset_1dgp.exp_sq_kernel
  num_locations: int = 200
  
@dataclass
class Args:  
  # Training params
  loss_fn: LossFun = loss.compute_mse_loss
  epochs: int = 500_000
  eval_frequency: int = 1000
  learning_rate: float = 1e-3
  beta: float = 1e-2  # beta-VAE
  
  # Model params
  hidden_gnn_dim: int = 2
  hidden_fc_dim: int = 60
  latent_dim: int = 30
  output_dim: int = 1
  act_fn: Callable = jax.nn.elu

GP1D_ARGS = GP1DArgs()
ARGS = Args()

# %%
model_name = (
    f'PriorVGAE_1DGP_lr{ARGS.learning_rate}_epochs{ARGS.epochs}_'
    f'beta{ARGS.beta}_gnn{ARGS.hidden_gnn_dim}_fc{ARGS.hidden_fc_dim}_z{ARGS.latent_dim}_'
    f'numLocations{GP1D_ARGS.num_locations}'
)

model_params_title = (
    '('
    f'epochs = {plotting.convert_to_string_int(ARGS.epochs)}, '
    f'lr = {ARGS.learning_rate}, '
    f'act_fn = {jax.nn.elu.__name__}, '
    rf'$\beta = {ARGS.beta}$, '
    f'\ngnn_dim = {ARGS.hidden_gnn_dim},  fc_dim = {ARGS.hidden_fc_dim},  z_dim = {ARGS.latent_dim}'
    f'\n num_loc = {GP1D_ARGS.num_locations}'
    ')'
)

print(model_name)
# Out:
# PriorVGAE_1DGP_lr0.001_epochs500000_beta0.01_gnn2_fc60_z30_numLocations200

# %% [markdown]
# # Dataset: GP priors to be encoded

# %%
# GP priors to encode
X = jnp.arange(0, 1, 1/GP1D_ARGS.num_locations)

num_to_plot = 10
gp_draws = dataset_1dgp.generate_gp_batch(RNG_KEY, 
                                          X, 
                                          batch_size=num_to_plot,
                                          kernel=GP1D_ARGS.kernel)

plotting.plot_gp_draws(
    X, gp_draws,
    num_draws_to_plot=num_to_plot,
    title='Example of GP priors to encode', 
    x_label='$x$', 
    y_label='$y=f_{GP}(x)$',
)

# %% [markdown]
# # Building the model

# %%
data_filepath = DATASET_PATH / f'1DGP_numLoc{GP1D_ARGS.num_locations}_110k_train_data.npy'

OVERRIDE_SAVE = False

# Initial RNG_KEY seed is 44.
RNG_KEY, data_rng = jax.random.split(RNG_KEY)
if data_filepath.exists() and not OVERRIDE_SAVE:
    print(f"Loading dataset from {data_filepath}")
    data = np.load(data_filepath)
else:
    num_samples = 110_000
    data = dataset_1dgp.generate_gp_batch(data_rng, X, 
                                          batch_size=num_samples, 
                                          kernel=GP1D_ARGS.kernel)
    print(f"Saving dataset to {data_filepath}")
    np.save(data_filepath, np.asarray(data))
# Out:
# Saving dataset to dataset.nosync/1DGP_numLoc200_110k_train_data.npy

# %%
# Remove NaNs from dataset
data = data[~np.isnan(data).any(axis=1), :]

train_size_limit = 70_000
val_size = 11_000  # + 1000 for the final epoch evaluation and batching

train_data = data[:train_size_limit]
val_data = data[train_size_limit:train_size_limit+val_size]

# %%
BASE_GRAPH = dataset_1dgp.create_1dgp_graph(GP1D_ARGS.num_locations)

graph_train_data = [BASE_GRAPH._replace(nodes=nodes.reshape(-1, 1)) for nodes in train_data]
graph_val_data = [BASE_GRAPH._replace(nodes=nodes.reshape(-1, 1)) for nodes in val_data]

# %% [markdown]
# Comment: Removing linear (hidden_fc) before latent hidden layer makes samples even NOISIER

# %%
from model import VGAEOutput
import layer

class VGAE(hk.Module):
    """VGAE network definition."""

    def __init__(
        self,
        hidden_gnn_dim: int,
        hidden_fc_dim: int,
        latent_dim: int,
        output_dim: int,
        num_nodes: int,
    ):
        super().__init__()
        self._hidden_gnn_dim = hidden_gnn_dim
        self._hidden_fc_dim = hidden_fc_dim
        self._latent_dim = latent_dim
        self._output_dim = output_dim
        self._num_nodes = num_nodes
        self.act = ARGS.act_fn

    def __call__(self, graph: jraph.GraphsTuple) -> VGAEOutput:
        mean, log_std = encoder(
            graph,
            self._hidden_gnn_dim,
            self._hidden_fc_dim,
            self._latent_dim,
            self._num_nodes,
            self.act,
        )

        std = jnp.exp(log_std)
        z = mean + std * jax.random.normal(hk.next_rng_key(), mean.shape)

        output = decoder(
            z,
            self._hidden_fc_dim,
            self._hidden_gnn_dim,
            self._output_dim,
            self._num_nodes,
            self.act
        )

        return VGAEOutput(mean, log_std, output)

def encoder(
        graph: jraph.GraphsTuple,
        hidden_gnn_dim: int,
        hidden_fc_dim: int,
        latent_dim: int,
        num_nodes: int,
        act_fn: Callable = jax.nn.elu) -> Tuple[jnp.ndarray, jnp.ndarray]:
    
    # Graph layer
    gn = jraph.GraphConvolution(
        update_node_fn=hk.Sequential([
            hk.Linear(hidden_gnn_dim), act_fn,
        ]),
        add_self_edges=True,
    )
    graph = gn(graph)
    
    # Layer normalization
    graph = layer.GraphwiseLayerNorm()(graph)
    
    x = graph.nodes.reshape(1, num_nodes, hidden_gnn_dim)
    x = hk.Flatten()(x)  # dim: (1, num_nodes*hidden_gnn_dim)

    x = hk.Linear(hidden_fc_dim)(x)
    x = act_fn(x)
    
    x = hk.Linear(hidden_fc_dim)(x)
    x = act_fn(x)
    
    # No activation
    mean = hk.Linear(latent_dim, name='mean')(x)
    log_std = hk.Linear(latent_dim, name='log_std')(x)
    return mean, log_std


def decoder(
        z: jnp.ndarray,
        hidden_fc_dim: int,
        hidden_gnn_dim: int,
        output_dim: int,
        num_nodes: int,
        act_fn: Callable = jax.nn.elu) -> jraph.GraphsTuple:
    
    z = hk.Linear(hidden_fc_dim, name='decoder_hidden_fc')(z)
    z = act_fn(z)
    
    z = hk.Linear(hidden_fc_dim, name='decoder_hidden_fc')(z)
    z = act_fn(z)
    
    z = hk.Linear(num_nodes*hidden_gnn_dim,
                  name='decoder_hidden2_fc')(z)  # (1, num_nodes*hidden_gnn_dim)
    z = act_fn(z)
    
    # Reshape to jraph.batch format: (num_nodes, hidden_gnn_dim)
    z = z.reshape((num_nodes, hidden_gnn_dim))
    # graph = BASE_GRAPH._replace(nodes=z)
    graph = BASE_GRAPH._replace(nodes=z)
    
    gn = layer.GraphConvolutionSharpening(
        update_node_fn=hk.Sequential([
            hk.Linear(hidden_gnn_dim, name='decoder_hidden_gnn'), act_fn,
        ]),
        add_self_edges=True,
    )
    graph = gn(graph)
    
    # Layer normalization
    # NOTE :- Layer normalization on the decoder yields a shrinked GP.
    # graph = layer.GraphwiseLayerNorm()(graph)
    
    # No activation
    gn = layer.GraphConvolutionSharpening(
        update_node_fn=hk.Linear(output_dim, name='decoder_output'),
        add_self_edges=False,
    )
    graph = gn(graph)

    return graph

# %%
extend_model_params_title = True
    
extension_string = 'add_self_edges = True'

if extend_model_params_title:
    model_params_title = model_params_title[:-1] + ', ' + extension_string

# %% [markdown]
# # Training time

# %%
# Initialize network and optimizer.
net = hk.transform(
  lambda x: VGAE(hidden_gnn_dim=ARGS.hidden_gnn_dim,
                 hidden_fc_dim=ARGS.hidden_fc_dim,
                 latent_dim=ARGS.latent_dim, 
                 output_dim=ARGS.output_dim,
                 num_nodes=GP1D_ARGS.num_locations)(x))

# %% [markdown]
# ## Training optimizer

# %%
# optimizer = optax.adam(ARGS.learning_rate)

scheduler = optax.exponential_decay(
    init_value=ARGS.learning_rate,
    transition_steps=2000,
    decay_rate=0.99,
)

# Combining gradient transforms using `optax.chain`
optimizer = optax.chain(
    optax.clip_by_global_norm(1.0),  # Clip by the gradient by the global norm.
    optax.scale_by_adam(),  # Use the updates from adam.
    optax.scale_by_schedule(scheduler),  # Use the learning rate from the scheduler.
    # Scale updates by -1 since optax.apply_updates is additive and we want to descend on the loss.
    optax.scale(-1.0)
)

# %% [markdown]
# ### Loss function and update

# %%
@jax.jit
def loss_fn(
    params: hk.Params, 
    rng_key: jnp.ndarray,
    graph: jraph.GraphsTuple,
) -> jnp.ndarray:
  """Computes VGAE loss."""
  log_likelihood_loss_fn = ARGS.loss_fn
  
  outputs: VGAEOutput = net.apply(params, rng_key, graph)
  log_likelihood = -log_likelihood_loss_fn(outputs.output.nodes, graph.nodes)
  kld = jnp.mean(loss.compute_kl_gaussian(outputs.mean, outputs.log_std), axis=-1)
  elbo = (1.0/ARGS.beta)*log_likelihood - kld
  
  return -elbo, kld
  
@jax.jit
def update(
    params: hk.Params,
    rng_key: jnp.ndarray,
    opt_state: optax.OptState,
    graph: jraph.GraphsTuple,
):
  """Updates the parameters of the network."""
  grads, _ = jax.grad(loss_fn, has_aux=True)(params, rng_key, graph)
  updates, new_opt_state = optimizer.update(grads, opt_state)
  new_params = optax.apply_updates(params, updates)
  return new_params, new_opt_state

# %% [markdown]
# ### Initialize net and optimizer

# %%
# Initialize net with an arbitrary graph
RNG_KEY, params_rng = jax.random.split(RNG_KEY)

init_graph = graph_train_data[0]
params = net.init(params_rng, init_graph)
opt_state = optimizer.init(params)

# %%
RNG_KEY, train_rng = jax.random.split(RNG_KEY)

train_losses = []
val_losses = []
train_klds = []
val_klds = []

train_size = len(graph_train_data)
val_size = len(graph_val_data)

eval_counter: int = 0

training_start_time = time.time()
print('using: ', ARGS.loss_fn)
for epoch in range(ARGS.epochs):
  update_rng = jax.random.fold_in(train_rng, epoch)

  train_graph_batch = graph_train_data[epoch % train_size]
  params, opt_state = update(params, update_rng, opt_state, train_graph_batch)
    
  if epoch % ARGS.eval_frequency == 0 or epoch == (ARGS.epochs - 1):
    evaluate_rng = jax.random.fold_in(update_rng, epoch)
    train_loss_rng, eval_loss_rng = jax.random.split(evaluate_rng)
    
    train_loss, train_kld = loss_fn(params, train_loss_rng, train_graph_batch)
    
    val_graph_batch = graph_val_data[eval_counter]
    val_loss, val_kld = loss_fn(params, eval_loss_rng, val_graph_batch)
    
    print(f'{time.strftime("%H:%M:%S", time.localtime())} STEP: {epoch}; '
          f'Train loss: {train_loss:.3f}; Validation loss: {val_loss:.3f}; '
          # f'Train kld: {train_kld:.3f}; Validation kld: {val_kld:.3f}'
    )
      
    train_losses.append(train_loss.item())
    val_losses.append(val_loss.item())
    train_klds.append(train_kld.item())
    val_klds.append(val_kld.item())
    
    eval_counter += 1

training_end_time = time.time() - training_start_time
print(f'Training took: ({training_end_time:.3f} secs; equivalently {training_end_time/60:.3f} mins)')
# Out:
# using:  <function compute_mse_loss at 0x15a463040>
# 11:27:32 STEP: 0; Train loss: 35.685; Validation loss: 150.506;
# 11:27:33 STEP: 1000; Train loss: 30.215; Validation loss: 52.648;
# 11:27:33 STEP: 2000; Train loss: 19.071; Validation loss: 81.510;
# 11:27:33 STEP: 3000; Train loss: 32.513; Validation loss: 36.685;
# 11:27:34 STEP: 4000; Train loss: 19.155; Validation loss: 22.654;
# 11:27:34 STEP: 5000; Train loss: 14.714; Validation loss: 14.297;
# 11:27:35 STEP: 6000; Train loss: 25.758; Validation loss: 47.913;
# 11:27:35 STEP: 7000; Train loss: 106.692; Validation loss: 29.805;
# 11:27:35 STEP: 8000; Train loss: 22.133; Validation loss: 31.662;
# 11:27:36 STEP: 9000; Train loss: 33.848; Validation loss: 26.297;
# 11:27:36 STEP: 10000; Train loss: 19.415; Validation loss: 24.123;
# 11:27:37 STEP: 11000; Train loss: 32.264; Validation loss: 9.909;
# 11:27:37 STEP: 12000; Train loss: 54.773; Validation loss: 63.215;
# 11:27:37 STEP: 13000; Train loss: 50.679; Validation loss: 25.314;
# 11:27:38 STEP: 14000; Train loss: 117.717; Validation loss: 33.424;
# 11:27:38 STEP: 15000; Train loss: 25.049; Validation loss: 15.389;
# 11:27:39 STEP: 16000; Train loss: 16.418; Validation loss: 6.388;
# 11:27:39 STEP: 17000; Train loss: 59.544; Validation loss: 70.960;
# 11:27:39 STEP: 18000; Train loss: 19.509; Validation loss: 19.566;
# 11:27:40 STEP: 19000; Train loss: 12.008; Validation loss: 10.613;
# 11:27:40 STEP: 20000; Train loss: 39.890; Validation loss: 17.183;
# 11:27:41 STEP: 21000; Train loss: 30.222; Validation loss: 23.755;
# 11:27:41 STEP: 22000; Train loss: 12.951; Validation loss: 6.788;
# 11:27:41 STEP: 23000; Train loss: 22.100; Validation loss: 25.355;
# 11:27:42 STEP: 24000; Train loss: 18.744; Validation loss: 14.899;
# 11:27:42 STEP: 25000; Train loss: 33.016; Validation loss: 11.995;
# 11:27:43 STEP: 26000; Train loss: 11.387; Validation loss: 18.008;
# 11:27:43 STEP: 27000; Train loss: 18.368; Validation loss: 40.617;
# 11:27:43 STEP: 28000; Train loss: 9.239; Validation loss: 13.340;
# 11:27:44 STEP: 29000; Train loss: 17.705; Validation loss: 18.471;
# 11:27:44 STEP: 30000; Train loss: 8.518; Validation loss: 8.153;
# 11:27:45 STEP: 31000; Train loss: 8.073; Validation loss: 16.216;
# 11:27:45 STEP: 32000; Train loss: 17.977; Validation loss: 6.697;
# 11:27:45 STEP: 33000; Train loss: 16.637; Validation loss: 11.786;
# 11:27:46 STEP: 34000; Train loss: 10.529; Validation loss: 31.506;
# 11:27:46 STEP: 35000; Train loss: 12.202; Validation loss: 18.427;
# 11:27:47 STEP: 36000; Train loss: 18.887; Validation loss: 6.611;
# 11:27:47 STEP: 37000; Train loss: 9.550; Validation loss: 8.258;
# 11:27:47 STEP: 38000; Train loss: 14.638; Validation loss: 8.761;
# 11:27:48 STEP: 39000; Train loss: 14.839; Validation loss: 5.246;
# 11:27:48 STEP: 40000; Train loss: 13.227; Validation loss: 16.156;
# 11:27:48 STEP: 41000; Train loss: 27.774; Validation loss: 7.135;
# 11:27:49 STEP: 42000; Train loss: 20.852; Validation loss: 13.689;
# 11:27:49 STEP: 43000; Train loss: 5.438; Validation loss: 11.649;
# 11:27:50 STEP: 44000; Train loss: 16.406; Validation loss: 10.431;
# 11:27:50 STEP: 45000; Train loss: 83.603; Validation loss: 11.337;
# 11:27:50 STEP: 46000; Train loss: 35.864; Validation loss: 24.733;
# 11:27:51 STEP: 47000; Train loss: 63.462; Validation loss: 16.394;
# 11:27:51 STEP: 48000; Train loss: 9.770; Validation loss: 93.606;
# 11:27:52 STEP: 49000; Train loss: 8.854; Validation loss: 14.942;
# 11:27:52 STEP: 50000; Train loss: 8.777; Validation loss: 23.238;
# 11:27:52 STEP: 51000; Train loss: 10.140; Validation loss: 24.961;
# 11:27:53 STEP: 52000; Train loss: 9.794; Validation loss: 11.701;
# 11:27:53 STEP: 53000; Train loss: 12.496; Validation loss: 11.263;
# 11:27:54 STEP: 54000; Train loss: 12.940; Validation loss: 13.849;
# 11:27:54 STEP: 55000; Train loss: 17.714; Validation loss: 12.027;
# 11:27:54 STEP: 56000; Train loss: 13.664; Validation loss: 13.166;
# 11:27:55 STEP: 57000; Train loss: 14.942; Validation loss: 15.070;
# 11:27:55 STEP: 58000; Train loss: 8.749; Validation loss: 11.930;
# 11:27:56 STEP: 59000; Train loss: 13.446; Validation loss: 13.953;
# 11:27:56 STEP: 60000; Train loss: 11.172; Validation loss: 13.161;
# 11:27:56 STEP: 61000; Train loss: 7.470; Validation loss: 32.321;
# 11:27:57 STEP: 62000; Train loss: 5.150; Validation loss: 14.443;
# 11:27:57 STEP: 63000; Train loss: 16.791; Validation loss: 17.330;
# 11:27:58 STEP: 64000; Train loss: 20.085; Validation loss: 11.013;
# 11:27:58 STEP: 65000; Train loss: 32.140; Validation loss: 11.642;
# 11:27:58 STEP: 66000; Train loss: 25.251; Validation loss: 8.173;
# 11:27:59 STEP: 67000; Train loss: 15.201; Validation loss: 10.898;
# 11:27:59 STEP: 68000; Train loss: 15.336; Validation loss: 13.694;
# 11:27:59 STEP: 69000; Train loss: 9.407; Validation loss: 6.308;
# 11:28:00 STEP: 70000; Train loss: 16.565; Validation loss: 13.237;
# 11:28:00 STEP: 71000; Train loss: 9.501; Validation loss: 24.675;
# 11:28:01 STEP: 72000; Train loss: 20.033; Validation loss: 12.154;
# 11:28:01 STEP: 73000; Train loss: 13.474; Validation loss: 27.435;
# 11:28:01 STEP: 74000; Train loss: 12.043; Validation loss: 7.944;
# 11:28:02 STEP: 75000; Train loss: 14.361; Validation loss: 13.036;
# 11:28:02 STEP: 76000; Train loss: 10.959; Validation loss: 10.088;
# 11:28:03 STEP: 77000; Train loss: 10.594; Validation loss: 5.748;
# 11:28:03 STEP: 78000; Train loss: 11.985; Validation loss: 9.774;
# 11:28:03 STEP: 79000; Train loss: 11.104; Validation loss: 10.161;
# 11:28:04 STEP: 80000; Train loss: 6.487; Validation loss: 9.945;
# 11:28:04 STEP: 81000; Train loss: 17.098; Validation loss: 18.784;
# 11:28:05 STEP: 82000; Train loss: 28.624; Validation loss: 14.426;
# 11:28:05 STEP: 83000; Train loss: 23.908; Validation loss: 15.184;
# 11:28:05 STEP: 84000; Train loss: 30.389; Validation loss: 15.142;
# 11:28:06 STEP: 85000; Train loss: 7.910; Validation loss: 11.130;
# 11:28:06 STEP: 86000; Train loss: 6.446; Validation loss: 9.043;
# 11:28:07 STEP: 87000; Train loss: 34.629; Validation loss: 15.130;
# 11:28:07 STEP: 88000; Train loss: 22.121; Validation loss: 10.172;
# 11:28:07 STEP: 89000; Train loss: 11.485; Validation loss: 12.625;
# 11:28:08 STEP: 90000; Train loss: 15.287; Validation loss: 26.509;
# 11:28:08 STEP: 91000; Train loss: 13.660; Validation loss: 11.822;
# 11:28:09 STEP: 92000; Train loss: 13.638; Validation loss: 9.855;
# 11:28:09 STEP: 93000; Train loss: 8.460; Validation loss: 35.439;
# 11:28:09 STEP: 94000; Train loss: 16.443; Validation loss: 23.297;
# 11:28:10 STEP: 95000; Train loss: 20.713; Validation loss: 13.730;
# 11:28:10 STEP: 96000; Train loss: 6.371; Validation loss: 15.628;
# 11:28:11 STEP: 97000; Train loss: 7.389; Validation loss: 5.811;
# 11:28:11 STEP: 98000; Train loss: 10.342; Validation loss: 17.036;
# 11:28:12 STEP: 99000; Train loss: 14.093; Validation loss: 9.348;
# 11:28:12 STEP: 100000; Train loss: 9.606; Validation loss: 6.491;
# 11:28:13 STEP: 101000; Train loss: 8.221; Validation loss: 11.306;
# 11:28:13 STEP: 102000; Train loss: 7.031; Validation loss: 5.422;
# 11:28:14 STEP: 103000; Train loss: 13.552; Validation loss: 15.657;
# 11:28:14 STEP: 104000; Train loss: 22.009; Validation loss: 16.434;
# 11:28:15 STEP: 105000; Train loss: 12.846; Validation loss: 6.191;
# 11:28:15 STEP: 106000; Train loss: 18.497; Validation loss: 45.897;
# 11:28:16 STEP: 107000; Train loss: 7.466; Validation loss: 17.744;
# 11:28:16 STEP: 108000; Train loss: 6.053; Validation loss: 15.061;
# 11:28:17 STEP: 109000; Train loss: 6.503; Validation loss: 10.890;
# 11:28:17 STEP: 110000; Train loss: 13.332; Validation loss: 7.594;
# 11:28:18 STEP: 111000; Train loss: 15.658; Validation loss: 33.263;
# 11:28:18 STEP: 112000; Train loss: 20.292; Validation loss: 9.804;
# 11:28:19 STEP: 113000; Train loss: 8.037; Validation loss: 6.654;
# 11:28:20 STEP: 114000; Train loss: 15.820; Validation loss: 7.225;
# 11:28:20 STEP: 115000; Train loss: 23.034; Validation loss: 11.490;
# 11:28:20 STEP: 116000; Train loss: 25.112; Validation loss: 10.112;
# 11:28:21 STEP: 117000; Train loss: 36.697; Validation loss: 10.437;
# 11:28:22 STEP: 118000; Train loss: 9.041; Validation loss: 10.783;
# 11:28:22 STEP: 119000; Train loss: 15.356; Validation loss: 6.436;
# 11:28:23 STEP: 120000; Train loss: 9.986; Validation loss: 25.331;
# 11:28:23 STEP: 121000; Train loss: 7.659; Validation loss: 28.808;
# 11:28:24 STEP: 122000; Train loss: 8.311; Validation loss: 28.398;
# 11:28:24 STEP: 123000; Train loss: 8.348; Validation loss: 10.081;
# 11:28:25 STEP: 124000; Train loss: 8.420; Validation loss: 13.115;
# 11:28:25 STEP: 125000; Train loss: 18.866; Validation loss: 5.865;
# 11:28:26 STEP: 126000; Train loss: 14.893; Validation loss: 17.700;
# 11:28:27 STEP: 127000; Train loss: 17.719; Validation loss: 23.760;
# 11:28:27 STEP: 128000; Train loss: 12.212; Validation loss: 11.368;
# 11:28:28 STEP: 129000; Train loss: 10.154; Validation loss: 9.874;
# 11:28:28 STEP: 130000; Train loss: 7.668; Validation loss: 6.560;
# 11:28:29 STEP: 131000; Train loss: 7.792; Validation loss: 6.205;
# 11:28:30 STEP: 132000; Train loss: 11.104; Validation loss: 8.117;
# 11:28:31 STEP: 133000; Train loss: 14.812; Validation loss: 8.495;
# 11:28:31 STEP: 134000; Train loss: 101.022; Validation loss: 20.178;
# 11:28:32 STEP: 135000; Train loss: 14.460; Validation loss: 13.443;
# 11:28:32 STEP: 136000; Train loss: 28.033; Validation loss: 39.753;
# 11:28:33 STEP: 137000; Train loss: 6.886; Validation loss: 8.511;
# 11:28:33 STEP: 138000; Train loss: 12.265; Validation loss: 24.512;
# 11:28:34 STEP: 139000; Train loss: 9.617; Validation loss: 6.451;
# 11:28:34 STEP: 140000; Train loss: 8.140; Validation loss: 10.819;
# 11:28:35 STEP: 141000; Train loss: 16.978; Validation loss: 33.698;
# 11:28:35 STEP: 142000; Train loss: 8.012; Validation loss: 33.617;
# 11:28:36 STEP: 143000; Train loss: 18.743; Validation loss: 16.094;
# 11:28:37 STEP: 144000; Train loss: 9.705; Validation loss: 9.534;
# 11:28:37 STEP: 145000; Train loss: 7.525; Validation loss: 10.303;
# 11:28:38 STEP: 146000; Train loss: 10.008; Validation loss: 41.240;
# 11:28:39 STEP: 147000; Train loss: 10.869; Validation loss: 10.109;
# 11:28:39 STEP: 148000; Train loss: 12.811; Validation loss: 10.710;
# 11:28:40 STEP: 149000; Train loss: 5.831; Validation loss: 12.712;
# 11:28:40 STEP: 150000; Train loss: 9.231; Validation loss: 12.267;
# 11:28:41 STEP: 151000; Train loss: 14.071; Validation loss: 8.147;
# 11:28:41 STEP: 152000; Train loss: 12.929; Validation loss: 8.252;
# 11:28:42 STEP: 153000; Train loss: 18.261; Validation loss: 14.159;
# 11:28:42 STEP: 154000; Train loss: 17.754; Validation loss: 35.274;
# 11:28:43 STEP: 155000; Train loss: 4.588; Validation loss: 8.471;
# 11:28:44 STEP: 156000; Train loss: 10.901; Validation loss: 23.210;
# 11:28:44 STEP: 157000; Train loss: 23.172; Validation loss: 4.898;
# 11:28:44 STEP: 158000; Train loss: 8.167; Validation loss: 8.968;
# 11:28:45 STEP: 159000; Train loss: 11.790; Validation loss: 7.948;
# 11:28:45 STEP: 160000; Train loss: 10.014; Validation loss: 33.302;
# 11:28:46 STEP: 161000; Train loss: 14.367; Validation loss: 20.015;
# 11:28:46 STEP: 162000; Train loss: 9.460; Validation loss: 18.489;
# 11:28:47 STEP: 163000; Train loss: 17.504; Validation loss: 19.885;
# 11:28:47 STEP: 164000; Train loss: 10.781; Validation loss: 11.031;
# 11:28:48 STEP: 165000; Train loss: 19.907; Validation loss: 11.642;
# 11:28:48 STEP: 166000; Train loss: 8.294; Validation loss: 9.079;
# 11:28:49 STEP: 167000; Train loss: 6.810; Validation loss: 24.401;
# 11:28:49 STEP: 168000; Train loss: 4.751; Validation loss: 10.529;
# 11:28:49 STEP: 169000; Train loss: 21.656; Validation loss: 7.375;
# 11:28:50 STEP: 170000; Train loss: 4.531; Validation loss: 18.203;
# 11:28:50 STEP: 171000; Train loss: 6.064; Validation loss: 21.292;
# 11:28:51 STEP: 172000; Train loss: 5.558; Validation loss: 8.670;
# 11:28:51 STEP: 173000; Train loss: 15.859; Validation loss: 7.283;
# 11:28:52 STEP: 174000; Train loss: 12.460; Validation loss: 15.369;
# 11:28:52 STEP: 175000; Train loss: 6.829; Validation loss: 20.241;
# 11:28:53 STEP: 176000; Train loss: 14.482; Validation loss: 19.420;
# 11:28:53 STEP: 177000; Train loss: 10.347; Validation loss: 8.969;
# 11:28:54 STEP: 178000; Train loss: 11.638; Validation loss: 18.049;
# 11:28:54 STEP: 179000; Train loss: 32.674; Validation loss: 14.768;
# 11:28:55 STEP: 180000; Train loss: 9.786; Validation loss: 6.229;
# 11:28:55 STEP: 181000; Train loss: 9.348; Validation loss: 12.231;
# 11:28:55 STEP: 182000; Train loss: 24.739; Validation loss: 8.567;
# 11:28:56 STEP: 183000; Train loss: 8.897; Validation loss: 19.344;
# 11:28:56 STEP: 184000; Train loss: 16.022; Validation loss: 7.270;
# 11:28:57 STEP: 185000; Train loss: 21.803; Validation loss: 6.436;
# 11:28:57 STEP: 186000; Train loss: 18.695; Validation loss: 14.260;
# 11:28:57 STEP: 187000; Train loss: 25.622; Validation loss: 6.605;
# 11:28:58 STEP: 188000; Train loss: 7.023; Validation loss: 20.708;
# 11:28:58 STEP: 189000; Train loss: 8.303; Validation loss: 10.071;
# 11:28:59 STEP: 190000; Train loss: 12.776; Validation loss: 4.741;
# 11:28:59 STEP: 191000; Train loss: 6.381; Validation loss: 13.783;
# 11:29:00 STEP: 192000; Train loss: 13.428; Validation loss: 17.481;
# 11:29:01 STEP: 193000; Train loss: 10.491; Validation loss: 8.590;
# 11:29:02 STEP: 194000; Train loss: 8.630; Validation loss: 8.685;
# 11:29:02 STEP: 195000; Train loss: 11.514; Validation loss: 7.969;
# 11:29:03 STEP: 196000; Train loss: 18.101; Validation loss: 45.260;
# 11:29:03 STEP: 197000; Train loss: 14.032; Validation loss: 16.327;
# 11:29:04 STEP: 198000; Train loss: 10.041; Validation loss: 14.228;
# 11:29:04 STEP: 199000; Train loss: 15.766; Validation loss: 7.329;
# 11:29:05 STEP: 200000; Train loss: 12.469; Validation loss: 7.503;
# 11:29:06 STEP: 201000; Train loss: 11.720; Validation loss: 7.586;
# 11:29:06 STEP: 202000; Train loss: 5.302; Validation loss: 11.147;
# 11:29:07 STEP: 203000; Train loss: 10.460; Validation loss: 5.819;
# 11:29:07 STEP: 204000; Train loss: 55.119; Validation loss: 8.955;
# 11:29:08 STEP: 205000; Train loss: 20.047; Validation loss: 6.496;
# 11:29:08 STEP: 206000; Train loss: 29.227; Validation loss: 13.333;
# 11:29:09 STEP: 207000; Train loss: 6.994; Validation loss: 11.570;
# 11:29:09 STEP: 208000; Train loss: 20.097; Validation loss: 12.853;
# 11:29:10 STEP: 209000; Train loss: 6.315; Validation loss: 22.384;
# 11:29:11 STEP: 210000; Train loss: 11.036; Validation loss: 24.895;
# 11:29:11 STEP: 211000; Train loss: 9.173; Validation loss: 18.199;
# 11:29:12 STEP: 212000; Train loss: 7.713; Validation loss: 10.328;
# 11:29:12 STEP: 213000; Train loss: 16.258; Validation loss: 23.605;
# 11:29:13 STEP: 214000; Train loss: 9.483; Validation loss: 12.889;
# 11:29:13 STEP: 215000; Train loss: 10.377; Validation loss: 5.041;
# 11:29:14 STEP: 216000; Train loss: 8.513; Validation loss: 10.343;
# 11:29:14 STEP: 217000; Train loss: 12.570; Validation loss: 10.795;
# 11:29:15 STEP: 218000; Train loss: 9.641; Validation loss: 12.479;
# 11:29:16 STEP: 219000; Train loss: 8.267; Validation loss: 11.625;
# 11:29:16 STEP: 220000; Train loss: 6.156; Validation loss: 16.791;
# 11:29:17 STEP: 221000; Train loss: 12.220; Validation loss: 18.337;
# 11:29:17 STEP: 222000; Train loss: 13.648; Validation loss: 11.695;
# 11:29:18 STEP: 223000; Train loss: 20.396; Validation loss: 15.680;
# 11:29:18 STEP: 224000; Train loss: 24.149; Validation loss: 20.961;
# 11:29:19 STEP: 225000; Train loss: 6.085; Validation loss: 11.888;
# 11:29:19 STEP: 226000; Train loss: 7.055; Validation loss: 12.896;
# 11:29:20 STEP: 227000; Train loss: 22.889; Validation loss: 41.685;
# 11:29:20 STEP: 228000; Train loss: 15.004; Validation loss: 6.908;
# 11:29:21 STEP: 229000; Train loss: 13.400; Validation loss: 11.051;
# 11:29:21 STEP: 230000; Train loss: 10.041; Validation loss: 15.183;
# 11:29:22 STEP: 231000; Train loss: 10.279; Validation loss: 12.350;
# 11:29:22 STEP: 232000; Train loss: 7.512; Validation loss: 8.497;
# 11:29:23 STEP: 233000; Train loss: 9.607; Validation loss: 7.987;
# 11:29:23 STEP: 234000; Train loss: 8.861; Validation loss: 12.628;
# 11:29:24 STEP: 235000; Train loss: 22.124; Validation loss: 21.667;
# 11:29:24 STEP: 236000; Train loss: 13.658; Validation loss: 10.558;
# 11:29:25 STEP: 237000; Train loss: 6.869; Validation loss: 18.097;
# 11:29:25 STEP: 238000; Train loss: 6.251; Validation loss: 19.591;
# 11:29:26 STEP: 239000; Train loss: 20.250; Validation loss: 23.303;
# 11:29:26 STEP: 240000; Train loss: 10.414; Validation loss: 11.927;
# 11:29:26 STEP: 241000; Train loss: 9.065; Validation loss: 9.924;
# 11:29:27 STEP: 242000; Train loss: 5.001; Validation loss: 14.016;
# 11:29:27 STEP: 243000; Train loss: 13.060; Validation loss: 17.046;
# 11:29:28 STEP: 244000; Train loss: 5.566; Validation loss: 4.774;
# 11:29:28 STEP: 245000; Train loss: 8.768; Validation loss: 8.734;
# 11:29:28 STEP: 246000; Train loss: 15.431; Validation loss: 14.433;
# 11:29:29 STEP: 247000; Train loss: 6.614; Validation loss: 8.853;
# 11:29:29 STEP: 248000; Train loss: 13.592; Validation loss: 13.733;
# 11:29:30 STEP: 249000; Train loss: 9.631; Validation loss: 35.412;
# 11:29:30 STEP: 250000; Train loss: 10.324; Validation loss: 15.257;
# 11:29:31 STEP: 251000; Train loss: 18.293; Validation loss: 10.578;
# 11:29:31 STEP: 252000; Train loss: 19.735; Validation loss: 9.253;
# 11:29:32 STEP: 253000; Train loss: 8.435; Validation loss: 28.321;
# 11:29:32 STEP: 254000; Train loss: 18.014; Validation loss: 7.903;
# 11:29:32 STEP: 255000; Train loss: 18.546; Validation loss: 25.433;
# 11:29:33 STEP: 256000; Train loss: 32.596; Validation loss: 13.402;
# 11:29:33 STEP: 257000; Train loss: 35.132; Validation loss: 12.619;
# 11:29:34 STEP: 258000; Train loss: 9.119; Validation loss: 9.257;
# 11:29:34 STEP: 259000; Train loss: 9.839; Validation loss: 10.292;
# 11:29:35 STEP: 260000; Train loss: 11.488; Validation loss: 10.718;
# 11:29:35 STEP: 261000; Train loss: 9.444; Validation loss: 25.059;
# 11:29:35 STEP: 262000; Train loss: 12.190; Validation loss: 13.885;
# 11:29:36 STEP: 263000; Train loss: 9.090; Validation loss: 8.787;
# 11:29:36 STEP: 264000; Train loss: 9.691; Validation loss: 9.958;
# 11:29:37 STEP: 265000; Train loss: 16.149; Validation loss: 6.080;
# 11:29:37 STEP: 266000; Train loss: 15.190; Validation loss: 9.594;
# 11:29:37 STEP: 267000; Train loss: 10.470; Validation loss: 40.719;
# 11:29:38 STEP: 268000; Train loss: 12.336; Validation loss: 12.808;
# 11:29:39 STEP: 269000; Train loss: 13.398; Validation loss: 8.830;
# 11:29:39 STEP: 270000; Train loss: 7.722; Validation loss: 12.257;
# 11:29:40 STEP: 271000; Train loss: 8.417; Validation loss: 13.405;
# 11:29:40 STEP: 272000; Train loss: 6.384; Validation loss: 9.846;
# 11:29:40 STEP: 273000; Train loss: 10.727; Validation loss: 8.408;
# 11:29:41 STEP: 274000; Train loss: 40.514; Validation loss: 53.928;
# 11:29:41 STEP: 275000; Train loss: 16.088; Validation loss: 9.308;
# 11:29:42 STEP: 276000; Train loss: 26.280; Validation loss: 7.142;
# 11:29:42 STEP: 277000; Train loss: 9.473; Validation loss: 8.824;
# 11:29:42 STEP: 278000; Train loss: 14.725; Validation loss: 25.404;
# 11:29:43 STEP: 279000; Train loss: 6.646; Validation loss: 12.668;
# 11:29:43 STEP: 280000; Train loss: 9.395; Validation loss: 14.380;
# 11:29:44 STEP: 281000; Train loss: 8.856; Validation loss: 12.785;
# 11:29:44 STEP: 282000; Train loss: 9.420; Validation loss: 20.831;
# 11:29:45 STEP: 283000; Train loss: 16.856; Validation loss: 9.526;
# 11:29:45 STEP: 284000; Train loss: 5.561; Validation loss: 16.655;
# 11:29:46 STEP: 285000; Train loss: 9.336; Validation loss: 11.371;
# 11:29:46 STEP: 286000; Train loss: 10.861; Validation loss: 14.840;
# 11:29:47 STEP: 287000; Train loss: 13.334; Validation loss: 13.917;
# 11:29:47 STEP: 288000; Train loss: 19.078; Validation loss: 22.526;
# 11:29:48 STEP: 289000; Train loss: 5.213; Validation loss: 24.701;
# 11:29:48 STEP: 290000; Train loss: 5.177; Validation loss: 11.875;
# 11:29:49 STEP: 291000; Train loss: 12.750; Validation loss: 18.511;
# 11:29:49 STEP: 292000; Train loss: 11.570; Validation loss: 19.423;
# 11:29:49 STEP: 293000; Train loss: 12.344; Validation loss: 7.416;
# 11:29:50 STEP: 294000; Train loss: 20.886; Validation loss: 11.991;
# 11:29:50 STEP: 295000; Train loss: 4.454; Validation loss: 5.791;
# 11:29:51 STEP: 296000; Train loss: 5.602; Validation loss: 3.836;
# 11:29:51 STEP: 297000; Train loss: 24.116; Validation loss: 16.451;
# 11:29:51 STEP: 298000; Train loss: 7.238; Validation loss: 9.668;
# 11:29:52 STEP: 299000; Train loss: 9.379; Validation loss: 15.285;
# 11:29:52 STEP: 300000; Train loss: 10.965; Validation loss: 6.743;
# 11:29:53 STEP: 301000; Train loss: 11.614; Validation loss: 14.612;
# 11:29:53 STEP: 302000; Train loss: 6.477; Validation loss: 11.071;
# 11:29:54 STEP: 303000; Train loss: 11.758; Validation loss: 9.804;
# 11:29:54 STEP: 304000; Train loss: 12.067; Validation loss: 8.175;
# 11:29:54 STEP: 305000; Train loss: 17.195; Validation loss: 11.904;
# 11:29:55 STEP: 306000; Train loss: 6.574; Validation loss: 8.915;
# 11:29:55 STEP: 307000; Train loss: 7.613; Validation loss: 5.595;
# 11:29:56 STEP: 308000; Train loss: 5.276; Validation loss: 21.009;
# 11:29:56 STEP: 309000; Train loss: 14.812; Validation loss: 33.444;
# 11:29:56 STEP: 310000; Train loss: 6.950; Validation loss: 7.921;
# 11:29:57 STEP: 311000; Train loss: 7.109; Validation loss: 13.891;
# 11:29:57 STEP: 312000; Train loss: 7.139; Validation loss: 16.169;
# 11:29:58 STEP: 313000; Train loss: 12.078; Validation loss: 11.952;
# 11:29:58 STEP: 314000; Train loss: 16.432; Validation loss: 21.448;
# 11:29:59 STEP: 315000; Train loss: 8.104; Validation loss: 18.375;
# 11:29:59 STEP: 316000; Train loss: 24.338; Validation loss: 7.758;
# 11:29:59 STEP: 317000; Train loss: 5.611; Validation loss: 10.038;
# 11:30:00 STEP: 318000; Train loss: 7.117; Validation loss: 35.771;
# 11:30:00 STEP: 319000; Train loss: 18.061; Validation loss: 5.945;
# 11:30:01 STEP: 320000; Train loss: 12.150; Validation loss: 10.510;
# 11:30:01 STEP: 321000; Train loss: 10.372; Validation loss: 12.796;
# 11:30:02 STEP: 322000; Train loss: 17.793; Validation loss: 12.260;
# 11:30:02 STEP: 323000; Train loss: 6.111; Validation loss: 9.962;
# 11:30:02 STEP: 324000; Train loss: 12.322; Validation loss: 12.226;
# 11:30:03 STEP: 325000; Train loss: 16.813; Validation loss: 9.167;
# 11:30:03 STEP: 326000; Train loss: 20.328; Validation loss: 16.246;
# 11:30:04 STEP: 327000; Train loss: 26.554; Validation loss: 16.722;
# 11:30:04 STEP: 328000; Train loss: 5.497; Validation loss: 8.693;
# 11:30:04 STEP: 329000; Train loss: 10.360; Validation loss: 7.260;
# 11:30:05 STEP: 330000; Train loss: 14.464; Validation loss: 28.369;
# 11:30:05 STEP: 331000; Train loss: 6.132; Validation loss: 11.319;
# 11:30:05 STEP: 332000; Train loss: 8.897; Validation loss: 32.818;
# 11:30:06 STEP: 333000; Train loss: 8.633; Validation loss: 17.466;
# 11:30:06 STEP: 334000; Train loss: 9.154; Validation loss: 22.478;
# 11:30:07 STEP: 335000; Train loss: 22.440; Validation loss: 10.523;
# 11:30:07 STEP: 336000; Train loss: 16.118; Validation loss: 24.871;
# 11:30:07 STEP: 337000; Train loss: 10.790; Validation loss: 16.946;
# 11:30:08 STEP: 338000; Train loss: 11.199; Validation loss: 15.477;
# 11:30:08 STEP: 339000; Train loss: 11.589; Validation loss: 9.303;
# 11:30:09 STEP: 340000; Train loss: 13.349; Validation loss: 12.319;
# 11:30:09 STEP: 341000; Train loss: 6.826; Validation loss: 5.577;
# 11:30:09 STEP: 342000; Train loss: 6.883; Validation loss: 15.205;
# 11:30:10 STEP: 343000; Train loss: 10.035; Validation loss: 16.453;
# 11:30:10 STEP: 344000; Train loss: 50.931; Validation loss: 14.414;
# 11:30:10 STEP: 345000; Train loss: 15.340; Validation loss: 10.587;
# 11:30:11 STEP: 346000; Train loss: 31.292; Validation loss: 9.362;
# 11:30:11 STEP: 347000; Train loss: 7.505; Validation loss: 10.278;
# 11:30:12 STEP: 348000; Train loss: 15.356; Validation loss: 11.049;
# 11:30:12 STEP: 349000; Train loss: 7.070; Validation loss: 14.620;
# 11:30:12 STEP: 350000; Train loss: 11.612; Validation loss: 7.767;
# 11:30:13 STEP: 351000; Train loss: 12.412; Validation loss: 12.460;
# 11:30:13 STEP: 352000; Train loss: 7.743; Validation loss: 15.923;
# 11:30:14 STEP: 353000; Train loss: 12.682; Validation loss: 11.982;
# 11:30:14 STEP: 354000; Train loss: 12.766; Validation loss: 15.945;
# 11:30:15 STEP: 355000; Train loss: 8.958; Validation loss: 18.202;
# 11:30:15 STEP: 356000; Train loss: 12.808; Validation loss: 6.889;
# 11:30:15 STEP: 357000; Train loss: 12.184; Validation loss: 14.265;
# 11:30:16 STEP: 358000; Train loss: 16.403; Validation loss: 10.341;
# 11:30:16 STEP: 359000; Train loss: 7.461; Validation loss: 10.054;
# 11:30:17 STEP: 360000; Train loss: 5.639; Validation loss: 5.539;
# 11:30:17 STEP: 361000; Train loss: 14.987; Validation loss: 7.861;
# 11:30:17 STEP: 362000; Train loss: 11.077; Validation loss: 10.385;
# 11:30:18 STEP: 363000; Train loss: 17.739; Validation loss: 11.450;
# 11:30:18 STEP: 364000; Train loss: 21.850; Validation loss: 17.160;
# 11:30:19 STEP: 365000; Train loss: 5.599; Validation loss: 6.675;
# 11:30:19 STEP: 366000; Train loss: 8.014; Validation loss: 11.978;
# 11:30:19 STEP: 367000; Train loss: 21.081; Validation loss: 13.820;
# 11:30:20 STEP: 368000; Train loss: 8.452; Validation loss: 16.189;
# 11:30:20 STEP: 369000; Train loss: 11.012; Validation loss: 18.312;
# 11:30:21 STEP: 370000; Train loss: 10.414; Validation loss: 11.596;
# 11:30:21 STEP: 371000; Train loss: 18.235; Validation loss: 36.746;
# 11:30:21 STEP: 372000; Train loss: 8.889; Validation loss: 8.021;
# 11:30:22 STEP: 373000; Train loss: 8.033; Validation loss: 12.600;
# 11:30:22 STEP: 374000; Train loss: 9.965; Validation loss: 10.530;
# 11:30:23 STEP: 375000; Train loss: 17.804; Validation loss: 13.921;
# 11:30:23 STEP: 376000; Train loss: 6.225; Validation loss: 5.151;
# 11:30:24 STEP: 377000; Train loss: 6.545; Validation loss: 16.768;
# 11:30:24 STEP: 378000; Train loss: 4.841; Validation loss: 9.037;
# 11:30:24 STEP: 379000; Train loss: 14.157; Validation loss: 6.609;
# 11:30:25 STEP: 380000; Train loss: 14.869; Validation loss: 11.988;
# 11:30:25 STEP: 381000; Train loss: 9.513; Validation loss: 9.228;
# 11:30:26 STEP: 382000; Train loss: 5.990; Validation loss: 11.096;
# 11:30:26 STEP: 383000; Train loss: 13.063; Validation loss: 11.874;
# 11:30:26 STEP: 384000; Train loss: 5.036; Validation loss: 17.929;
# 11:30:27 STEP: 385000; Train loss: 10.901; Validation loss: 8.505;
# 11:30:27 STEP: 386000; Train loss: 17.624; Validation loss: 11.816;
# 11:30:27 STEP: 387000; Train loss: 8.841; Validation loss: 9.469;
# 11:30:28 STEP: 388000; Train loss: 5.481; Validation loss: 10.659;
# 11:30:28 STEP: 389000; Train loss: 9.285; Validation loss: 10.998;
# 11:30:29 STEP: 390000; Train loss: 10.706; Validation loss: 67.857;
# 11:30:29 STEP: 391000; Train loss: 8.642; Validation loss: 19.658;
# 11:30:29 STEP: 392000; Train loss: 12.448; Validation loss: 7.661;
# 11:30:30 STEP: 393000; Train loss: 8.083; Validation loss: 6.710;
# 11:30:30 STEP: 394000; Train loss: 12.144; Validation loss: 9.484;
# 11:30:30 STEP: 395000; Train loss: 12.264; Validation loss: 20.678;
# 11:30:31 STEP: 396000; Train loss: 14.904; Validation loss: 12.891;
# 11:30:31 STEP: 397000; Train loss: 26.311; Validation loss: 21.172;
# 11:30:31 STEP: 398000; Train loss: 15.020; Validation loss: 226.946;
# 11:30:32 STEP: 399000; Train loss: 9.178; Validation loss: 6.047;
# 11:30:32 STEP: 400000; Train loss: 10.170; Validation loss: 11.084;
# 11:30:33 STEP: 401000; Train loss: 11.689; Validation loss: 7.000;
# 11:30:33 STEP: 402000; Train loss: 8.645; Validation loss: 10.096;
# 11:30:33 STEP: 403000; Train loss: 10.281; Validation loss: 8.857;
# 11:30:34 STEP: 404000; Train loss: 13.350; Validation loss: 5.348;
# 11:30:34 STEP: 405000; Train loss: 19.464; Validation loss: 5.206;
# 11:30:35 STEP: 406000; Train loss: 15.858; Validation loss: 15.254;
# 11:30:35 STEP: 407000; Train loss: 15.713; Validation loss: 5.019;
# 11:30:35 STEP: 408000; Train loss: 9.139; Validation loss: 14.381;
# 11:30:36 STEP: 409000; Train loss: 8.742; Validation loss: 7.390;
# 11:30:36 STEP: 410000; Train loss: 10.243; Validation loss: 17.084;
# 11:30:37 STEP: 411000; Train loss: 10.953; Validation loss: 9.488;
# 11:30:37 STEP: 412000; Train loss: 5.389; Validation loss: 19.519;
# 11:30:37 STEP: 413000; Train loss: 8.707; Validation loss: 8.125;
# 11:30:38 STEP: 414000; Train loss: 54.247; Validation loss: 19.324;
# 11:30:38 STEP: 415000; Train loss: 12.472; Validation loss: 9.954;
# 11:30:38 STEP: 416000; Train loss: 30.328; Validation loss: 5.756;
# 11:30:39 STEP: 417000; Train loss: 8.452; Validation loss: 7.911;
# 11:30:39 STEP: 418000; Train loss: 9.859; Validation loss: 6.518;
# 11:30:40 STEP: 419000; Train loss: 7.463; Validation loss: 16.397;
# 11:30:40 STEP: 420000; Train loss: 9.398; Validation loss: 11.555;
# 11:30:40 STEP: 421000; Train loss: 10.918; Validation loss: 10.795;
# 11:30:41 STEP: 422000; Train loss: 9.095; Validation loss: 14.955;
# 11:30:41 STEP: 423000; Train loss: 12.127; Validation loss: 17.274;
# 11:30:42 STEP: 424000; Train loss: 7.467; Validation loss: 6.959;
# 11:30:42 STEP: 425000; Train loss: 8.431; Validation loss: 14.650;
# 11:30:42 STEP: 426000; Train loss: 8.977; Validation loss: 10.473;
# 11:30:43 STEP: 427000; Train loss: 15.390; Validation loss: 11.155;
# 11:30:43 STEP: 428000; Train loss: 11.034; Validation loss: 11.100;
# 11:30:43 STEP: 429000; Train loss: 13.522; Validation loss: 12.501;
# 11:30:44 STEP: 430000; Train loss: 6.442; Validation loss: 13.888;
# 11:30:44 STEP: 431000; Train loss: 11.564; Validation loss: 8.550;
# 11:30:45 STEP: 432000; Train loss: 14.281; Validation loss: 7.878;
# 11:30:45 STEP: 433000; Train loss: 14.561; Validation loss: 15.404;
# 11:30:45 STEP: 434000; Train loss: 32.417; Validation loss: 6.837;
# 11:30:46 STEP: 435000; Train loss: 6.184; Validation loss: 7.516;
# 11:30:46 STEP: 436000; Train loss: 6.069; Validation loss: 17.596;
# 11:30:46 STEP: 437000; Train loss: 22.725; Validation loss: 12.440;
# 11:30:47 STEP: 438000; Train loss: 7.152; Validation loss: 8.973;
# 11:30:47 STEP: 439000; Train loss: 10.600; Validation loss: 16.930;
# 11:30:47 STEP: 440000; Train loss: 9.860; Validation loss: 8.301;
# 11:30:48 STEP: 441000; Train loss: 10.095; Validation loss: 15.266;
# 11:30:48 STEP: 442000; Train loss: 11.028; Validation loss: 13.792;
# 11:30:49 STEP: 443000; Train loss: 10.778; Validation loss: 8.682;
# 11:30:49 STEP: 444000; Train loss: 9.974; Validation loss: 19.256;
# 11:30:49 STEP: 445000; Train loss: 21.189; Validation loss: 8.645;
# 11:30:50 STEP: 446000; Train loss: 12.623; Validation loss: 5.932;
# 11:30:50 STEP: 447000; Train loss: 8.160; Validation loss: 9.500;
# 11:30:50 STEP: 448000; Train loss: 6.872; Validation loss: 10.763;
# 11:30:51 STEP: 449000; Train loss: 17.697; Validation loss: 13.307;
# 11:30:51 STEP: 450000; Train loss: 8.778; Validation loss: 10.643;
# 11:30:51 STEP: 451000; Train loss: 9.812; Validation loss: 7.644;
# 11:30:52 STEP: 452000; Train loss: 7.500; Validation loss: 5.501;
# 11:30:52 STEP: 453000; Train loss: 16.654; Validation loss: 13.453;
# 11:30:52 STEP: 454000; Train loss: 8.498; Validation loss: 6.361;
# 11:30:53 STEP: 455000; Train loss: 13.189; Validation loss: 7.702;
# 11:30:53 STEP: 456000; Train loss: 16.041; Validation loss: 5.348;
# 11:30:54 STEP: 457000; Train loss: 5.307; Validation loss: 10.673;
# 11:30:54 STEP: 458000; Train loss: 8.242; Validation loss: 30.329;
# 11:30:54 STEP: 459000; Train loss: 5.471; Validation loss: 23.499;
# 11:30:55 STEP: 460000; Train loss: 11.291; Validation loss: 13.498;
# 11:30:55 STEP: 461000; Train loss: 9.122; Validation loss: 7.053;
# 11:30:55 STEP: 462000; Train loss: 13.949; Validation loss: 6.820;
# 11:30:56 STEP: 463000; Train loss: 8.776; Validation loss: 7.759;
# 11:30:56 STEP: 464000; Train loss: 9.841; Validation loss: 18.046;
# 11:30:57 STEP: 465000; Train loss: 12.888; Validation loss: 11.359;
# 11:30:57 STEP: 466000; Train loss: 22.596; Validation loss: 8.683;
# 11:30:57 STEP: 467000; Train loss: 29.495; Validation loss: 7.181;
# 11:30:58 STEP: 468000; Train loss: 5.265; Validation loss: 15.328;
# 11:30:58 STEP: 469000; Train loss: 8.783; Validation loss: 16.345;
# 11:30:58 STEP: 470000; Train loss: 12.075; Validation loss: 9.583;
# 11:30:59 STEP: 471000; Train loss: 7.311; Validation loss: 9.176;
# 11:30:59 STEP: 472000; Train loss: 13.933; Validation loss: 5.457;
# 11:30:59 STEP: 473000; Train loss: 10.534; Validation loss: 8.167;
# 11:31:00 STEP: 474000; Train loss: 9.427; Validation loss: 7.561;
# 11:31:00 STEP: 475000; Train loss: 10.130; Validation loss: 12.077;
# 11:31:00 STEP: 476000; Train loss: 22.106; Validation loss: 17.568;
# 11:31:01 STEP: 477000; Train loss: 9.140; Validation loss: 12.923;
# 11:31:01 STEP: 478000; Train loss: 8.049; Validation loss: 17.603;
# 11:31:02 STEP: 479000; Train loss: 10.447; Validation loss: 14.097;
# 11:31:02 STEP: 480000; Train loss: 7.639; Validation loss: 7.470;
# 11:31:02 STEP: 481000; Train loss: 8.081; Validation loss: 29.560;
# 11:31:03 STEP: 482000; Train loss: 5.981; Validation loss: 11.153;
# 11:31:03 STEP: 483000; Train loss: 14.400; Validation loss: 5.864;
# 11:31:04 STEP: 484000; Train loss: 40.006; Validation loss: 7.182;
# 11:31:04 STEP: 485000; Train loss: 12.983; Validation loss: 18.880;
# 11:31:04 STEP: 486000; Train loss: 33.906; Validation loss: 7.482;
# 11:31:05 STEP: 487000; Train loss: 6.335; Validation loss: 8.931;
# 11:31:05 STEP: 488000; Train loss: 9.412; Validation loss: 5.472;
# 11:31:05 STEP: 489000; Train loss: 7.227; Validation loss: 12.538;
# 11:31:06 STEP: 490000; Train loss: 10.289; Validation loss: 4.234;
# 11:31:06 STEP: 491000; Train loss: 11.591; Validation loss: 11.732;
# 11:31:07 STEP: 492000; Train loss: 7.637; Validation loss: 8.548;
# 11:31:07 STEP: 493000; Train loss: 23.166; Validation loss: 9.706;
# 11:31:07 STEP: 494000; Train loss: 5.447; Validation loss: 9.145;
# 11:31:08 STEP: 495000; Train loss: 7.972; Validation loss: 6.668;
# 11:31:08 STEP: 496000; Train loss: 9.177; Validation loss: 14.890;
# 11:31:08 STEP: 497000; Train loss: 12.735; Validation loss: 11.984;
# 11:31:09 STEP: 498000; Train loss: 15.639; Validation loss: 7.044;
# 11:31:09 STEP: 499000; Train loss: 7.394; Validation loss: 19.593;
# 11:31:10 STEP: 499999; Train loss: 8.977; Validation loss: 13.570;
# Training took: (220.530 secs; equivalently 3.676 mins)

# %%
from matplotlib.ticker import MaxNLocator

# Loss plots
fig, axes = plt.subplots(2, 2, figsize=(14, 10))

# for i in range(2): axes[i].xaxis.set_major_locator(MaxNLocator(integer=True))

xs = np.arange(len(train_losses))*ARGS.eval_frequency
axes[0, 0].plot(xs, train_losses, label='train_loss')
axes[0, 0].plot(xs, val_losses, label='val_loss')
axes[0, 1].plot(xs[1:], train_losses[1:], label='train_loss')
axes[0, 1].plot(xs[1:], val_losses[1:], label='val_loss')
axes[0, 0].set_title('Loss (all epochs)')
axes[0, 1].set_title('Loss (all except first epoch)')

for i in range(2): 
    axes[0, i].set_ylabel('Loss')
    axes[0, i].set_xlabel('Epochs')
    axes[0, i].legend()
    
# KLD plots
xs = np.arange(len(train_klds))*ARGS.eval_frequency
axes[1, 0].plot(xs, train_klds, label='train_kld')
axes[1, 0].plot(xs, val_klds, label='val_kld')
axes[1, 1].plot(xs[1:], train_klds[1:], label='train_kld')
axes[1, 1].plot(xs[1:], val_klds[1:], label='val_kld')
axes[1, 0].set_title('KLD (all epochs)')
axes[1, 1].set_title('KLD (all except first epoch)')

for i in range(2): 
    axes[1, i].set_ylabel('KLD')
    axes[1, i].set_xlabel('Epochs')
    axes[1, i].legend()

fig.suptitle(f'Loss and KLD (left: all epochs; right: all except first epochs) \n{model_params_title}', fontsize='xx-large')

plt.tight_layout()
plt.show()

loss_kld_path = FIG_PATH / 'loss_kld_figures'
loss_kld_path.mkdir(exist_ok=True)
fig.savefig(loss_kld_path / f'{model_name}.jpg', dpi=300)

# %%
RNG_KEY, rng_recon = jax.random.split(RNG_KEY)

num_to_plot = 5
fig, axes = plt.subplots(num_to_plot, 2, figsize=(15, 25))

for i in range(num_to_plot):
    original_data = val_data[i]
    graph_data = graph_val_data[i]
    
    outputs = net.apply(params, RNG_KEY, graph_data)
    recon_data = outputs.output.nodes.T

    original_gp = jnp.ravel(original_data)
    recon_gp = jnp.ravel(recon_data)

    axes[i, 0].plot(X, original_gp)
    axes[i, 1].plot(X, recon_gp)
    
    axes[i, 0].set_title(f'Example {i} (input)')
    axes[i, 1].set_title(f'Example {i} (recon)')

fig.suptitle(f'Input vs Recon\n{model_params_title}', fontsize='xx-large')

plt.tight_layout()
plt.show()

input_v_recon_path = FIG_PATH / 'recon_figures'
input_v_recon_path.mkdir(exist_ok=True)
fig.savefig(input_v_recon_path / f'{model_name}.jpg', dpi=300)

# %%
from functools import partial

decoder_params_keys = [k for k in list(params.keys()) if k.startswith('vgae/decoder')]
decoder_params = {}
for full_key_name in decoder_params_keys:
    key_name = full_key_name.split('/')[-1]  # remove the 'vgae/' prefix
    decoder_params[key_name] = params[full_key_name]
    
GP1D_ARGS.decoder_params = decoder_params

decoder_net_fn = partial(decoder,
                         hidden_fc_dim=ARGS.hidden_fc_dim,
                         hidden_gnn_dim=ARGS.hidden_gnn_dim,
                         output_dim=ARGS.output_dim,
                         num_nodes=GP1D_ARGS.num_locations)
decoder_net = hk.without_apply_rng(hk.transform(decoder_net_fn))

# %%
def decoder_predictive_model():
    z = numpyro.sample('z', dist.Normal(0, 1).expand([ARGS.latent_dim]))
    vgae_out = jnp.squeeze(decoder_net.apply(GP1D_ARGS.decoder_params, z).nodes)
    numpyro.deterministic('f', vgae_out)

# %%
# Rough comparison of the shape of GP draws with learnt VGAE priors.

# Drawing VGAE priors.
RNG_KEY, vgae_sample_rng = jax.random.split(RNG_KEY)
vgae_draws = Predictive(
  decoder_predictive_model, num_samples=10)(vgae_sample_rng)['f']

# Plotting the GP draws and VGAE draws.
_, ax = plt.subplots(1, 2, figsize=(18, 5))

plotting.plot_gp_draws(X, gp_draws, num_draws_to_plot=5, 
                     ax=ax[0], title='Example of GP priors to encode', y_label='$y=f_{GP}(x)$')

plotting.plot_gp_draws(X, vgae_draws, num_draws_to_plot=5, 
                     ax=ax[1], title='Example of learnt priors using VGAE', y_label='$y=f_{VGAE}(x)$', )

plt.show()

# %%
# Comparing distribution of GP draws with learnt VGAE priors.
RNG_KEY, gp_rng, vgae_rng = jax.random.split(RNG_KEY, 3)

num_samples = 1000
gp_draws = dataset_1dgp.generate_gp_batch(gp_rng, X, 
                                          batch_size=num_samples, 
                                          kernel=GP1D_ARGS.kernel)
vgae_draws = Predictive(decoder_predictive_model, num_samples=num_samples)(vgae_rng)['f']

# Computing the mean and HPDI of the GP draws and VGAE draws.
gp_draws = gp_draws[~np.isnan(gp_draws).any(axis=1), :]
mean_gp = jnp.nanmean(gp_draws, axis=0)
hpdi_gp = hpdi(gp_draws, 0.9)

vgae_draws = vgae_draws[~np.isnan(vgae_draws).any(axis=1), :]
mean_vgae = jnp.nanmean(vgae_draws, axis=0)
hpdi_vgae = hpdi(vgae_draws, 0.9)

# %%
# Plotting the GP draws and VGAE draws.
fig, axes = plt.subplots(1, 2, figsize=(18, 7))

y_lim = [-2, 2]
lines_alpha_gp = 0.1
lines_alpha_vgae = 0.1
num_draws_to_plot = 15
plotting.plot_gp_draws_with_stats(
    X, gp_draws, 
    mean_gp, hpdi_gp,lines_alpha_gp, 
    num_draws_to_plot, y_lim=y_lim, ax=axes[0],
    title='GP priors to encode', y_label='$y=f_{GP}(x)$')
plotting.plot_gp_draws_with_stats(
    X, vgae_draws, mean_vgae, hpdi_vgae,
    lines_alpha_vgae, num_draws_to_plot, 
    y_lim=y_lim, ax=axes[1],
    title='VGAE priors learnt',
    y_label='$y=f_{VGAE}(x)$')

fig.suptitle(f'GP Priors vs Learnt VGAE Priors \n{model_params_title}', fontsize='xx-large')

plt.tight_layout()
plt.show()

estimate_plot_path = FIG_PATH / 'estimate_figures'
estimate_plot_path.mkdir(exist_ok=True)
fig.savefig(estimate_plot_path / f'{model_name}.jpg', dpi=300)

# %%
assert False
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# /Users/salmanfaris/Desktop/ds-projects/msc-proj/PriorVGAE/1dGP_priorVGAE_flatten_changeNumLoc.ipynb Cell 31 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/Users/salmanfaris/Desktop/ds-projects/msc-proj/PriorVGAE/1dGP_priorVGAE_flatten_changeNumLoc.ipynb#X42sZmlsZQ%3D%3D?line=0'>1</a> assert False
#
# AssertionError:

# %% [markdown]
# # Inference on Observed Data

# %%
def vgae_mcmc_predictive_model(y=None, obs_idx=None):
    z = numpyro.sample('z', dist.Normal(0, 1).expand([ARGS.latent_dim]))
    vgae_out = jnp.squeeze(decoder_net.apply(decoder_params, z).nodes)
    f = numpyro.deterministic('f', vgae_out)
    sigma = numpyro.sample('noise', dist.HalfNormal(0.1))

    if y is None: # at prediction time
        numpyro.sample('y_pred', dist.Normal(f, sigma))
    else: # at inference time
        numpyro.sample('y', dist.Normal(f[obs_idx], sigma), obs=y)

# %%
def run_mcmc(rng, model_mcmc, y, obs_idx, verbose=False):
    start = time.time()
    init_strategy = init_to_median(num_samples=10)
    kernel = NUTS(model_mcmc, init_strategy=init_strategy)
    mcmc = MCMC(
        kernel,
        num_warmup=1000,
        num_samples=1000,
        num_chains=4,
        thinning=1,
        progress_bar=False if 'NUMPYRO_SPHINXBUILD' in os.environ else True,
    )
    mcmc.run(rng, y, obs_idx)
    if verbose:
        mcmc.print_summary(exclude_deterministic=False)
    print('\nMCMC elapsed time:', time.time() - start)

    return mcmc.get_samples()

# %%
RNG_KEY, gp_rng = jax.random.split(RNG_KEY)

# Generate true data and observed dataset to infer
draws = Predictive(dataset_1dgp.gp_predictive_model, num_samples=1)(
  gp_rng, x=X, gp_kernel=GP1D_ARGS.kernel, noise=True)
gp_draw = draws['f'].T  # True data
y_draw = draws['y'].T  # True data + noise

# Choose indices of datapoints for inference.
obs_locations = [
  jnp.array([122, 321]),  # 2 observed datapoints
  jnp.array([126, 133, 296, 370]),  # 4 observed datapoints
  jnp.array([71, 85, 111, 291, 314, 380]),  # 6 observed datapoints
]

# %%
mean_post_preds_list = []
hpdi_post_preds_list = []
obs_xs = []
obs_ys = []
predictions_list = []

RNG_KEY, inference_rng = jax.random.split(RNG_KEY)

for i, obs_location in enumerate(obs_locations):
    mcmc_rng, pred_rng = jax.random.split(jax.random.fold_in(inference_rng, i), 2)
    
    x_obs = X[obs_location]
    y_obs = jnp.squeeze(y_draw[obs_location])
    
    print(f'Running chain for n_obs = {len(obs_location)}')
    mcmc_samples = run_mcmc(mcmc_rng, vgae_mcmc_predictive_model, y_obs, obs_location)

    predictions = Predictive(vgae_mcmc_predictive_model, mcmc_samples)(pred_rng)['f']
    mean_post_pred = jnp.mean(predictions, axis=0)
    hpdi_post_pred = hpdi(predictions, 0.9)
    
    obs_xs.append(x_obs)
    obs_ys.append(y_obs)
    predictions_list.append(predictions)
    mean_post_preds_list.append(mean_post_pred)
    hpdi_post_preds_list.append(hpdi_post_pred)
# Out:
# Running chain for n_obs = 2
# /var/folders/6h/lf5jg1fn1h163zw3042tmtnc0000gn/T/ipykernel_47057/3494085863.py:5: UserWarning: There are not enough devices to run parallel chains: expected 4 but got 1. Chains will be drawn sequentially. If you are running MCMC in CPU, consider using `numpyro.set_host_device_count(4)` at the beginning of your program. You can double-check how many devices are available in your system using `jax.local_device_count()`.
#   mcmc = MCMC(
# sample: 100%|██████████| 2000/2000 [00:37<00:00, 53.32it/s, 6 steps of size 1.47e-01. acc. prob=0.68]
# sample: 100%|██████████| 2000/2000 [00:50<00:00, 39.48it/s, 3 steps of size 8.57e-02. acc. prob=0.90]
# sample: 100%|██████████| 2000/2000 [00:46<00:00, 42.77it/s, 31 steps of size 1.22e-01. acc. prob=0.78]
# sample: 100%|██████████| 2000/2000 [00:40<00:00, 49.52it/s, 31 steps of size 1.15e-01. acc. prob=0.87]
# MCMC elapsed time: 179.64923906326294
# Running chain for n_obs = 4
# /var/folders/6h/lf5jg1fn1h163zw3042tmtnc0000gn/T/ipykernel_47057/3494085863.py:5: UserWarning: There are not enough devices to run parallel chains: expected 4 but got 1. Chains will be drawn sequentially. If you are running MCMC in CPU, consider using `numpyro.set_host_device_count(4)` at the beginning of your program. You can double-check how many devices are available in your system using `jax.local_device_count()`.
#   mcmc = MCMC(
# sample: 100%|██████████| 2000/2000 [00:32<00:00, 61.70it/s, 63 steps of size 1.45e-01. acc. prob=0.86]
# sample: 100%|██████████| 2000/2000 [00:39<00:00, 50.81it/s, 63 steps of size 1.11e-01. acc. prob=0.93]
# sample: 100%|██████████| 2000/2000 [00:32<00:00, 60.88it/s, 15 steps of size 1.35e-01. acc. prob=0.91]
# sample: 100%|██████████| 2000/2000 [00:38<00:00, 51.83it/s, 31 steps of size 1.80e-01. acc. prob=0.84]
# MCMC elapsed time: 146.24972915649414
# Running chain for n_obs = 6
# /var/folders/6h/lf5jg1fn1h163zw3042tmtnc0000gn/T/ipykernel_47057/3494085863.py:5: UserWarning: There are not enough devices to run parallel chains: expected 4 but got 1. Chains will be drawn sequentially. If you are running MCMC in CPU, consider using `numpyro.set_host_device_count(4)` at the beginning of your program. You can double-check how many devices are available in your system using `jax.local_device_count()`.
#   mcmc = MCMC(
# sample: 100%|██████████| 2000/2000 [00:33<00:00, 59.81it/s, 11 steps of size 1.57e-01. acc. prob=0.86]
# sample: 100%|██████████| 2000/2000 [00:26<00:00, 76.29it/s, 31 steps of size 2.25e-01. acc. prob=0.80]
# sample: 100%|██████████| 2000/2000 [00:25<00:00, 78.95it/s, 15 steps of size 2.51e-01. acc. prob=0.72]
# sample: 100%|██████████| 2000/2000 [00:22<00:00, 87.93it/s, 7 steps of size 2.48e-01. acc. prob=0.77]
# MCMC elapsed time: 110.6666419506073

# %%
# Plotting results after inference using MCMC.
_, axes = plt.subplots(nrows=1, ncols=len(obs_locations)+1, figsize=(25,6))

# Plotting VAE prior predictive.
RNG_KEY, prior_rng = jax.random.split(RNG_KEY)
prior_predictions = Predictive(vgae_mcmc_predictive_model, num_samples=10000)(prior_rng)['f']
mean_prior_pred = jnp.mean(prior_predictions, axis=0)
hpdi_prior_pred = hpdi(prior_predictions, 0.9)

num_draws_to_plot = 30
for j in range(num_draws_to_plot):
    axes[0].plot(X, prior_predictions[j], alpha=0.1, color='darkgreen')
axes[0].plot(X, prior_predictions[0], 
             alpha=0.1, color='darkgreen', label='prior draws')  
axes[0].fill_between(X, hpdi_prior_pred[0], hpdi_prior_pred[1], 
                     alpha=0.1, interpolate=True, label='VAE prior: 95% BCI')
axes[0].plot(X, mean_prior_pred, label='mean')
axes[0].set_title('VAE prior')


# Plotting VAE posterior predictive
num_draws_to_plot = 15
for idx in range(len(obs_locations)):
    axes[idx+1].fill_between(X, hpdi_post_preds_list[idx][0], hpdi_post_preds_list[idx][1], 
                           alpha=0.1, interpolate=True, label='VAE posterior: 95% BCI')
    for j in range(num_draws_to_plot): 
        axes[idx+1].plot(X, predictions_list[idx][j], alpha=0.1, color='darkgreen')
    axes[idx+1].plot(X, predictions_list[idx][0],
                   alpha=0.1, color='darkgreen', label='posterior draws')  
    axes[idx+1].plot(X, mean_post_preds_list[idx], label='predicted mean')
    axes[idx+1].plot(X, gp_draw, label='ground truth', color='orange')
    axes[idx+1].scatter(obs_xs[idx], obs_ys[idx], color='red', label='observed data', s=60)
    axes[idx+1].set_title('n_datapoints = ' + str(len(obs_locations[idx])))


for i in range(len(obs_locations)+1):    
    axes[i].legend(loc=4)
    axes[i].set_ylim([-2.5, 2.5])

plt.tight_layout()
plt.show()
